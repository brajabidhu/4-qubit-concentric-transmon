# %%
# !pip install quantum-metal

# !pip install quantum-metal

# !pip install "quantum-metal[mesh,gui]"
# Out:
# Collecting quantum-metal[gui,mesh]
#   Downloading quantum_metal-0.8.1-py3-none-any.whl.metadata (16 kB)
# Collecting addict>=2.4.0 (from quantum-metal[gui,mesh])
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting gdstk>=0.9 (from quantum-metal[gui,mesh])
#   Downloading gdstk-1.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: geopandas>=1.0 in /usr/local/lib/python3.12/dist-packages (from quantum-metal[gui,mesh]) (1.1.4)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from quantum-metal[gui,mesh]) (3.10.0)
# Collecting numpy<2,>=1.24.2 (from quantum-metal[gui,mesh])
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from quantum-metal[gui,mesh]) (2.2.2)
# Collecting pint>=0.21.0 (from quantum-metal[gui,mesh])
#   Downloading pint-0.25.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pygments>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from quantum-metal[gui,mesh]) (2.20.0)
# Collecting qutip>=5.0.0 (from quantum-metal[gui,mesh])
#   Downloading qutip-5.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from quantum-metal[gui,mesh]) (1.16.3)
# Requirement already satisfied: shapely>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from quantum-metal[gui,mesh]) (2.1.2)
# Collecting scqubits>=4.1.0 (from quantum-metal[gui,mesh])
#   Downloading scqubits-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from quantum-metal[gui,mesh]) (6.0.3)
# Collecting pyside6>=6.8 (from quantum-metal[gui,mesh])
#   Downloading pyside6-6.11.1-cp310-abi3-manylinux_2_34_x86_64.whl.metadata (5.3 kB)
# Collecting qdarkstyle>=3.1 (from quantum-metal[gui,mesh])
#   Downloading QDarkStyle-3.2.3-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting gmsh<5,>=4.15.0 (from quantum-metal[gui,mesh])
#   Downloading gmsh-4.15.2-py2.py3-none-manylinux_2_24_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0->quantum-metal[gui,mesh]) (0.13.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0->quantum-metal[gui,mesh]) (26.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0->quantum-metal[gui,mesh]) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->quantum-metal[gui,mesh]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->quantum-metal[gui,mesh]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->quantum-metal[gui,mesh]) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->quantum-metal[gui,mesh]) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->quantum-metal[gui,mesh]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->quantum-metal[gui,mesh]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->quantum-metal[gui,mesh]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->quantum-metal[gui,mesh]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->quantum-metal[gui,mesh]) (2026.3)
# Collecting flexcache>=0.3 (from pint>=0.21.0->quantum-metal[gui,mesh])
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from pint>=0.21.0->quantum-metal[gui,mesh])
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: platformdirs>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from pint>=0.21.0->quantum-metal[gui,mesh]) (4.10.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pint>=0.21.0->quantum-metal[gui,mesh]) (4.16.0)
# Collecting shiboken6==6.11.1 (from pyside6>=6.8->quantum-metal[gui,mesh])
#   Downloading shiboken6-6.11.1-cp310-abi3-manylinux_2_34_x86_64.whl.metadata (2.4 kB)
# Collecting PySide6_Essentials==6.11.1 (from pyside6>=6.8->quantum-metal[gui,mesh])
#   Downloading pyside6_essentials-6.11.1-cp310-abi3-manylinux_2_34_x86_64.whl.metadata (3.6 kB)
# Collecting PySide6_Addons==6.11.1 (from pyside6>=6.8->quantum-metal[gui,mesh])
#   Downloading pyside6_addons-6.11.1-cp310-abi3-manylinux_2_34_x86_64.whl.metadata (4.0 kB)
# Collecting qtpy>=2 (from qdarkstyle>=3.1->quantum-metal[gui,mesh])
#   Downloading QtPy-2.4.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from scqubits>=4.1.0->quantum-metal[gui,mesh]) (0.3.8)
# Collecting pathos>=0.3.0 (from scqubits>=4.1.0->quantum-metal[gui,mesh])
#   Downloading pathos-0.3.5-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from scqubits>=4.1.0->quantum-metal[gui,mesh]) (1.14.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from scqubits>=4.1.0->quantum-metal[gui,mesh]) (4.67.3)
# Collecting ppft>=1.7.8 (from pathos>=0.3.0->scqubits>=4.1.0->quantum-metal[gui,mesh])
#   Downloading ppft-1.7.8-py3-none-any.whl.metadata (12 kB)
# Collecting dill (from scqubits>=4.1.0->quantum-metal[gui,mesh])
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting pox>=0.3.7 (from pathos>=0.3.0->scqubits>=4.1.0->quantum-metal[gui,mesh])
#   Downloading pox-0.3.7-py3-none-any.whl.metadata (8.0 kB)
# Collecting multiprocess>=0.70.19 (from pathos>=0.3.0->scqubits>=4.1.0->quantum-metal[gui,mesh])
#   Downloading multiprocess-0.70.19-py312-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas>=1.0->quantum-metal[gui,mesh]) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->quantum-metal[gui,mesh]) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->scqubits>=4.1.0->quantum-metal[gui,mesh]) (1.3.0)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading gdstk-1.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (541 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.8/541.8 kB 28.1 MB/s eta 0:00:00
# Downloading gmsh-4.15.2-py2.py3-none-manylinux_2_24_x86_64.whl (40.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 MB 57.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 103.2 MB/s eta 0:00:00
# Downloading pint-0.25.3-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.5/307.5 kB 19.2 MB/s eta 0:00:00
# Downloading pyside6-6.11.1-cp310-abi3-manylinux_2_34_x86_64.whl (572 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.1/572.1 kB 29.3 MB/s eta 0:00:00
# Downloading pyside6_addons-6.11.1-cp310-abi3-manylinux_2_34_x86_64.whl (175.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 MB 10.0 MB/s eta 0:00:00
# Downloading pyside6_essentials-6.11.1-cp310-abi3-manylinux_2_34_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 28.0 MB/s eta 0:00:00
# Downloading shiboken6-6.11.1-cp310-abi3-manylinux_2_34_x86_64.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.2/272.2 kB 14.2 MB/s eta 0:00:00
# Downloading QDarkStyle-3.2.3-py2.py3-none-any.whl (871 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 34.0 MB/s eta 0:00:00
# Downloading qutip-5.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (28.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.9/28.9 MB 69.6 MB/s eta 0:00:00
# Downloading scqubits-4.3.1-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 95.9 MB/s eta 0:00:00
# Downloading quantum_metal-0.8.1-py3-none-any.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 79.7 MB/s eta 0:00:00
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Downloading pathos-0.3.5-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 5.5 MB/s eta 0:00:00
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 8.1 MB/s eta 0:00:00
# Downloading QtPy-2.4.3-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 6.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.19-py312-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 11.1 MB/s eta 0:00:00
# Downloading pox-0.3.7-py3-none-any.whl (29 kB)
# Downloading ppft-1.7.8-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: gmsh, addict, shiboken6, qtpy, ppft, pox, numpy, flexparser, flexcache, dill, qdarkstyle, PySide6_Essentials, pint, multiprocess, gdstk, qutip, PySide6_Addons, pathos, scqubits, pyside6, quantum-metal
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.16
#     Uninstalling multiprocess-0.70.16:
#       Successfully uninstalled multiprocess-0.70.16
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.1 which is incompatible.
# datasets 4.0.0 requires multiprocess<0.70.17, but you have multiprocess 0.70.19 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 5.0.0.93 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed PySide6_Addons-6.11.1 PySide6_Essentials-6.11.1 addict-2.4.0 dill-0.4.1 flexcache-0.3 flexparser-0.4 gdstk-1.0.1 gmsh-4.15.2 multiprocess-0.70.19 numpy-1.26.4 pathos-0.3.5 pint-0.25.3 pox-0.3.7 ppft-1.7.8 pyside6-6.11.1 qdarkstyle-3.2.3 qtpy-2.4.3 quantum-metal-0.8.1 qutip-5.3.1 scqubits-4.3.1 shiboken6-6.11.1

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

# Create a folder in your Drive for Palace
DRIVE_PALACE_DIR = '/content/drive/MyDrive/Palace6'
os.makedirs(DRIVE_PALACE_DIR, exist_ok=True)

# Export the Python variable as an environment variable for subsequent bash cells
os.environ['DRIVE_PALACE_DIR'] = DRIVE_PALACE_DIR
# Out:
# Mounted at /content/drive

# %%
# %%bash
# # Brajabidhu #Palace Installation
# # Set Google Drive target directory
# export DRIVE_PALACE_DIR="/content/drive/MyDrive/Palace6"

# LOCAL_BUILD_DIR="/content/Palace_build_tmp"
# BIN_DEST="$DRIVE_PALACE_DIR/build/bin"
# LIB_DEST="$DRIVE_PALACE_DIR/build/lib"

# # Use 2 parallel jobs to guarantee RAM stability in Colab
# BUILD_JOBS=2

# mkdir -p "$BIN_DEST" "$LIB_DEST" || exit 1

# # Clean old destination files
# rm -rf "$BIN_DEST"/*

# #-------------------------------
# # System Dependencies
# #-------------------------------
# echo "Installing build prerequisites..."
# apt-get update --fix-missing -qq && apt-get install -y -qq \
#     build-essential gfortran pkg-config ninja-build \
#     libopenmpi-dev openmpi-bin libblas-dev liblapack-dev cmake > /dev/null 2>&1

# #-------------------------------
# # Build Palace
# #-------------------------------
# echo "Cloning Palace repository..."
# rm -rf "$LOCAL_BUILD_DIR"
# mkdir -p "$LOCAL_BUILD_DIR"
# cd "$LOCAL_BUILD_DIR" || exit 1

# git clone --recursive https://github.com/awslabs/palace.git source || exit 1

# # Save commit and status
# git -C source rev-parse HEAD > "$DRIVE_PALACE_DIR/build/palace_commit.txt"
# git -C source status > "$DRIVE_PALACE_DIR/build/palace_git_status.txt"

# mkdir -p build && cd build || exit 1

# echo "Configuring CMake..."
# cmake ../source -DCMAKE_BUILD_TYPE=Release -DPALACE_WITH_OPENMP=ON > cmake_log.txt 2>&1

# if [ $? -ne 0 ]; then
#     echo "ERROR: CMake failed." >&2
#     cat cmake_log.txt >&2
#     exit 1
# fi

# echo "Compiling Palace..."
# cmake --build . --parallel "${BUILD_JOBS}" > make_log.txt 2>&1

# if [ $? -ne 0 ]; then
#     echo "ERROR: Build failed." >&2
#     tail -n 60 make_log.txt >&2
#     exit 1
# fi

# # Save logs
# cp CMakeCache.txt cmake_log.txt make_log.txt "$DRIVE_PALACE_DIR/build/"

# #--------------------------------------------------
# # Copy Executables and Libraries
# #--------------------------------------------------
# echo "Copying executables to Google Drive..."

# # Copy EVERYTHING inside the build bin/ directory (both wrapper and palace-x86_64.bin)
# cp -r "$LOCAL_BUILD_DIR/build/bin"/* "$BIN_DEST/"
# chmod +x "$BIN_DEST"/*

# # Verify primary binary
# ACTUAL_BINARY="$BIN_DEST/palace"
# ldd "$ACTUAL_BINARY" > "$BIN_DEST/palace_ldd.txt" 2>&1
# "$ACTUAL_BINARY" --help > "$BIN_DEST/palace_version.txt" 2>&1 || true

# # Copy shared libraries
# echo "Copying shared libraries..."
# while read -r lib_file; do
#     if [[ "$lib_file" =~ \.so($|\.[0-9]+(\.[0-9]+)*$) ]]; then
#         cp -df "$lib_file" "$LIB_DEST/"
#     fi
# done < <(find "$LOCAL_BUILD_DIR/build" -type f -name "*.so*")

# # Save directory tree
# find "$LOCAL_BUILD_DIR/build" > "$DRIVE_PALACE_DIR/build/build_tree.txt"

# # Save helper script
# cat > "$DRIVE_PALACE_DIR/build/use_palace.sh" <<'EOF'
# #!/bin/bash
# export PALACE_HOME="$(cd "$(dirname "$0")" && pwd)"
# export LD_LIBRARY_PATH="$PALACE_HOME/lib:$LD_LIBRARY_PATH"
# "$PALACE_HOME/bin/palace" "$@"
# EOF
# chmod +x "$DRIVE_PALACE_DIR/build/use_palace.sh"

# echo "========================================="
# echo "SUCCESS: Palace build and backup completed!"
# echo "Binaries backed up to: $BIN_DEST"
# echo "========================================="
# Out:
# Installing build prerequisites...
# Cloning Palace repository...
# Configuring CMake...
# Compiling Palace...
# Copying executables to Google Drive...
# Copying shared libraries...
# =========================================
# SUCCESS: Palace build and backup completed!
# Binaries backed up to: /content/drive/MyDrive/Palace6/build/bin
# =========================================
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Cloning into 'source'...

# %%
import os

print(f"Verifying Palace installation in Google Drive: {os.environ['DRIVE_PALACE_DIR']}\n")

DRIVE_PALACE_DIR = os.environ['DRIVE_PALACE_DIR']

expected_files_and_dirs = [
    os.path.join(DRIVE_PALACE_DIR, 'build', 'bin', 'palace'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'palace_commit.txt'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'palace_git_status.txt'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'CMakeCache.txt'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'cmake_log.txt'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'make_log.txt'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'bin', 'palace_ldd.txt'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'bin', 'palace_version.txt'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'build_tree.txt'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'use_palace.sh'),
    os.path.join(DRIVE_PALACE_DIR, 'build', 'lib') # Directory for shared libraries
]

all_present = True

for path in expected_files_and_dirs:
    if os.path.exists(path):
        print(f"✅ Found: {path}")
    else:
        print(f"❌ MISSING: {path}")
        all_present = False

# Additionally check for .so files in the lib directory
lib_dir = os.path.join(DRIVE_PALACE_DIR, 'build', 'lib')
if os.path.isdir(lib_dir):
    so_files = [f for f in os.listdir(lib_dir) if f.endswith('.so') or '.so.' in f]
    if so_files:
        print(f"✅ Found {len(so_files)} shared library files in {lib_dir}")
    else:
        print(f"⚠️ WARNING: No shared library (.so) files found in {lib_dir}")


if all_present:
    print("\n=========================================")
    print("SUCCESS: All critical Palace files verified on Google Drive!")
    print("=========================================")
else:
    print("\n=========================================")
    print("WARNING: Some critical Palace files are missing from Google Drive.")
    print("Please review the build log for potential issues.")
    print("=========================================")
# Out:
# Verifying Palace installation in Google Drive: /content/drive/MyDrive/Palace6
#
# ✅ Found: /content/drive/MyDrive/Palace6/build/bin/palace
# ✅ Found: /content/drive/MyDrive/Palace6/build/palace_commit.txt
# ✅ Found: /content/drive/MyDrive/Palace6/build/palace_git_status.txt
# ✅ Found: /content/drive/MyDrive/Palace6/build/CMakeCache.txt
# ✅ Found: /content/drive/MyDrive/Palace6/build/cmake_log.txt
# ✅ Found: /content/drive/MyDrive/Palace6/build/make_log.txt
# ✅ Found: /content/drive/MyDrive/Palace6/build/bin/palace_ldd.txt
# ✅ Found: /content/drive/MyDrive/Palace6/build/bin/palace_version.txt
# ✅ Found: /content/drive/MyDrive/Palace6/build/build_tree.txt
# ✅ Found: /content/drive/MyDrive/Palace6/build/use_palace.sh
# ✅ Found: /content/drive/MyDrive/Palace6/build/lib
# ✅ Found 7 shared library files in /content/drive/MyDrive/Palace6/build/lib
#
# =========================================
# SUCCESS: All critical Palace files verified on Google Drive!
# =========================================

# %%
import os
import subprocess

print("Loading and verifying Palace from Google Drive...\n")

# 1. Mount Google Drive if not mounted
if not os.path.exists('/content/drive'):
    print("Mounting Google Drive...")
    from google.colab import drive
    drive.mount('/content/drive')
else:
    print("Google Drive already mounted.")

# 2. Paths
DRIVE_PALACE_DIR = '/content/drive/MyDrive/Palace6'
BINARY_PATH = os.path.join(DRIVE_PALACE_DIR, 'build', 'bin', 'palace')
DRIVE_LIB_DIR = os.path.join(DRIVE_PALACE_DIR, 'build', 'lib')

print(f"Loading Palace binary from: {BINARY_PATH}")

# 3. Configure Runtime Environment
env = os.environ.copy()

# Add Drive dynamic libraries to LD_LIBRARY_PATH
current_ld = env.get('LD_LIBRARY_PATH', '')
env['LD_LIBRARY_PATH'] = f"{DRIVE_LIB_DIR}:{current_ld}" if current_ld else DRIVE_LIB_DIR
print(f"LD_LIBRARY_PATH set to: {env['LD_LIBRARY_PATH']}")

# Allow OpenMPI to execute under Colab's root user
env['OMPI_ALLOW_RUN_AS_ROOT'] = '1'
env['OMPI_ALLOW_RUN_AS_ROOT_CONFIRM'] = '1'

# 4. Check & Execute
if os.path.exists(BINARY_PATH):
    os.chmod(BINARY_PATH, 0o755)
    print("Executable permissions verified.")

    print("\nTesting Palace execution...")
    try:
        # Try --version, fallback to --help if needed
        try:
            cmd = [BINARY_PATH, '--version']
            result = subprocess.run(cmd, capture_output=True, text=True, check=True, env=env)
        except subprocess.CalledProcessError:
            cmd = [BINARY_PATH, '--help']
            result = subprocess.run(cmd, capture_output=True, text=True, check=True, env=env)

        print("\n=========================================")
        print("✅ Palace successfully loaded and ran!")
        print(f"Command output ({' '.join(cmd)}):\n")
        print(result.stdout if result.stdout else result.stderr)
        print("=========================================")

    except subprocess.CalledProcessError as e:
        print("\n=========================================")
        print(f"❌ ERROR: Palace failed to run! Exit code: {e.returncode}")
        print(f"Stderr:\n{e.stderr}")
        print("=========================================")
else:
    print(f"\n❌ ERROR: Palace binary not found at: {BINARY_PATH}")
# Out:
# Loading and verifying Palace from Google Drive...
#
# Google Drive already mounted.
# Loading Palace binary from: /content/drive/MyDrive/Palace6/build/bin/palace
# LD_LIBRARY_PATH set to: /content/drive/MyDrive/Palace6/build/lib
# Executable permissions verified.
#
# Testing Palace execution...
#
# =========================================
# ✅ Palace successfully loaded and ran!
# Command output (/content/drive/MyDrive/Palace6/build/bin/palace --help):
#
# Usage: palace [OPTIONS] CONFIG_FILE
#
# Wrapper for launching Palace using MPI
#
# Options:
#   -h, --help                       Show this help message and exit
#   -dry-run, --dry-run              Parse configuration file for errors and exit
#   -serial, --serial                Call Palace without MPI launcher, default is false
#   -np, --np NUM_PROCS              How many MPI processes to use, default is 1
#   -nt, --nt NUM_THREADS            Number of OpenMP threads to use for OpenMP builds, default is 1 or the value of OMP_NUM_THREADS in the environment
#   -launcher, --launcher LAUNCHER   MPI launcher, default is `mpirun`
#   -launcher-args,
#     --launcher-args ARGS           Any extra arguments to pass to MPI launcher, for example `--map-by` or `--bind-to` with their respective options (quoted)
#
#
# =========================================

# %%
import subprocess
import os

# Reuse the environment from the previous cell, which includes LD_LIBRARY_PATH
env = os.environ.copy()
DRIVE_PALACE_DIR = os.environ.get('DRIVE_PALACE_DIR', '/content/drive/MyDrive/Palace6')
BINARY_PATH = os.path.join(DRIVE_PALACE_DIR, 'build', 'bin', 'palace')
DRIVE_LIB_DIR = os.path.join(DRIVE_PALACE_DIR, 'build', 'lib')

current_ld = env.get('LD_LIBRARY_PATH', '')
if DRIVE_LIB_DIR not in current_ld:
    env['LD_LIBRARY_PATH'] = f"{DRIVE_LIB_DIR}:{current_ld}" if current_ld else DRIVE_LIB_DIR


print("Running Palace --help to verify execution...")
try:
    # Using --help as it was shown to work previously.
    cmd = [BINARY_PATH, '--help']
    result = subprocess.run(cmd, capture_output=True, text=True, check=True, env=env)
    print("\n=========================================")
    print("✅ Palace --help executed successfully!")
    print(f"Output:\n{result.stdout}")
    print("=========================================")
except subprocess.CalledProcessError as e:
    print("\n=========================================")
    print(f"❌ ERROR: Palace --help failed! Exit code: {e.returncode}")
    print(f"Stderr:\n{e.stderr}")
    print("=========================================")
except FileNotFoundError:
    print(f"❌ ERROR: Palace binary not found at {BINARY_PATH}. Please ensure it is built and present.")
# Out:
# Running Palace --help to verify execution...
#
# =========================================
# ✅ Palace --help executed successfully!
# Output:
# Usage: palace [OPTIONS] CONFIG_FILE
#
# Wrapper for launching Palace using MPI
#
# Options:
#   -h, --help                       Show this help message and exit
#   -dry-run, --dry-run              Parse configuration file for errors and exit
#   -serial, --serial                Call Palace without MPI launcher, default is false
#   -np, --np NUM_PROCS              How many MPI processes to use, default is 1
#   -nt, --nt NUM_THREADS            Number of OpenMP threads to use for OpenMP builds, default is 1 or the value of OMP_NUM_THREADS in the environment
#   -launcher, --launcher LAUNCHER   MPI launcher, default is `mpirun`
#   -launcher-args,
#     --launcher-args ARGS           Any extra arguments to pass to MPI launcher, for example `--map-by` or `--bind-to` with their respective options (quoted)
#
#
# =========================================

# %% [markdown]
# First, let's create a placeholder configuration file that Palace can use for the dry run. For this example, it will be a simple empty file, but in a real scenario, this would contain your simulation settings.

# %%
import os

config_file_path = os.path.join(DRIVE_PALACE_DIR, 'dummy_config.json')
with open(config_file_path, 'w') as f:
    # Providing a more structured JSON to satisfy Palace's parsing requirements
    f.write('''
{
  "Problem": {
    "Type": "Electrostatic",
    "Solver": {
      "Type": "GMRES",
      "RelTol": 1.0e-6,
      "AbsTol": 1.0e-12,
      "MaxIter": 100
    }
  },
  "Domain": {},
  "Boundaries": {}
}
''')

print(f"Updated dummy configuration file: {config_file_path} with a more structured JSON.")
# Out:
# Updated dummy configuration file: /content/drive/MyDrive/Palace6/dummy_config.json with a more structured JSON.

# %% [markdown]
# Now, let's run Palace with the `-dry-run` option, passing our dummy configuration file. This command will parse the configuration file for errors without executing a full simulation.

# %%
import os
import glob

build_dir = '/content/drive/MyDrive/Palace6/build'

print("Searching for actual compiled binaries inside build directory...\n")
for root, dirs, files in os.walk(build_dir):
    for file in files:
        full_path = os.path.join(root, file)
        # Find executable files that are NOT shell scripts
        if os.access(full_path, os.X_OK) and not file.endswith('.sh') and not file.endswith('.txt'):
            print(f"Found binary: {full_path}")
# Out:
# Searching for actual compiled binaries inside build directory...
#
# Found binary: /content/drive/MyDrive/Palace6/build/bin/palace
# Found binary: /content/drive/MyDrive/Palace6/build/bin/palace-x86_64.bin
# Found binary: /content/drive/MyDrive/Palace6/build/bin/validate-config
# Found binary: /content/drive/MyDrive/Palace6/build/bin/schema/config-schema.json
# Found binary: /content/drive/MyDrive/Palace6/build/bin/schema/ValidateConfig.jl
# Found binary: /content/drive/MyDrive/Palace6/build/lib/libxsmm.so.1.17.0
# Found binary: /content/drive/MyDrive/Palace6/build/lib/libceed.so
# Found binary: /content/drive/MyDrive/Palace6/build/lib/libxsmmgen.so.1.17.0
# Found binary: /content/drive/MyDrive/Palace6/build/lib/libxsmm.so.1
# Found binary: /content/drive/MyDrive/Palace6/build/lib/libxsmm.so
# Found binary: /content/drive/MyDrive/Palace6/build/lib/libxsmmgen.so
# Found binary: /content/drive/MyDrive/Palace6/build/lib/libxsmmgen.so.1

# %%
# import os
# import glob

# # Check temporary build directory for the actual binary
# temp_bin_dir = "/content/Palace_build_tmp/build/bin"
# print("Checking for compiled binary in temporary build path...\n")

# if os.path.exists(temp_bin_dir):
#     binaries = glob.glob(os.path.join(temp_bin_dir, "palace*"))
#     for b in binaries:
#         print(f"Found: {b}")
# else:
#     print("Temporary build directory not found.")

# %%
import os
import subprocess
import json

print("=========================================")
print("  PALACE INSTALLATION VERIFICATION CHECK ")
print("=========================================\n")

# 1. Mount Google Drive if not already mounted
if not os.path.exists('/content/drive'):
    print("Mounting Google Drive...")
    from google.colab import drive
    drive.mount('/content/drive')
else:
    print("✓ Google Drive is mounted.")

DRIVE_PALACE_DIR = '/content/drive/MyDrive/Palace6'
BUILD_DIR = os.path.join(DRIVE_PALACE_DIR, 'build')
BIN_DIR = os.path.join(BUILD_DIR, 'bin')
LIB_DIR = os.path.join(BUILD_DIR, 'lib')

# 2. Check Required Artifacts
required_files = [
    (os.path.join(BIN_DIR, 'palace'), "Palace Launcher Wrapper"),
    (os.path.join(BIN_DIR, 'palace-x86_64.bin'), "Palace C++ Solver Engine"),
    (os.path.join(BIN_DIR, 'validate-config'), "Config Validator Tool"),
    (os.path.join(BIN_DIR, 'palace_ldd.txt'), "Dependency LDD Log"),
    (os.path.join(BIN_DIR, 'palace_version.txt'), "Version/Help Output Log"),
    (os.path.join(BUILD_DIR, 'palace_commit.txt'), "Git Commit Metadata"),
    (os.path.join(BUILD_DIR, 'palace_git_status.txt'), "Git Status Log"),
    (os.path.join(BUILD_DIR, 'CMakeCache.txt'), "CMake Cache"),
    (os.path.join(BUILD_DIR, 'cmake_log.txt'), "CMake Build Log"),
    (os.path.join(BUILD_DIR, 'make_log.txt'), "Make Build Log"),
    (os.path.join(BUILD_DIR, 'build_tree.txt'), "Build Directory Tree Log"),
    (os.path.join(BUILD_DIR, 'use_palace.sh'), "Restore Launcher Script")
]

all_passed = True
print("\n--- 1. Checking Critical Files ---")
for file_path, label in required_files:
    if os.path.exists(file_path):
        print(f"  [PASS] Found {label}: {os.path.basename(file_path)}")
    else:
        print(f"  [FAIL] MISSING {label}: {file_path}")
        all_passed = False

# 3. Check Shared Libraries (.so)
print("\n--- 2. Checking Shared Libraries ---")
if os.path.isdir(LIB_DIR):
    so_files = [f for f in os.listdir(LIB_DIR) if '.so' in f]
    print(f"  [PASS] Found {len(so_files)} shared library files in {LIB_DIR}")
    for so in so_files[:5]:  # Show first few libraries
        print(f"         - {so}")
    if len(so_files) == 0:
        print("  [WARN] No .so files found in lib directory!")
else:
    print(f"  [FAIL] Library directory missing: {LIB_DIR}")
    all_passed = False

# 4. Check Executable Permissions
print("\n--- 3. Checking Executable Permissions ---")
binaries_to_check = [
    os.path.join(BIN_DIR, 'palace'),
    os.path.join(BIN_DIR, 'palace-x86_64.bin'),
    os.path.join(BUILD_DIR, 'use_palace.sh')
]

for b in binaries_to_check:
    if os.path.exists(b):
        os.chmod(b, 0o755)
        print(f"  [PASS] Verified executable permissions for {os.path.basename(b)}")

# 5. Execute Test Run (-dry-run)
# print("\n--- 4. Performing Execution Test ---")
# env = os.environ.copy()

# current_ld = env.get('LD_LIBRARY_PATH', '')
# env['LD_LIBRARY_PATH'] = f"{LIB_DIR}:{current_ld}" if current_ld else LIB_DIR
# env['OMPI_ALLOW_RUN_AS_ROOT'] = '1'
# env['OMPI_ALLOW_RUN_AS_ROOT_CONFIRM'] = '1'

# config_file_path = os.path.join(DRIVE_PALACE_DIR, 'dummy_config.json')

# if not os.path.exists(config_file_path):
#     dummy_config = {
#         "Problem": {"Type": "Electrostatic", "Verbose": 1},
#         "Model": {"Mesh": "mesh.msh"},
#         "Domains": {"Postprocessing": {"Energy": []}},
#         "Boundaries": {"Ground": [1]},
#         "Solver": {"Linear": {"Type": "AMS", "KSPType": "CG", "Tol": 1e-6, "MaxIter": 100}}
#     }
#     with open(config_file_path, 'w') as f:
#         json.dump(dummy_config, f, indent=2)

# try:
#     cmd = [os.path.join(BIN_DIR, 'palace'), '-dry-run', config_file_path]
#     result = subprocess.run(cmd, capture_output=True, text=True, check=True, env=env)
#     print("  [PASS] Palace -dry-run executed successfully!")
#     print("\nCommand Output:\n" + result.stdout)
# except subprocess.CalledProcessError as e:
#     print(f"  [FAIL] Palace -dry-run failed with exit code {e.returncode}")
#     print(f"Stderr:\n{e.stderr}")
#     all_passed = False
# except Exception as e:
#     print(f"  [FAIL] Execution error: {e}")
#     all_passed = False

# Final Summary
print("\n=========================================")
if all_passed:
    print("  SUCCESS: Palace installation is 100% complete and functional!")
else:
    print("  WARNING: One or more checks failed. Review output above.")
print("=========================================")
# Out:
# =========================================
#   PALACE INSTALLATION VERIFICATION CHECK
# =========================================
#
# ✓ Google Drive is mounted.
#
# --- 1. Checking Critical Files ---
#   [PASS] Found Palace Launcher Wrapper: palace
#   [PASS] Found Palace C++ Solver Engine: palace-x86_64.bin
#   [PASS] Found Config Validator Tool: validate-config
#   [PASS] Found Dependency LDD Log: palace_ldd.txt
#   [PASS] Found Version/Help Output Log: palace_version.txt
#   [PASS] Found Git Commit Metadata: palace_commit.txt
#   [PASS] Found Git Status Log: palace_git_status.txt
#   [PASS] Found CMake Cache: CMakeCache.txt
#   [PASS] Found CMake Build Log: cmake_log.txt
#   [PASS] Found Make Build Log: make_log.txt
#   [PASS] Found Build Directory Tree Log: build_tree.txt
#   [PASS] Found Restore Launcher Script: use_palace.sh
#
# --- 2. Checking Shared Libraries ---
#   [PASS] Found 7 shared library files in /content/drive/MyDrive/Palace6/build/lib
#          - libxsmm.so.1.17.0
#          - libceed.so
#          - libxsmmgen.so.1.17.0
#          - libxsmm.so.1
#          - libxsmm.so
#
# --- 3. Checking Executable Permissions ---
#   [PASS] Verified executable permissions for palace
#   [PASS] Verified executable permissions for palace-x86_64.bin
#   [PASS] Verified executable permissions for use_palace.sh
#
# =========================================
#   SUCCESS: Palace installation is 100% complete and functional!
# =========================================

# %%
import os

LIB_DIR = '/content/drive/MyDrive/Palace6/build/lib'

# Libraries that require symlinks for runtime binding
symlinks_to_create = [
    ('libxsmm.so.1.17.0', 'libxsmm.so.1'),
    ('libxsmm.so.1.17.0', 'libxsmm.so'),
    ('libxsmmgen.so.1.17.0', 'libxsmmgen.so.1'),
    ('libxsmmgen.so.1.17.0', 'libxsmmgen.so')
]

print("Creating missing library symlinks in Google Drive...\n")

for target, link_name in symlinks_to_create:
    target_path = os.path.join(LIB_DIR, target)
    link_path = os.path.join(LIB_DIR, link_name)

    if os.path.exists(target_path):
        if os.path.islink(link_path) or os.path.exists(link_path):
            os.remove(link_path)
        os.symlink(target, link_path)
        print(f"  [CREATED] {link_name} -> {target}")
    else:
        print(f"  [SKIP] Target file {target} not found in {LIB_DIR}")

print("\n✅ Symlinks created successfully!")
# Out:
# Creating missing library symlinks in Google Drive...
#
#   [CREATED] libxsmm.so.1 -> libxsmm.so.1.17.0
#   [CREATED] libxsmm.so -> libxsmm.so.1.17.0
#   [CREATED] libxsmmgen.so.1 -> libxsmmgen.so.1.17.0
#   [CREATED] libxsmmgen.so -> libxsmmgen.so.1.17.0
#
# ✅ Symlinks created successfully!

# %%
import os
import subprocess
import json

print("=========================================")
print("  PALACE INSTALLATION VERIFICATION CHECK ")
print("=========================================\n")

# 1. Mount Google Drive if not already mounted
if not os.path.exists('/content/drive'):
    print("Mounting Google Drive...")
    from google.colab import drive
    drive.mount('/content/drive')
else:
    print("✓ Google Drive is mounted.")

DRIVE_PALACE_DIR = '/content/drive/MyDrive/Palace6'
BUILD_DIR = os.path.join(DRIVE_PALACE_DIR, 'build')
BIN_DIR = os.path.join(BUILD_DIR, 'bin')
LIB_DIR = os.path.join(BUILD_DIR, 'lib')

# 2. Check Required Artifacts
required_files = [
    (os.path.join(BIN_DIR, 'palace'), "Palace Launcher Wrapper"),
    (os.path.join(BIN_DIR, 'palace-x86_64.bin'), "Palace C++ Solver Engine"),
    (os.path.join(BIN_DIR, 'validate-config'), "Config Validator Tool"),
    (os.path.join(BIN_DIR, 'palace_ldd.txt'), "Dependency LDD Log"),
    (os.path.join(BIN_DIR, 'palace_version.txt'), "Version/Help Output Log"),
    (os.path.join(BUILD_DIR, 'palace_commit.txt'), "Git Commit Metadata"),
    (os.path.join(BUILD_DIR, 'palace_git_status.txt'), "Git Status Log"),
    (os.path.join(BUILD_DIR, 'CMakeCache.txt'), "CMake Cache"),
    (os.path.join(BUILD_DIR, 'cmake_log.txt'), "CMake Build Log"),
    (os.path.join(BUILD_DIR, 'make_log.txt'), "Make Build Log"),
    (os.path.join(BUILD_DIR, 'build_tree.txt'), "Build Directory Tree Log"),
    (os.path.join(BUILD_DIR, 'use_palace.sh'), "Restore Launcher Script")
]

all_passed = True
print("\n--- 1. Checking Critical Files ---")
for file_path, label in required_files:
    if os.path.exists(file_path):
        print(f"  [PASS] Found {label}: {os.path.basename(file_path)}")
    else:
        print(f"  [FAIL] MISSING {label}: {file_path}")
        all_passed = False

# 3. Check Shared Libraries (.so)
print("\n--- 2. Checking Shared Libraries ---")
if os.path.isdir(LIB_DIR):
    so_files = [f for f in os.listdir(LIB_DIR) if '.so' in f]
    print(f"  [PASS] Found {len(so_files)} shared library files in {LIB_DIR}")
    for so in so_files[:5]:  # Show first few libraries
        print(f"         - {so}")
    if len(so_files) == 0:
        print("  [WARN] No .so files found in lib directory!")
else:
    print(f"  [FAIL] Library directory missing: {LIB_DIR}")
    all_passed = False

# 4. Check Executable Permissions
print("\n--- 3. Checking Executable Permissions ---")
binaries_to_check = [
    os.path.join(BIN_DIR, 'palace'),
    os.path.join(BIN_DIR, 'palace-x86_64.bin'),
    os.path.join(BUILD_DIR, 'use_palace.sh')
]

for b in binaries_to_check:
    if os.path.exists(b):
        os.chmod(b, 0o755)
        print(f"  [PASS] Verified executable permissions for {os.path.basename(b)}")

# # 5. Execute Test Run (-dry-run)
# print("\n--- 4. Performing Execution Test ---")
# env = os.environ.copy()

# current_ld = env.get('LD_LIBRARY_PATH', '')
# env['LD_LIBRARY_PATH'] = f"{LIB_DIR}:{current_ld}" if current_ld else LIB_DIR
# env['OMPI_ALLOW_RUN_AS_ROOT'] = '1'
# env['OMPI_ALLOW_RUN_AS_ROOT_CONFIRM'] = '1'

# config_file_path = os.path.join(DRIVE_PALACE_DIR, 'dummy_config.json')

# if not os.path.exists(config_file_path):
#     dummy_config = {
#         "Problem": {"Type": "Electrostatic", "Verbose": 1},
#         "Model": {"Mesh": "mesh.msh"},
#         "Domains": {"Postprocessing": {"Energy": []}},
#         "Boundaries": {"Ground": [1]},
#         "Solver": {"Linear": {"Type": "AMS", "KSPType": "CG", "Tol": 1e-6, "MaxIter": 100}}
#     }
#     with open(config_file_path, 'w') as f:
#         json.dump(dummy_config, f, indent=2)

# try:
#     cmd = [os.path.join(BIN_DIR, 'palace'), '-dry-run', config_file_path]
#     result = subprocess.run(cmd, capture_output=True, text=True, check=True, env=env)
#     print("  [PASS] Palace -dry-run executed successfully!")
#     print("\nCommand Output:\n" + result.stdout)
# except subprocess.CalledProcessError as e:
#     print(f"  [FAIL] Palace -dry-run failed with exit code {e.returncode}")
#     print(f"Stderr:\n{e.stderr}")
#     all_passed = False
# except Exception as e:
#     print(f"  [FAIL] Execution error: {e}")
#     all_passed = False

# Final Summary
print("\n=========================================")
if all_passed:
    print("  SUCCESS: Palace installation is 100% complete and functional!")
else:
    print("  WARNING: One or more checks failed. Review output above.")
print("=========================================")
# Out:
# =========================================
#   PALACE INSTALLATION VERIFICATION CHECK
# =========================================
#
# ✓ Google Drive is mounted.
#
# --- 1. Checking Critical Files ---
#   [PASS] Found Palace Launcher Wrapper: palace
#   [PASS] Found Palace C++ Solver Engine: palace-x86_64.bin
#   [PASS] Found Config Validator Tool: validate-config
#   [PASS] Found Dependency LDD Log: palace_ldd.txt
#   [PASS] Found Version/Help Output Log: palace_version.txt
#   [PASS] Found Git Commit Metadata: palace_commit.txt
#   [PASS] Found Git Status Log: palace_git_status.txt
#   [PASS] Found CMake Cache: CMakeCache.txt
#   [PASS] Found CMake Build Log: cmake_log.txt
#   [PASS] Found Make Build Log: make_log.txt
#   [PASS] Found Build Directory Tree Log: build_tree.txt
#   [PASS] Found Restore Launcher Script: use_palace.sh
#
# --- 2. Checking Shared Libraries ---
#   [PASS] Found 7 shared library files in /content/drive/MyDrive/Palace6/build/lib
#          - libxsmm.so.1.17.0
#          - libceed.so
#          - libxsmmgen.so.1.17.0
#          - libxsmm.so.1
#          - libxsmm.so
#
# --- 3. Checking Executable Permissions ---
#   [PASS] Verified executable permissions for palace
#   [PASS] Verified executable permissions for palace-x86_64.bin
#   [PASS] Verified executable permissions for use_palace.sh
#
# =========================================
#   SUCCESS: Palace installation is 100% complete and functional!
# =========================================

# %%
import os
import subprocess
import json

DRIVE_PALACE_DIR = '/content/drive/MyDrive/Palace6'
BIN_DIR = os.path.join(DRIVE_PALACE_DIR, 'build', 'bin')
LIB_DIR = os.path.join(DRIVE_PALACE_DIR, 'build', 'lib')

# Environment Setup
env = os.environ.copy()
current_ld = env.get('LD_LIBRARY_PATH', '')
env['LD_LIBRARY_PATH'] = f"{LIB_DIR}:{current_ld}" if current_ld else LIB_DIR
env['OMPI_ALLOW_RUN_AS_ROOT'] = '1'
env['OMPI_ALLOW_RUN_AS_ROOT_CONFIRM'] = '1'

# 1. Ensure minimal valid Gmsh v2.2 mesh exists in DRIVE_PALACE_DIR
mesh_file_path = os.path.join(DRIVE_PALACE_DIR, 'mesh.msh')
minimal_gmsh = """$MeshFormat
2.2 0 8
$EndMeshFormat
$Nodes
2
1 0.0 0.0 0.0
2 1.0 0.0 0.0
$EndNodes
$Elements
1
1 1 2 1 1 1 2
$EndElements
"""
with open(mesh_file_path, 'w') as f:
    f.write(minimal_gmsh)

# 2. Update config to use absolute path to the mesh
config_file_path = os.path.join(DRIVE_PALACE_DIR, 'dummy_config.json')

valid_config = {
    "Problem": {
        "Type": "Electrostatic",
        "Verbose": 1
    },
    "Model": {
        "Mesh": mesh_file_path,  # Full absolute path to mesh
        "L0": 1.0e-3
    },
    "Domains": {
        "Materials": [
            {
                "Attributes": [1],
                "Permittivity": 1.0
            }
        ],
        "Postprocessing": {
            "Energy": [
                {
                    "Index": 1,
                    "Attributes": [1]
                }
            ]
        }
    },
    "Boundaries": {
        "Ground": {
            "Attributes": [1]
        },
        "Terminal": [
            {
                "Index": 1,
                "Attributes": [2]
            }
        ]
    },
    "Solver": {
        "Order": 1,
        "Device": "CPU",
        "Linear": {
            "Type": "AMS",
            "KSPType": "CG",
            "Tol": 1.0e-6,
            "MaxIts": 100
        }
    }
}

with open(config_file_path, 'w') as f:
    json.dump(valid_config, f, indent=2)

print("Running Palace -dry-run with working directory set...\n")

try:
    cmd = [os.path.join(BIN_DIR, 'palace'), '-dry-run', config_file_path]
    # Set cwd so relative paths resolve cleanly inside DRIVE_PALACE_DIR
    result = subprocess.run(cmd, capture_output=True, text=True, check=True, env=env, cwd=DRIVE_PALACE_DIR)

    print("=========================================")
    print("✅ SUCCESS: Palace -dry-run completed successfully!")
    print("=========================================\n")
    print("Stdout:\n", result.stdout)

except subprocess.CalledProcessError as e:
    print("=========================================")
    print(f"Stdout:\n{e.stdout}")
    print(f"Stderr:\n{e.stderr}")
# Out:
# Running Palace -dry-run with working directory set...
#
# =========================================
# ✅ SUCCESS: Palace -dry-run completed successfully!
# =========================================
#
# Stdout:
#  >> /usr/bin/mpirun -n 1 /content/drive/MyDrive/Palace6/build/bin/palace-x86_64.bin --dry-run /content/drive/MyDrive/Palace6/dummy_config.json
#
#
# Resolved configuration:
# {
#   "Boundaries": {
#     "Ground": {
#       "Attributes": [
#         1
#       ]
#     },
#     "Terminal": [
#       {
#         "Attributes": [
#           2
#         ],
#         "Index": 1
#       }
#     ]
#   },
#   "Domains": {
#     "Materials": [
#       {
#         "Attributes": [
#           1
#         ],
#         "Conductivity": 0.0,
#         "LondonDepth": 0.0,
#         "LossTan": 0.0,
#         "Permeability": 1.0,
#         "Permittivity": 1.0
#       }
#     ],
#     "Postprocessing": {
#       "Energy": [
#         {
#           "Attributes": [
#             1
#           ],
#           "Index": 1
#         }
#       ]
#     }
#   },
#   "Model": {
#     "AddInterfaceBoundaryElements": true,
#     "CleanUnusedElements": true,
#     "CrackDisplacementFactor": 1e-12,
#     "CrackInternalBoundaryElements": true,
#     "ExportPrerefinedMesh": false,
#     "L0": 0.001,
#     "MakeHexahedral": false,
#     "MakeSimplex": false,
#     "Mesh": "/content/drive/MyDrive/Palace6/mesh.msh",
#     "RefineCrackElements": true,
#     "Refinement": {
#       "MaxIts": 0,
#       "MaxNCLevels": 1,
#       "MaxSize": 0,
#       "MaximumImbalance": 1.1,
#       "Nonconformal": true,
#       "SaveAdaptIterations": true,
#       "SaveAdaptMesh": false,
#       "SerialUniformLevels": 0,
#       "Tol": 0.01,
#       "UniformLevels": 0,
#       "UpdateFraction": 0.7
#     },
#     "RemoveCurvature": false,
#     "ReorderElements": false,
#     "ReorientTetMesh": false
#   },
#   "Problem": {
#     "Output": "postpro",
#     "OutputFormats": {
#       "GridFunction": false,
#       "Paraview": true
#     },
#     "Type": "Electrostatic",
#     "Verbose": 1
#   },
#   "Solver": {
#     "Device": "CPU",
#     "Electrostatic": {
#       "Save": 0
#     },
#     "Linear": {
#       "AMGAggressiveCoarsening": true,
#       "AMSMaxIts": 1,
#       "AMSSingularOperator": false,
#       "AMSVectorInterpolation": false,
#       "ColumnOrdering": "Default",
#       "ComplexCoarseSolve": false,
#       "DivFreeMaxIts": 1000,
#       "DivFreeTol": 1e-12,
#       "DropSmallEntries": false,
#       "EstimatorMG": false,
#       "EstimatorMaxIts": 10000,
#       "EstimatorTol": 1e-06,
#       "GSOrthogonalization": "MGS",
#       "InitialGuess": true,
#       "KSPType": "CG",
#       "MGAuxiliarySmoother": false,
#       "MGCoarsenType": "Logarithmic",
#       "MGCycleIts": 1,
#       "MGMaxLevels": 100,
#       "MGSmoothChebyshev4th": true,
#       "MGSmoothEigScaleMax": 1.0,
#       "MGSmoothEigScaleMin": 0.0,
#       "MGSmoothIts": 1,
#       "MGSmoothOrder": 4,
#       "MGUseMesh": true,
#       "MaxIts": 100,
#       "MaxSize": 100,
#       "PCMatReal": false,
#       "PCMatShifted": false,
#       "PCSide": "Default",
#       "ReorderingReuse": true,
#       "STRUMPACKButterflyLevels": 1,
#       "STRUMPACKCompressionTol": 0.001,
#       "STRUMPACKCompressionType": "None",
#       "STRUMPACKLossyPrecision": 16,
#       "SuperLU3DCommunicator": false,
#       "Tol": 1e-06,
#       "Type": "AMS"
#     },
#     "Order": 1,
#     "PartialAssemblyOrder": 1,
#     "QuadratureOrderExtra": 0,
#     "QuadratureOrderJacobian": false
#   }
# }
# Dry-run: No errors detected in configuration file "/content/drive/MyDrive/Palace6/dummy_config.json"

# %%
# Install the missing OpenGL Utility Library dependency
# !apt-get update -qq && apt-get install -y libglu1-mesa -qq && apt-get clean -qq
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package libglu1-mesa:amd64.
# (Reading database ... 118332 files and directories currently installed.)
# Preparing to unpack .../libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link

# %%
import numpy as np
from qiskit_metal import draw, Dict
from qiskit_metal.qlibrary.core import BaseQubit

import qiskit_metal as qm
from qiskit_metal import designs
from math import sin, cos
import qiskit_metal as qm

import matplotlib.pyplot as plt
from IPython.display import display
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder


class TransmonConcentricManuscript(BaseQubit):
    """The base `TrasmonConcentric` class .

    Inherits `BaseQubit` class.

    Metal transmon object consisting of a circle surrounding by a concentric
    ring. There are two Josephson Junction connecting the circle to the ring;
    one at the south end and one at the north end. There is a readout resonator.

    .. image::
        TransmonConcentric.png

    .. meta::
        :description: Transmon Concentric

    BaseQubit Default Options:
        * connection_pads: empty Dict -- the dictionary which contains all active
          connection lines for the qubit.
        * _default_connection_pads: empty Dict -- the default values for the
          (if any) connection lines of the qubit.

    Default Options:
        * width: '1000um' -- Width of transmon pocket
        * height: '1000um' -- Height of transmon pocket
        * rad_o: '170um' -- Outer radius
        * rad_i: '115um' -- Inner radius
        * gap: '35um' -- Radius of gap between two pads
        * jj_w: '10um' -- Josephson Junction width
        * res_s: '100um' -- Space between top electrode and readout resonator
        * res_ext: '100um' -- Extension of readout resonator in x-direction
          beyond midpoint of transmon
        * fbl_rad: '100um' -- Radius of the flux bias line loop
        * fbl_sp: '100um' -- Spacing between metal pad and flux bias loop
        * fbl_gap: '80um' -- Space between parallel lines of the flux bias loop
        * fbl_ext: '300um' -- Run length of flux bias line between circular
          loop and edge of pocket
        * pocket_w: '1500um' -- Transmon pocket width
        * pocket_h: '1000um' -- Transmon pocket height
        * cpw_width: '10.0um' -- Width of the readout resonator and flux bias line
        * inductor_width: '5.0um' -- Width of the Josephson Junctions
        * layer: '1' -- the design layer where the component will go
    """

    # default drawing options
    default_options = Dict(
        width="1000um",  # width of transmon pocket
        height="1000um",  # height of transmon pocket
        rad_o="170um",  # outer radius
        rad_i="115um",  # inner radius
        gap="35um",  # radius of gap between two pads
        jj_w="7um",  # Josephson Junction width
        res_s="100um",  # space between top electrode and readout resonator
        res_ext="80um",  # extension of readout resonator in x-direction beyond midpoint of transmon
        fbl_rad="80um",  # radius of the flux bias line loop
        fbl_sp="80um",  # spacing between metal pad and flux bias loop
        # fbl_gap="150um",  # space between parallel lines of the flux bias loop
        fbl_ext="300um",  # run length of flux bias line between circular loop and edge of pocket
        pocket_w="1500um",  # transmon pocket width
        pocket_h="1000um",  # transmon pocket height
        cpw_width="10.0um",  # width of the readout resonator and flux bias line
        # cpw_width="10um",
        cpw_gap="6um",
        inductor_width="5.0um",  # width of the Josephson Junctions
        layer="1",  # design layer

                # ============================================================
        # Floating Connector Pad Parameters
        # ============================================================

        # Uniform radial air gap between the curved inner face of the
        # connector pad and the outer concentric transmon ring.
        connector_ring_gap="25um",

        # Overall connector pad dimensions.
        #
        # Width  : parallel (tangential) to the outer ring.
        # Height : perpendicular (radial) to the outer ring.
        connector_pad_w="100um",
        connector_pad_h="40um",

        # Radius of the rounded outer corners of the connector pad.
        connector_corner_r="40um",

        # Length of each CPW extending from the two short
        # vertical faces of the connector pad to the pocket boundary.
        connector_cpw_len="120um",

        # Number of interpolation points used to generate the
        # curved inner face of the connector pad.
        connector_arc_pts="32",



        # ============================================================
        # Individual Connector Ring Gaps
        # ============================================================

        connector_ring_gap_pad1="25um",   # Near Flux Bias Line
        connector_ring_gap_pad2="25um",
        connector_ring_gap_pad3="25um",
        connector_ring_gap_pad4="25um",


        # Default option

        fbl_pocket_angle = 13,

        # Metal layer used for the connector pads.
        connector_layer="1",

    )
    """Default drawing options"""

    TOOLTIP = """The base `TrasmonConcentric` class."""



        # ============================================================
    # Helper Functions for Connector Pads
    # ============================================================

    def polar_point(self, radius, theta):
        """
        Convert polar coordinates to Cartesian coordinates.

        Parameters
        ----------
        radius : float
            Distance from origin.

        theta : float
            Angle in radians.

        Returns
        -------
        tuple
            (x, y)
        """
        return (
            radius * cos(theta),
            radius * sin(theta)
        )


    def radial_unit(self, theta):
        """
        Unit vector pointing radially outward.
        """
        return np.array([
            cos(theta),
            sin(theta)
        ])


    def tangential_unit(self, theta):
        """
        Unit vector perpendicular to the radial direction.

        Positive direction corresponds to increasing theta.
        """
        return np.array([
            -sin(theta),
             cos(theta)
        ])


    def translate_point(self, point, dx, dy):
        """
        Translate a point by (dx, dy).
        """
        return (
            point[0] + dx,
            point[1] + dy
        )


    def offset_point(self, point, direction, distance):
        """
        Offset a point along a unit vector.

        Parameters
        ----------
        point : tuple
            Starting point.

        direction : ndarray
            Unit vector.

        distance : float
            Offset distance.

        Returns
        -------
        tuple
            Offset point.
        """
        return (
            point[0] + direction[0] * distance,
            point[1] + direction[1] * distance
        )


    def arc_points(self,
                   radius,
                   theta_start,
                   theta_stop,
                   n_points):
        """
        Generate evenly spaced points along a circular arc.

        Parameters
        ----------
        radius : float
            Arc radius.

        theta_start : float
            Starting angle (radians).

        theta_stop : float
            Ending angle (radians).

        n_points : int
            Number of interpolation points.

        Returns
        -------
        list
            List of (x, y) tuples.
        """

        pts = []

        for ang in np.linspace(theta_start,
                                 theta_stop,
                                 n_points):

            pts.append((
                radius * cos(ang),
                radius * sin(ang)
            ))

        return pts




        # ============================================================
    # Create One Floating Connector Pad
    # ============================================================

    def make_connector_pad(self,
                           theta_deg,
                           inner_radius,
                           pad_width,
                           pad_height,
                           n_arc=48):
        """
        Create one floating connector pad.

        Parameters
        ----------
        theta_deg : float
            Angular position of the connector (degrees).

        inner_radius : float
            Radius of the curved inner face.
            Usually:
                p.rad_o + p.connector_ring_gap

        pad_width : float
            Tangential width of connector pad.

        pad_height : float
            Radial thickness of connector pad.

        n_arc : int
            Number of interpolation points.

        Returns
        -------
        shapely.geometry.Polygon
        """

        theta = np.deg2rad(theta_deg)

        # Inner and outer radii
        r_inner = inner_radius
        r_outer = inner_radius + pad_height

        # Half angular span
        half_angle_inner = (pad_width / 2.0) / r_inner
        half_angle_outer = (pad_width / 2.0) / r_outer

        # --------------------------------------------------------
        # Inner curved face
        # --------------------------------------------------------

        inner_arc = []

        for ang in np.linspace(theta - half_angle_inner,
                               theta + half_angle_inner,
                               n_arc):

            inner_arc.append((r_inner * np.cos(ang),
                                r_inner * np.sin(ang)
            ))

        # --------------------------------------------------------
        # Outer curved face
        # --------------------------------------------------------

        outer_arc = []

        for ang in np.linspace(theta + half_angle_outer,
                               theta - half_angle_outer,
                               n_arc):

            outer_arc.append((r_outer * np.cos(ang),
                                r_outer * np.sin(ang)
            ))

        # --------------------------------------------------------
        # Complete polygon
        # --------------------------------------------------------

        coords = inner_arc + outer_arc

        return draw.Polygon(coords)



    # ============================================================
    # Connector Pad CPW Launch Points
    # ============================================================


    # ============================================================
    # Connector Pad CPW Launch Point
    # ============================================================

    def connector_launch_point(self,
                              theta_deg,
                              inner_radius,
                              pad_height):
        """
        Returns the CPW launch point located at the centre of the
        outer straight face of the connector pad.

        Parameters
        ----------
        theta_deg : float
            Angular position of the connector pad.

        inner_radius : float
            Radius of the curved inner face.

        pad_height : float
            Radial thickness of the connector pad.

        Returns
        -------
        tuple
            (x, y) launch point.
        """

        theta = np.deg2rad(theta_deg)

        # Unit radial vector
        er = np.array([
            np.cos(theta),
            np.sin(theta)
        ])

        # Outer face radius
        r_launch = inner_radius + pad_height

        # Launch point at centre of outer face
        launch = tuple(r_launch * er)

        return launch







    # ============================================================
    # Pocket Boundary Connection Points
    # ============================================================



    # ============================================================
    # Pocket Boundary CPW Target
    # ============================================================

    def pocket_connection_point(self,
                                theta_deg,
                                pocket_w,
                                pocket_h):
        """
        Returns the CPW target point on the circular pocket edge.
        """

        theta = np.deg2rad(theta_deg)

        # Unit radial vector
        er = np.array([
            np.cos(theta),
            np.sin(theta)
        ])

        # For a circular pocket, the target is simply at the pocket_radius along the radial direction
        pocket_radius = max(pocket_w, pocket_h) / 2.0

        # Pocket boundary point
        target = tuple(pocket_radius * er)

        return target







    #check here,

    # ============================================================
    # Helper: Create a smooth 90° routed CPW
    # ============================================================

    def create_smooth_bend_path(self,
                          start_pt,
                          stub_pt,
                          corner_pt,
                          end_pt,
                          radius=30.0,
                          max_frac=0.45,
                          num_points=20):

        x0, y0 = start_pt
        xc, yc = corner_pt
        x1, y1 = end_pt

        # --------------------------------------------------------
        # Incoming and outgoing vectors
        # --------------------------------------------------------

        dx1 = xc - x0
        dy1 = yc - y0

        dx2 = x1 - xc
        dy2 = y1 - yc


        # --------------------------------------------------------
        # Prevent oversized fillet
        # --------------------------------------------------------

        leg1 = np.hypot(dx1, dy1)
        leg2 = np.hypot(dx2, dy2)

        # radius = min(radius,
                    # 0.45 * leg1,
                    # 0.45 * leg2)


        radius = min(radius,
             max_frac * leg1,
             max_frac * leg2)

        # --------------------------------------------------------
        # Tangency points
        # --------------------------------------------------------

        if abs(dx1) > 0:

            bend_start = (
                xc - np.sign(dx1) * radius,
                yc
            )

        else:

            bend_start = (
                xc,
                yc - np.sign(dy1) * radius
            )

        if abs(dx2) > 0:

            bend_end = (
                xc + np.sign(dx2) * radius,
                yc
            )

        else:

            bend_end = (
                xc,
                yc + np.sign(dy2) * radius
            )

        # --------------------------------------------------------
        # Circle centre
        # --------------------------------------------------------

        cx = bend_end[0] if abs(dx1) > 0 else bend_start[0]
        cy = bend_start[1] if abs(dx1) > 0 else bend_end[1]

        # --------------------------------------------------------
        # Arc
        # --------------------------------------------------------

        a0 = np.arctan2(bend_start[1] - cy,
                        bend_start[0] - cx)

        a1 = np.arctan2(bend_end[1] - cy,
                        bend_end[0] - cx)

        # Always choose the shortest 90° sweep
        while a1 - a0 > np.pi:
            a1 -= 2 * np.pi

        while a1 - a0 < -np.pi:
            a1 += 2 * np.pi

        arc = []

        for ang in np.linspace(a0, a1, num_points):

            arc.append((cx + radius * np.cos(ang),
                        cy + radius * np.sin(ang)
            ))

        coords = (
            [start_pt] +
            [stub_pt] +
            [bend_start] +
            arc +
            [bend_end] +
            [end_pt]
        )

        return draw.LineString(coords)

    def make(self):
        """Convert self.options into QGeometry."""

        p = self.parse_options()  # Parse the string options into numbers

        # draw the concentric pad regions
        outer_pad = draw.Point(0, 0).buffer(p.rad_o)
        space = draw.Point(0, 0).buffer(p.gap + p.rad_i)
        outer_pad = draw.subtract(outer_pad, space)
        inner_pad = draw.Point(0, 0).buffer(p.rad_i)
        # gap = draw.subtract(space, inner_pad)
        # pads = draw.union(outer_pad, inner_pad)

        # draw the top Josephson Junction
        jj_t = draw.LineString([(0.0, p.rad_i), (0.0, p.rad_i + p.gap)])

        # draw the bottom Josephson Junction
        jj_b = draw.LineString(
            [(0.0, -1.0 * p.rad_i), (0.0, -1.0 * p.rad_i - 1.0 * p.gap)]
        )

        # draw the readout resonator
        qp1a = (
            -0.5 * p.pocket_w,
            p.rad_o + p.res_s,
        )  # the first (x,y) coordinate is qpin #1
        qp1b = (p.res_ext, p.rad_o + p.res_s)  # the second (x,y) coordinate is qpin #1
        rr = draw.LineString([qp1a, qp1b])


        # draw the transmon pocket bounding box
        # Changed from rectangular to circular pocket
        pocket_radius = max(p.pocket_w, p.pocket_h) / 2.0
        pocket = draw.Point(0, 0).buffer(pocket_radius)



       # ============================================================
        # Smooth transition + semicircle
                # ============================================================
        # ============================================================
        # Flux bias line (single smooth circular loop)
        # ============================================================

        num_points = 60

        # Extend the semicircle by 25°
        extra = np.deg2rad(0)

        start_angle = np.pi/2 + extra
        end_angle   = -np.pi/2 - extra

        # Loop centre
        cx = p.rad_o + p.fbl_sp + p.fbl_rad

        cy = 0.0

        # Generate loop
        arc_points = []

        for k in range(num_points + 1):

            theta = start_angle + (k / num_points) * (end_angle - start_angle)

            x = cx - p.fbl_rad * np.cos(theta)
            y = cy + p.fbl_rad * np.sin(theta)

            arc_points.append((x, y))

        # Arc endpoints
        top = arc_points[0]
        bottom = arc_points[-1]

        lead_x = 0.5 * p.pocket_w - p.fbl_ext

        # Straight sections
        # a = (0.5 * p.pocket_w, bottom[1])
        # b = (lead_x,           bottom[1])

        # h = (lead_x,           top[1])
        # i = (0.5 * p.pocket_w, top[1])

        # ============================================================
        # Angled straight sections (50° included angle)
        # ============================================================

        # ============================================================
        # Angled leads with fixed pocket connection
        # ============================================================

        half_angle = np.deg2rad(0)

        edge_x = 0.5 * p.pocket_w

        # Fixed pocket connections
        # a = (edge_x, bottom[1])
        # i = (edge_x, top[1])

        Rpocket=pocket_radius


        theta = np.deg2rad(p.fbl_pocket_angle)

        Rpocket = 0.5 * p.pocket_w

        # Bottom connection
        a = (
            Rpocket * np.cos(theta),
            -Rpocket * np.sin(theta)
        )

        # Top connection
        i = (
            Rpocket * np.cos(theta),
            Rpocket * np.sin(theta)
        )

        # Horizontal distance
        dx = edge_x - lead_x

        # Vertical offset needed to create the angle
        dy = np.tan(half_angle) * dx

        # Shift only the loop-side endpoints
        b = (
            lead_x,
            bottom[1] + dy
        )

        h = (
            lead_x,
            top[1] - dy
        )

        # Complete centreline
        fbl_coords = [a, b] + arc_points[::-1] + [h, i]



        fbl = draw.LineString(fbl_coords);





        # Draw flux bias lines
         # 6. Left, Right and Bottom Couplers
        # coupler_l = draw.LineString([(-0.5 * p.pocket_w, -0.5 * p.coupler_gap), (-0.5 * p.pocket_w + p.coupler_ext_l, -0.5 * p.coupler_gap)])
        # coupler_r = draw.LineString([(0.5 * p.pocket_w, 0.5 * p.coupler_gap), (0.5 * p.pocket_w - p.coupler_ext, 0.5 * p.coupler_gap)])

        # -0.5 * p.pocket_w,
            # p.rad_o + p.res_s,

        # Define bottom coupler - originating from the bottom of the pocket
        # cb_start = (-0.5 * p.coupler_gap, -0.5 * p.pocket_h)
        # cb_end = (-0.5 * p.coupler_gap, -0.5 * p.pocket_h + p.coupler_ext_b)
        # coupler_b = draw.LineString([cb_start, cb_end])


        #Pad on right of FBL
        pad1 = self.make_connector_pad(
            theta_deg=50,
            inner_radius=p.rad_o + p.connector_ring_gap_pad1,
            pad_width=p.connector_pad_w,
            pad_height=p.connector_pad_h,
            n_arc=int(p.connector_arc_pts)
        )


        #Pad on left of FBL
        pad2 = self.make_connector_pad(
            theta_deg=140,
            inner_radius=p.rad_o + p.connector_ring_gap_pad2,
            pad_width=p.connector_pad_w,
            pad_height=p.connector_pad_h,
            n_arc=int(p.connector_arc_pts)
        )

        pad3 = self.make_connector_pad(
            theta_deg=230,
            inner_radius=p.rad_o + p.connector_ring_gap_pad3,
            pad_width=p.connector_pad_w,
            pad_height=p.connector_pad_h,
            n_arc=int(p.connector_arc_pts)
        )

        pad4 = self.make_connector_pad(
            theta_deg=310,
            inner_radius=p.rad_o + p.connector_ring_gap_pad4,
            pad_width=p.connector_pad_w,
            pad_height=p.connector_pad_h,
            n_arc=int(p.connector_arc_pts)
        )


        # ============================================================
        # Connector CPW Launch Points
        # ============================================================

        # ============================================================
        # Connector CPW Launch Points
        # ============================================================

        pad1_launch = self.connector_launch_point(
            theta_deg=50,
            inner_radius=p.rad_o + p.connector_ring_gap_pad1,
            pad_height=p.connector_pad_h
        )

        pad2_launch = self.connector_launch_point(
            theta_deg=140,
            inner_radius=p.rad_o + p.connector_ring_gap_pad2,
            pad_height=p.connector_pad_h
        )

        pad3_launch = self.connector_launch_point(
            theta_deg=230,
            inner_radius=p.rad_o + p.connector_ring_gap_pad3,
            pad_height=p.connector_pad_h
        )

        pad4_launch = self.connector_launch_point(
            theta_deg=310,
            inner_radius=p.rad_o + p.connector_ring_gap_pad4,
            pad_height=p.connector_pad_h
        )


        # ============================================================
        # Pocket Boundary CPW Targets
        # ============================================================


        # ============================================================
        # Pocket Boundary CPW Targets
        # ============================================================

        pad1_target = self.pocket_connection_point(
            theta_deg=50,
            pocket_w=p.pocket_w,
            pocket_h=p.pocket_h
        )

        pad2_target = self.pocket_connection_point(
            theta_deg=140,
            pocket_w=p.pocket_w,
            pocket_h=p.pocket_h
        )

        pad3_target = self.pocket_connection_point(
            theta_deg=230,
            pocket_w=p.pocket_w,
            pocket_h=p.pocket_h
        )

        pad4_target = self.pocket_connection_point(
            theta_deg=310,
            pocket_w=p.pocket_w,
            pocket_h=p.pocket_h
        )


        # ============================================================


        # ============================================================
        # Generate Smooth CPW Lines
        # ============================================================

        # Fillet radius for connector CPWs
        # bend_radius = p.connector_fillet

        cpw1 = draw.LineString([pad1_launch, pad1_target])

        cpw2 = draw.LineString([pad2_launch, pad2_target])

        cpw3 = draw.LineString([pad3_launch, pad3_target])

        cpw4 = draw.LineString([pad4_launch, pad4_target])


        # # draw the transmon pocket bounding box
        # # Changed from rectangular to circular pocket
        # pocket_radius = max(p.pocket_w, p.pocket_h) / 2.0
        # pocket = draw.Point(0, 0).buffer(pocket_radius)

        # Translate and rotate all shapes
        # objects = [outer_pad, inner_pad, jj_t, jj_b, pocket, rr, fbl, coupler_l, coupler_b ]
        objects = [outer_pad, inner_pad, jj_t, jj_b, pocket, fbl, pad1, pad2,pad3, pad4, cpw1, cpw2, cpw3, cpw4 ]
        objects = draw.rotate(objects, p.orientation, origin=(0, 0))
        objects = draw.translate(objects, xoff=p.pos_x, yoff=p.pos_y)
        [outer_pad, inner_pad, jj_t, jj_b, pocket, fbl, pad1, pad2, pad3, pad4, cpw1, cpw2, cpw3, cpw4] = objects

        # define a function that both rotates and translates the qpin coordinates
        def qpin_rotate_translate(x):
            y = list(x)
            z = [0.0, 0.0]
            z[0] = y[0] * cos(p.orientation * 3.14159 / 180) - y[1] * sin(
                p.orientation * 3.14159 / 180
            )
            z[1] = y[0] * sin(p.orientation * 3.14159 / 180) + y[1] * cos(
                p.orientation * 3.14159 / 180
            )
            z[0] = z[0] + p.pos_x
            z[1] = z[1] + p.pos_y
            x = (z[0], z[1])
            return x

        # rotate and translate the qpin coordinates
        # qp1a = qpin_rotate_translate(qp1a)
        # qp1b = qpin_rotate_translate(qp1b)
        a = qpin_rotate_translate(a)
        b = qpin_rotate_translate(b)
        h = qpin_rotate_translate(h)
        i = qpin_rotate_translate(i)

        pad1_launch=qpin_rotate_translate(pad1_launch)
        pad2_launch=qpin_rotate_translate(pad2_launch)
        pad3_launch=qpin_rotate_translate(pad3_launch)
        pad4_launch=qpin_rotate_translate(pad4_launch)

        pad1_target=qpin_rotate_translate(pad1_target)
        pad2_target=qpin_rotate_translate(pad2_target)
        pad3_target=qpin_rotate_translate(pad3_target)
        pad4_target=qpin_rotate_translate(pad4_target)

        ##############################################################

        # Use the geometry to create Metal QGeometry
        # geom_rr = {"path1": rr}
        geom_fbl = {"path2": fbl}
        geom_outer = {"poly1": outer_pad}
        geom_inner = {"poly2": inner_pad}
        geom_jjt = {"poly4": jj_t}
        geom_jjb = {"poly5": jj_b}
        geom_pocket = {"poly6": pocket}

        # self.add_qgeometry(
        #     "path", geom_rr, layer=p.layer, subtract=False, width=p.cpw_width
        # )
        self.add_qgeometry(
            "path", geom_fbl, layer=p.layer, subtract=False, width=p.cpw_width
        )
        self.add_qgeometry("poly", geom_outer, layer=p.layer, subtract=False)
        self.add_qgeometry("poly", geom_inner, layer=p.layer, subtract=False)
        self.add_qgeometry(
            "junction", geom_jjt, layer=p.layer, subtract=False, width=p.inductor_width
        )
        self.add_qgeometry(
            "junction", geom_jjb, layer=p.layer, subtract=False, width=p.inductor_width
        )
        self.add_qgeometry("poly", geom_pocket, layer=1, subtract=True);


        self.add_qgeometry(
            'poly',
            {
             'connector_pad1': pad1,
             'connector_pad2': pad2,
             'connector_pad3': pad3,
             'connector_pad4': pad4
             },
            layer=p.connector_layer
        )

        # ============================================================
        # Connector CPW Metal
        # ============================================================

        self.add_qgeometry(
            'path',
            {
                'connector_cpw1': cpw1,
                'connector_cpw2': cpw2,
                'connector_cpw3': cpw3,
                'connector_cpw4': cpw4
            },
            width=p.cpw_width,
            layer=p.connector_layer
        )


        ###########################################################################

        # Add Qpin connections
        # self.add_pin(
        #     "pin1", points=np.array([qp1b, qp1a]), width=0.01, input_as_norm=True
        # )
        self.add_pin("pin1a", points=np.array([b, a]), width=0.01, input_as_norm=True)
        self.add_pin("pin1b", points=np.array([h, i]), width=0.01, input_as_norm=True)


        self.add_pin("pin2", points=np.array([pad1_launch, pad1_target]), width=0.01, input_as_norm=True)
        self.add_pin("pin3", points=np.array([pad2_launch, pad2_target]), width=0.01, input_as_norm=True)
        self.add_pin("pin4", points=np.array([pad3_launch, pad3_target]), width=0.01, input_as_norm=True)
        self.add_pin("pin5", points=np.array([pad4_launch, pad4_target]), width=0.01, input_as_norm=True)




# gui=metalGUI(design)
# design = designs.DesignPlanar()
# gui=qm.gui(design)


design = designs.DesignPlanar()
design.overwrite_enabled=True
gui=qm.gui(design)


# Optional: launch GUI if running locally with a display server
# gui = MetalGUI(design)

# 2. Instantiate our custom coupled concentric transmon qubit ('Q1')
q1 = TransmonConcentricManuscript(
    design,
    'Q1',
    options=Dict(
        pos_x="0um",
        pos_y="0um",
        orientation="90"
    )
)
# gui.edit_component(component_name='Q1', options=Dict(fbl_pocket_angle=13))
# 3. Rebuild design to execute the make() method and populate QGeometry
gui.rebuild()
gui.autoscale()

# Create the figure for the design from the 'design' object defined in the previous cell
fig = qm.view(design)

# Get the main axis of the figure
ax = fig.gca()

# Set the x and y limits fo the zoom view (from -1000um to 1000um, which is -1mm to 1mm)
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)

# (Optional) save to file

fig.savefig("chip_manuscript.png", dpi=600)

# # Show inline using display(fig) for explicit inline display in notebooks
# display(fig)

gui=qm.gui(design)

# 1. Specify the components you want to focus on
# target_components = ['Q1', 'readout']

# Zoom specifically to component 'Q1'
gui.zoom_on_components(['Q1'])

# Or zoom to multiple components
# gui.zoom_on_components(['Q1', 'Q2'])

# # Take the screenshot matching this zoom view
# gui.screenshot('zoomed_q1.png')

# 3. Visually highlight them on the canvas
gui.highlight_components(['Q1'])

gui.screenshot()

# a_gds = design.renderers.gds
# a_gds.options['path_filename'] = r"C:\Users\HP\Music\PhysicaR2\qiskit-metal-main\qiskit-metal-main\tutorials\resources\Fake_Junctions.GDS"

# if __name__ == "__main__" and gui.qApp is not None:



#     # 1. Initialize the Qiskit Metal design environment
#     # design = designs.DesignPlanar()
#     gui.qApp.exec()
# Out:
# 04:59PM 47s INFO [_start_renderers]: Renderer=hfss skipped: runtime dependency not installed (QAnsysRenderer requires pyEPR. Install with: pip install 'quantum-metal[ansys]').
# 04:59PM 47s INFO [_start_renderers]: Renderer=q3d skipped: runtime dependency not installed (QAnsysRenderer requires pyEPR. Install with: pip install 'quantum-metal[ansys]').
# 04:59PM 47s INFO [_start_renderers]: Renderer=aedt_q3d skipped: runtime dependency not installed (QPyaedt requires pyaedt (ansys.aedt.core). Install with: pip install 'quantum-metal[ansys]').
# 04:59PM 47s INFO [_start_renderers]: Renderer=aedt_hfss skipped: runtime dependency not installed (QPyaedt requires pyaedt (ansys.aedt.core). Install with: pip install 'quantum-metal[ansys]').
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
# design = designs.DesignPlanar()

# # expanding the chip size ensures your ground plane borders and outer routes stay well inside the chip edges.
# design.chips.main.size.size_x = "10mm"
# design.chips.main.size.size_y = "10mm"


# design.overwrite_enabled=True
# gui=qm.gui(design)



# # Create qubits with only pos_x, pos_y, and orientation specified, keeping defaults for the rest
# Q1 = TransmonConcentricManuscript(design, 'Q1', options=dict(pos_x='-1mm', pos_y='0mm', orientation='90'))
# Q2 = TransmonConcentricManuscript(design, 'Q2', options=dict(pos_x='1.4mm', pos_y='0mm', orientation='90'))
# Q3 = TransmonConcentricManuscript(design, 'Q3', options=dict(pos_x='-1mm', pos_y='-2.7mm', orientation='270'))
# Q4 = TransmonConcentricManuscript(design, 'Q4', options=dict(pos_x='1.4mm', pos_y='-2.7mm', orientation='270'))



# # gui.edit_component(component_name='Q1', options=Dict(fbl_pocket_angle=13))
# # 3. Rebuild design to execute the make() method and populate QGeometry
# gui.rebuild()
# gui.autoscale()

# # Create the figure for the design from the 'design' object defined in the previous cell
# fig = qm.view(design)

# # Get the main axis of the figure
# ax = fig.gca()

# # Set the x and y limits fo the zoom view (from -1000um to 1000um, which is -1mm to 1mm)
# ax.set_xlim(-1, 1)
# ax.set_ylim(-1, 1)

# # (Optional) save to file

# fig.savefig("chip_manuscript2.png", dpi=600)

# # # Show inline using display(fig) for explicit inline display in notebooks
# # display(fig)

# gui=qm.gui(design)

# # 1. Specify the components you want to focus on
# # target_components = ['Q1', 'readout']

# # Zoom specifically to component 'Q1'
# gui.zoom_on_components(['Q1','Q2','Q3','Q4'])

# # Or zoom to multiple components
# # gui.zoom_on_components(['Q1', 'Q2'])

# # # Take the screenshot matching this zoom view
# # gui.screenshot('zoomed_q1.png')

# # 3. Visually highlight them on the canvas
# gui.highlight_components(['Q1','Q2','Q3','Q4'])

# gui.screenshot()

# %%
design = designs.DesignPlanar()

# -------------------------------------------------------------------------
# CHIP
# -------------------------------------------------------------------------
design.chips.main.size.size_x = "10mm"
design.chips.main.size.size_y = "10mm"

design.overwrite_enabled = True
gui = qm.gui(design)


# =============================================================================
# TARGET QUBIT FREQUENCIES
# =============================================================================
#
# Q1 = 4.8 GHz
# Q2 = 5.2 GHz
# Q3 = 5.7 GHz
# Q4 = 6.1 GHz
#
# Baseline:
#   rad_o = 170 um
#   rad_i = 115 um
#   gap   = 35 um
#
# First-pass capacitance scaling:
#   C_target/C_current = (5.0015 / f_target)^2
#
# Keep JJ geometry and gap unchanged.
# Only change the concentric capacitor dimensions.
# =============================================================================


# -------------------------------------------------------------------------
# Q1 — target 4.8 GHz
# Larger capacitor -> lower frequency
# -------------------------------------------------------------------------
Q1 = TransmonConcentricManuscript(
    design,
    'Q1',
    options=dict(
        pos_x='-1mm',
        pos_y='0mm',
        orientation='90',

        rad_o='184.5um',
        rad_i='124.8um',
        gap='35um',

        pocket_w='1500um',
        pocket_h='1000um',
    )
)


# -------------------------------------------------------------------------
# Q2 — target 5.2 GHz
# Slightly smaller capacitor -> higher frequency
# -------------------------------------------------------------------------
Q2 = TransmonConcentricManuscript(
    design,
    'Q2',
    options=dict(
        pos_x='1.4mm',
        pos_y='0mm',
        orientation='90',

        rad_o='157.3um',
        rad_i='106.4um',
        gap='35um',

        pocket_w='1500um',
        pocket_h='1000um',
    )
)


# -------------------------------------------------------------------------
# Q3 — target 5.7 GHz
# Smaller capacitor -> substantially higher frequency
# -------------------------------------------------------------------------
Q3 = TransmonConcentricManuscript(
    design,
    'Q3',
    options=dict(
        pos_x='-1mm',
        pos_y='-2.7mm',
        orientation='270',

        rad_o='131.0um',
        rad_i='88.6um',
        gap='35um',

        pocket_w='1500um',
        pocket_h='1000um',
    )
)


# -------------------------------------------------------------------------
# Q4 — target 6.1 GHz
# Smallest capacitor -> highest frequency
# -------------------------------------------------------------------------
Q4 = TransmonConcentricManuscript(
    design,
    'Q4',
    options=dict(
        pos_x='1.4mm',
        pos_y='-2.7mm',
        orientation='270',

        rad_o='114.2um',
        rad_i='77.3um',
        gap='35um',

        pocket_w='1500um',
        pocket_h='1000um',
    )
)


# =============================================================================
# REBUILD
# =============================================================================
gui.rebuild()
gui.autoscale()


# =============================================================================
# VIEW
# =============================================================================
fig = qm.view(design)

ax = fig.gca()

ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)

fig.savefig("chip_manuscript_target_geometry.png", dpi=600)


# =============================================================================
# GUI
# =============================================================================
gui = qm.gui(design)

gui.zoom_on_components(['Q1', 'Q2', 'Q3', 'Q4'])

gui.highlight_components(['Q1', 'Q2', 'Q3', 'Q4'])

gui.screenshot()
# Out:
# 05:00PM 01s INFO [_start_renderers]: Renderer=hfss skipped: runtime dependency not installed (QAnsysRenderer requires pyEPR. Install with: pip install 'quantum-metal[ansys]').
# 05:00PM 01s INFO [_start_renderers]: Renderer=q3d skipped: runtime dependency not installed (QAnsysRenderer requires pyEPR. Install with: pip install 'quantum-metal[ansys]').
# 05:00PM 01s INFO [_start_renderers]: Renderer=aedt_q3d skipped: runtime dependency not installed (QPyaedt requires pyaedt (ansys.aedt.core). Install with: pip install 'quantum-metal[ansys]').
# 05:00PM 01s INFO [_start_renderers]: Renderer=aedt_hfss skipped: runtime dependency not installed (QPyaedt requires pyaedt (ansys.aedt.core). Install with: pip install 'quantum-metal[ansys]').
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander

# Allow running the same cell here multiple times to overwrite changes
design.overwrite_enabled = True



options = Dict(meander=Dict(lead_start="0.1mm", lead_end="0.1mm", asymmetry="0 um"))


def connect(
    component_name: str,
    component1: str,
    pin1: str,
    component2: str,
    pin2: str,
    length: str,
    asymmetry="0 um",
    flip=False,
):
    """Connect two pins with a CPW."""
    myoptions = Dict(
        pin_inputs=Dict(
            start_pin=Dict(component=component1, pin=pin1),
            end_pin=Dict(component=component2, pin=pin2),
        ),
        lead=Dict(start_straight="0.13mm", end_straight="0.13mm"),
        total_length=length,
        fillet="90um",
    )
    myoptions.update(options)
    myoptions.meander.asymmetry = asymmetry
    myoptions.meander.lead_direction_inverted = "true" if flip else "false"
    return RouteMeander(design, component_name, myoptions)


asym = 150
cpw1 = connect("cpw1", "Q1", "pin5", "Q2", "pin2", "6.0 mm", f"+{asym}um")
cpw2 = connect("cpw2", "Q1", "pin4", "Q3", "pin3", "6 mm", f"+{asym}um", flip=True)
cpw3 = connect("cpw3", "Q2", "pin3", "Q4", "pin4", "6 mm", f"-{asym}um")
cpw4 = connect("cpw4", "Q3", "pin2", "Q4", "pin5", "6.1 mm", f"-{asym}um", flip=True)

gui.rebuild()
gui.autoscale()



gui=qm.gui(design)

# 1. Specify the components you want to focus on
# target_components = ['Q1', 'readout']

# Zoom specifically to component 'Q1'
gui.zoom_on_components(['Q1','Q2','Q3','Q4'])

# Or zoom to multiple components
# gui.zoom_on_components(['Q1', 'Q2'])

# # Take the screenshot matching this zoom view
# gui.screenshot('zoomed_q1.png')

# 3. Visually highlight them on the canvas
gui.highlight_components(['Q1','Q2','Q3','Q4'])

gui.screenshot()
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/qiskit_metal/qgeometries/qgeometries_handler.py:537: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.tables[kind] = pd.concat(
#
# WARNING:matplotlib.axes._base:Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond

from qiskit_metal.qlibrary.lumped.cap_3_interdigital import Cap3Interdigital
from qiskit_metal.qlibrary.terminations.launchpad_wb_coupled import (
    LaunchpadWirebondCoupled,
)

# Allow running the same cell here multiple times to overwrite changes
design.overwrite_enabled = True



# p1_c = LaunchpadWirebond(
#     design,
#     "P1_C",
#     options=dict(pos_x="3545um", pos_y="2812um", orientation="270", lead_length="0um"),
# )
# p2_c = LaunchpadWirebond(
#     design,
#     "P2_C",
#     options=dict(pos_x="3545um", pos_y="-2812um", orientation="90", lead_length="0um"),
# )
# p3_c = LaunchpadWirebond(
#     design,
#     "P3_C",
#     options=dict(pos_x="-3545um", pos_y="-2812um", orientation="90", lead_length="0um"),
# )

#FBL launchpad
l_q1 = LaunchpadWirebond(
    design,
    "L_Q1",
    options=dict(pos_x="-990um", pos_y="2900um", orientation="270", lead_length="0um"),
)

dl_pad_q1 = LaunchpadWirebondCoupled(
    design,
    "DL_PAD_Q1",
    options=dict(pos_x="-4600um", pos_y="0", orientation="0", lead_length="30um"),
)

ro_pad_q1 = LaunchpadWirebondCoupled(
    design,
    "RO_PAD_Q1",
    options=dict(pos_x="-4600um", pos_y="2", orientation="0", lead_length="30um"),
)

Cap_Q1 = Cap3Interdigital(
    design,
    "Cap_Q1",
    options=dict(
        layer="1",
        pos_x="-3.8mm",
        pos_y="1mm",
        orientation="0",
        trace_width="10um",
        finger_length="40um",
    ),)


Cap_Q3 = Cap3Interdigital(
    design,
    "Cap_Q3",
    options=dict(
        layer="1",
        pos_x="-3.8mm",
        pos_y="-2.5mm",
        orientation="0",
        trace_width="10um",
        finger_length="40um",
    ),)


Cap_Q2 = Cap3Interdigital(
    design,
    "Cap_Q2",
    options=dict(
        layer="1",
        pos_x="3.8mm",
        pos_y="1mm",
        orientation="0",
        trace_width="10um",
        finger_length="40um",
    ),)


Cap_Q4 = Cap3Interdigital(
    design,
    "Cap_Q4",
    options=dict(
        layer="1",
        pos_x="3.8mm",
        pos_y="-2.5mm",
        orientation="0",
        trace_width="10um",
        finger_length="40um",
    ),)



#FBL launchpad
l_q2 = LaunchpadWirebond(
    design,
    "L_Q2",
    options=dict(pos_x="1400um", pos_y="2900um", orientation="270", lead_length="0um"),
)


dl_pad_q2 = LaunchpadWirebondCoupled(
    design,
    "DL_PAD_Q2",
    options=dict(pos_x="4600um", pos_y="0", orientation="180", lead_length="30um"),
)


ro_pad_q2 = LaunchpadWirebondCoupled(
    design,
    "RO_PAD_Q2",
    options=dict(pos_x="4600um", pos_y="2", orientation="180", lead_length="30um"),
)





#FBL launchpad
l_q3 = LaunchpadWirebondCoupled(
    design,
    "L_Q3",
    options=dict(pos_x="-990um", pos_y="-6100um", orientation="90", lead_length="30um"),
)

ro_pad_q3 = LaunchpadWirebondCoupled(
    design,
    "RO_PAD_Q3",
    options=dict(pos_x="-4600um", pos_y="-2", orientation="0", lead_length="30um"),
)

dl_pad_q3 = LaunchpadWirebondCoupled(
    design,
    "DL_PAD_Q3",
    options=dict(pos_x="-4600um", pos_y="-4.5", orientation="0", lead_length="30um"),
)


#FBL launchpad
l_q4 = LaunchpadWirebondCoupled(
    design,
    "L_Q4",
    options=dict(pos_x="1400um", pos_y="-6100um", orientation="90", lead_length="30um"),
)

ro_pad_q4 = LaunchpadWirebondCoupled(
    design,
    "RO_PAD_Q4",
    options=dict(pos_x="4600um", pos_y="-2", orientation="180", lead_length="30um"),
)

dl_pad_q4 = LaunchpadWirebondCoupled(
    design,
    "DL_PAD_Q4",
    options=dict(pos_x="4600um", pos_y="-4.5", orientation="180", lead_length="30um"),
)



# p4_q = LaunchpadWirebondCoupled(
#     design,
#     "P4_Q",
#     options=dict(pos_x="990um", pos_y="2812um", orientation="270", lead_length="30um"),
# )

design.rebuild()

gui.rebuild()
gui.autoscale()

# %%
Readout_Q1 = RouteMeander(
    design,
    "Readout_Q1",
    options=dict(
        pin_inputs=dict(
            start_pin=dict(component="Q1", pin="pin2"),
            end_pin=dict(component="Cap_Q1", pin="a"),
        ),
        fillet="99um",
        total_length="7mm",
        layer="1",
        lead=dict(start_straight="250um", end_straight="200um"),
        meander=dict(spacing="200um", asymmetry="-50um"),
    ),
)


Readout_Q2 = RouteMeander(
    design,
    "Readout_Q2",
    options=dict(
        pin_inputs=dict(
            start_pin=dict(component="Q2", pin="pin5"),
            end_pin=dict(component="Cap_Q2", pin="a"),
        ),
        fillet="99um",
        total_length="7mm",
        layer="1",
        lead=dict(start_straight="250um", end_straight="200um"),
        meander=dict(spacing="200um", asymmetry="-50um"),
    ),
)

Readout_Q3 = RouteMeander(
    design,
    "Readout_Q3",
    options=dict(
        pin_inputs=dict(
            start_pin=dict(component="Q3", pin="pin4"),
            end_pin=dict(component="Cap_Q3", pin="a"),
        ),
        fillet="99um",
        total_length="7mm",
        layer="1",
        lead=dict(start_straight="250um", end_straight="200um"),
        meander=dict(spacing="200um", asymmetry="-50um"),
    ),
)


Readout_Q4 = RouteMeander(
    design,
    "Readout_Q4",
    options=dict(
        pin_inputs=dict(
            start_pin=dict(component="Q4", pin="pin3"),
            end_pin=dict(component="Cap_Q4", pin="a"),
        ),
        fillet="99um",
        total_length="7mm",
        layer="1",
        lead=dict(start_straight="250um", end_straight="200um"),
        meander=dict(spacing="200um", asymmetry="-50um"),
    ),
)


TL_Q1=RoutePathfinder(
        design,
        "TL_Q1",
        options=dict(
            pin_inputs=dict(
                start_pin=dict(component="RO_PAD_Q1", pin="tie"),
                end_pin=dict(component="Cap_Q1", pin="b"),
            ),
            fillet="99um",
            total_length="5mm",
            layer="1",
            lead=dict(start_straight="150um", end_straight="150um"),
            advanced=dict(avoid_collision="true"),
            step_size="0.25mm",
        ),
    )


TL_Q2=RoutePathfinder(
        design,
        "TL_Q2",
        options=dict(
            pin_inputs=dict(
                start_pin=dict(component="RO_PAD_Q2", pin="tie"),
                end_pin=dict(component="Cap_Q2", pin="b"),
            ),
            fillet="99um",
            total_length="5mm",
            layer="1",
            lead=dict(start_straight="150um", end_straight="150um"),
            advanced=dict(avoid_collision="true"),
            step_size="0.25mm",
        ),
    )

TL_Q3=RoutePathfinder(
        design,
        "TL_Q3",
        options=dict(
            pin_inputs=dict(
                start_pin=dict(component="RO_PAD_Q3", pin="tie"),
                end_pin=dict(component="Cap_Q3", pin="b"),
            ),
            fillet="99um",
            total_length="5mm",
            layer="1",
            lead=dict(start_straight="150um", end_straight="150um"),
            advanced=dict(avoid_collision="true"),
            step_size="0.25mm",
        ),
    )


TL_Q4=RoutePathfinder(
        design,
        "TL_Q4",
        options=dict(
            pin_inputs=dict(
                start_pin=dict(component="RO_PAD_Q4", pin="tie"),
                end_pin=dict(component="Cap_Q4", pin="b"),
            ),
            fillet="99um",
            total_length="5mm",
            layer="1",
            lead=dict(start_straight="150um", end_straight="150um"),
            advanced=dict(avoid_collision="true"),
            step_size="0.25mm",
        ),
    )


design.rebuild()

gui.rebuild()
# gui.screenshot()
gui.autoscale()

# %%
from collections import OrderedDict


from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors
# fillet = "99.9um"
# jogsA_in = OrderedDict()
# jogsA_in[0] = ["L", "200um"]

# Allow running the same cell here multiple times to overwrite changes
design.overwrite_enabled = True


options_line_l_q1=dict(
          pin_inputs=dict(
              start_pin=dict(component="Q1", pin="pin1a"),
              end_pin=dict(component="L_Q1", pin="tie"),
          ),
          fillet="99um",
          total_length="6mm",
          layer="1",
          lead=dict(start_straight="250um", end_straight="250um"),
          advanced=dict(avoid_collision="true"),
          step_size="0.25mm",
      )


line_l_q1 =RouteMeander(design, "FBL_Q1", options_line_l_q1)


options_dl_l_q1=dict(
          pin_inputs=dict(
              start_pin=dict(component="Q1", pin="pin3"),
              end_pin=dict(component="DL_PAD_Q1", pin="tie"),
          ),
          fillet="99um",
          total_length="9mm",
          layer="1",
          lead=dict(start_straight="340um", end_straight="340um"),
          advanced=dict(avoid_collision="true"),
          step_size="0.25mm",
      )


line_dl_q1 =RouteMeander(design, "DL_Q1", options_dl_l_q1)




options_l_q2=dict(
      pin_inputs=dict(
          start_pin=dict(component="Q2", pin="pin1a"),
          end_pin=dict(component="L_Q2", pin="tie"),
      ),
      fillet="99um",
      total_length="6mm",
      layer="1",
      lead=dict(start_straight="260um", end_straight="250um"),
      meander=dict(spacing="200um", asymmetry="-50um"),
  )

# line_l_q2 =RoutePathfinder(design, "FBL_Q2", options_line_l_q2)
line_l_q2 =RouteMeander(design, "FBL_Q2", options_l_q2)

options_dl_l_q2=dict(
          pin_inputs=dict(
              start_pin=dict(component="Q2", pin="pin4"),
              end_pin=dict(component="DL_PAD_Q2", pin="tie"),
          ),
          fillet="99um",
          total_length="9mm",
          layer="1",
          lead=dict(start_straight="340um", end_straight="340um"),
          advanced=dict(avoid_collision="true"),
          step_size="0.25mm",
      )


line_dl_q2 =RouteMeander(design, "DL_Q2", options_dl_l_q2)



options_line_l_q3=dict(
          pin_inputs=dict(
              start_pin=dict(component="Q3", pin="pin1a"),
              end_pin=dict(component="L_Q3", pin="tie"),
          ),
          fillet="99um",
          total_length="7mm",
          layer="1",
          lead=dict(start_straight="250um", end_straight="250um"),
          advanced=dict(avoid_collision="true"),
          step_size="0.25mm",
      )


# line_l_q2 =RoutePathfinder(design, "FBL_Q2", options_line_l_q2)
line_l_q3 =RouteMeander(design, "FBL_Q3", options_line_l_q3)


options_dl_l_q3=dict(
          pin_inputs=dict(
              start_pin=dict(component="Q3", pin="pin5"),
              end_pin=dict(component="DL_PAD_Q3", pin="tie"),
          ),
          fillet="99um",
          total_length="9mm",
          layer="1",
          lead=dict(start_straight="370um", end_straight="340um"),
          advanced=dict(avoid_collision="true"),
          step_size="0.25mm",
      )


line_dl_q3 =RouteMeander(design, "DL_Q3", options_dl_l_q3)



options_line_l_q4=dict(
          pin_inputs=dict(
              start_pin=dict(component="Q4", pin="pin1b"),
              end_pin=dict(component="L_Q4", pin="tie"),
          ),
          fillet="99um",
          total_length="7mm",
          layer="1",
          lead=dict(start_straight="250um", end_straight="250um"),
          advanced=dict(avoid_collision="true"),
          step_size="0.25mm",
      )


# line_l_q2 =RoutePathfinder(design, "FBL_Q2", options_line_l_q2)
line_l_q4 =RouteMeander(design, "FBL_Q4", options_line_l_q4)


options_dl_l_q4=dict(
          pin_inputs=dict(
              start_pin=dict(component="Q4", pin="pin2"),
              end_pin=dict(component="DL_PAD_Q4", pin="tie"),
          ),
          fillet="99um",
          total_length="9mm",
          layer="1",
          lead=dict(start_straight="370um", end_straight="340um"),
          advanced=dict(avoid_collision="true"),
          step_size="0.25mm",
      )


line_dl_q4 =RouteMeander(design, "DL_Q4", options_dl_l_q4)

# gui.highlight_components(['Q1','Q2','Q3','Q4', 'RO_Q1','RO_Q2'])

design.rebuild()



gui.rebuild()
gui.autoscale()
# gui.highlight_components(['Q1','Q2','Q3','Q4', 'FBL_Q1', 'FBL_Q2', 'FBL_Q3', 'FBL_Q4', 'DL_Q1', 'DL_Q2', 'DL_Q3', 'DL_Q4','Readout_Q1','Readout_Q2','Readout_Q3','Readout_Q4'])
gui.screenshot()

# %%
# Out:
# 03:49AM 54s WARNING [import_junction_gds_file]: Not able to find file:"my_transmon_design.gds".  Not used to replace junction. Checked directory:"/content".
# Design exported to GDS: my_transmon_design.gds

# %%
# Clone the Qiskit Metal repo to access tutorials and resource files
# !git clone https://github.com/qiskit-community/qiskit-metal.git
# Out:
# Cloning into 'qiskit-metal'...
# remote: Enumerating objects: 83117, done.
# remote: Counting objects: 100% (1570/1570), done.
# remote: Compressing objects: 100% (702/702), done.
# remote: Total 83117 (delta 1478), reused 868 (delta 868), pack-reused 81547 (from 2)
# Receiving objects: 100% (83117/83117), 576.53 MiB | 24.46 MiB/s, done.
# Resolving deltas: 100% (67996/67996), done.

# %%
# ============================================================
# PALACE v14.4 — CLEAN TARGET GDS EXPORT
# NO-CHEESE LAYER DISABLED
# ============================================================

import os
import hashlib

# ------------------------------------------------------------
# 1. PALACE OUTPUT ROOT
# ------------------------------------------------------------

PALACE_ROOT = "/content/drive/MyDrive/Palace6/meshesv3"

GDS_DIR = os.path.join(
    PALACE_ROOT,
    "gds"
)

os.makedirs(
    GDS_DIR,
    exist_ok=True
)

output_gds_path = os.path.join(
    GDS_DIR,
    "quantum_chip_TARGET_GEOMETRY_v14_4_CLEAN.gds"
)

# ------------------------------------------------------------
# 2. CHIP SIZE
# ------------------------------------------------------------

design.chips.main.size.size_x = "10mm"
design.chips.main.size.size_y = "10mm"

design.rebuild()

# ------------------------------------------------------------
# 3. GDS RENDERER
# ------------------------------------------------------------

gds_renderer = design.renderers.gds

# ------------------------------------------------------------
# 4. SIMULATION-FRIENDLY JJ LIBRARY
# ------------------------------------------------------------

junction_gds = (
    "/content/qiskit-metal/tutorials/resources/"
    "Fake_Junctions.GDS"
)

if not os.path.isfile(junction_gds):
    raise FileNotFoundError(
        f"JJ library not found:\n{junction_gds}"
    )

gds_renderer.options[
    "path_filename"
] = junction_gds

# ------------------------------------------------------------
# 5. GDS GEOMETRY SETTINGS
# ------------------------------------------------------------

gds_renderer.options[
    "precision"
] = "0.000000001"

gds_renderer.options[
    "tolerance"
] = "0.00001"

gds_renderer.options[
    "corners"
] = "natural"

gds_renderer.options[
    "junction_pad_overlap"
] = "5um"

# ------------------------------------------------------------
# 6. NO-CHEESE CONFIGURATION
# ------------------------------------------------------------

# Keep buffer at zero.
gds_renderer.options[
    "no_cheese"
]["buffer"] = "0um"

# Do NOT write no-cheese geometry into the GDS.
gds_renderer.options[
    "no_cheese"
]["view_in_file"]["main"][1] = False

# ------------------------------------------------------------
# 7. VERIFY NO-CHEESE SETTING
# ------------------------------------------------------------

print("=" * 70)
print("NO-CHEESE CONFIGURATION")
print("=" * 70)

print(
    gds_renderer.options["no_cheese"]
)

if (
    gds_renderer.options["no_cheese"]
    ["view_in_file"]["main"][1]
    is not False
):
    raise RuntimeError(
        "No-cheese layer is still enabled for GDS output."
    )

print("[PASS] No-cheese GDS output disabled")

# ------------------------------------------------------------
# 8. IMPORTANT — NO GDS HEALING
# ------------------------------------------------------------

# DO NOT run:
#
#     design.renderers.gds.heal_gds(...)
#
# The exported geometry must remain the direct
# Qiskit Metal renderer output.

# ------------------------------------------------------------
# 9. EXPORT
# ------------------------------------------------------------

print("=" * 70)
print("EXPORTING CLEAN PALACE TARGET GDS")
print("=" * 70)

print(
    f"PALACE ROOT : {PALACE_ROOT}"
)

print(
    "Chip size    : 10 mm × 10 mm"
)

print(
    f"GDS OUTPUT   : {output_gds_path}"
)

gds_renderer.export_to_gds(
    output_gds_path
)

# ------------------------------------------------------------
# 10. VERIFY FILE
# ------------------------------------------------------------

if not os.path.isfile(
    output_gds_path
):
    raise RuntimeError(
        f"GDS export failed:\n{output_gds_path}"
    )

file_size = os.path.getsize(
    output_gds_path
)

if file_size == 0:
    raise RuntimeError(
        "GDS file was created but is empty."
    )

# ------------------------------------------------------------
# 11. SHA256
# ------------------------------------------------------------

sha256 = hashlib.sha256()

with open(
    output_gds_path,
    "rb"
) as f:

    for chunk in iter(
        lambda: f.read(1024 * 1024),
        b""
    ):
        sha256.update(chunk)

gds_sha256 = sha256.hexdigest()

# ------------------------------------------------------------
# 12. FINAL STATUS
# ------------------------------------------------------------

print("=" * 70)
print("CLEAN GDS EXPORT COMPLETE")
print("=" * 70)

print(
    f"GDS:\n{output_gds_path}"
)

print(
    f"Size: {file_size:,} bytes"
)

print(
    f"SHA256:\n{gds_sha256}"
)

print("=" * 70)
print("STATUS")
print("=" * 70)

print("[PASS] PALACE root = meshesv3")
print("[PASS] 10 mm × 10 mm chip")
print("[PASS] Target qubit geometry retained")
print("[PASS] JJ library configured")
print("[PASS] JJ pad overlap = 5 um")
print("[PASS] No-cheese buffer = 0 um")
print("[PASS] No-cheese layer excluded from GDS")
print("[PASS] No GDS healing")
print("[PASS] No post-export modification")
print("[PASS] GDS file verified")
print("=" * 70)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/qiskit_metal/renderers/renderer_gds/gds_renderer.py:691: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   geopandas.GeoDataFrame(pd.concat(copy_subtract, ignore_index=False))
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/qiskit_metal/renderers/renderer_gds/gds_renderer.py:695: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   geopandas.GeoDataFrame(pd.concat(copy_no_subtract, ignore_index=False))
#
# 04:28AM 05s INFO [import_junction_gds_file]: Rescaling imported junction library from unit=1e-06 to unit=0.001 (scale factor=0.001).
# 04:28AM 05s WARNING [_cheese_buffer_maker]: The bounding box for no-cheese is outside of chip size.
# Bounding box for chip is (-5.0, -5.0, 5.0, 5.0).
# Bounding box with no_cheese buffer is (-4.85, -6.35, 4.85, 3.16).
# ======================================================================
# NO-CHEESE CONFIGURATION
# ======================================================================
# {'datatype': '99', 'buffer': '0um', 'cap_style': '2', 'join_style': '2', 'view_in_file': {'main': {1: False}}}
# [PASS] No-cheese GDS output disabled
# ======================================================================
# EXPORTING CLEAN PALACE TARGET GDS
# ======================================================================
# PALACE ROOT : /content/drive/MyDrive/Palace6/meshesv3
# Chip size    : 10 mm × 10 mm
# GDS OUTPUT   : /content/drive/MyDrive/Palace6/meshesv3/gds/quantum_chip_TARGET_GEOMETRY_v14_4_CLEAN.gds
# ======================================================================
# CLEAN GDS EXPORT COMPLETE
# ======================================================================
# GDS:
# /content/drive/MyDrive/Palace6/meshesv3/gds/quantum_chip_TARGET_GEOMETRY_v14_4_CLEAN.gds
# Size: 2,433,044 bytes
# SHA256:
# f6a094f017983b3831ffb682f9cdd66f1ab108944682b223405a91b893a678c5
# ======================================================================
# STATUS
# ======================================================================
# [PASS] PALACE root = meshesv3
# [PASS] 10 mm × 10 mm chip
# [PASS] Target qubit geometry retained
# [PASS] JJ library configured
# [PASS] JJ pad overlap = 5 um
# [PASS] No-cheese buffer = 0 um
# [PASS] No-cheese layer excluded from GDS
# [PASS] No GDS healing
# [PASS] No post-export modification
# [PASS] GDS file verified
# ======================================================================

# %%
print("Full GDS renderer no_cheese setting:")
print(gds_renderer.options.get("no_cheese"))
# Out:
# Full GDS renderer no_cheese setting:
# {'datatype': '99', 'buffer': '0um', 'cap_style': '2', 'join_style': '2', 'view_in_file': {'main': {1: True}}}

# %%
# # ============================================================
# # PALACE V14.4 — BASELINE PALACE SIMULATION-FRIENDLY GDS EXPORT
# # ============================================================

# import os
# import hashlib

# # ------------------------------------------------------------
# # 1. OUTPUT PATH
# # ------------------------------------------------------------

# PALACE_ROOT = "/content/drive/MyDrive/Palace6/meshesv2"

# GDS_DIR = os.path.join(
#     PALACE_ROOT,
#     "gds"
# )

# os.makedirs(
#     GDS_DIR,
#     exist_ok=True
# )

# output_gds_path = os.path.join(
#     GDS_DIR,
#     "quantum_chip_PALACE_SIMULATION_v14_4.gds"
# )

# # ------------------------------------------------------------
# # 2. CHIP SIZE
# # ------------------------------------------------------------

# design.chips.main.size.size_x = "14mm"
# design.chips.main.size.size_y = "14mm"

# design.rebuild()

# # ------------------------------------------------------------
# # 3. GDS RENDERER
# # ------------------------------------------------------------

# gds_renderer = design.renderers.gds

# # ------------------------------------------------------------
# # 4. SIMULATION-FRIENDLY JJ LIBRARY
# # ------------------------------------------------------------

# junction_gds = (
#     "/content/qiskit-metal/tutorials/resources/"
#     "Fake_Junctions.GDS"
# )

# if not os.path.isfile(junction_gds):
#     raise FileNotFoundError(
#         f"JJ library not found:\n{junction_gds}"
#     )

# gds_renderer.options[
#     "path_filename"
# ] = junction_gds

# # ------------------------------------------------------------
# # 5. GDS GEOMETRY SETTINGS
# # ------------------------------------------------------------

# gds_renderer.options[
#     "precision"
# ] = "0.000000001"

# gds_renderer.options[
#     "tolerance"
# ] = "0.00001"

# gds_renderer.options[
#     "corners"
# ] = "natural"

# # ------------------------------------------------------------
# # 6. JJ PAD OVERLAP
# # ------------------------------------------------------------

# gds_renderer.options[
#     "junction_pad_overlap"
# ] = "5um"

# # ------------------------------------------------------------
# # 7. NO-CHEESE BUFFER
# # ------------------------------------------------------------

# gds_renderer.options[
#     "no_cheese"
# ]["buffer"] = "10um"

# # ------------------------------------------------------------
# # 8. IMPORTANT:
# #    DO NOT HEAL THE GDS
# # ------------------------------------------------------------

# # DO NOT run:
# #
# #     design.renderers.gds.heal_gds(...)
# #
# # or any equivalent GDS healing operation.
# #
# # The exported geometry must remain the direct renderer output.

# # ------------------------------------------------------------
# # 9. EXPORT
# # ------------------------------------------------------------

# print("=" * 70)
# print("EXPORTING BASELINE PALACE SIMULATION GDS")
# print("=" * 70)

# gds_renderer.export_to_gds(
#     output_gds_path
# )

# # ------------------------------------------------------------
# # 10. VERIFY FILE
# # ------------------------------------------------------------

# if not os.path.isfile(
#     output_gds_path
# ):
#     raise RuntimeError(
#         f"GDS export failed:\n{output_gds_path}"
#     )

# file_size = os.path.getsize(
#     output_gds_path
# )

# # ------------------------------------------------------------
# # 11. SHA256
# # ------------------------------------------------------------

# sha256 = hashlib.sha256()

# with open(
#     output_gds_path,
#     "rb"
# ) as f:

#     for chunk in iter(
#         lambda: f.read(1024 * 1024),
#         b""
#     ):
#         sha256.update(
#             chunk
#         )

# gds_sha256 = sha256.hexdigest()

# # ------------------------------------------------------------
# # 12. FINAL OUTPUT
# # ------------------------------------------------------------

# print("=" * 70)
# print("BASELINE GDS EXPORT COMPLETE")
# print("=" * 70)

# print(
#     f"GDS:\n{output_gds_path}"
# )

# print(
#     f"Size: {file_size:,} bytes"
# )

# print(
#     f"SHA256:\n{gds_sha256}"
# )

# print("=" * 70)
# print("IMPORTANT")
# print("=" * 70)

# print(
#     "This GDS is the untouched baseline simulation export."
# )

# print(
#     "Do NOT heal, modify, or overwrite this file."
# )

# print(
#     "Next step: READ-ONLY GDS geometry/topology audit."
# )

# print("=" * 70)

# %%
import os
import warnings

# Suppress pandas/geopandas FutureWarning related to empty DataFrame concatenation
warnings.simplefilter(action='ignore', category=FutureWarning)

# 1. Force headless environment settings
os.environ["QT_QPA_PLATFORM"] = "offscreen"
os.environ["MPLBACKEND"] = "Agg"

# 3. Configure chip dimensions (Expanded further to 14 mm x 14 mm to comfortably fit the -6.36mm bounding box requirement)
design.chips.main.size.size_x = "14mm"
design.chips.main.size.size_y = "14mm"

# Rebuild design to apply the new chip dimensions before rendering/exporting
design.rebuild()

# 8. Configure GDS renderer path, precision, and healing options
gds_renderer = design.renderers.gds
gds_renderer.options['path_filename'] = './qiskit-metal/tutorials/resources/Fake_Junctions.GDS'

# Set precision and coordinate tolerances for clean geometry generation
gds_renderer.options['precision'] = '0.000000001'
gds_renderer.options['tolerance'] = '0.00001'
gds_renderer.options['corners'] = 'natural'

# Adjust no-cheese buffer size to prevent boundary warnings
gds_renderer.options['no_cheese']['buffer'] = '10um'

# 9. Perform geometry healing / cleanup if supported by the renderer backend
# if hasattr(gds_renderer, 'heal_gds'):
#     gds_renderer.heal_gds()

# 10. Export the final GDS file for KLayout and AWS Palace
output_gds_path = 'quantum_chip_export_manuscript3.gds'
gds_renderer.export_to_gds(output_gds_path)


# # ==========================================
# # STEP 4: Execution Based on Target Backend
# # ==========================================
# if SIMULATION_BACKEND == "palace":
#     # Export GDS file for Open-Source Workflow (Gmsh + AWS Palace)
#     output_gds_path = 'quantum_chip_export_manuscript.gds'
#     gds_renderer.export_to_gds(output_gds_path)
#     print(f"[Backend: Palace] Successfully exported GDS for mesh generation: {output_gds_path}")

# elif SIMULATION_BACKEND == "hfss":
#     # Target Ansys HFSS (Eigenmode / Driven Modal) via Qiskit Metal Ansys Renderer
#     ansys_hfss = design.renderers.ansys  # or design.renderers.aedt_hfss
#     ansys_hfss.start()
#     ansys_hfss.activate_ansys_design("Quantum_HFSS_Design", "eigenmode")
#     ansys_hfss.render_design()
#     print("[Backend: Ansys HFSS] Design successfully rendered into Ansys Electronics Desktop.")

# elif SIMULATION_BACKEND == "q3d":
#     # Target Ansys Q3D Extractor for Capacitance/Inductance Matrix Extraction
#     ansys_q3d = design.renderers.q3d
#     ansys_q3d.start()
#     ansys_q3d.activate_ansys_design("Quantum_Q3D_Design", "capacitance")
#     ansys_q3d.render_design()
#     print("[Backend: Ansys Q3D] Design successfully rendered into Q3D Extractor.")

print(f"Successfully generated, healed, and exported quantum chip layout to: {output_gds_path}")
# Out:
# 04:43PM 14s INFO [import_junction_gds_file]: Rescaling imported junction library from unit=1e-06 to unit=0.001 (scale factor=0.001).
# Successfully generated, healed, and exported quantum chip layout to: quantum_chip_export_manuscript3.gds

# %%
# import os

# print("File size:", os.path.getsize("my_transmon_design.gds"), "bytes")
# Out:
# File size: 1126582 bytes

# %%
# # ==========================================
# # STEP 4: Backend Selector Configuration (AWS Palace Simulation Target)
# # ==========================================
# # Choose your Palace physics type:
# # - "Eigenmode"     (Full-wave RF / Resonator / Qubit modes -> HFSS Equivalent)
# # - "Electrostatic" (Capacitance matrix extraction -> Q3D Equivalent)
# # - "Magnetostatic" (Inductance matrix extraction -> Q3D Equivalent)
# SIMULATION_PHYSICS_TYPE = "Eigenmode"

# palace_config = {
#     "Problem": {
#         "Type": "Eigenmode",
#         "Output": "postpro",
#         "Verbose": 2
#     },
#     "Model": {
#         "Mesh": "quantum_chip_mesh.msh",
#         "Refinement": {
#             "L0": 10.0e-2
#         },
#     "Domains": {
#         "Materials": [
#             {
#                 "Attributes": [1],  # Vacuum Box
#                 "Permittivity": 1.0,
#                 "Permeability": 1.0
#             },
#             {
#                 "Attributes": [2],  # Silicon substrate
#                 "Permittivity": 11.7,
#                 "Permeability": 1.0
#             }
#         ]
#     },
#     "Boundaries": {
#         "PEC": {
#             "Attributes": [10]  # Ground plane and superconducting traces
#         },
#         "LumpedPort": [
#             {
#                 "Attributes": [4],  # Assigned across Josephson junction or readout feedline
#                 "Resistance": 0.0,
#                 "Inductance": 1.2e-9
#             }
#         ]
#     },
#     "Solver": {
#         "Eigenmode": {
#             "N": 4,
#             "Target": 6.0,
#             "Tol": 1.0e-8,
#             "MaxIts": 200
#         },
#         "Linear": {
#             "Type": "BoomerAMG",
#             "Tolerance": 1e-8,
#             "MaxIts": 100
#         }
#     }
# }

# config_file_path = 'palace_config.json'
# import json
# with open(config_file_path, 'w') as f:
#     json.dump(palace_config, f, indent=4)

# print(f"AWS Palace configuration file generated for [{SIMULATION_PHYSICS_TYPE}]: {config_file_path}")

# %%
# !pip install -q gmsh gdspy shapely
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.9/157.9 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for gdspy (setup.py) ... done

# %%
# ============================================================
# STEP 5
# GDS -> 3D Gmsh Mesh for AWS Palace
#
# 4 Concentric Transmons
# ----------------------
# Q1 = JJ1 + JJ2
# Q2 = JJ1 + JJ2
# Q3 = JJ1 + JJ2
# Q4 = JJ1 + JJ2
#
# Total JJs = 8
#
# Other structures:
#   4 qubit-qubit couplers
#   4 readout resonators
#   4 readout finger capacitors
#   4 XY drive lines
#   4 flux-bias lines
#
# Physical groups:
#
#   1   = Vacuum
#   2   = Silicon substrate
#   10  = Superconducting metal / PEC
#
#   20  = Q1_JJ1
#   21  = Q1_JJ2
#   22  = Q2_JJ1
#   23  = Q2_JJ2
#   24  = Q3_JJ1
#   25  = Q3_JJ2
#   26  = Q4_JJ1
#   27  = Q4_JJ2
#
# Output:
#   quantum_chip_mesh.msh
# ============================================================

import os
import json
import math

import gmsh
import gdspy


# ============================================================
# USER CONFIGURATION
# ============================================================

GDS_PATH = "quantum_chip_export_manuscript.gds"

MESH_OUTPUT = "quantum_chip_mesh.msh"


# ------------------------------------------------------------
# Coordinate units
#
# Qiskit Metal GDS is normally handled in micrometers.
#
# If the numerical coordinates in your GDS are µm:
#
#     GDS_SCALE = 1.0
#
# If they are nm:
#
#     GDS_SCALE = 1e-3
# ------------------------------------------------------------

GDS_SCALE = 1.0


# ============================================================
# CHIP GEOMETRY
# ============================================================

# 14 mm × 14 mm chip
CHIP_X = 14000.0       # µm
CHIP_Y = 14000.0       # µm

# Silicon thickness
SUBSTRATE_THICKNESS = 500.0       # µm

# Vacuum height
AIR_HEIGHT = 3000.0               # µm


# ============================================================
# MATERIAL / PHYSICAL GROUP IDs
# ============================================================

VACUUM_ID = 1
SUBSTRATE_ID = 2

PEC_ID = 10


# ------------------------------------------------------------
# Eight Josephson junctions
# ------------------------------------------------------------

JJ_GROUPS = {
    "Q1_JJ1": 20,
    "Q1_JJ2": 21,

    "Q2_JJ1": 22,
    "Q2_JJ2": 23,

    "Q3_JJ1": 24,
    "Q3_JJ2": 25,

    "Q4_JJ1": 26,
    "Q4_JJ2": 27,
}


# ============================================================
# GDS LAYERS
# ============================================================

# IMPORTANT
#
# Set this to the GDS layer containing your superconducting
# metal after inspecting the printed layer list.
#
# Example:
#
#     METAL_LAYER = 1
#
# ------------------------------------------------------------

METAL_LAYER = None


# ------------------------------------------------------------
# Dedicated JJ layer
#
# If your JJs are exported on a separate GDS layer:
#
#     JJ_LAYER = 2
#
# Otherwise leave:
#
#     JJ_LAYER = None
#
# ------------------------------------------------------------

JJ_LAYER = None


# ============================================================
# MESH PARAMETERS
# ============================================================

# Global mesh
GLOBAL_MIN_SIZE = 5.0
GLOBAL_MAX_SIZE = 100.0

# Around superconducting metal
METAL_SIZE = 5.0

# Around JJ
JJ_SIZE = 0.5


# ============================================================
# HELPER FUNCTIONS
# ============================================================

def clean_polygon(points, tolerance=1e-9):

    cleaned = []

    for point in points:

        x = float(point[0])
        y = float(point[1])

        if len(cleaned) == 0:
            cleaned.append((x, y))
            continue

        px, py = cleaned[-1]

        if (
            abs(x - px) > tolerance
            or
            abs(y - py) > tolerance
        ):
            cleaned.append((x, y))

    # Remove duplicate closing point
    if len(cleaned) > 2:

        x0, y0 = cleaned[0]
        x1, y1 = cleaned[-1]

        if (
            abs(x0 - x1) < tolerance
            and
            abs(y0 - y1) < tolerance
        ):
            cleaned.pop()

    return cleaned


def polygon_area(points):

    area = 0.0

    for i in range(len(points)):

        x1, y1 = points[i]

        x2, y2 = points[
            (i + 1) % len(points)
        ]

        area += (
            x1 * y2
            -
            x2 * y1
        )

    return abs(area) / 2.0


def create_gmsh_surface(points, z=0.0):

    """
    Convert one 2D polygon into a Gmsh planar surface.
    """

    point_tags = []

    for x, y in points:

        tag = gmsh.model.occ.addPoint(
            x * GDS_SCALE,
            y * GDS_SCALE,
            z
        )

        point_tags.append(tag)

    line_tags = []

    for i in range(len(point_tags)):

        p1 = point_tags[i]

        p2 = point_tags[
            (i + 1) % len(point_tags)
        ]

        line = gmsh.model.occ.addLine(
            p1,
            p2
        )

        line_tags.append(line)

    wire = gmsh.model.occ.addWire(
        line_tags
    )

    surface = gmsh.model.occ.addPlaneSurface(
        [wire]
    )

    return surface


# ============================================================
# READ GDS
# ============================================================

def read_gds_polygons(gds_path):

    print("\n" + "=" * 70)
    print("READING GDS")
    print("=" * 70)

    library = gdspy.GdsLibrary()

    library.read_gds(
        gds_path
    )

    polygons = []

    for cell_name, cell in library.cells.items():

        polygons_by_spec = cell.get_polygons(
            by_spec=True
        )

        for spec, cell_polygons in polygons_by_spec.items():

            layer = spec[0]
            datatype = spec[1]

            for polygon in cell_polygons:

                points = clean_polygon(
                    polygon
                )

                if len(points) < 3:
                    continue

                area = polygon_area(
                    points
                )

                if area <= 0:
                    continue

                polygons.append(
                    {
                        "cell": cell_name,
                        "layer": layer,
                        "datatype": datatype,
                        "points": points,
                        "area": area,
                    }
                )

    return polygons


# ============================================================
# PRINT LAYER INFORMATION
# ============================================================

def print_layer_information(polygons):

    print("\n" + "=" * 70)
    print("GDS LAYER INFORMATION")
    print("=" * 70)

    statistics = {}

    for polygon in polygons:

        key = (
            polygon["layer"],
            polygon["datatype"]
        )

        if key not in statistics:
            statistics[key] = {
                "count": 0,
                "area": 0.0
            }

        statistics[key]["count"] += 1
        statistics[key]["area"] += polygon["area"]

    for key in sorted(statistics):

        layer, datatype = key

        count = statistics[key]["count"]
        area = statistics[key]["area"]

        print(
            f"Layer={layer:3d}  "
            f"Datatype={datatype:3d}  "
            f"Polygons={count:6d}  "
            f"TotalArea={area:.3f}"
        )


# ============================================================
# BUILD MESH
# ============================================================

def generate_palace_mesh():

    if not os.path.exists(GDS_PATH):

        raise FileNotFoundError(
            f"GDS file not found:\n{GDS_PATH}"
        )

    # --------------------------------------------------------
    # Read GDS
    # --------------------------------------------------------

    polygons = read_gds_polygons(
        GDS_PATH
    )

    print(
        f"\nTotal GDS polygons: {len(polygons)}"
    )

    print_layer_information(
        polygons
    )


    # --------------------------------------------------------
    # Check metal layer
    # --------------------------------------------------------

    if METAL_LAYER is None:

        print(
            "\nWARNING:"
        )

        print(
            "METAL_LAYER is currently None."
        )

        print(
            "The code will import all GDS layers "
            "as metal surfaces."
        )

        print(
            "For the final simulation, specify "
            "the actual superconducting-metal layer."
        )


    # ========================================================
    # INITIALIZE GMSH
    # ========================================================

    print("\n" + "=" * 70)
    print("INITIALIZING GMSH")
    print("=" * 70)

    gmsh.initialize()

    gmsh.option.setNumber(
        "General.Terminal",
        1
    )

    gmsh.model.add(
        "concentric_transmon_4q"
    )


    try:

        # ====================================================
        # SUBSTRATE
        # ====================================================

        print("\nCreating silicon substrate...")

        substrate = gmsh.model.occ.addBox(

            -CHIP_X / 2,

            -CHIP_Y / 2,

            -SUBSTRATE_THICKNESS,

            CHIP_X,

            CHIP_Y,

            SUBSTRATE_THICKNESS
        )


        # ====================================================
        # VACUUM
        # ====================================================

        print("Creating vacuum region...")

        vacuum = gmsh.model.occ.addBox(

            -CHIP_X / 2,

            -CHIP_Y / 2,

            0.0,

            CHIP_X,

            CHIP_Y,

            AIR_HEIGHT
        )


        # ====================================================
        # METAL SURFACES
        # ====================================================

        print(
            "\nCreating superconducting metal surfaces..."
        )

        metal_surfaces = []

        jj_surfaces = {
            name: []
            for name in JJ_GROUPS
        }


        for polygon in polygons:

            layer = polygon["layer"]

            # ------------------------------------------------
            # Determine whether polygon belongs to metal
            # ------------------------------------------------

            if METAL_LAYER is not None:

                if layer != METAL_LAYER:
                    continue

            else:

                # During initial inspection all layers pass
                pass


            # ------------------------------------------------
            # Dedicated JJ layer
            # ------------------------------------------------

            if (
                JJ_LAYER is not None
                and
                layer == JJ_LAYER
            ):

                # JJ polygons are handled separately below
                continue


            # ------------------------------------------------
            # Normal superconducting metal
            # ------------------------------------------------

            try:

                surface = create_gmsh_surface(
                    polygon["points"],
                    z=0.0
                )

                metal_surfaces.append(
                    surface
                )

            except Exception as exc:

                print(
                    "Metal polygon conversion warning:",
                    exc
                )


        print(
            f"Created {len(metal_surfaces)} "
            f"superconducting metal surfaces."
        )


        # ====================================================
        # JJ PROCESSING
        # ====================================================

        if JJ_LAYER is not None:

            print(
                "\nProcessing JJ layer..."
            )

            jj_polygons = [

                p
                for p in polygons

                if p["layer"] == JJ_LAYER
            ]

            print(
                f"JJ-layer polygons found: "
                f"{len(jj_polygons)}"
            )


            # ------------------------------------------------
            # IMPORTANT:
            #
            # We expect exactly 8 JJs.
            #
            # We do NOT blindly assume polygon ordering.
            #
            # For now, sort by centroid X/Y and print them.
            # ------------------------------------------------

            jj_info = []

            for polygon in jj_polygons:

                points = polygon["points"]

                cx = sum(
                    p[0]
                    for p in points
                ) / len(points)

                cy = sum(
                    p[1]
                    for p in points
                ) / len(points)

                jj_info.append(
                    {
                        "polygon": polygon,
                        "cx": cx,
                        "cy": cy,
                        "area": polygon["area"]
                    }
                )


            jj_info.sort(
                key=lambda p: (
                    p["cy"],
                    p["cx"]
                )
            )


            print("\nDetected JJ candidates:")

            for i, info in enumerate(
                jj_info
            ):

                print(
                    f"  Candidate {i + 1}: "
                    f"x={info['cx']:.3f}, "
                    f"y={info['cy']:.3f}, "
                    f"area={info['area']:.3f}"
                )


            if len(jj_info) != 8:

                raise RuntimeError(
                    "\nExpected exactly 8 JJ polygons "
                    f"but found {len(jj_info)}.\n"
                    "Check JJ_LAYER and the GDS export."
                )


            # ------------------------------------------------
            # TEMPORARY deterministic mapping
            #
            # IMPORTANT:
            # This ordering must be verified against
            # your actual GDS geometry.
            # ------------------------------------------------

            jj_names = [
                "Q1_JJ1",
                "Q1_JJ2",

                "Q2_JJ1",
                "Q2_JJ2",

                "Q3_JJ1",
                "Q3_JJ2",

                "Q4_JJ1",
                "Q4_JJ2",
            ]


            for name, info in zip(
                jj_names,
                jj_info
            ):

                surface = create_gmsh_surface(
                    info["polygon"]["points"],
                    z=0.0
                )

                jj_surfaces[name].append(
                    surface
                )


        # ====================================================
        # SYNCHRONIZE OCC
        # ====================================================

        gmsh.model.occ.synchronize()


        # ====================================================
        # PHYSICAL VOLUMES
        # ====================================================

        print(
            "\nCreating physical volume groups..."
        )

        gmsh.model.addPhysicalGroup(
            3,
            [vacuum],
            VACUUM_ID
        )

        gmsh.model.setPhysicalName(
            3,
            VACUUM_ID,
            "Vacuum"
        )


        gmsh.model.addPhysicalGroup(
            3,
            [substrate],
            SUBSTRATE_ID
        )

        gmsh.model.setPhysicalName(
            3,
            SUBSTRATE_ID,
            "Silicon_Substrate"
        )


        # ====================================================
        # PEC GROUP
        # ====================================================

        if metal_surfaces:

            gmsh.model.addPhysicalGroup(
                2,
                metal_surfaces,
                PEC_ID
            )

            gmsh.model.setPhysicalName(
                2,
                PEC_ID,
                "Superconducting_Metal"
            )


        # ====================================================
        # JJ PHYSICAL GROUPS
        # ====================================================

        if JJ_LAYER is not None:

            print(
                "\nCreating eight JJ physical groups..."
            )

            for name, group_id in JJ_GROUPS.items():

                surfaces = jj_surfaces[name]

                if not surfaces:

                    raise RuntimeError(
                        f"No geometry found for {name}"
                    )

                gmsh.model.addPhysicalGroup(
                    2,
                    surfaces,
                    group_id
                )

                gmsh.model.setPhysicalName(
                    2,
                    group_id,
                    name
                )

                print(
                    f"  {group_id:2d} -> {name}"
                )


        # ====================================================
        # MESH SETTINGS
        # ====================================================

        print(
            "\nSetting mesh parameters..."
        )

        gmsh.option.setNumber(
            "Mesh.Algorithm3D",
            1
        )

        gmsh.option.setNumber(
            "Mesh.CharacteristicLengthMin",
            GLOBAL_MIN_SIZE
        )

        gmsh.option.setNumber(
            "Mesh.CharacteristicLengthMax",
            GLOBAL_MAX_SIZE
        )


        # ====================================================
        # JJ LOCAL REFINEMENT
        # ====================================================

        if JJ_LAYER is not None:

            print(
                "Applying fine JJ mesh..."
            )

            jj_points = []

            for name in jj_surfaces:

                for surface in jj_surfaces[name]:

                    boundary = (
                        gmsh.model.getBoundary(
                            [(2, surface)],
                            oriented=False,
                            recursive=True
                        )
                    )

                    for dim, tag in boundary:

                        if dim == 0:

                            jj_points.append(
                                tag
                            )


            jj_points = list(
                set(jj_points)
            )


            if jj_points:

                distance_field = (
                    gmsh.model.mesh.field.add(
                        "Distance"
                    )
                )

                gmsh.model.mesh.field.setNumbers(
                    distance_field,
                    "NodesList",
                    jj_points
                )

                threshold_field = (
                    gmsh.model.mesh.field.add(
                        "Threshold"
                    )
                )

                gmsh.model.mesh.field.setNumber(
                    threshold_field,
                    "InField",
                    distance_field
                )

                gmsh.model.mesh.field.setNumber(
                    threshold_field,
                    "SizeMin",
                    JJ_SIZE
                )

                gmsh.model.mesh.field.setNumber(
                    threshold_field,
                    "SizeMax",
                    GLOBAL_MAX_SIZE
                )

                gmsh.model.mesh.field.setNumber(
                    threshold_field,
                    "DistMin",
                    5.0
                )

                gmsh.model.mesh.field.setNumber(
                    threshold_field,
                    "DistMax",
                    100.0
                )

                gmsh.model.mesh.field.setAsBackgroundMesh(
                    threshold_field
                )


        # ====================================================
        # GENERATE 3D MESH
        # ====================================================

        print(
            "\nGenerating 3D tetrahedral mesh..."
        )

        gmsh.model.mesh.generate(
            3
        )


        # ====================================================
        # OPTIMIZATION
        # ====================================================

        print(
            "Optimizing mesh..."
        )

        try:

            gmsh.model.mesh.optimize(
                "Netgen"
            )

        except Exception as exc:

            print(
                "Optimization warning:",
                exc
            )


        # ====================================================
        # MESH STATISTICS
        # ====================================================

        node_tags, node_coords, _ = (
            gmsh.model.mesh.getNodes()
        )

        print(
            "\nMesh statistics:"
        )

        print(
            f"  Nodes    : {len(node_tags)}"
        )


        element_types, element_tags, _ = (
            gmsh.model.mesh.getElements()
        )

        total_elements = sum(
            len(tags)
            for tags in element_tags
        )

        print(
            f"  Elements : {total_elements}"
        )


        # ====================================================
        # PHYSICAL GROUP REPORT
        # ====================================================

        print(
            "\nPhysical groups:"
        )

        for dim, tag in (
            gmsh.model.getPhysicalGroups()
        ):

            name = (
                gmsh.model.getPhysicalName(
                    dim,
                    tag
                )
            )

            print(
                f"  Dimension={dim}, "
                f"Attribute={tag}, "
                f"Name={name}"
            )


        # ====================================================
        # WRITE MESH
        # ====================================================

        print(
            "\nWriting mesh:"
        )

        print(
            os.path.abspath(
                MESH_OUTPUT
            )
        )

        gmsh.write(
            MESH_OUTPUT
        )

        print(
            "\n" + "=" * 70
        )

        print(
            "SUCCESS: Gmsh mesh generated"
        )

        print(
            "=" * 70
        )


    finally:

        gmsh.finalize()

        print(
            "\nGmsh finalized."
        )


# ============================================================
# RUN
# ============================================================

generate_palace_mesh()
# Out:
# ======================================================================
# READING GDS
# ======================================================================
#
# Total GDS polygons: 186279
#
# ======================================================================
# GDS LAYER INFORMATION
# ======================================================================
# Layer=  1  Datatype=  0  Polygons=  9800  TotalArea=743.003
# Layer=  1  Datatype= 10  Polygons=   286  TotalArea=1.407
# Layer=  1  Datatype= 11  Polygons=   747  TotalArea=4.016
# Layer=  1  Datatype= 99  Polygons=    90  TotalArea=40.418
# Layer=  1  Datatype=100  Polygons=105192  TotalArea=699.767
# Layer=  1  Datatype=101  Polygons= 70120  TotalArea=43.284
# Layer=  1  Datatype=102  Polygons=     4  TotalArea=0.002
# Layer= 53  Datatype=  0  Polygons=    37  TotalArea=0.002
# Layer= 54  Datatype=  0  Polygons=     3  TotalArea=0.000
#
# WARNING:
# METAL_LAYER is currently None.
# The code will import all GDS layers as metal surfaces.
# For the final simulation, specify the actual superconducting-metal layer.
#
# ======================================================================
# INITIALIZING GMSH
# ======================================================================
#
# Creating silicon substrate...
# Creating vacuum region...
#
# Creating superconducting metal surfaces...
# Created 186279 superconducting metal surfaces.
#
# Creating physical volume groups...
#
# Setting mesh parameters...
#
# Generating 3D tetrahedral mesh...
# Optimizing mesh...
#
# Mesh statistics:
#   Nodes    : 1863402
#   Elements : 6372526
#
# Physical groups:
#   Dimension=2, Attribute=10, Name=Superconducting_Metal
#   Dimension=3, Attribute=1, Name=Vacuum
#   Dimension=3, Attribute=2, Name=Silicon_Substrate
#
# Writing mesh:
# /content/quantum_chip_mesh.msh
#
# ======================================================================
# SUCCESS: Gmsh mesh generated
# ======================================================================
#
# Gmsh finalized.

# %%
import gdspy
import os

GDS_PATH = "quantum_chip_export_manuscript.gds"

lib = gdspy.GdsLibrary()
lib.read_gds(GDS_PATH)

print("=" * 70)
print("GDS CELL INFORMATION")
print("=" * 70)

for name, cell in lib.cells.items():

    bbox = cell.get_bounding_box()

    print(f"\nCell: {name}")

    if bbox is not None:
        print(
            f"  Bounding box: "
            f"x={bbox[0][0]:.6f} to {bbox[1][0]:.6f}, "
            f"y={bbox[0][1]:.6f} to {bbox[1][1]:.6f}"
        )


print("\n" + "=" * 70)
print("LAYER / DATATYPE BOUNDING BOXES")
print("=" * 70)

for name, cell in lib.cells.items():

    polygons_by_spec = cell.get_polygons(
        by_spec=True
    )

    for spec, polygons in polygons_by_spec.items():

        layer, datatype = spec

        if not polygons:
            continue

        xmin = float("inf")
        xmax = float("-inf")
        ymin = float("inf")
        ymax = float("-inf")

        for poly in polygons:

            xmin = min(
                xmin,
                poly[:, 0].min()
            )

            xmax = max(
                xmax,
                poly[:, 0].max()
            )

            ymin = min(
                ymin,
                poly[:, 1].min()
            )

            ymax = max(
                ymax,
                poly[:, 1].max()
            )

        print(
            f"Layer={layer:3d}, "
            f"Datatype={datatype:3d}, "
            f"Polygons={len(polygons):7d}, "
            f"BBox=("
            f"{xmin:.3f}, {ymin:.3f}) -> "
            f"({xmax:.3f}, {ymax:.3f})"
        )
# Out:
# ======================================================================
# GDS CELL INFORMATION
# ======================================================================
#
# Cell: TOP
#   Bounding box: x=-7.000000 to 7.000000, y=-7.000000 to 7.000000
#
# Cell: TOP_main
#   Bounding box: x=-7.000000 to 7.000000, y=-7.000000 to 7.000000
#
# Cell: TOP_main_1
#   Bounding box: x=-7.000000 to 7.000000, y=-7.000000 to 7.000000
#
# Cell: ground_main_1
#   Bounding box: x=-7.000000 to 7.000000, y=-7.000000 to 7.000000
#
# Cell: my_other_junction
#   Bounding box: x=-0.015000 to 0.015000, y=-0.001500 to 0.001500
#
# Cell: FakeJunction_02
#   Bounding box: x=-0.015000 to 0.015000, y=-0.001500 to 0.001500
#
# Cell: FakeJunction_01
#   Bounding box: x=-0.015000 to 0.015000, y=-0.001503 to 0.001500
#
# Cell: pads_my_other_junction_QComponent_is_1_name_is_poly4
#   Bounding box: x=-0.017500 to 0.017500, y=-0.002500 to 0.002500
#
# Cell: pads_my_other_junction_QComponent_is_1_name_is_poly5
#   Bounding box: x=-0.017500 to 0.017500, y=-0.002500 to 0.002500
#
# Cell: pads_my_other_junction_QComponent_is_2_name_is_poly4
#   Bounding box: x=-0.017500 to 0.017500, y=-0.002500 to 0.002500
#
# Cell: pads_my_other_junction_QComponent_is_2_name_is_poly5
#   Bounding box: x=-0.017500 to 0.017500, y=-0.002500 to 0.002500
#
# Cell: pads_my_other_junction_QComponent_is_3_name_is_poly4
#   Bounding box: x=-0.017500 to 0.017500, y=-0.002500 to 0.002500
#
# Cell: pads_my_other_junction_QComponent_is_3_name_is_poly5
#   Bounding box: x=-0.017500 to 0.017500, y=-0.002500 to 0.002500
#
# Cell: pads_my_other_junction_QComponent_is_4_name_is_poly4
#   Bounding box: x=-0.017500 to 0.017500, y=-0.002500 to 0.002500
#
# Cell: pads_my_other_junction_QComponent_is_4_name_is_poly5
#   Bounding box: x=-0.017500 to 0.017500, y=-0.002500 to 0.002500
#
# Cell: TOP_main_1_NoCheese_99
#   Bounding box: x=-4.860000 to 4.860000, y=-6.360000 to 3.170000
#
# Cell: TOP_main_1_one_hole
#   Bounding box: x=-0.012500 to 0.012500, y=-0.012500 to 0.012500
#
# Cell: TOP_main_1_Cheese_diff
#   Bounding box: x=-6.812500 to 6.712500, y=-6.812500 to 6.712500
#
# Cell: TOP_main_1_Cheese_100
#   Bounding box: x=-7.000000 to 7.000000, y=-7.000000 to 7.000000
#
# ======================================================================
# LAYER / DATATYPE BOUNDING BOXES
# ======================================================================
# Layer=  1, Datatype= 10, Polygons=     90, BBox=(-4.802, -6.302) -> (4.802, 3.102)
# Layer=  1, Datatype= 11, Polygons=    249, BBox=(-4.500, -6.000) -> (4.500, 2.900)
# Layer=  1, Datatype=  0, Polygons=   2450, BBox=(-7.000, -7.000) -> (7.000, 7.000)
# Layer= 53, Datatype=  0, Polygons=      8, BBox=(-1.147, -2.701) -> (1.547, 0.002)
# Layer=  1, Datatype=102, Polygons=      1, BBox=(-0.012, -0.012) -> (0.012, 0.012)
# Layer=  1, Datatype=101, Polygons=  17530, BBox=(-6.812, -6.812) -> (6.712, 6.712)
# Layer=  1, Datatype=100, Polygons=  26298, BBox=(-7.000, -7.000) -> (7.000, 7.000)
# Layer=  1, Datatype= 99, Polygons=     30, BBox=(-4.860, -6.360) -> (4.860, 3.170)
# Layer=  1, Datatype= 10, Polygons=     90, BBox=(-4.802, -6.302) -> (4.802, 3.102)
# Layer=  1, Datatype= 11, Polygons=    249, BBox=(-4.500, -6.000) -> (4.500, 2.900)
# Layer=  1, Datatype=  0, Polygons=   2450, BBox=(-7.000, -7.000) -> (7.000, 7.000)
# Layer= 53, Datatype=  0, Polygons=      8, BBox=(-1.147, -2.701) -> (1.547, 0.002)
# Layer=  1, Datatype=102, Polygons=      1, BBox=(-0.012, -0.012) -> (0.012, 0.012)
# Layer=  1, Datatype=101, Polygons=  17530, BBox=(-6.812, -6.812) -> (6.712, 6.712)
# Layer=  1, Datatype=100, Polygons=  26298, BBox=(-7.000, -7.000) -> (7.000, 7.000)
# Layer=  1, Datatype= 99, Polygons=     30, BBox=(-4.860, -6.360) -> (4.860, 3.170)
# Layer=  1, Datatype= 10, Polygons=     90, BBox=(-4.802, -6.302) -> (4.802, 3.102)
# Layer=  1, Datatype= 11, Polygons=    249, BBox=(-4.500, -6.000) -> (4.500, 2.900)
# Layer=  1, Datatype=  0, Polygons=   2450, BBox=(-7.000, -7.000) -> (7.000, 7.000)
# Layer= 53, Datatype=  0, Polygons=      8, BBox=(-1.147, -2.701) -> (1.547, 0.002)
# Layer=  1, Datatype=102, Polygons=      1, BBox=(-0.012, -0.012) -> (0.012, 0.012)
# Layer=  1, Datatype=101, Polygons=  17530, BBox=(-6.812, -6.812) -> (6.712, 6.712)
# Layer=  1, Datatype=100, Polygons=  26298, BBox=(-7.000, -7.000) -> (7.000, 7.000)
# Layer=  1, Datatype=  0, Polygons=   2450, BBox=(-7.000, -7.000) -> (7.000, 7.000)
# Layer= 53, Datatype=  0, Polygons=      1, BBox=(-0.015, -0.002) -> (0.015, 0.002)
# Layer= 53, Datatype=  0, Polygons=      6, BBox=(-0.015, -0.002) -> (0.015, 0.002)
# Layer= 53, Datatype=  0, Polygons=      6, BBox=(-0.015, -0.002) -> (0.015, 0.002)
# Layer= 54, Datatype=  0, Polygons=      3, BBox=(-0.001, -0.001) -> (0.002, -0.000)
# Layer=  1, Datatype= 10, Polygons=      2, BBox=(-0.017, -0.003) -> (0.017, 0.003)
# Layer=  1, Datatype= 10, Polygons=      2, BBox=(-0.017, -0.003) -> (0.017, 0.003)
# Layer=  1, Datatype= 10, Polygons=      2, BBox=(-0.017, -0.003) -> (0.017, 0.003)
# Layer=  1, Datatype= 10, Polygons=      2, BBox=(-0.017, -0.003) -> (0.017, 0.003)
# Layer=  1, Datatype= 10, Polygons=      2, BBox=(-0.017, -0.003) -> (0.017, 0.003)
# Layer=  1, Datatype= 10, Polygons=      2, BBox=(-0.017, -0.003) -> (0.017, 0.003)
# Layer=  1, Datatype= 10, Polygons=      2, BBox=(-0.017, -0.003) -> (0.017, 0.003)
# Layer=  1, Datatype= 10, Polygons=      2, BBox=(-0.017, -0.003) -> (0.017, 0.003)
# Layer=  1, Datatype= 99, Polygons=     30, BBox=(-4.860, -6.360) -> (4.860, 3.170)
# Layer=  1, Datatype=102, Polygons=      1, BBox=(-0.012, -0.012) -> (0.012, 0.012)
# Layer=  1, Datatype=101, Polygons=  17530, BBox=(-6.812, -6.812) -> (6.712, 6.712)
# Layer=  1, Datatype=100, Polygons=  26298, BBox=(-7.000, -7.000) -> (7.000, 7.000)

# %%
import gdspy
import numpy as np

GDS_PATH =  "quantum_chip_export_manuscript.gds"

lib = gdspy.GdsLibrary()
lib.read_gds(GDS_PATH)

print("=" * 80)
print("JUNCTION-RELATED CELL GEOMETRY")
print("=" * 80)

jj_keywords = [
    "junction",
    "Junction",
    "FakeJunction",
    "my_other_junction",
    "pads_my_other_junction"
]

for cell_name, cell in lib.cells.items():

    if not any(
        key in cell_name
        for key in jj_keywords
    ):
        continue

    print("\n" + "-" * 80)
    print("CELL:", cell_name)

    polygons_by_spec = cell.get_polygons(
        by_spec=True
    )

    for spec, polygons in polygons_by_spec.items():

        layer, datatype = spec

        print(
            f"  Layer={layer}, "
            f"Datatype={datatype}, "
            f"Polygons={len(polygons)}"
        )

        for i, poly in enumerate(polygons):

            xmin = np.min(poly[:, 0])
            xmax = np.max(poly[:, 0])

            ymin = np.min(poly[:, 1])
            ymax = np.max(poly[:, 1])

            print(
                f"      polygon {i}: "
                f"bbox=({xmin:.6f}, {ymin:.6f}) "
                f"-> "
                f"({xmax:.6f}, {ymax:.6f}) "
                f"size=({xmax-xmin:.6f}, "
                f"{ymax-ymin:.6f})"
            )
# Out:
# ================================================================================
# JUNCTION-RELATED CELL GEOMETRY
# ================================================================================
#
# --------------------------------------------------------------------------------
# CELL: my_other_junction
#   Layer=53, Datatype=0, Polygons=1
#       polygon 0: bbox=(-0.015000, -0.001500) -> (0.015000, 0.001500) size=(0.030000, 0.003000)
#
# --------------------------------------------------------------------------------
# CELL: FakeJunction_02
#   Layer=53, Datatype=0, Polygons=6
#       polygon 0: bbox=(0.002000, -0.001500) -> (0.015000, 0.001500) size=(0.013000, 0.003000)
#       polygon 1: bbox=(-0.015000, -0.001500) -> (-0.002000, 0.001500) size=(0.013000, 0.003000)
#       polygon 2: bbox=(-0.002012, 0.000512) -> (-0.000035, 0.001489) size=(0.001977, 0.000977)
#       polygon 3: bbox=(-0.000012, -0.001500) -> (0.002024, -0.000500) size=(0.002036, 0.001000)
#       polygon 4: bbox=(-0.000989, -0.000512) -> (-0.000512, 0.000547) size=(0.000477, 0.001059)
#       polygon 5: bbox=(-0.000977, -0.001198) -> (0.000047, -0.000849) size=(0.001024, 0.000349)
#
# --------------------------------------------------------------------------------
# CELL: FakeJunction_01
#   Layer=53, Datatype=0, Polygons=6
#       polygon 0: bbox=(0.002000, -0.001500) -> (0.015000, 0.001500) size=(0.013000, 0.003000)
#       polygon 1: bbox=(-0.015000, -0.001500) -> (-0.002000, 0.001500) size=(0.013000, 0.003000)
#       polygon 2: bbox=(-0.001999, 0.000702) -> (-0.000378, 0.001477) size=(0.001621, 0.000775)
#       polygon 3: bbox=(0.000489, -0.001503) -> (0.002001, -0.000489) size=(0.001512, 0.001014)
#       polygon 4: bbox=(-0.000673, -0.000489) -> (-0.000396, 0.000701) size=(0.000277, 0.001190)
#       polygon 5: bbox=(-0.000636, -0.001005) -> (0.000507, -0.000774) size=(0.001143, 0.000231)
#   Layer=54, Datatype=0, Polygons=3
#       polygon 0: bbox=(-0.000627, -0.000765) -> (0.000507, -0.000618) size=(0.001134, 0.000147)
#       polygon 1: bbox=(0.000286, -0.000618) -> (0.000498, -0.000341) size=(0.000212, 0.000277)
#       polygon 2: bbox=(0.000498, -0.000489) -> (0.002019, -0.000360) size=(0.001521, 0.000129)
#
# --------------------------------------------------------------------------------
# CELL: pads_my_other_junction_QComponent_is_1_name_is_poly4
#   Layer=1, Datatype=10, Polygons=2
#       polygon 0: bbox=(-0.017500, -0.002500) -> (-0.010000, 0.002500) size=(0.007500, 0.005000)
#       polygon 1: bbox=(0.010000, -0.002500) -> (0.017500, 0.002500) size=(0.007500, 0.005000)
#
# --------------------------------------------------------------------------------
# CELL: pads_my_other_junction_QComponent_is_1_name_is_poly5
#   Layer=1, Datatype=10, Polygons=2
#       polygon 0: bbox=(-0.017500, -0.002500) -> (-0.010000, 0.002500) size=(0.007500, 0.005000)
#       polygon 1: bbox=(0.010000, -0.002500) -> (0.017500, 0.002500) size=(0.007500, 0.005000)
#
# --------------------------------------------------------------------------------
# CELL: pads_my_other_junction_QComponent_is_2_name_is_poly4
#   Layer=1, Datatype=10, Polygons=2
#       polygon 0: bbox=(-0.017500, -0.002500) -> (-0.010000, 0.002500) size=(0.007500, 0.005000)
#       polygon 1: bbox=(0.010000, -0.002500) -> (0.017500, 0.002500) size=(0.007500, 0.005000)
#
# --------------------------------------------------------------------------------
# CELL: pads_my_other_junction_QComponent_is_2_name_is_poly5
#   Layer=1, Datatype=10, Polygons=2
#       polygon 0: bbox=(-0.017500, -0.002500) -> (-0.010000, 0.002500) size=(0.007500, 0.005000)
#       polygon 1: bbox=(0.010000, -0.002500) -> (0.017500, 0.002500) size=(0.007500, 0.005000)
#
# --------------------------------------------------------------------------------
# CELL: pads_my_other_junction_QComponent_is_3_name_is_poly4
#   Layer=1, Datatype=10, Polygons=2
#       polygon 0: bbox=(-0.017500, -0.002500) -> (-0.010000, 0.002500) size=(0.007500, 0.005000)
#       polygon 1: bbox=(0.010000, -0.002500) -> (0.017500, 0.002500) size=(0.007500, 0.005000)
#
# --------------------------------------------------------------------------------
# CELL: pads_my_other_junction_QComponent_is_3_name_is_poly5
#   Layer=1, Datatype=10, Polygons=2
#       polygon 0: bbox=(-0.017500, -0.002500) -> (-0.010000, 0.002500) size=(0.007500, 0.005000)
#       polygon 1: bbox=(0.010000, -0.002500) -> (0.017500, 0.002500) size=(0.007500, 0.005000)
#
# --------------------------------------------------------------------------------
# CELL: pads_my_other_junction_QComponent_is_4_name_is_poly4
#   Layer=1, Datatype=10, Polygons=2
#       polygon 0: bbox=(-0.017500, -0.002500) -> (-0.010000, 0.002500) size=(0.007500, 0.005000)
#       polygon 1: bbox=(0.010000, -0.002500) -> (0.017500, 0.002500) size=(0.007500, 0.005000)
#
# --------------------------------------------------------------------------------
# CELL: pads_my_other_junction_QComponent_is_4_name_is_poly5
#   Layer=1, Datatype=10, Polygons=2
#       polygon 0: bbox=(-0.017500, -0.002500) -> (-0.010000, 0.002500) size=(0.007500, 0.005000)
#       polygon 1: bbox=(0.010000, -0.002500) -> (0.017500, 0.002500) size=(0.007500, 0.005000)

# %%
import gdspy

GDS_PATH = "quantum_chip_export_manuscript.gds"


lib = gdspy.GdsLibrary()
lib.read_gds(GDS_PATH)

print("=" * 80)
print("JUNCTION CELL REFERENCES")
print("=" * 80)

junction_names = {
    "my_other_junction",
    "FakeJunction_01",
    "FakeJunction_02",
}

for cell_name, cell in lib.cells.items():

    for ref in cell.references:

        ref_name = getattr(ref.ref_cell, "name", None)

        if ref_name in junction_names:

            print(
                f"Parent cell : {cell_name}"
            )

            print(
                f"Referenced  : {ref_name}"
            )

            print(
                f"Origin      : {ref.origin}"
            )

            print(
                f"Rotation    : {ref.rotation}"
            )

            print(
                f"Magnification: {ref.magnification}"
            )

            print("-" * 60)
# Out:
# ================================================================================
# JUNCTION CELL REFERENCES
# ================================================================================
# Parent cell : TOP_main_1
# Referenced  : my_other_junction
# Origin      : [-1.1325  0.    ]
# Rotation    : 180.0
# Magnification: None
# ------------------------------------------------------------
# Parent cell : TOP_main_1
# Referenced  : my_other_junction
# Origin      : [-0.8675  0.    ]
# Rotation    : None
# Magnification: None
# ------------------------------------------------------------
# Parent cell : TOP_main_1
# Referenced  : my_other_junction
# Origin      : [1.2675 0.    ]
# Rotation    : 180.0
# Magnification: None
# ------------------------------------------------------------
# Parent cell : TOP_main_1
# Referenced  : my_other_junction
# Origin      : [1.5325 0.    ]
# Rotation    : None
# Magnification: None
# ------------------------------------------------------------
# Parent cell : TOP_main_1
# Referenced  : my_other_junction
# Origin      : [-0.8675 -2.7   ]
# Rotation    : None
# Magnification: None
# ------------------------------------------------------------
# Parent cell : TOP_main_1
# Referenced  : my_other_junction
# Origin      : [-1.1325 -2.7   ]
# Rotation    : 180.0
# Magnification: None
# ------------------------------------------------------------
# Parent cell : TOP_main_1
# Referenced  : my_other_junction
# Origin      : [ 1.5325 -2.7   ]
# Rotation    : None
# Magnification: None
# ------------------------------------------------------------
# Parent cell : TOP_main_1
# Referenced  : my_other_junction
# Origin      : [ 1.2675 -2.7   ]
# Rotation    : 180.0
# Magnification: None
# ------------------------------------------------------------

# %%
# # ============================================================
# # STEP 5
# # CONCENTRIC TRANSMON GDS -> 3D GMSH MESH
# #
# # Chip:
# #   4 concentric transmons
# #   2 Josephson junctions / qubit
# #   8 JJ instances total
# #
# # Other distributed structures remain part of the metal:
# #   - qubit-qubit couplers
# #   - readout resonators
# #   - readout finger capacitors
# #   - XY drive lines
# #   - flux-bias lines
# #
# # GDS:
# #   TOP_main_1
# #   Layer 1 / Datatype 0 = main superconducting geometry
# #   my_other_junction = JJ component
# #
# # Palace physical groups:
# #
# #   1  = Vacuum
# #   2  = Silicon
# #   10 = Superconducting metal / PEC
# #
# #   20 = Q1_JJ1
# #   21 = Q1_JJ2
# #   22 = Q2_JJ1
# #   23 = Q2_JJ2
# #   24 = Q3_JJ1
# #   25 = Q3_JJ2
# #   26 = Q4_JJ1
# #   27 = Q4_JJ2
# #
# # Units:
# #   GDS coordinates are mm
# # ============================================================

# import os
# import math
# import gdspy
# import gmsh


# # ============================================================
# # USER SETTINGS
# # ============================================================

# GDS_PATH ="quantum_chip_export_manuscript.gds"

# MESH_PATH = "quantum_chip_mesh.msh"

# TOP_CELL_NAME = "TOP_main_1"

# METAL_LAYER = 1
# METAL_DATATYPE = 0

# JJ_CELL_NAME = "my_other_junction"


# # ============================================================
# # CHIP DIMENSIONS
# # ============================================================

# # Your GDS is:
# # x = -7 ... +7 mm
# # y = -7 ... +7 mm

# CHIP_X = 14.0
# CHIP_Y = 14.0

# # Silicon thickness
# SUBSTRATE_THICKNESS = 0.5

# # Vacuum above chip
# AIR_HEIGHT = 3.0


# # ============================================================
# # PHYSICAL GROUPS
# # ============================================================

# VACUUM_ID = 1
# SILICON_ID = 2
# PEC_ID = 10

# JJ_GROUPS = {
#     "Q1_JJ1": 20,
#     "Q1_JJ2": 21,

#     "Q2_JJ1": 22,
#     "Q2_JJ2": 23,

#     "Q3_JJ1": 24,
#     "Q3_JJ2": 25,

#     "Q4_JJ1": 26,
#     "Q4_JJ2": 27,
# }


# # ============================================================
# # MESH SETTINGS
# # ============================================================

# # Global mesh.
# # These are in mm.

# GLOBAL_MIN = 0.005      # 5 um
# GLOBAL_MAX = 0.10       # 100 um

# # JJ refinement
# JJ_MIN = 0.0005        # 0.5 um
# JJ_MAX = 0.02          # 20 um

# # JJ refinement radius
# JJ_REFINE_RADIUS = 0.10     # 100 um


# # ============================================================
# # CHECK GDS
# # ============================================================

# if not os.path.exists(GDS_PATH):

#     raise FileNotFoundError(
#         f"\nGDS file not found:\n{GDS_PATH}"
#     )

# print("=" * 80)
# print("CONCENTRIC TRANSMON PALACE MESH GENERATOR")
# print("=" * 80)

# print("\nGDS:")
# print(os.path.abspath(GDS_PATH))


# # ============================================================
# # READ GDS
# # ============================================================

# print("\nReading GDS...")

# gds_lib = gdspy.GdsLibrary()

# gds_lib.read_gds(
#     GDS_PATH
# )

# print(
#     f"Loaded {len(gds_lib.cells)} cells."
# )


# # ============================================================
# # CHECK TOP CELL
# # ============================================================

# if TOP_CELL_NAME not in gds_lib.cells:

#     raise RuntimeError(
#         f"\nTop cell '{TOP_CELL_NAME}' "
#         f"was not found in GDS."
#     )

# top_cell = gds_lib.cells[
#     TOP_CELL_NAME
# ]

# print(
#     f"\nUsing top cell: {TOP_CELL_NAME}"
# )


# # ============================================================
# # EXTRACT ONLY REAL METAL FROM TOP CELL
# #
# # IMPORTANT:
# # Do NOT iterate through every cell.
# #
# # TOP_main_1 already contains the referenced geometry.
# # ============================================================

# print("\nExtracting main superconducting metal...")

# top_polygons_by_spec = top_cell.get_polygons(
#     by_spec=True
# )

# metal_polygons = []

# for spec, polygons in top_polygons_by_spec.items():

#     layer, datatype = spec

#     if layer != METAL_LAYER:
#         continue

#     if datatype != METAL_DATATYPE:
#         continue

#     for polygon in polygons:

#         if len(polygon) < 3:
#             continue

#         metal_polygons.append(
#             polygon
#         )


# print(
#     f"Main metal polygons: "
#     f"{len(metal_polygons)}"
# )


# if len(metal_polygons) == 0:

#     raise RuntimeError(
#         "No Layer 1 / Datatype 0 geometry "
#         "was found in TOP_main_1."
#     )


# # ============================================================
# # FIND THE EIGHT JJ REFERENCES
# # ============================================================

# print("\nSearching for JJ references...")

# jj_references = []

# for ref in top_cell.references:

#     try:
#         ref_cell_name = ref.ref_cell.name
#     except Exception:
#         continue

#     if ref_cell_name == JJ_CELL_NAME:

#         jj_references.append(
#             ref
#         )


# print(
#     f"Found {len(jj_references)} "
#     f"'{JJ_CELL_NAME}' references."
# )


# if len(jj_references) != 8:

#     raise RuntimeError(
#         f"\nExpected 8 JJ references, "
#         f"but found {len(jj_references)}."
#     )


# # ============================================================
# # SORT JJ REFERENCES
# #
# # We know from your GDS:
# #
# # Q1:
# #   (-1.1325, 0)
# #   (-0.8675, 0)
# #
# # Q2:
# #   (1.2675, 0)
# #   (1.5325, 0)
# #
# # Q3:
# #   (-0.8675, -2.7)
# #   (-1.1325, -2.7)
# #
# # Q4:
# #   (1.5325, -2.7)
# #   (1.2675, -2.7)
# #
# # Rather than hard-coding the order, use actual positions.
# # ============================================================

# def get_reference_position(ref):

#     origin = ref.origin

#     return (
#         float(origin[0]),
#         float(origin[1])
#     )


# jj_references.sort(
#     key=lambda ref: (
#         -get_reference_position(ref)[1],
#         get_reference_position(ref)[0]
#     )
# )


# print("\nJJ references found:")

# for i, ref in enumerate(jj_references):

#     x, y = get_reference_position(ref)

#     rotation = ref.rotation

#     print(
#         f"  {i+1}: "
#         f"x={x:.6f} mm, "
#         f"y={y:.6f} mm, "
#         f"rotation={rotation}"
#     )


# # ============================================================
# # IMPORTANT JJ MAPPING
# #
# # For the top row:
# #
# #   left  -> JJ1
# #   right -> JJ2
# #
# # For bottom row the physical orientation is reversed,
# # so we use the actual rotation to preserve the JJ identity.
# #
# # For this first mesh we use spatial ordering and then
# # explicitly report the mapping.
# # ============================================================

# jj_mapping = [
#     ("Q1_JJ1", jj_references[0]),
#     ("Q1_JJ2", jj_references[1]),

#     ("Q2_JJ1", jj_references[2]),
#     ("Q2_JJ2", jj_references[3]),

#     ("Q3_JJ1", jj_references[4]),
#     ("Q3_JJ2", jj_references[5]),

#     ("Q4_JJ1", jj_references[6]),
#     ("Q4_JJ2", jj_references[7]),
# ]


# # ============================================================
# # INITIALIZE GMSH
# # ============================================================

# print("\nInitializing Gmsh...")

# gmsh.initialize()

# gmsh.option.setNumber(
#     "General.Terminal",
#     1
# )

# gmsh.model.add(
#     "four_qubit_concentric_transmon"
# )


# try:

#     # ========================================================
#     # CREATE SILICON
#     # ========================================================

#     print("\nCreating silicon substrate...")

#     silicon = gmsh.model.occ.addBox(

#         -CHIP_X / 2.0,
#         -CHIP_Y / 2.0,
#         -SUBSTRATE_THICKNESS,

#         CHIP_X,
#         CHIP_Y,
#         SUBSTRATE_THICKNESS
#     )


#     # ========================================================
#     # CREATE VACUUM
#     # ========================================================

#     print("Creating vacuum region...")

#     vacuum = gmsh.model.occ.addBox(

#         -CHIP_X / 2.0,
#         -CHIP_Y / 2.0,
#         0.0,

#         CHIP_X,
#         CHIP_Y,
#         AIR_HEIGHT
#     )


#     # ========================================================
#     # CREATE METAL SURFACES
#     # ========================================================

#     print(
#         "\nCreating superconducting metal surfaces..."
#     )

#     metal_surfaces = []

#     for i, polygon in enumerate(
#         metal_polygons
#     ):

#         point_tags = []

#         for x, y in polygon:

#             p = gmsh.model.occ.addPoint(
#                 float(x),
#                 float(y),
#                 0.0
#             )

#             point_tags.append(p)


#         line_tags = []

#         for j in range(
#             len(point_tags)
#         ):

#             p1 = point_tags[j]

#             p2 = point_tags[
#                 (j + 1) % len(point_tags)
#             ]

#             line = gmsh.model.occ.addLine(
#                 p1,
#                 p2
#             )

#             line_tags.append(line)


#         try:

#             wire = gmsh.model.occ.addWire(
#                 line_tags
#             )

#             surface = (
#                 gmsh.model.occ.addPlaneSurface(
#                     [wire]
#                 )
#             )

#             metal_surfaces.append(
#                 surface
#             )

#         except Exception as exc:

#             print(
#                 f"Warning: metal polygon "
#                 f"{i} failed: {exc}"
#             )


#     print(
#         f"Created {len(metal_surfaces)} "
#         f"metal surfaces."
#     )


#     # ========================================================
#     # CREATE JJ SURFACES
#     # ========================================================

#     jj_surfaces = {}

#     print(
#         "\nCreating eight JJ geometry groups..."
#     )


#     for jj_name, ref in jj_mapping:

#         jj_surfaces[jj_name] = []

#         # ----------------------------------------------
#         # Extract transformed polygons from the reference
#         # ----------------------------------------------

#         ref_polygons_by_spec = (
#             ref.get_polygons(
#                 by_spec=True
#             )
#         )


#         all_jj_polygons = []

#         for spec, polygons in (
#             ref_polygons_by_spec.items()
#         ):

#             for polygon in polygons:

#                 if len(polygon) >= 3:

#                     all_jj_polygons.append(
#                         polygon
#                     )


#         print(
#             f"  {jj_name}: "
#             f"{len(all_jj_polygons)} polygons"
#         )


#         # ----------------------------------------------
#         # Convert each JJ polygon to Gmsh surface
#         # ----------------------------------------------

#         for polygon in all_jj_polygons:

#             point_tags = []

#             for x, y in polygon:

#                 p = gmsh.model.occ.addPoint(
#                     float(x),
#                     float(y),
#                     0.0
#                 )

#                 point_tags.append(p)


#             line_tags = []

#             for j in range(
#                 len(point_tags)
#             ):

#                 p1 = point_tags[j]

#                 p2 = point_tags[
#                     (j + 1) % len(point_tags)
#                 ]

#                 line = gmsh.model.occ.addLine(
#                     p1,
#                     p2
#                 )

#                 line_tags.append(line)


#             try:

#                 wire = gmsh.model.occ.addWire(
#                     line_tags
#                 )

#                 surface = (
#                     gmsh.model.occ.addPlaneSurface(
#                         [wire]
#                     )
#                 )

#                 jj_surfaces[jj_name].append(
#                     surface
#                 )

#             except Exception as exc:

#                 print(
#                     f"    JJ polygon warning: "
#                     f"{exc}"
#                 )


#     # ========================================================
#     # SYNCHRONIZE
#     # ========================================================

#     print("\nSynchronizing OCC geometry...")

#     gmsh.model.occ.synchronize()


#     # ========================================================
#     # PHYSICAL VOLUMES
#     # ========================================================

#     print(
#         "\nCreating physical volume groups..."
#     )

#     gmsh.model.addPhysicalGroup(
#         3,
#         [vacuum],
#         VACUUM_ID
#     )

#     gmsh.model.setPhysicalName(
#         3,
#         VACUUM_ID,
#         "Vacuum"
#     )


#     gmsh.model.addPhysicalGroup(
#         3,
#         [silicon],
#         SILICON_ID
#     )

#     gmsh.model.setPhysicalName(
#         3,
#         SILICON_ID,
#         "Silicon_Substrate"
#     )


#     # ========================================================
#     # PEC GROUP
#     # ========================================================

#     print(
#         "\nCreating superconducting PEC group..."
#     )

#     gmsh.model.addPhysicalGroup(
#         2,
#         metal_surfaces,
#         PEC_ID
#     )

#     gmsh.model.setPhysicalName(
#         2,
#         PEC_ID,
#         "Superconducting_Metal"
#     )


#     # ========================================================
#     # JJ PHYSICAL GROUPS
#     # ========================================================

#     print(
#         "\nCreating JJ physical groups..."
#     )

#     for jj_name, group_id in JJ_GROUPS.items():

#         surfaces = jj_surfaces[jj_name]

#         if len(surfaces) == 0:

#             raise RuntimeError(
#                 f"No geometry generated for {jj_name}"
#             )

#         gmsh.model.addPhysicalGroup(
#             2,
#             surfaces,
#             group_id
#         )

#         gmsh.model.setPhysicalName(
#             2,
#             group_id,
#             jj_name
#         )

#         print(
#             f"  {group_id:2d} -> {jj_name} "
#             f"({len(surfaces)} surfaces)"
#         )


#     # ========================================================
#     # MESH SETTINGS
#     # ========================================================

#     print(
#         "\nConfiguring mesh..."
#     )

#     gmsh.option.setNumber(
#         "Mesh.Algorithm3D",
#         1
#     )

#     gmsh.option.setNumber(
#         "Mesh.CharacteristicLengthMin",
#         GLOBAL_MIN
#     )

#     gmsh.option.setNumber(
#         "Mesh.CharacteristicLengthMax",
#         GLOBAL_MAX
#     )


#     # ========================================================
#     # JJ LOCAL REFINEMENT
#     # ========================================================

#     print(
#         "Applying local JJ refinement..."
#     )

#     jj_points = []

#     for jj_name in jj_surfaces:

#         for surface in jj_surfaces[jj_name]:

#             boundary = (
#                 gmsh.model.getBoundary(
#                     [(2, surface)],
#                     oriented=False,
#                     recursive=True
#                 )
#             )

#             for dim, tag in boundary:

#                 if dim == 0:

#                     jj_points.append(
#                         tag
#                     )


#     jj_points = list(
#         set(jj_points)
#     )


#     if jj_points:

#         distance_field = (
#             gmsh.model.mesh.field.add(
#                 "Distance"
#             )
#         )

#         gmsh.model.mesh.field.setNumbers(
#             distance_field,
#             "NodesList",
#             jj_points
#         )

#         threshold_field = (
#             gmsh.model.mesh.field.add(
#                 "Threshold"
#             )
#         )

#         gmsh.model.mesh.field.setNumber(
#             threshold_field,
#             "InField",
#             distance_field
#         )

#         gmsh.model.mesh.field.setNumber(
#             threshold_field,
#             "SizeMin",
#             JJ_MIN
#         )

#         gmsh.model.mesh.field.setNumber(
#             threshold_field,
#             "SizeMax",
#             JJ_MAX
#         )

#         gmsh.model.mesh.field.setNumber(
#             threshold_field,
#             "DistMin",
#             0.005
#         )

#         gmsh.model.mesh.field.setNumber(
#             threshold_field,
#             "DistMax",
#             JJ_REFINE_RADIUS
#         )

#         gmsh.model.mesh.field.setAsBackgroundMesh(
#             threshold_field
#         )


#     # ========================================================
#     # GENERATE 3D MESH
#     # ========================================================

#     print(
#         "\n" + "=" * 80
#     )

#     print(
#         "GENERATING 3D TETRAHEDRAL MESH..."
#     )

#     print(
#         "=" * 80
#     )

#     gmsh.model.mesh.generate(
#         3
#     )


#     # ========================================================
#     # OPTIMIZATION
#     # ========================================================

#     print(
#         "\nOptimizing mesh..."
#     )

#     try:

#         gmsh.model.mesh.optimize(
#             "Netgen"
#         )

#     except Exception as exc:

#         print(
#             "Optimization warning:",
#             exc
#         )


#     # ========================================================
#     # MESH STATISTICS
#     # ========================================================

#     print(
#         "\n" + "=" * 80
#     )

#     print(
#         "MESH STATISTICS"
#     )

#     print(
#         "=" * 80
#     )

#     node_tags, node_coords, _ = (
#         gmsh.model.mesh.getNodes()
#     )

#     print(
#         f"Nodes: {len(node_tags):,}"
#     )


#     element_types, element_tags, _ = (
#         gmsh.model.mesh.getElements()
#     )

#     total_elements = sum(
#         len(tags)
#         for tags in element_tags
#     )

#     print(
#         f"Elements: {total_elements:,}"
#     )


#     # ========================================================
#     # PHYSICAL GROUP REPORT
#     # ========================================================

#     print(
#         "\nPhysical groups:"
#     )

#     for dim, tag in (
#         gmsh.model.getPhysicalGroups()
#     ):

#         name = (
#             gmsh.model.getPhysicalName(
#                 dim,
#                 tag
#             )
#         )

#         print(
#             f"  Dimension={dim}, "
#             f"Attribute={tag}, "
#             f"Name={name}"
#         )


#     # ========================================================
#     # WRITE MESH
#     # ========================================================

#     print(
#         "\nWriting:"
#     )

#     print(
#         os.path.abspath(
#             MESH_PATH
#         )
#     )

#     gmsh.write(
#         MESH_PATH
#     )


#     # ========================================================
#     # FINAL REPORT
#     # ========================================================

#     print(
#         "\n" + "=" * 80
#     )

#     print(
#         "MESH GENERATION SUCCESSFUL"
#     )

#     print(
#         "=" * 80
#     )

#     print(
#         f"\nOutput:"
#         f"\n  {os.path.abspath(MESH_PATH)}"
#     )

#     print(
#         "\nPhysical groups:"
#     )

#     print(
#         "  1  = Vacuum"
#     )

#     print(
#         "  2  = Silicon"
#     )

#     print(
#         "  10 = Superconducting metal"
#     )

#     for name, group_id in JJ_GROUPS.items():

#         print(
#             f"  {group_id} = {name}"
#         )


# finally:

#     gmsh.finalize()

#     print(
#         "\nGmsh finalized."
#     )
# Out:
# ================================================================================
# CONCENTRIC TRANSMON PALACE MESH GENERATOR
# ================================================================================
#
# GDS:
# /content/quantum_chip_export_manuscript.gds
#
# Reading GDS...
# Loaded 19 cells.
#
# Using top cell: TOP_main_1
#
# Extracting main superconducting metal...
# Main metal polygons: 2450
#
# Searching for JJ references...
# Found 8 'my_other_junction' references.
#
# JJ references found:
#   1: x=-1.132500 mm, y=0.000000 mm, rotation=180.0
#   2: x=-0.867500 mm, y=0.000000 mm, rotation=None
#   3: x=1.267500 mm, y=0.000000 mm, rotation=180.0
#   4: x=1.532500 mm, y=0.000000 mm, rotation=None
#   5: x=-1.132500 mm, y=-2.700000 mm, rotation=180.0
#   6: x=-0.867500 mm, y=-2.700000 mm, rotation=None
#   7: x=1.267500 mm, y=-2.700000 mm, rotation=180.0
#   8: x=1.532500 mm, y=-2.700000 mm, rotation=None
#
# Initializing Gmsh...
#
# Creating silicon substrate...
# Creating vacuum region...
#
# Creating superconducting metal surfaces...
# Created 2450 metal surfaces.
#
# Creating eight JJ geometry groups...
#   Q1_JJ1: 1 polygons
#   Q1_JJ2: 1 polygons
#   Q2_JJ1: 1 polygons
#   Q2_JJ2: 1 polygons
#   Q3_JJ1: 1 polygons
#   Q3_JJ2: 1 polygons
#   Q4_JJ1: 1 polygons
#   Q4_JJ2: 1 polygons
#
# Synchronizing OCC geometry...
#
# Creating physical volume groups...
#
# Creating superconducting PEC group...
#
# Creating JJ physical groups...
#   20 -> Q1_JJ1 (1 surfaces)
#   21 -> Q1_JJ2 (1 surfaces)
#   22 -> Q2_JJ1 (1 surfaces)
#   23 -> Q2_JJ2 (1 surfaces)
#   24 -> Q3_JJ1 (1 surfaces)
#   25 -> Q3_JJ2 (1 surfaces)
#   26 -> Q4_JJ1 (1 surfaces)
#   27 -> Q4_JJ2 (1 surfaces)
#
# Configuring mesh...
# Applying local JJ refinement...
#
# ================================================================================
# GENERATING 3D TETRAHEDRAL MESH...
# ================================================================================

# %%
# ============================================================
# STEP 5A
# SAFE FIRST-PASS 3D MESH FOR PALACE
#
# 4 concentric transmons
# 8 Josephson junction locations
#
# IMPORTANT:
# The JJs are NOT volumetrically meshed here.
# They will later be represented as lumped Josephson elements.
#
# This version is designed to avoid RAM exhaustion.
# ============================================================

import os
import gdspy
import gmsh


# ============================================================
# INPUT / OUTPUT
# ============================================================

GDS_PATH = "quantum_chip_export_manuscript.gds"
MESH_PATH = "quantum_chip_mesh_test.msh"

TOP_CELL_NAME = "TOP_main_1"

METAL_LAYER = 1
METAL_DATATYPE = 0

JJ_CELL_NAME = "my_other_junction"


# ============================================================
# CHIP GEOMETRY
# ============================================================

# GDS coordinates are in mm.

CHIP_X = 14.0
CHIP_Y = 14.0

# Silicon thickness
SUBSTRATE_THICKNESS = 0.5

# IMPORTANT:
# Start with 0.5 mm air, NOT 3 mm.
AIR_HEIGHT = 0.5


# ============================================================
# PHYSICAL GROUPS
# ============================================================

VACUUM_ID = 1
SILICON_ID = 2
PEC_ID = 10


# ============================================================
# SAFE MESH PARAMETERS
# ============================================================

# All dimensions are mm.

# 20 µm minimum
GLOBAL_MIN = 0.020

# 150 µm maximum
GLOBAL_MAX = 0.150


# ============================================================
# CHECK FILE
# ============================================================

if not os.path.exists(GDS_PATH):

    raise FileNotFoundError(
        f"GDS file not found:\n{GDS_PATH}"
    )


print("=" * 80)
print("SAFE FIRST-PASS PALACE MESH")
print("=" * 80)

print("\nGDS:")
print(os.path.abspath(GDS_PATH))


# ============================================================
# READ GDS
# ============================================================

print("\nReading GDS...")

lib = gdspy.GdsLibrary()

lib.read_gds(
    GDS_PATH
)

print(
    f"Loaded {len(lib.cells)} cells."
)


# ============================================================
# TOP CELL
# ============================================================

if TOP_CELL_NAME not in lib.cells:

    raise RuntimeError(
        f"Top cell not found: {TOP_CELL_NAME}"
    )

top = lib.cells[
    TOP_CELL_NAME
]

print(
    f"Using top cell: {TOP_CELL_NAME}"
)


# ============================================================
# EXTRACT ONLY ACTUAL METAL
# ============================================================

print(
    "\nExtracting Layer 1 / Datatype 0..."
)

polygons_by_spec = top.get_polygons(
    by_spec=True
)

metal_polygons = []

for spec, polygons in polygons_by_spec.items():

    layer, datatype = spec

    if layer != METAL_LAYER:
        continue

    if datatype != METAL_DATATYPE:
        continue

    for polygon in polygons:

        if len(polygon) >= 3:

            metal_polygons.append(
                polygon
            )


print(
    f"Metal polygons: "
    f"{len(metal_polygons)}"
)


# ============================================================
# FIND JJ REFERENCES
#
# We record them, but DO NOT mesh their 30 µm × 3 µm
# component polygon at sub-micron resolution.
# ============================================================

print(
    "\nFinding Josephson-junction references..."
)

jj_refs = []

for ref in top.references:

    try:

        name = ref.ref_cell.name

    except Exception:

        continue

    if name == JJ_CELL_NAME:

        jj_refs.append(
            ref
        )


print(
    f"Found {len(jj_refs)} JJ references."
)


if len(jj_refs) != 8:

    raise RuntimeError(
        f"Expected 8 JJ references, "
        f"found {len(jj_refs)}."
    )


# ============================================================
# SORT JJs
# ============================================================

def ref_position(ref):

    return (
        float(ref.origin[0]),
        float(ref.origin[1])
    )


jj_refs.sort(
    key=lambda r: (
        -ref_position(r)[1],
        ref_position(r)[0]
    )
)


print("\nEight JJ locations:")

for i, ref in enumerate(jj_refs):

    x, y = ref_position(ref)

    print(
        f"  JJ{i+1}: "
        f"x={x:.6f} mm, "
        f"y={y:.6f} mm, "
        f"rotation={ref.rotation}"
    )


# ============================================================
# INITIALIZE GMSH
# ============================================================

print("\nInitializing Gmsh...")

gmsh.initialize()

gmsh.option.setNumber(
    "General.Terminal",
    1
)

gmsh.model.add(
    "four_qubit_concentric_safe"
)


try:

    # ========================================================
    # SILICON
    # ========================================================

    print(
        "\nCreating silicon substrate..."
    )

    silicon = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        -SUBSTRATE_THICKNESS,

        CHIP_X,
        CHIP_Y,
        SUBSTRATE_THICKNESS
    )


    # ========================================================
    # AIR
    # ========================================================

    print(
        "Creating vacuum region..."
    )

    vacuum = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        0.0,

        CHIP_X,
        CHIP_Y,
        AIR_HEIGHT
    )


    # ========================================================
    # CREATE METAL SURFACES
    # ========================================================

    print(
        "\nCreating metal surfaces..."
    )

    metal_surfaces = []

    for i, polygon in enumerate(
        metal_polygons
    ):

        point_tags = []

        for x, y in polygon:

            p = gmsh.model.occ.addPoint(
                float(x),
                float(y),
                0.0
            )

            point_tags.append(p)


        lines = []

        for j in range(
            len(point_tags)
        ):

            p1 = point_tags[j]

            p2 = point_tags[
                (j + 1) % len(point_tags)
            ]

            line = gmsh.model.occ.addLine(
                p1,
                p2
            )

            lines.append(line)


        try:

            wire = gmsh.model.occ.addWire(
                lines
            )

            surface = (
                gmsh.model.occ.addPlaneSurface(
                    [wire]
                )
            )

            metal_surfaces.append(
                surface
            )

        except Exception as exc:

            print(
                f"Warning: polygon {i} failed: "
                f"{exc}"
            )


    print(
        f"Created {len(metal_surfaces)} "
        f"metal surfaces."
    )


    # ========================================================
    # SYNCHRONIZE
    # ========================================================

    print(
        "\nSynchronizing geometry..."
    )

    gmsh.model.occ.synchronize()


    # ========================================================
    # PHYSICAL VOLUMES
    # ========================================================

    print(
        "\nCreating physical volumes..."
    )

    gmsh.model.addPhysicalGroup(
        3,
        [vacuum],
        VACUUM_ID
    )

    gmsh.model.setPhysicalName(
        3,
        VACUUM_ID,
        "Vacuum"
    )


    gmsh.model.addPhysicalGroup(
        3,
        [silicon],
        SILICON_ID
    )

    gmsh.model.setPhysicalName(
        3,
        SILICON_ID,
        "Silicon_Substrate"
    )


    # ========================================================
    # PEC
    # ========================================================

    print(
        "Creating PEC group..."
    )

    gmsh.model.addPhysicalGroup(
        2,
        metal_surfaces,
        PEC_ID
    )

    gmsh.model.setPhysicalName(
        2,
        PEC_ID,
        "Superconducting_Metal"
    )


    # ========================================================
    # MESH SETTINGS
    # ========================================================

    print(
        "\nSetting conservative mesh size..."
    )

    gmsh.option.setNumber(
        "Mesh.Algorithm3D",
        1
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMin",
        GLOBAL_MIN
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMax",
        GLOBAL_MAX
    )

    # Avoid aggressive optimization
    gmsh.option.setNumber(
        "Mesh.Optimize",
        0
    )

    gmsh.option.setNumber(
        "Mesh.OptimizeNetgen",
        0
    )


    # ========================================================
    # GENERATE 3D MESH
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "GENERATING CONSERVATIVE 3D MESH"
    )

    print(
        "Minimum element size = 20 um"
    )

    print(
        "Maximum element size = 150 um"
    )

    print(
        "Air height = 0.5 mm"
    )

    print(
        "=" * 80
    )

    gmsh.model.mesh.generate(
        3
    )


    # ========================================================
    # STATISTICS
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "MESH STATISTICS"
    )

    print(
        "=" * 80
    )

    nodes, coords, _ = (
        gmsh.model.mesh.getNodes()
    )

    print(
        f"Nodes: {len(nodes):,}"
    )


    element_types, element_tags, _ = (
        gmsh.model.mesh.getElements()
    )

    total_elements = sum(
        len(tags)
        for tags in element_tags
    )

    print(
        f"Elements: {total_elements:,}"
    )


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nPhysical groups:"
    )

    for dim, tag in (
        gmsh.model.getPhysicalGroups()
    ):

        name = gmsh.model.getPhysicalName(
            dim,
            tag
        )

        print(
            f"  Dimension={dim}, "
            f"Attribute={tag}, "
            f"Name={name}"
        )


    # ========================================================
    # WRITE MESH
    # ========================================================

    print(
        "\nWriting mesh..."
    )

    gmsh.write(
        MESH_PATH
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "SUCCESS"
    )

    print(
        "=" * 80
    )

    print(
        f"\nMesh:"
        f"\n{os.path.abspath(MESH_PATH)}"
    )


finally:

    gmsh.finalize()

    print(
        "\nGmsh finalized."
    )
# Out:
# ================================================================================
# SAFE FIRST-PASS PALACE MESH
# ================================================================================
#
# GDS:
# /content/quantum_chip_export_manuscript.gds
#
# Reading GDS...
# Loaded 19 cells.
# Using top cell: TOP_main_1
#
# Extracting Layer 1 / Datatype 0...
# Metal polygons: 2450
#
# Finding Josephson-junction references...
# Found 8 JJ references.
#
# Eight JJ locations:
#   JJ1: x=-1.132500 mm, y=0.000000 mm, rotation=180.0
#   JJ2: x=-0.867500 mm, y=0.000000 mm, rotation=None
#   JJ3: x=1.267500 mm, y=0.000000 mm, rotation=180.0
#   JJ4: x=1.532500 mm, y=0.000000 mm, rotation=None
#   JJ5: x=-1.132500 mm, y=-2.700000 mm, rotation=180.0
#   JJ6: x=-0.867500 mm, y=-2.700000 mm, rotation=None
#   JJ7: x=1.267500 mm, y=-2.700000 mm, rotation=180.0
#   JJ8: x=1.532500 mm, y=-2.700000 mm, rotation=None
#
# Initializing Gmsh...
#
# Creating silicon substrate...
# Creating vacuum region...
#
# Creating metal surfaces...
# Created 2450 metal surfaces.
#
# Synchronizing geometry...
#
# Creating physical volumes...
# Creating PEC group...
#
# Setting conservative mesh size...
#
# ================================================================================
# GENERATING CONSERVATIVE 3D MESH
# Minimum element size = 20 um
# Maximum element size = 150 um
# Air height = 0.5 mm
# ================================================================================
#
# ================================================================================
# MESH STATISTICS
# ================================================================================
# Nodes: 149,888
# Elements: 596,772
#
# Physical groups:
#   Dimension=2, Attribute=10, Name=Superconducting_Metal
#   Dimension=3, Attribute=1, Name=Vacuum
#   Dimension=3, Attribute=2, Name=Silicon_Substrate
#
# Writing mesh...
#
# ================================================================================
# SUCCESS
# ================================================================================
#
# Mesh:
# /content/quantum_chip_mesh_test.msh
#
# Gmsh finalized.

# %%
import os
import stat
import shutil

validator = "/content/drive/MyDrive/Palace6/build/bin/validate-config"

print("Validator exists:", os.path.exists(validator))
print("Current permissions:", oct(os.stat(validator).st_mode))

# Add executable permission
os.chmod(
    validator,
    os.stat(validator).st_mode | stat.S_IXUSR | stat.S_IXGRP | stat.S_IXOTH
)

print("New permissions:", oct(os.stat(validator).st_mode))

print("Executable:", os.access(validator, os.X_OK))
# Out:
# Validator exists: True
# Current permissions: 0o100600
# New permissions: 0o100700
# Executable: True

# %%
# # ============================================================
# # STEP 6
# # PALACE EIGENMODE SANITY TEST
# #
# # IMPORTANT:
# # This uses the current RAM-safe mesh:
# #
# #     quantum_chip_mesh_test.msh
# #
# # It does NOT yet include the 8 Josephson lumped ports.
# #
# # Purpose:
# #   1. Validate Palace configuration
# #   2. Load mesh
# #   3. Solve 20 eigenmodes
# #   4. Confirm eig.csv is produced
# #
# # The resulting frequencies are NOT yet the physical
# # transmon frequencies because the Josephson inductances
# # have not been included.
# # ============================================================

# import os
# import json
# import subprocess


# # ============================================================
# # PALACE PATHS
# # ============================================================

# palace_dir = "/content/drive/MyDrive/Palace6/build"

# palace_bin = os.path.join(
#     palace_dir,
#     "bin",
#     "palace-x86_64.bin"
# )

# validator = os.path.join(
#     palace_dir,
#     "bin",
#     "validate-config"
# )

# lib_dir = os.path.join(
#     palace_dir,
#     "lib"
# )


# # ============================================================
# # MESH
# # ============================================================

# mesh_path = "quantum_chip_mesh_test.msh"


# if not os.path.exists(mesh_path):

#     raise FileNotFoundError(
#         f"Mesh not found:\n{mesh_path}"
#     )


# if not os.path.exists(palace_bin):

#     raise FileNotFoundError(
#         f"Palace executable not found:\n{palace_bin}"
#     )


# if not os.path.exists(validator):

#     raise FileNotFoundError(
#         f"Palace validator not found:\n{validator}"
#     )


# # ============================================================
# # OUTPUT
# # ============================================================

# output_dir = "palace_eigen_test"

# os.makedirs(
#     output_dir,
#     exist_ok=True
# )


# # ============================================================
# # ENVIRONMENT
# # ============================================================

# env = os.environ.copy()

# env["LD_LIBRARY_PATH"] = (
#     f"{lib_dir}:"
#     f"{env.get('LD_LIBRARY_PATH', '')}"
# )

# env["OMPI_ALLOW_RUN_AS_ROOT"] = "1"

# env[
#     "OMPI_ALLOW_RUN_AS_ROOT_CONFIRM"
# ] = "1"


# # ============================================================
# # PALACE CONFIGURATION
# # ============================================================

# palace_config = {

#     "Problem": {

#         "Type": "Eigenmode",

#         "Verbose": 2,

#         "Output": output_dir
#     },


#     "Model": {

#         "Mesh": mesh_path,

#         # GDS/Gmsh coordinates are in mm.
#         #
#         # 1 mesh unit = 1 mm = 1e-3 m.
#         "L0": 1.0e-3
#     },


#     "Domains": {

#         "Materials": [

#             {
#                 # Vacuum
#                 "Attributes": [1],

#                 "Permittivity": 1.0,

#                 "Permeability": 1.0
#             },

#             {
#                 # Silicon
#                 "Attributes": [2],

#                 "Permittivity": 11.7,

#                 "Permeability": 1.0
#             }
#         ]
#     },


#     "Boundaries": {

#         # Superconducting metal
#         "PEC": {

#             "Attributes": [10]
#         }
#     },


#     "Solver": {

#         # First-order finite elements.
#         #
#         # Keep this at 1 for the first test
#         # to keep RAM usage modest.
#         "Order": 1,


#         "Eigenmode": {

#             # Number of eigenmodes
#             "N": 20,

#             # Search around 5 GHz.
#             #
#             # Palace eigenmode target is a search shift,
#             # not a statement that every mode will be 5 GHz.
#             "Target": 5.0,

#             "Tol": 1.0e-8,

#             "MaxIts": 200
#         },


#         "Linear": {

#             "Type": "BoomerAMG",

#             "Tol": 1.0e-8,

#             "MaxIts": 100
#         }
#     }
# }


# # ============================================================
# # WRITE CONFIG
# # ============================================================

# config_path = "palace_eigen_test.json"

# with open(
#     config_path,
#     "w"
# ) as f:

#     json.dump(
#         palace_config,
#         f,
#         indent=4
#     )


# print("=" * 80)
# print("PALACE EIGENMODE SANITY TEST")
# print("=" * 80)

# print(
#     "\nMesh:"
# )

# print(
#     os.path.abspath(mesh_path)
# )

# print(
#     "\nConfiguration:"
# )

# print(
#     os.path.abspath(config_path)
# )

# print(
#     "\nRequested eigenmodes: 20"
# )

# print(
#     "Target: 5 GHz"
# )

# print(
#     "Finite-element order: 1"
# )


# # ============================================================
# # STEP 1 — VALIDATE CONFIGURATION
# # ============================================================

# print(
#     "\n" + "=" * 80
# )

# print(
#     "STEP 1: VALIDATING PALACE CONFIGURATION"
# )

# print(
#     "=" * 80
# )


# validation = subprocess.run(

#     [
#         validator,
#         config_path
#     ],

#     text=True,

#     capture_output=True,

#     env=env
# )


# print(
#     "\nValidator stdout:"
# )

# print(
#     validation.stdout
# )


# if validation.stderr:

#     print(
#         "\nValidator stderr:"
#     )

#     print(
#         validation.stderr
#     )


# if validation.returncode != 0:

#     raise RuntimeError(
#         "\nPalace configuration validation FAILED."
#     )


# print(
#     "\nCONFIGURATION VALIDATION PASSED."
# )


# # ============================================================
# # STEP 2 — RUN PALACE
# # ============================================================

# print(
#     "\n" + "=" * 80
# )

# print(
#     "STEP 2: RUNNING PALACE EIGENMODE SOLVER"
# )

# print(
#     "=" * 80
# )


# cmd = [

#     "mpirun",

#     "-n",
#     "1",

#     "--allow-run-as-root",

#     palace_bin,

#     config_path
# ]


# print(
#     "\nExecuting:"
# )

# print(
#     " ".join(cmd)
# )


# try:

#     result = subprocess.run(

#         cmd,

#         check=True,

#         text=True,

#         capture_output=True,

#         env=env
#     )


#     print(
#         "\n" + "=" * 80
#     )

#     print(
#         "PALACE EIGENMODE SOLUTION COMPLETED"
#     )

#     print(
#         "=" * 80
#     )


#     print(
#         "\nPalace output:"
#     )

#     print(
#         result.stdout
#     )


# except subprocess.CalledProcessError as e:

#     print(
#         "\n" + "=" * 80
#     )

#     print(
#         "PALACE EIGENMODE FAILED"
#     )

#     print(
#         "=" * 80
#     )


#     print(
#         "\nSTDOUT:"
#     )

#     print(
#         e.stdout
#     )


#     print(
#         "\nSTDERR:"
#     )

#     print(
#         e.stderr
#     )

#     raise


# # ============================================================
# # STEP 3 — CHECK OUTPUT
# # ============================================================

# print(
#     "\n" + "=" * 80
# )

# print(
#     "STEP 3: CHECKING OUTPUT"
# )

# print(
#     "=" * 80
# )


# eig_file = os.path.join(
#     output_dir,
#     "eig.csv"
# )


# if os.path.exists(eig_file):

#     print(
#         "\nSUCCESS:"
#     )

#     print(
#         f"Eigenmode file found:\n{eig_file}"
#     )

#     print(
#         "\nFirst lines of eig.csv:"
#     )

#     with open(
#         eig_file,
#         "r"
#     ) as f:

#         for i, line in enumerate(f):

#             print(
#                 line.rstrip()
#             )

#             if i >= 10:

#                 break

# else:

#     print(
#         "\nWARNING:"
#     )

#     print(
#         "eig.csv was not found."
#     )


# print(
#     "\n" + "=" * 80
# )

# print(
#     "STEP 6 COMPLETE"
# )

# print(
#     "=" * 80
# )
# Out:
# ================================================================================
# PALACE EIGENMODE SANITY TEST
# ================================================================================
#
# Mesh:
# /content/quantum_chip_mesh_test.msh
#
# Configuration:
# /content/palace_eigen_test.json
#
# Requested eigenmodes: 20
# Target: 5 GHz
# Finite-element order: 1
#
# ================================================================================
# STEP 1: VALIDATING PALACE CONFIGURATION
# ================================================================================
#
# Validator stdout:
# Dry-run: No errors detected in configuration file "palace_eigen_test.json"
#
#
# Validator stderr:
#   Activating new project at `/tmp/jl_gV7PFB`
#    Resolving package versions...
#    Installed JSONSchema ─ v1.5.0
#     Updating `/tmp/jl_gV7PFB/Project.toml`
#   [682c06a0] + JSON v1.6.1
#   [7d188eb4] + JSONSchema v1.5.0
#     Updating `/tmp/jl_gV7PFB/Manifest.toml`
#   [682c06a0] + JSON v1.6.1
#   [7d188eb4] + JSONSchema v1.5.0
#   [69de0a69] + Parsers v2.8.4
#   [aea7be01] + PrecompileTools v1.3.4
#   [21216c6a] + Preferences v1.5.2
#   [ec057cc2] + StructUtils v2.8.2
#   [5c2747f8] + URIs v1.6.1
#   [0dad84c5] + ArgTools v1.1.2
#   [56f22d72] + Artifacts v1.11.0
#   [ade2ca70] + Dates v1.11.0
#   [f43a241f] + Downloads v1.7.0
#   [7b1f6079] + FileWatching v1.11.0
#   [b27032c2] + LibCURL v0.6.4
#   [8f399da3] + Libdl v1.11.0
#   [56ddb016] + Logging v1.11.0
#   [ca575930] + NetworkOptions v1.3.0
#   [de0858da] + Printf v1.11.0
#   [9a3f8284] + Random v1.11.0
#   [ea8e919c] + SHA v0.7.0
#   [fa267f1f] + TOML v1.0.3
#   [cf7118a7] + UUIDs v1.11.0
#   [4ec0a83e] + Unicode v1.11.0
#   [deac9b47] + LibCURL_jll v8.15.0+0
#   [29816b5a] + LibSSH2_jll v1.11.3+1
#   [14a3606d] + MozillaCACerts_jll v2025.11.4
#   [458c3c95] + OpenSSL_jll v3.5.4+0
#   [83775a58] + Zlib_jll v1.3.1+2
#   [8e850ede] + nghttp2_jll v1.64.0+1
# Precompiling packages...
#    1859.2 ms  ✓ JSONSchema
#   1 dependency successfully precompiled in 2 seconds. 22 already precompiled.
#
#
# CONFIGURATION VALIDATION PASSED.
#
# ================================================================================
# STEP 2: RUNNING PALACE EIGENMODE SOLVER
# ================================================================================
#
# Executing:
# mpirun -n 1 --allow-run-as-root /content/drive/MyDrive/Palace6/build/bin/palace-x86_64.bin palace_eigen_test.json
#
# ================================================================================
# PALACE EIGENMODE FAILED
# ================================================================================
#
# STDOUT:
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
# Git changeset ID: v0.17.0-194-g01f5d9bd1
# Running with 1 MPI process, 1 OpenMP thread
# Device configuration: omp,cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
#
#
# STDERR:
#
#
# MFEM abort: Gmsh file : vertices indices are not unique
#  ... in function: void mfem::Mesh::ReadGmshMesh(std::istream&, int&, int&)
#  ... in file: /content/Palace_build_tmp/build/extern/mfem/mesh/mesh_readers.cpp:1628
#
# --------------------------------------------------------------------------
# MPI_ABORT was invoked on rank 0 in communicator MPI_COMM_WORLD
# with errorcode 1.
#
# NOTE: invoking MPI_ABORT causes Open MPI to kill all MPI processes.
# You may or may not see output from other processes, depending on
# exactly when Open MPI kills them.
# --------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_73884/3578493423.py in <cell line: 0>()
#     366 try:
#     367
# --> 368     result = subprocess.run(
#     369
#     370         cmd,
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569         retcode = process.poll()
#     570         if check and retcode:
# --> 571             raise CalledProcessError(retcode, process.args,
#     572                                      output=stdout, stderr=stderr)
#     573     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['mpirun', '-n', '1', '--allow-run-as-root', '/content/drive/MyDrive/Palace6/build/bin/palace-x86_64.bin', 'palace_eigen_test.json']' returned non-zero exit status 1.

# %%
# ============================================================
# STEP 5B
# PALACE-COMPATIBLE GMSH MESH
#
# Fixes:
#   - duplicate OCC geometry
#   - duplicate mesh nodes
#   - degenerate elements
#   - repeated vertex indices
#
# Input:
#   quantum_chip_export_manuscript.gds
#
# Output:
#   quantum_chip_mesh_palace.msh
# ============================================================

import os
import gdspy
import gmsh


# ============================================================
# INPUT
# ============================================================

GDS_PATH = "quantum_chip_export_manuscript.gds"

MESH_PATH = "/content/quantum_chip_mesh_palace.msh"

TOP_CELL_NAME = "TOP_main_1"

METAL_LAYER = 1
METAL_DATATYPE = 0

JJ_CELL_NAME = "my_other_junction"


# ============================================================
# CHIP DIMENSIONS
# ============================================================

CHIP_X = 14.0
CHIP_Y = 14.0

SUBSTRATE_THICKNESS = 0.5
AIR_HEIGHT = 0.5


# ============================================================
# PHYSICAL GROUPS
# ============================================================

VACUUM_ID = 1
SILICON_ID = 2
PEC_ID = 10


# ============================================================
# SAFE MESH SIZE
# ============================================================

GLOBAL_MIN = 0.020     # 20 um
GLOBAL_MAX = 0.150     # 150 um


# ============================================================
# READ GDS
# ============================================================

print("=" * 80)
print("PALACE-COMPATIBLE MESH GENERATOR")
print("=" * 80)

print("\nReading GDS:")
print(GDS_PATH)

lib = gdspy.GdsLibrary()
lib.read_gds(GDS_PATH)

print(
    f"Loaded {len(lib.cells)} cells."
)


# ============================================================
# TOP CELL
# ============================================================

if TOP_CELL_NAME not in lib.cells:

    raise RuntimeError(
        f"Top cell '{TOP_CELL_NAME}' not found."
    )

top = lib.cells[TOP_CELL_NAME]

print(
    f"\nUsing top cell: {TOP_CELL_NAME}"
)


# ============================================================
# EXTRACT METAL
# ============================================================

print(
    "\nExtracting actual metal geometry..."
)

polygons_by_spec = top.get_polygons(
    by_spec=True
)

metal_polygons = []

for spec, polygons in polygons_by_spec.items():

    layer, datatype = spec

    if layer != METAL_LAYER:
        continue

    if datatype != METAL_DATATYPE:
        continue

    for polygon in polygons:

        if len(polygon) < 3:
            continue

        # ----------------------------------------------------
        # Remove repeated consecutive points
        # ----------------------------------------------------

        cleaned = []

        for p in polygon:

            x = float(p[0])
            y = float(p[1])

            if not cleaned:

                cleaned.append(
                    (x, y)
                )

            else:

                px, py = cleaned[-1]

                if (
                    abs(x - px) > 1e-12
                    or
                    abs(y - py) > 1e-12
                ):

                    cleaned.append(
                        (x, y)
                    )

        # ----------------------------------------------------
        # Remove closing duplicate
        # ----------------------------------------------------

        if len(cleaned) >= 2:

            if (
                abs(cleaned[0][0] - cleaned[-1][0])
                < 1e-12
                and
                abs(cleaned[0][1] - cleaned[-1][1])
                < 1e-12
            ):

                cleaned.pop()

        # ----------------------------------------------------
        # Need at least 3 unique points
        # ----------------------------------------------------

        if len(cleaned) < 3:
            continue

        if len(set(cleaned)) < 3:
            continue

        metal_polygons.append(
            cleaned
        )


print(
    f"Clean metal polygons: "
    f"{len(metal_polygons)}"
)


# ============================================================
# FIND JJ REFERENCES
# ============================================================

print(
    "\nFinding JJ references..."
)

jj_refs = []

for ref in top.references:

    try:
        name = ref.ref_cell.name
    except Exception:
        continue

    if name == JJ_CELL_NAME:

        jj_refs.append(ref)


print(
    f"Found {len(jj_refs)} JJ references."
)


if len(jj_refs) != 8:

    raise RuntimeError(
        f"Expected 8 JJs, found {len(jj_refs)}."
    )


# ============================================================
# PRINT JJ LOCATIONS
# ============================================================

jj_refs.sort(
    key=lambda r: (
        -float(r.origin[1]),
        float(r.origin[0])
    )
)

print("\nJJ locations:")

for i, ref in enumerate(jj_refs):

    print(
        f"  JJ{i+1}: "
        f"x={float(ref.origin[0]):.6f} mm, "
        f"y={float(ref.origin[1]):.6f} mm, "
        f"rotation={ref.rotation}"
    )


# ============================================================
# INITIALIZE GMSH
# ============================================================

print(
    "\nInitializing Gmsh..."
)

gmsh.initialize()

gmsh.option.setNumber(
    "General.Terminal",
    1
)

gmsh.model.add(
    "four_qubit_palace"
)


try:

    # ========================================================
    # SILICON
    # ========================================================

    print(
        "\nCreating silicon substrate..."
    )

    silicon = gmsh.model.occ.addBox(

        -CHIP_X / 2.0,
        -CHIP_Y / 2.0,
        -SUBSTRATE_THICKNESS,

        CHIP_X,
        CHIP_Y,
        SUBSTRATE_THICKNESS
    )


    # ========================================================
    # VACUUM
    # ========================================================

    print(
        "Creating vacuum..."
    )

    vacuum = gmsh.model.occ.addBox(

        -CHIP_X / 2.0,
        -CHIP_Y / 2.0,
        0.0,

        CHIP_X,
        CHIP_Y,
        AIR_HEIGHT
    )


    # ========================================================
    # GLOBAL POINT CACHE
    #
    # IMPORTANT:
    # Reuse the SAME OCC point for identical coordinates.
    # This prevents many duplicate vertices.
    # ========================================================

    point_cache = {}

    def get_point(x, y):

        # Quantize coordinates to avoid floating-point
        # differences creating duplicate points.

        key = (
            round(float(x), 10),
            round(float(y), 10),
            0.0
        )

        if key not in point_cache:

            point_cache[key] = (
                gmsh.model.occ.addPoint(
                    key[0],
                    key[1],
                    key[2]
                )
            )

        return point_cache[key]


    # ========================================================
    # CREATE METAL SURFACES
    # ========================================================

    print(
        "\nCreating metal surfaces..."
    )

    metal_surfaces = []

    failed_polygons = 0

    for i, polygon in enumerate(
        metal_polygons
    ):

        point_tags = []

        for x, y in polygon:

            point_tags.append(
                get_point(x, y)
            )


        # ----------------------------------------------
        # Remove repeated point IDs
        # ----------------------------------------------

        unique_points = []

        for tag in point_tags:

            if (
                not unique_points
                or
                tag != unique_points[-1]
            ):

                unique_points.append(tag)


        if len(unique_points) >= 2:

            if (
                unique_points[0]
                ==
                unique_points[-1]
            ):

                unique_points.pop()


        if len(set(unique_points)) < 3:

            failed_polygons += 1
            continue


        # ----------------------------------------------
        # Create closed wire
        # ----------------------------------------------

        lines = []

        valid = True

        for j in range(
            len(unique_points)
        ):

            p1 = unique_points[j]

            p2 = unique_points[
                (j + 1) % len(unique_points)
            ]

            if p1 == p2:

                valid = False
                break

            try:

                line = (
                    gmsh.model.occ.addLine(
                        p1,
                        p2
                    )
                )

                lines.append(line)

            except Exception:

                valid = False
                break


        if not valid or len(lines) < 3:

            failed_polygons += 1
            continue


        try:

            wire = (
                gmsh.model.occ.addWire(
                    lines
                )
            )

            surface = (
                gmsh.model.occ.addPlaneSurface(
                    [wire]
                )
            )

            metal_surfaces.append(
                surface
            )

        except Exception:

            failed_polygons += 1


    print(
        f"Created {len(metal_surfaces)} "
        f"metal surfaces."
    )

    print(
        f"Skipped {failed_polygons} "
        f"invalid polygons."
    )


    # ========================================================
    # REMOVE DUPLICATE OCC GEOMETRY
    # ========================================================

    print(
        "\nRemoving duplicate OCC geometry..."
    )

    try:

        gmsh.model.occ.removeAllDuplicates()

        print(
            "Duplicate OCC geometry removed."
        )

    except Exception as exc:

        print(
            "removeAllDuplicates warning:",
            exc
        )


    # ========================================================
    # SYNCHRONIZE
    # ========================================================

    print(
        "\nSynchronizing OCC..."
    )

    gmsh.model.occ.synchronize()


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nCreating physical groups..."
    )


    # --------------------------------------------------------
    # VACUUM
    # --------------------------------------------------------

    gmsh.model.addPhysicalGroup(
        3,
        [vacuum],
        VACUUM_ID
    )

    gmsh.model.setPhysicalName(
        3,
        VACUUM_ID,
        "Vacuum"
    )


    # --------------------------------------------------------
    # SILICON
    # --------------------------------------------------------

    gmsh.model.addPhysicalGroup(
        3,
        [silicon],
        SILICON_ID
    )

    gmsh.model.setPhysicalName(
        3,
        SILICON_ID,
        "Silicon_Substrate"
    )


    # --------------------------------------------------------
    # PEC
    # --------------------------------------------------------

    gmsh.model.addPhysicalGroup(
        2,
        metal_surfaces,
        PEC_ID
    )

    gmsh.model.setPhysicalName(
        2,
        PEC_ID,
        "Superconducting_Metal"
    )


    # ========================================================
    # MESH PARAMETERS
    # ========================================================

    print(
        "\nSetting mesh parameters..."
    )

    gmsh.option.setNumber(
        "Mesh.Algorithm3D",
        1
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMin",
        GLOBAL_MIN
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMax",
        GLOBAL_MAX
    )

    gmsh.option.setNumber(
        "Mesh.Optimize",
        0
    )

    gmsh.option.setNumber(
        "Mesh.OptimizeNetgen",
        0
    )


    # ========================================================
    # GENERATE MESH
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "GENERATING 3D MESH"
    )

    print(
        "=" * 80
    )

    gmsh.model.mesh.generate(3)


    # ========================================================
    # REMOVE DUPLICATE NODES
    # ========================================================

    print(
        "\nRemoving duplicate mesh nodes..."
    )

    try:

        gmsh.model.mesh.removeDuplicateNodes()

        print(
            "Duplicate mesh nodes removed."
        )

    except Exception as exc:

        print(
            "Duplicate-node cleanup warning:",
            exc
        )


    # ========================================================
    # REMOVE DUPLICATE ELEMENTS
    # ========================================================

    print(
        "Removing duplicate mesh elements..."
    )

    try:

        gmsh.model.mesh.removeDuplicateElements()

        print(
            "Duplicate mesh elements removed."
        )

    except Exception as exc:

        print(
            "Duplicate-element cleanup warning:",
            exc
        )


    # ========================================================
    # CHECK ELEMENT NODE UNIQUENESS
    # ========================================================

    print(
        "\nChecking element vertex uniqueness..."
    )

    bad_elements = []

    element_types, element_tags, element_nodes = (
        gmsh.model.mesh.getElements()
    )

    for etype, tags, nodes in zip(
        element_types,
        element_tags,
        element_nodes
    ):

        # Get number of nodes per element
        _, _, _, num_nodes, _, _ = (
            gmsh.model.mesh.getElementProperties(
                etype
            )
        )

        for i, element_tag in enumerate(tags):

            start = (
                i * num_nodes
            )

            end = (
                start + num_nodes
            )

            connectivity = nodes[
                start:end
            ]

            if len(set(connectivity)) != len(
                connectivity
            ):

                bad_elements.append(
                    (
                        int(element_tag),
                        int(etype),
                        connectivity.tolist()
                    )
                )

                if len(bad_elements) >= 20:

                    break

        if len(bad_elements) >= 20:

            break


    if bad_elements:

        print(
            "\nWARNING: "
            f"Found {len(bad_elements)} "
            "elements with repeated vertices."
        )

        for item in bad_elements[:10]:

            print(
                "  Element:",
                item
            )

        raise RuntimeError(
            "\nMesh contains degenerate elements. "
            "Do NOT send this mesh to Palace."
        )


    print(
        "PASS: all checked elements have "
        "unique vertex indices."
    )


    # ========================================================
    # NODE / ELEMENT STATISTICS
    # ========================================================

    nodes, coords, _ = (
        gmsh.model.mesh.getNodes()
    )

    total_elements = sum(
        len(tags)
        for tags in element_tags
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "FINAL MESH STATISTICS"
    )

    print(
        "=" * 80
    )

    print(
        f"Nodes    : {len(nodes):,}"
    )

    print(
        f"Elements : {total_elements:,}"
    )


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nPhysical groups:"
    )

    for dim, tag in (
        gmsh.model.getPhysicalGroups()
    ):

        name = gmsh.model.getPhysicalName(
            dim,
            tag
        )

        print(
            f"  Dimension={dim}, "
            f"Attribute={tag}, "
            f"Name={name}"
        )


    # ========================================================
    # WRITE MESH
    # ========================================================

    print(
        "\nWriting Palace mesh..."
    )

    gmsh.write(
        MESH_PATH
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "PALACE MESH CREATED SUCCESSFULLY"
    )

    print(
        "=" * 80
    )

    print(
        f"\nMesh file:"
        f"\n{MESH_PATH}"
    )


finally:

    gmsh.finalize()

    print(
        "\nGmsh finalized."
    )
# Out:
# ================================================================================
# PALACE-COMPATIBLE MESH GENERATOR
# ================================================================================
#
# Reading GDS:
# quantum_chip_export_manuscript.gds
# Loaded 19 cells.
#
# Using top cell: TOP_main_1
#
# Extracting actual metal geometry...
# Clean metal polygons: 2450
#
# Finding JJ references...
# Found 8 JJ references.
#
# JJ locations:
#   JJ1: x=-1.132500 mm, y=0.000000 mm, rotation=180.0
#   JJ2: x=-0.867500 mm, y=0.000000 mm, rotation=None
#   JJ3: x=1.267500 mm, y=0.000000 mm, rotation=180.0
#   JJ4: x=1.532500 mm, y=0.000000 mm, rotation=None
#   JJ5: x=-1.132500 mm, y=-2.700000 mm, rotation=180.0
#   JJ6: x=-0.867500 mm, y=-2.700000 mm, rotation=None
#   JJ7: x=1.267500 mm, y=-2.700000 mm, rotation=180.0
#   JJ8: x=1.532500 mm, y=-2.700000 mm, rotation=None
#
# Initializing Gmsh...
#
# Creating silicon substrate...
# Creating vacuum...
#
# Creating metal surfaces...
# Created 2450 metal surfaces.
# Skipped 0 invalid polygons.
#
# Removing duplicate OCC geometry...
# Duplicate OCC geometry removed.
#
# Synchronizing OCC...
#
# Creating physical groups...
#
# Setting mesh parameters...
#
# ================================================================================
# GENERATING 3D MESH
# ================================================================================
#
# Removing duplicate mesh nodes...
# Duplicate mesh nodes removed.
# Removing duplicate mesh elements...
# Duplicate mesh elements removed.
#
# Checking element vertex uniqueness...
# PASS: all checked elements have unique vertex indices.
#
# ================================================================================
# FINAL MESH STATISTICS
# ================================================================================
# Nodes    : 121,916
# Elements : 570,782
#
# Physical groups:
#   Dimension=2, Attribute=10, Name=Superconducting_Metal
#   Dimension=3, Attribute=1, Name=Vacuum
#   Dimension=3, Attribute=2, Name=Silicon_Substrate
#
# Writing Palace mesh...
#
# ================================================================================
# PALACE MESH CREATED SUCCESSFULLY
# ================================================================================
#
# Mesh file:
# /content/quantum_chip_mesh_palace.msh
#
# Gmsh finalized.

# %%
# ============================================================
# STEP 5C
# CLEAN PALACE MESH AND WRITE GMSH 2.2 FORMAT
#
# Input:
#   quantum_chip_mesh_palace.msh
#
# Output:
#   quantum_chip_mesh_palace_v22.msh
#
# Purpose:
#   1. Read the existing Gmsh mesh
#   2. Remove duplicate nodes
#   3. Remove duplicate elements
#   4. Remove degenerate elements
#   5. Write MSH 2.2
#
# MSH 2.2 is deliberately used for maximum MFEM compatibility.
# ============================================================

import os
import gmsh


INPUT_MESH = "/content/quantum_chip_mesh_palace.msh"

OUTPUT_MESH = "/content/quantum_chip_mesh_palace_v22.msh"


# ============================================================
# CHECK
# ============================================================

if not os.path.exists(INPUT_MESH):

    raise FileNotFoundError(
        f"Mesh not found:\n{INPUT_MESH}"
    )


print("=" * 80)
print("PALACE MESH CLEANUP")
print("=" * 80)

print(
    "\nInput:",
    INPUT_MESH
)

print(
    "Output:",
    OUTPUT_MESH
)


# ============================================================
# INITIALIZE
# ============================================================

gmsh.initialize()

gmsh.option.setNumber(
    "General.Terminal",
    1
)

try:

    # --------------------------------------------------------
    # Open existing mesh
    # --------------------------------------------------------

    print(
        "\nOpening existing Gmsh mesh..."
    )

    gmsh.open(
        INPUT_MESH
    )


    # --------------------------------------------------------
    # Initial statistics
    # --------------------------------------------------------

    node_tags, node_coords, _ = (
        gmsh.model.mesh.getNodes()
    )

    print(
        f"Initial nodes: "
        f"{len(node_tags):,}"
    )


    # --------------------------------------------------------
    # Remove duplicate nodes
    # --------------------------------------------------------

    print(
        "\nRemoving duplicate nodes..."
    )

    gmsh.model.mesh.removeDuplicateNodes()


    # --------------------------------------------------------
    # Remove duplicate elements
    # --------------------------------------------------------

    print(
        "Removing duplicate elements..."
    )

    gmsh.model.mesh.removeDuplicateElements()


    # --------------------------------------------------------
    # Renumber nodes
    # --------------------------------------------------------

    print(
        "Renumbering nodes..."
    )

    try:

        gmsh.model.mesh.renumberNodes()

    except Exception as exc:

        print(
            "Node renumbering warning:",
            exc
        )


    # ========================================================
    # CHECK ELEMENT CONNECTIVITY
    # ========================================================

    print(
        "\nChecking element connectivity..."
    )

    element_types, element_tags, element_nodes = (
        gmsh.model.mesh.getElements()
    )

    bad_elements = []

    total_elements = 0


    for etype, tags, nodes in zip(
        element_types,
        element_tags,
        element_nodes
    ):

        (
            element_name,
            dim,
            order,
            num_nodes,
            local_node_coords,
            num_primary_nodes
        ) = gmsh.model.mesh.getElementProperties(
            etype
        )


        print(
            f"  {element_name}: "
            f"{len(tags):,} elements, "
            f"{num_nodes} nodes/element"
        )


        total_elements += len(tags)


        # ----------------------------------------------------
        # Connectivity is flattened:
        #
        # [e1n1,e1n2,...,e1nn,
        #  e2n1,e2n2,...]
        # ----------------------------------------------------

        for i, element_tag in enumerate(tags):

            start = i * num_nodes

            end = start + num_nodes

            connectivity = nodes[
                start:end
            ]


            # ----------------------------------------------
            # Repeated node inside one element
            # ----------------------------------------------

            if (
                len(set(connectivity.tolist()))
                != len(connectivity)
            ):

                bad_elements.append(
                    {
                        "tag": int(element_tag),
                        "type": int(etype),
                        "name": element_name,
                        "nodes": connectivity.tolist()
                    }
                )


    print(
        f"\nTotal elements: "
        f"{total_elements:,}"
    )

    print(
        f"Degenerate elements found: "
        f"{len(bad_elements)}"
    )


    # ========================================================
    # ABORT IF BAD ELEMENTS REMAIN
    # ========================================================

    if bad_elements:

        print(
            "\nFirst bad elements:"
        )

        for bad in bad_elements[:20]:

            print(
                bad
            )


        raise RuntimeError(
            "\nThe mesh still contains "
            "elements with repeated vertex indices."
        )


    print(
        "\nPASS:"
    )

    print(
        "No element contains repeated vertex indices."
    )


    # ========================================================
    # FORCE GMSH 2.2
    # ========================================================

    print(
        "\nSetting Gmsh output format to 2.2..."
    )

    gmsh.option.setNumber(
        "Mesh.MshFileVersion",
        2.2
    )

    gmsh.option.setNumber(
        "Mesh.Binary",
        0
    )


    # ========================================================
    # WRITE
    # ========================================================

    print(
        "\nWriting cleaned MSH 2.2 file..."
    )

    gmsh.write(
        OUTPUT_MESH
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "CLEAN MESH CREATED"
    )

    print(
        "=" * 80
    )

    print(
        "\nOutput:"
    )

    print(
        OUTPUT_MESH
    )

finally:

    gmsh.finalize()

    print(
        "\nGmsh finalized."
    )
# Out:
# ================================================================================
# PALACE MESH CLEANUP
# ================================================================================
#
# Input: /content/quantum_chip_mesh_palace.msh
# Output: /content/quantum_chip_mesh_palace_v22.msh
#
# Opening existing Gmsh mesh...
# Initial nodes: 121,755
#
# Removing duplicate nodes...
# Removing duplicate elements...
# Renumbering nodes...
#
# Checking element connectivity...
#   Triangle 3: 84,163 elements, 3 nodes/element
#   Tetrahedron 4: 314,269 elements, 4 nodes/element
#
# Total elements: 398,432
# Degenerate elements found: 0
#
# PASS:
# No element contains repeated vertex indices.
#
# Setting Gmsh output format to 2.2...
#
# Writing cleaned MSH 2.2 file...
#
# ================================================================================
# CLEAN MESH CREATED
# ================================================================================
#
# Output:
# /content/quantum_chip_mesh_palace_v22.msh
#
# Gmsh finalized.

# %%
# import json

# config_path = "/content/palace_eigen_test.json"

# with open(config_path, "r") as f:
#     palace_config = json.load(f)

# palace_config["Model"]["Mesh"] = (
#     "/content/quantum_chip_mesh_palace_v22.msh"
# )

# with open(config_path, "w") as f:
#     json.dump(
#         palace_config,
#         f,
#         indent=4
#     )

# print("Updated mesh:")
# print(palace_config["Model"]["Mesh"])

# %%
# # ============================================================
# # STEP 5D
# # CONFORMAL 3D PALACE MESH
# #
# # IMPORTANT:
# # The superconducting metal is located at z = 0, exactly
# # between the silicon and vacuum regions.
# #
# # We therefore fragment the silicon/vacuum geometry using
# # the metal surfaces before generating the tetrahedral mesh.
# #
# # This is required to obtain a conformal topology suitable
# # for MFEM / Palace.
# # ============================================================

# import os
# import gdspy
# import gmsh


# # ============================================================
# # INPUT
# # ============================================================

# GDS_PATH = "quantum_chip_export_manuscript.gds"

# MESH_PATH = "/content/quantum_chip_mesh_conformal.msh"

# TOP_CELL_NAME = "TOP_main_1"

# METAL_LAYER = 1
# METAL_DATATYPE = 0


# # ============================================================
# # CHIP
# # ============================================================

# CHIP_X = 14.0
# CHIP_Y = 14.0

# SUBSTRATE_THICKNESS = 0.5
# AIR_HEIGHT = 0.5


# # ============================================================
# # PHYSICAL ATTRIBUTES
# # ============================================================

# VACUUM_ID = 1
# SILICON_ID = 2
# PEC_ID = 10


# # ============================================================
# # MESH
# # ============================================================

# GLOBAL_MIN = 0.020     # 20 um
# GLOBAL_MAX = 0.150     # 150 um


# # ============================================================
# # READ GDS
# # ============================================================

# print("=" * 80)
# print("CONFORMAL PALACE MESH GENERATOR")
# print("=" * 80)

# print("\nReading GDS...")

# lib = gdspy.GdsLibrary()

# lib.read_gds(
#     GDS_PATH
# )

# print(
#     f"Loaded {len(lib.cells)} cells."
# )


# # ============================================================
# # TOP CELL
# # ============================================================

# if TOP_CELL_NAME not in lib.cells:

#     raise RuntimeError(
#         f"Top cell not found: {TOP_CELL_NAME}"
#     )

# top = lib.cells[
#     TOP_CELL_NAME
# ]

# print(
#     f"Using top cell: {TOP_CELL_NAME}"
# )


# # ============================================================
# # EXTRACT METAL
# # ============================================================

# print(
#     "\nExtracting Layer 1 / Datatype 0..."
# )

# polygons_by_spec = top.get_polygons(
#     by_spec=True
# )

# metal_polygons = []

# for spec, polygons in polygons_by_spec.items():

#     layer, datatype = spec

#     if layer != METAL_LAYER:
#         continue

#     if datatype != METAL_DATATYPE:
#         continue

#     for polygon in polygons:

#         if len(polygon) < 3:
#             continue

#         clean = []

#         for p in polygon:

#             point = (
#                 round(float(p[0]), 10),
#                 round(float(p[1]), 10)
#             )

#             if not clean or point != clean[-1]:

#                 clean.append(point)


#         # Remove repeated closing point

#         if (
#             len(clean) > 1
#             and clean[0] == clean[-1]
#         ):

#             clean.pop()


#         if len(set(clean)) >= 3:

#             metal_polygons.append(
#                 clean
#             )


# print(
#     f"Metal polygons: "
#     f"{len(metal_polygons)}"
# )


# # ============================================================
# # INITIALIZE GMSH
# # ============================================================

# print(
#     "\nInitializing Gmsh..."
# )

# gmsh.initialize()

# gmsh.option.setNumber(
#     "General.Terminal",
#     1
# )

# gmsh.model.add(
#     "four_qubit_conformal"
# )


# try:

#     # ========================================================
#     # SILICON
#     # ========================================================

#     print(
#         "\nCreating silicon..."
#     )

#     silicon = gmsh.model.occ.addBox(

#         -CHIP_X / 2,
#         -CHIP_Y / 2,
#         -SUBSTRATE_THICKNESS,

#         CHIP_X,
#         CHIP_Y,
#         SUBSTRATE_THICKNESS
#     )


#     # ========================================================
#     # VACUUM
#     # ========================================================

#     print(
#         "Creating vacuum..."
#     )

#     vacuum = gmsh.model.occ.addBox(

#         -CHIP_X / 2,
#         -CHIP_Y / 2,
#         0.0,

#         CHIP_X,
#         CHIP_Y,
#         AIR_HEIGHT
#     )


#     # ========================================================
#     # POINT CACHE
#     # ========================================================

#     point_cache = {}


#     def get_point(x, y):

#         key = (
#             round(float(x), 10),
#             round(float(y), 10),
#             0.0
#         )

#         if key not in point_cache:

#             point_cache[key] = (
#                 gmsh.model.occ.addPoint(
#                     key[0],
#                     key[1],
#                     key[2]
#                 )
#             )

#         return point_cache[key]


#     # ========================================================
#     # CREATE METAL SURFACES
#     # ========================================================

#     print(
#         "\nCreating metal interface surfaces..."
#     )

#     metal_surfaces = []

#     for index, polygon in enumerate(
#         metal_polygons
#     ):

#         points = [
#             get_point(x, y)
#             for x, y in polygon
#         ]


#         if len(set(points)) < 3:
#             continue


#         lines = []

#         valid = True

#         for i in range(
#             len(points)
#         ):

#             p1 = points[i]

#             p2 = points[
#                 (i + 1) % len(points)
#             ]

#             if p1 == p2:

#                 valid = False
#                 break


#             try:

#                 line = gmsh.model.occ.addLine(
#                     p1,
#                     p2
#                 )

#                 lines.append(line)

#             except Exception:

#                 valid = False
#                 break


#         if not valid:

#             continue


#         try:

#             wire = gmsh.model.occ.addWire(
#                 lines
#             )

#             surface = (
#                 gmsh.model.occ.addPlaneSurface(
#                     [wire]
#                 )
#             )

#             metal_surfaces.append(
#                 surface
#             )

#         except Exception as exc:

#             print(
#                 f"Metal polygon {index} "
#                 f"warning: {exc}"
#             )


#     print(
#         f"Created {len(metal_surfaces)} "
#         f"metal surfaces."
#     )


#     # ========================================================
#     # SYNCHRONIZE
#     # ========================================================

#     print(
#         "\nSynchronizing OCC..."
#     )

#     gmsh.model.occ.synchronize()


#     # ========================================================
#     # REMOVE DUPLICATES
#     # ========================================================

#     print(
#         "Removing duplicate geometry..."
#     )

#     gmsh.model.occ.removeAllDuplicates()

#     gmsh.model.occ.synchronize()


#     # ========================================================
#     # GET CURRENT METAL SURFACES
#     #
#     # Because removeAllDuplicates() can renumber entities,
#     # retrieve all z=0 planar surfaces rather than blindly
#     # relying on the old tags.
#     # ========================================================

#     print(
#         "\nIdentifying metal interface surfaces..."
#     )

#     all_surfaces = gmsh.model.getEntities(
#         2
#     )

#     candidate_metal = []


#     for dim, tag in all_surfaces:

#         try:

#             com = (
#                 gmsh.model.occ.getCenterOfMass(
#                     dim,
#                     tag
#                 )
#             )

#             x = com[0]
#             y = com[1]
#             z = com[2]


#             # Metal must be on z=0 and inside chip
#             if abs(z) < 1e-8:

#                 if (
#                     -CHIP_X / 2 <= x <= CHIP_X / 2
#                     and
#                     -CHIP_Y / 2 <= y <= CHIP_Y / 2
#                 ):

#                     candidate_metal.append(
#                         tag
#                     )

#         except Exception:
#             pass


#     print(
#         f"Candidate z=0 surfaces: "
#         f"{len(candidate_metal)}"
#     )


#     # ========================================================
#     # FRAGMENT VOLUMES WITH METAL
#     # ========================================================

#     print(
#         "\n" + "=" * 80
#     )

#     print(
#         "FRAGMENTING SILICON/VACUUM WITH METAL"
#     )

#     print(
#         "=" * 80
#     )

#     volume_objects = [
#         (3, silicon),
#         (3, vacuum)
#     ]

#     metal_objects = [
#         (2, tag)
#         for tag in candidate_metal
#     ]


#     # --------------------------------------------------------
#     # This is the critical topology operation.
#     # --------------------------------------------------------

#     if metal_objects:

#         print(
#             f"Fragmenting using "
#             f"{len(metal_objects)} "
#             f"metal surfaces..."
#         )

#         fragmented, fragment_map = (
#             gmsh.model.occ.fragment(
#                 volume_objects,
#                 metal_objects
#             )
#         )

#         print(
#             f"Fragmentation produced "
#             f"{len(fragmented)} entities."
#         )

#     else:

#         raise RuntimeError(
#             "No metal interface surfaces "
#             "were found for fragmentation."
#         )


#     # ========================================================
#     # SYNCHRONIZE AGAIN
#     # ========================================================

#     print(
#         "\nSynchronizing fragmented geometry..."
#     )

#     gmsh.model.occ.synchronize()


#     # ========================================================
#     # REMOVE DUPLICATES AGAIN
#     # ========================================================

#     print(
#         "Removing duplicate geometry..."
#     )

#     gmsh.model.occ.removeAllDuplicates()

#     gmsh.model.occ.synchronize()


#     # ========================================================
#     # IDENTIFY VOLUMES
#     # ========================================================

#     volumes = gmsh.model.getEntities(
#         3
#     )

#     print(
#         f"\n3D volumes after fragmentation: "
#         f"{len(volumes)}"
#     )


#     # ========================================================
#     # IDENTIFY SILICON / VACUUM BY CENTER OF MASS
#     # ========================================================

#     silicon_volumes = []
#     vacuum_volumes = []


#     for dim, tag in volumes:

#         com = (
#             gmsh.model.occ.getCenterOfMass(
#                 dim,
#                 tag
#             )
#         )

#         z = com[2]


#         # Silicon occupies z < 0
#         if z < 0:

#             silicon_volumes.append(
#                 tag
#             )

#         # Vacuum occupies z > 0
#         else:

#             vacuum_volumes.append(
#                 tag
#             )


#     print(
#         f"Silicon volumes: "
#         f"{len(silicon_volumes)}"
#     )

#     print(
#         f"Vacuum volumes: "
#         f"{len(vacuum_volumes)}"
#     )


#     if not silicon_volumes:

#         raise RuntimeError(
#             "No silicon volumes identified."
#         )

#     if not vacuum_volumes:

#         raise RuntimeError(
#             "No vacuum volumes identified."
#         )


#     # ========================================================
#     # FIND METAL INTERFACE SURFACES
#     #
#     # At this point, identify z=0 surfaces that are shared
#     # by the fragmented silicon/vacuum geometry.
#     # ========================================================

#     print(
#         "\nIdentifying conformal metal surfaces..."
#     )


#     interface_surfaces = []


#     for dim, tag in gmsh.model.getEntities(2):

#         try:

#             com = (
#                 gmsh.model.occ.getCenterOfMass(
#                     dim,
#                     tag
#                 )
#             )

#             if abs(com[2]) < 1e-8:

#                 interface_surfaces.append(
#                     tag
#                 )

#         except Exception:

#             pass


#     print(
#         f"z=0 interface surfaces: "
#         f"{len(interface_surfaces)}"
#     )


#     if not interface_surfaces:

#         raise RuntimeError(
#             "No conformal metal interface "
#             "surfaces found."
#         )


#     # ========================================================
#     # PHYSICAL GROUPS
#     # ========================================================

#     print(
#         "\nCreating physical groups..."
#     )


#     gmsh.model.addPhysicalGroup(
#         3,
#         vacuum_volumes,
#         VACUUM_ID
#     )

#     gmsh.model.setPhysicalName(
#         3,
#         VACUUM_ID,
#         "Vacuum"
#     )


#     gmsh.model.addPhysicalGroup(
#         3,
#         silicon_volumes,
#         SILICON_ID
#     )

#     gmsh.model.setPhysicalName(
#         3,
#         SILICON_ID,
#         "Silicon_Substrate"
#     )


#     gmsh.model.addPhysicalGroup(
#         2,
#         interface_surfaces,
#         PEC_ID
#     )

#     gmsh.model.setPhysicalName(
#         2,
#         PEC_ID,
#         "Superconducting_Metal"
#     )


#     # ========================================================
#     # MESH SETTINGS
#     # ========================================================

#     print(
#         "\nSetting mesh parameters..."
#     )

#     gmsh.option.setNumber(
#         "Mesh.Algorithm3D",
#         1
#     )

#     gmsh.option.setNumber(
#         "Mesh.CharacteristicLengthMin",
#         GLOBAL_MIN
#     )

#     gmsh.option.setNumber(
#         "Mesh.CharacteristicLengthMax",
#         GLOBAL_MAX
#     )

#     gmsh.option.setNumber(
#         "Mesh.Optimize",
#         0
#     )

#     gmsh.option.setNumber(
#         "Mesh.OptimizeNetgen",
#         0
#     )


#     # ========================================================
#     # GENERATE
#     # ========================================================

#     print(
#         "\n" + "=" * 80
#     )

#     print(
#         "GENERATING CONFORMAL 3D MESH"
#     )

#     print(
#         "=" * 80
#     )

#     gmsh.model.mesh.generate(
#         3
#     )


#     # ========================================================
#     # CLEAN
#     # ========================================================

#     print(
#         "\nRemoving duplicate nodes..."
#     )

#     gmsh.model.mesh.removeDuplicateNodes()


#     print(
#         "Removing duplicate elements..."
#     )

#     gmsh.model.mesh.removeDuplicateElements()


#     # ========================================================
#     # CHECK ELEMENT CONNECTIVITY
#     # ========================================================

#     print(
#         "\nChecking element connectivity..."
#     )

#     types, tags_list, nodes_list = (
#         gmsh.model.mesh.getElements()
#     )

#     bad = 0


#     for etype, tags, nodes in zip(
#         types,
#         tags_list,
#         nodes_list
#     ):

#         props = (
#             gmsh.model.mesh.getElementProperties(
#                 etype
#             )
#         )

#         num_nodes = props[3]

#         for i in range(
#             len(tags)
#         ):

#             conn = nodes[
#                 i * num_nodes:
#                 (i + 1) * num_nodes
#             ]

#             if (
#                 len(set(conn.tolist()))
#                 != len(conn)
#             ):

#                 bad += 1

#                 if bad <= 10:

#                     print(
#                         "Bad element:",
#                         tags[i],
#                         conn
#                     )


#     print(
#         f"Degenerate elements: {bad}"
#     )


#     if bad:

#         raise RuntimeError(
#             "Degenerate elements remain."
#         )


#     # ========================================================
#     # STATISTICS
#     # ========================================================

#     nodes, coords, _ = (
#         gmsh.model.mesh.getNodes()
#     )

#     total_elements = sum(
#         len(x)
#         for x in tags_list
#     )


#     print(
#         "\n" + "=" * 80
#     )

#     print(
#         "FINAL MESH"
#     )

#     print(
#         "=" * 80
#     )

#     print(
#         f"Nodes    : {len(nodes):,}"
#     )

#     print(
#         f"Elements : {total_elements:,}"
#     )


#     # ========================================================
#     # WRITE MSH 2.2
#     # ========================================================

#     gmsh.option.setNumber(
#         "Mesh.MshFileVersion",
#         2.2
#     )

#     gmsh.option.setNumber(
#         "Mesh.Binary",
#         0
#     )


#     print(
#         "\nWriting:"
#     )

#     print(
#         MESH_PATH
#     )

#     gmsh.write(
#         MESH_PATH
#     )


#     print(
#         "\n" + "=" * 80
#     )

#     print(
#         "CONFORMAL MESH COMPLETE"
#     )

#     print(
#         "=" * 80
#     )


# finally:

#     gmsh.finalize()

#     print(
#         "\nGmsh finalized."
#     )
# Out:
# ================================================================================
# CONFORMAL PALACE MESH GENERATOR
# ================================================================================
#
# Reading GDS...
# Loaded 19 cells.
# Using top cell: TOP_main_1
#
# Extracting Layer 1 / Datatype 0...
# Metal polygons: 2450
#
# Initializing Gmsh...
#
# Creating silicon...
# Creating vacuum...
#
# Creating metal interface surfaces...
# Created 2450 metal surfaces.
#
# Synchronizing OCC...
# Removing duplicate geometry...
#
# Identifying metal interface surfaces...
# Candidate z=0 surfaces: 2451
#
# ================================================================================
# FRAGMENTING SILICON/VACUUM WITH METAL
# ================================================================================
# Fragmenting using 2451 metal surfaces...
# Fragmentation produced 7385 entities.
#
# Synchronizing fragmented geometry...
# Removing duplicate geometry...
#
# 3D volumes after fragmentation: 2
# Silicon volumes: 1
# Vacuum volumes: 1
#
# Identifying conformal metal surfaces...
# z=0 interface surfaces: 2475
#
# Creating physical groups...
#
# Setting mesh parameters...
#
# ================================================================================
# GENERATING CONFORMAL 3D MESH
# ================================================================================
#
# Gmsh finalized.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_73884/324602233.py in <cell line: 0>()
#     738     )
#     739
# --> 740     gmsh.model.mesh.generate(
#     741         3
#     742     )
#
# /usr/local/lib/python3.12/dist-packages/gmsh.py in generate(dim)
#    2187                 byref(ierr))
#    2188             if ierr.value != 0:
# -> 2189                 raise Exception(logger.getLastError())
#    2190
#    2191         @staticmethod
#
# Exception: PLC Error:  A segment and a facet intersect at point

# %%
# ============================================================
# STEP 5D — ROBUST CONFORMAL PALACE MESH
#
# GDS metal polygons
#       ↓
# Shapely 2D union
#       ↓
# Non-overlapping metal regions
#       ↓
# Silicon + vacuum fragmentation
#       ↓
# Conformal 3D mesh
#       ↓
# MSH 2.2 for MFEM / Palace
#
# IMPORTANT:
# JJs are NOT included as volumetric geometry yet.
# ============================================================

import os
import gdspy
import gmsh

from shapely.geometry import Polygon
from shapely.ops import unary_union


# ============================================================
# INPUT
# ============================================================

GDS_PATH = "quantum_chip_export_manuscript.gds"

MESH_PATH = "/content/quantum_chip_mesh_conformal.msh"

TOP_CELL_NAME = "TOP_main_1"

METAL_LAYER = 1
METAL_DATATYPE = 0


# ============================================================
# CHIP GEOMETRY
# ============================================================

CHIP_X = 14.0
CHIP_Y = 14.0

SUBSTRATE_THICKNESS = 0.5
AIR_HEIGHT = 0.5


# ============================================================
# PHYSICAL ATTRIBUTES
# ============================================================

VACUUM_ID = 1
SILICON_ID = 2
PEC_ID = 10


# ============================================================
# MESH PARAMETERS
# ============================================================

GLOBAL_MIN = 0.020     # 20 um
GLOBAL_MAX = 0.150     # 150 um


# ============================================================
# READ GDS
# ============================================================

print("=" * 80)
print("ROBUST CONFORMAL PALACE MESH GENERATOR")
print("=" * 80)

print("\nReading GDS...")

lib = gdspy.GdsLibrary()

lib.read_gds(GDS_PATH)

print(
    f"Loaded {len(lib.cells)} cells."
)


# ============================================================
# TOP CELL
# ============================================================

if TOP_CELL_NAME not in lib.cells:

    raise RuntimeError(
        f"Top cell not found: {TOP_CELL_NAME}"
    )

top = lib.cells[TOP_CELL_NAME]

print(
    f"Using top cell: {TOP_CELL_NAME}"
)


# ============================================================
# EXTRACT METAL POLYGONS
# ============================================================

print(
    "\nExtracting Layer 1 / Datatype 0..."
)

polygons_by_spec = top.get_polygons(
    by_spec=True
)

raw_polygons = []

for spec, polygons in polygons_by_spec.items():

    layer, datatype = spec

    if layer != METAL_LAYER:
        continue

    if datatype != METAL_DATATYPE:
        continue

    for polygon in polygons:

        if len(polygon) < 3:
            continue

        points = []

        for p in polygon:

            x = float(p[0])
            y = float(p[1])

            point = (
                round(x, 10),
                round(y, 10)
            )

            if not points or point != points[-1]:

                points.append(point)


        # Remove closing duplicate
        if (
            len(points) > 1
            and points[0] == points[-1]
        ):

            points.pop()


        if len(set(points)) >= 3:

            raw_polygons.append(
                points
            )


print(
    f"Raw metal polygons: "
    f"{len(raw_polygons)}"
)


# ============================================================
# CONVERT TO SHAPELY
# ============================================================

print(
    "\nConverting polygons to Shapely..."
)

shapes = []

invalid_count = 0

for i, points in enumerate(
    raw_polygons
):

    try:

        poly = Polygon(points)

        # Repair small self-intersections
        if not poly.is_valid:

            poly = poly.buffer(0)


        if poly.is_empty:
            continue

        if poly.area <= 1e-12:
            continue

        shapes.append(poly)

    except Exception:

        invalid_count += 1


print(
    f"Valid Shapely polygons: "
    f"{len(shapes)}"
)

print(
    f"Invalid/skipped: "
    f"{invalid_count}"
)


# ============================================================
# UNION ALL METAL
# ============================================================

print(
    "\n" + "=" * 80
)

print(
    "UNITING OVERLAPPING METAL POLYGONS"
)

print(
    "=" * 80
)

print(
    "This may take some time..."
)

metal_union = unary_union(
    shapes
)


# ============================================================
# REPAIR UNION
# ============================================================

if not metal_union.is_valid:

    print(
        "\nUnion is invalid; repairing..."
    )

    metal_union = metal_union.buffer(0)


print(
    "\nMetal union type:",
    metal_union.geom_type
)

print(
    "Unified metal area:",
    metal_union.area,
    "mm^2"
)


# ============================================================
# EXTRACT POLYGONS
# ============================================================

if metal_union.geom_type == "Polygon":

    unified_polygons = [
        metal_union
    ]

elif metal_union.geom_type == "MultiPolygon":

    unified_polygons = list(
        metal_union.geoms
    )

else:

    raise RuntimeError(
        "Unexpected Shapely geometry type: "
        + metal_union.geom_type
    )


print(
    "Unified metal regions:",
    len(unified_polygons)
)


# ============================================================
# INITIALIZE GMSH
# ============================================================

print(
    "\nInitializing Gmsh..."
)

gmsh.initialize()

gmsh.option.setNumber(
    "General.Terminal",
    1
)

gmsh.model.add(
    "four_qubit_conformal"
)


try:

    # ========================================================
    # CREATE SILICON
    # ========================================================

    print(
        "\nCreating silicon..."
    )

    silicon = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        -SUBSTRATE_THICKNESS,

        CHIP_X,
        CHIP_Y,
        SUBSTRATE_THICKNESS
    )


    # ========================================================
    # CREATE VACUUM
    # ========================================================

    print(
        "Creating vacuum..."
    )

    vacuum = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        0.0,

        CHIP_X,
        CHIP_Y,
        AIR_HEIGHT
    )


    # ========================================================
    # POINT CACHE
    # ========================================================

    point_cache = {}


    def get_point(x, y):

        key = (
            round(float(x), 10),
            round(float(y), 10),
            0.0
        )

        if key not in point_cache:

            point_cache[key] = (
                gmsh.model.occ.addPoint(
                    key[0],
                    key[1],
                    key[2]
                )
            )

        return point_cache[key]


    # ========================================================
    # CREATE UNIFIED METAL SURFACES
    # ========================================================

    print(
        "\nCreating unified metal surfaces..."
    )

    metal_surfaces = []


    for index, poly in enumerate(
        unified_polygons
    ):

        # ----------------------------------------------------
        # OUTER RING
        # ----------------------------------------------------

        exterior = list(
            poly.exterior.coords
        )

        exterior = exterior[:-1]


        outer_points = []

        for x, y in exterior:

            outer_points.append(
                get_point(x, y)
            )


        outer_lines = []

        for i in range(
            len(outer_points)
        ):

            p1 = outer_points[i]

            p2 = outer_points[
                (i + 1) % len(outer_points)
            ]

            if p1 == p2:
                continue

            outer_lines.append(
                gmsh.model.occ.addLine(
                    p1,
                    p2
                )
            )


        outer_wire = (
            gmsh.model.occ.addWire(
                outer_lines
            )
        )


        # ----------------------------------------------------
        # HOLES
        # ----------------------------------------------------

        hole_wires = []


        for interior in poly.interiors:

            coords = list(
                interior.coords
            )

            coords = coords[:-1]


            hole_points = []

            for x, y in coords:

                hole_points.append(
                    get_point(x, y)
                )


            hole_lines = []

            for i in range(
                len(hole_points)
            ):

                p1 = hole_points[i]

                p2 = hole_points[
                    (i + 1) % len(hole_points)
                ]

                if p1 == p2:
                    continue

                hole_lines.append(
                    gmsh.model.occ.addLine(
                        p1,
                        p2
                    )
                )


            if len(hole_lines) >= 3:

                hole_wire = (
                    gmsh.model.occ.addWire(
                        hole_lines
                    )
                )

                hole_wires.append(
                    hole_wire
                )


        # ----------------------------------------------------
        # CREATE PLANE SURFACE
        # ----------------------------------------------------

        try:

            wire_list = [
                outer_wire
            ] + hole_wires

            surface = (
                gmsh.model.occ.addPlaneSurface(
                    wire_list
                )
            )

            metal_surfaces.append(
                surface
            )

        except Exception as exc:

            print(
                f"Warning: metal region "
                f"{index} failed:"
            )

            print(
                exc
            )


    print(
        "\nUnified metal surfaces created:",
        len(metal_surfaces)
    )


    # ========================================================
    # SYNCHRONIZE
    # ========================================================

    gmsh.model.occ.synchronize()


    # ========================================================
    # REMOVE DUPLICATES
    # ========================================================

    print(
        "\nRemoving duplicate OCC geometry..."
    )

    gmsh.model.occ.removeAllDuplicates()

    gmsh.model.occ.synchronize()


    # ========================================================
    # FRAGMENT SILICON + VACUUM USING METAL
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "FRAGMENTING VOLUMES WITH UNIFIED METAL"
    )

    print(
        "=" * 80
    )

    volume_objects = [

        (3, silicon),

        (3, vacuum)
    ]

    metal_objects = [

        (2, s)

        for s in metal_surfaces
    ]


    print(
        f"Silicon/vacuum volumes: "
        f"{len(volume_objects)}"
    )

    print(
        f"Unified metal surfaces: "
        f"{len(metal_objects)}"
    )


    fragmented, fragment_map = (
        gmsh.model.occ.fragment(
            volume_objects,
            metal_objects
        )
    )


    print(
        f"Fragmentation produced "
        f"{len(fragmented)} entities."
    )


    # ========================================================
    # SYNCHRONIZE
    # ========================================================

    print(
        "\nSynchronizing fragmented geometry..."
    )

    gmsh.model.occ.synchronize()


    # ========================================================
    # REMOVE DUPLICATES
    # ========================================================

    print(
        "Removing duplicate geometry..."
    )

    gmsh.model.occ.removeAllDuplicates()

    gmsh.model.occ.synchronize()


    # ========================================================
    # IDENTIFY VOLUMES
    # ========================================================

    volumes = gmsh.model.getEntities(3)

    print(
        "\n3D volumes:",
        len(volumes)
    )


    silicon_volumes = []

    vacuum_volumes = []


    for dim, tag in volumes:

        com = (
            gmsh.model.occ.getCenterOfMass(
                dim,
                tag
            )
        )

        if com[2] < -1e-8:

            silicon_volumes.append(tag)

        elif com[2] > 1e-8:

            vacuum_volumes.append(tag)


    print(
        "Silicon volumes:",
        len(silicon_volumes)
    )

    print(
        "Vacuum volumes:",
        len(vacuum_volumes)
    )


    # ========================================================
    # GET METAL SURFACES FROM FRAGMENT MAP
    # ========================================================

    print(
        "\nRecovering metal surfaces..."
    )

    mapped_metal_surfaces = []


    # fragment_map corresponds to input objects.
    #
    # First two input objects are the two volumes.
    # Remaining mappings correspond to metal surfaces.

    for mapping in fragment_map[2:]:

        for dim, tag in mapping:

            if dim == 2:

                mapped_metal_surfaces.append(
                    tag
                )


    # Remove duplicate tags

    mapped_metal_surfaces = sorted(
        set(mapped_metal_surfaces)
    )


    print(
        "Recovered metal surfaces:",
        len(mapped_metal_surfaces)
    )


    if not mapped_metal_surfaces:

        raise RuntimeError(
            "Could not recover metal surfaces "
            "after fragmentation."
        )


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nCreating physical groups..."
    )


    # --------------------------------------------------------
    # VACUUM
    # --------------------------------------------------------

    gmsh.model.addPhysicalGroup(
        3,
        vacuum_volumes,
        VACUUM_ID
    )

    gmsh.model.setPhysicalName(
        3,
        VACUUM_ID,
        "Vacuum"
    )


    # --------------------------------------------------------
    # SILICON
    # --------------------------------------------------------

    gmsh.model.addPhysicalGroup(
        3,
        silicon_volumes,
        SILICON_ID
    )

    gmsh.model.setPhysicalName(
        3,
        SILICON_ID,
        "Silicon_Substrate"
    )


    # --------------------------------------------------------
    # PEC
    # --------------------------------------------------------

    gmsh.model.addPhysicalGroup(
        2,
        mapped_metal_surfaces,
        PEC_ID
    )

    gmsh.model.setPhysicalName(
        2,
        PEC_ID,
        "Superconducting_Metal"
    )


    # ========================================================
    # MESH SETTINGS
    # ========================================================

    print(
        "\nSetting mesh parameters..."
    )

    gmsh.option.setNumber(
        "Mesh.Algorithm3D",
        1
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMin",
        GLOBAL_MIN
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMax",
        GLOBAL_MAX
    )

    gmsh.option.setNumber(
        "Mesh.Optimize",
        0
    )

    gmsh.option.setNumber(
        "Mesh.OptimizeNetgen",
        0
    )


    # ========================================================
    # GENERATE 3D MESH
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "GENERATING CONFORMAL 3D MESH"
    )

    print(
        "=" * 80
    )

    gmsh.model.mesh.generate(3)


    # ========================================================
    # CLEAN MESH
    # ========================================================

    print(
        "\nRemoving duplicate mesh nodes..."
    )

    gmsh.model.mesh.removeDuplicateNodes()


    print(
        "Removing duplicate mesh elements..."
    )

    gmsh.model.mesh.removeDuplicateElements()


    # ========================================================
    # CHECK ELEMENTS
    # ========================================================

    print(
        "\nChecking element connectivity..."
    )

    element_types, element_tags, element_nodes = (
        gmsh.model.mesh.getElements()
    )

    bad_elements = []

    total_elements = 0


    for etype, tags, nodes in zip(
        element_types,
        element_tags,
        element_nodes
    ):

        properties = (
            gmsh.model.mesh.getElementProperties(
                etype
            )
        )

        element_name = properties[0]

        num_nodes = properties[3]

        total_elements += len(tags)


        for i, tag in enumerate(tags):

            connectivity = nodes[
                i * num_nodes:
                (i + 1) * num_nodes
            ]


            if (
                len(
                    set(
                        connectivity.tolist()
                    )
                )
                !=
                len(connectivity)
            ):

                bad_elements.append(
                    int(tag)
                )


                if len(bad_elements) >= 10:

                    break


    print(
        f"Total elements: "
        f"{total_elements:,}"
    )

    print(
        f"Degenerate elements: "
        f"{len(bad_elements)}"
    )


    if bad_elements:

        print(
            "Bad element IDs:",
            bad_elements[:10]
        )

        raise RuntimeError(
            "Degenerate elements detected."
        )


    # ========================================================
    # FINAL STATISTICS
    # ========================================================

    nodes, coords, _ = (
        gmsh.model.mesh.getNodes()
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "FINAL MESH STATISTICS"
    )

    print(
        "=" * 80
    )

    print(
        f"Nodes    : {len(nodes):,}"
    )

    print(
        f"Elements : {total_elements:,}"
    )


    print(
        "\nPhysical groups:"
    )

    for dim, tag in (
        gmsh.model.getPhysicalGroups()
    ):

        name = gmsh.model.getPhysicalName(
            dim,
            tag
        )

        print(
            f"  Dimension={dim}, "
            f"Attribute={tag}, "
            f"Name={name}"
        )


    # ========================================================
    # WRITE MSH 2.2
    # ========================================================

    print(
        "\nWriting MSH 2.2..."
    )

    gmsh.option.setNumber(
        "Mesh.MshFileVersion",
        2.2
    )

    gmsh.option.setNumber(
        "Mesh.Binary",
        0
    )

    gmsh.write(
        MESH_PATH
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "CONFORMAL PALACE MESH SUCCESS"
    )

    print(
        "=" * 80
    )

    print(
        "\nMesh:"
    )

    print(
        MESH_PATH
    )


finally:

    gmsh.finalize()

    print(
        "\nGmsh finalized."
    )
# Out:
# ================================================================================
# ROBUST CONFORMAL PALACE MESH GENERATOR
# ================================================================================
#
# Reading GDS...
# Loaded 19 cells.
# Using top cell: TOP_main_1
#
# Extracting Layer 1 / Datatype 0...
# Raw metal polygons: 2450
#
# Converting polygons to Shapely...
# Valid Shapely polygons: 2450
# Invalid/skipped: 0
#
# ================================================================================
# UNITING OVERLAPPING METAL POLYGONS
# ================================================================================
# This may take some time...
#
# Metal union type: Polygon
# Unified metal area: 185.75073679172058 mm^2
# Unified metal regions: 1
#
# Initializing Gmsh...
#
# Creating silicon...
# Creating vacuum...
#
# Creating unified metal surfaces...
#
# Unified metal surfaces created: 1
#
# Removing duplicate OCC geometry...
#
# ================================================================================
# FRAGMENTING VOLUMES WITH UNIFIED METAL
# ================================================================================
# Silicon/vacuum volumes: 2
# Unified metal surfaces: 1
# Fragmentation produced 35 entities.
#
# Synchronizing fragmented geometry...
# Removing duplicate geometry...
#
# 3D volumes: 2
# Silicon volumes: 1
# Vacuum volumes: 1
#
# Recovering metal surfaces...
# Recovered metal surfaces: 1
#
# Creating physical groups...
#
# Setting mesh parameters...
#
# ================================================================================
# GENERATING CONFORMAL 3D MESH
# ================================================================================
#
# Removing duplicate mesh nodes...
# Removing duplicate mesh elements...
#
# Checking element connectivity...
# Total elements: 25,971,489
# Degenerate elements: 0
#
# ================================================================================
# FINAL MESH STATISTICS
# ================================================================================
# Nodes    : 3,694,497
# Elements : 25,971,489
#
# Physical groups:
#   Dimension=2, Attribute=10, Name=Superconducting_Metal
#   Dimension=3, Attribute=1, Name=Vacuum
#   Dimension=3, Attribute=2, Name=Silicon_Substrate
#
# Writing MSH 2.2...
#
# ================================================================================
# CONFORMAL PALACE MESH SUCCESS
# ================================================================================
#
# Mesh:
# /content/quantum_chip_mesh_conformal.msh
#
# Gmsh finalized.

# %%
import os

# ==========================================
# STEP 19: Save Success Status to Google Drive permanently
# ==========================================
success_output = """================================================================================
CONFORMAL PALACE MESH SUCCESS
================================================================================

Mesh:
/content/quantum_chip_mesh_conformal.msh

Gmsh finalized."""

# Define permanent storage path in Google Drive
drive_dir = "/content/drive/MyDrive/Palace6"
os.makedirs(drive_dir, exist_ok=True)
log_file_path = os.path.join(drive_dir, "conformal_mesh_success.txt")

# Write output to Drive
with open(log_file_path, "w") as f:
    f.write(success_output)

print(f"Status successfully saved permanently to Google Drive at:\n{log_file_path}")
# Out:
# Status successfully saved permanently to Google Drive at:
# /content/drive/MyDrive/Palace6/conformal_mesh_success.txt

# %%
import shutil
import os

# Define the source and destination paths
source_file = '/content/quantum_chip_mesh_conformal.msh'
destination_dir = '/content/drive/MyDrive/Palace6/meshes'
destination_file = os.path.join(destination_dir, 'quantum_chip_mesh_conformal.msh')

# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Copy the file to Google Drive
if os.path.exists(source_file):
    shutil.copy2(source_file, destination_file)
    print(f"File successfully saved permanently to: {destination_file}")
else:
    print(f"Error: {source_file} not found. Please ensure the file was generated in the current session.")
# Out:
# File successfully saved permanently to: /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_conformal.msh

# %%
import shutil
import os

# ==========================================
# STEP 20: Permanent Google Drive Archival of Mesh & GDS Files
# ==========================================
files_to_save = [
    "/content/quantum_chip_export_manuscript.gds",
    "/content/quantum_chip_mesh.msh",
    "/content/quantum_chip_mesh_palace.msh",
    "/content/quantum_chip_mesh_palace_v22.msh",
    "/content/quantum_chip_mesh_test.msh",
    "/content/quantum_chip_mesh_conformal.msh"
]

destination_dir = "/content/drive/MyDrive/Palace6/meshes"
os.makedirs(destination_dir, exist_ok=True)

print(f"Beginning permanent archival to Google Drive: {destination_dir}\n")

saved_count = 0
for file_path in files_to_save:
    if os.path.exists(file_path):
        file_name = os.path.basename(file_path)
        dest_path = os.path.join(destination_dir, file_name)
        shutil.copy2(file_path, dest_path)
        print(f"[SAVED] {file_name} -> {dest_path}")
        saved_count += 1
    else:
        print(f"[SKIPPED] File not found locally: {file_path}")

print(f"\nSuccessfully archived {saved_count} file(s) permanently to Google Drive.")
# Out:
# Beginning permanent archival to Google Drive: /content/drive/MyDrive/Palace6/meshes
#
# [SAVED] quantum_chip_export_manuscript.gds -> /content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds
# [SAVED] quantum_chip_mesh.msh -> /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh.msh
# [SAVED] quantum_chip_mesh_palace.msh -> /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_palace.msh
# [SAVED] quantum_chip_mesh_palace_v22.msh -> /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_palace_v22.msh
# [SAVED] quantum_chip_mesh_test.msh -> /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_test.msh
# [SAVED] quantum_chip_mesh_conformal.msh -> /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_conformal.msh
#
# Successfully archived 6 file(s) permanently to Google Drive.

# %%
import os

# ==========================================
# STEP 21: List files in Google Drive meshes directory
# ==========================================
meshes_dir = "/content/drive/MyDrive/Palace6/meshes"

if os.path.exists(meshes_dir):
    files = os.listdir(meshes_dir)
    print(f"Files found in '{meshes_dir}':")
    for file in files:
        print(f" - {file}")
else:
    print(f"Directory not found: {meshes_dir}")
# Out:
# Files found in '/content/drive/MyDrive/Palace6/meshes':
#  - quantum_chip_mesh_conformal.msh
#  - quantum_chip_export_manuscript.gds
#  - quantum_chip_mesh.msh
#  - quantum_chip_mesh_palace.msh
#  - quantum_chip_mesh_palace_v22.msh
#  - quantum_chip_mesh_test.msh

# %%
# ============================================================
# PALACE MESH-READ TEST + 1 EIGENMODE
#
# Purpose:
#   Confirm that Palace/MFEM can successfully read:
#
#       quantum_chip_mesh_conformal.msh
#
#   and proceed into the eigenmode solver.
#
# NO Josephson junctions yet.
# NO EPR yet.
# ============================================================

import os
import json
import subprocess
import shutil


# ============================================================
# PATHS
# ============================================================

PALACE_DIR = "/content/drive/MyDrive/Palace6/build"

PALACE_BIN = os.path.join(
    PALACE_DIR,
    "bin",
    "palace-x86_64.bin"
)

LIB_DIR = os.path.join(
    PALACE_DIR,
    "lib"
)

MESH = "/content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_conformal.msh"

CONFIG = "/content/palace_mesh_test.json"

OUTPUT = "/content/palace_mesh_test_output"


# ============================================================
# CHECK FILES
# ============================================================

print("=" * 80)
print("PALACE MESH READ + 1 MODE TEST")
print("=" * 80)

if not os.path.exists(MESH):

    raise FileNotFoundError(
        f"\nMesh not found:\n{MESH}"
    )

if not os.path.exists(PALACE_BIN):

    raise FileNotFoundError(
        f"\nPalace executable not found:\n{PALACE_BIN}"
    )


mesh_size_gb = (
    os.path.getsize(MESH)
    / (1024 ** 3)
)

print("\nMesh:")
print(MESH)

print(
    f"\nMesh file size: "
    f"{mesh_size_gb:.2f} GB"
)

print(
    "\nExpected mesh:"
)

print(
    "  Nodes    : ~3.69 million"
)

print(
    "  Elements : ~25.97 million"
)


# ============================================================
# OUTPUT DIRECTORY
# ============================================================

if os.path.exists(OUTPUT):

    print(
        "\nRemoving previous Palace output..."
    )

    shutil.rmtree(
        OUTPUT
    )

os.makedirs(
    OUTPUT,
    exist_ok=True
)


# ============================================================
# ENVIRONMENT
# ============================================================

env = os.environ.copy()

env["LD_LIBRARY_PATH"] = (
    LIB_DIR
    + ":"
    + env.get(
        "LD_LIBRARY_PATH",
        ""
    )
)

env["OMPI_ALLOW_RUN_AS_ROOT"] = "1"

env[
    "OMPI_ALLOW_RUN_AS_ROOT_CONFIRM"
] = "1"


# ============================================================
# PALACE CONFIGURATION
# ============================================================

palace_config = {

    "Problem": {

        "Type": "Eigenmode",

        "Verbose": 2,

        "Output": OUTPUT
    },


    "Model": {

        "Mesh": MESH,

        # Gmsh coordinates are in mm.
        # Convert mm -> meters.
        "L0": 1.0e-3
    },


    "Domains": {

        "Materials": [

            {
                # Attribute 1 = Vacuum
                "Attributes": [1],

                "Permittivity": 1.0,

                "Permeability": 1.0
            },

            {
                # Attribute 2 = Silicon
                "Attributes": [2],

                "Permittivity": 11.7,

                "Permeability": 1.0
            }
        ]
    },


    "Boundaries": {

        # Attribute 10 = superconducting metal
        "PEC": {

            "Attributes": [10]
        }
    },


    "Solver": {

        # Lowest order elements to minimize RAM.
        "Order": 1,


        "Eigenmode": {

            # ONLY ONE MODE
            "N": 1,

            # Search target = 5 GHz
            "Target": 5.0,

            # Relaxed tolerance for this sanity test.
            "Tol": 1.0e-6,

            "MaxIts": 100
        },


        "Linear": {

            "Type": "BoomerAMG",

            "Tol": 1.0e-6,

            "MaxIts": 50
        }
    }
}


# ============================================================
# WRITE CONFIG
# ============================================================

with open(
    CONFIG,
    "w"
) as f:

    json.dump(
        palace_config,
        f,
        indent=4
    )


print(
    "\nConfiguration written:"
)

print(
    CONFIG
)


# ============================================================
# COMMAND
# ============================================================

cmd = [

    "mpirun",

    "-n",
    "1",

    "--allow-run-as-root",

    PALACE_BIN,

    CONFIG
]


print(
    "\n" + "=" * 80
)

print(
    "STARTING PALACE"
)

print(
    "=" * 80
)

print(
    "\nCommand:"
)

print(
    " ".join(cmd)
)


# ============================================================
# RUN
# ============================================================

try:

    result = subprocess.run(

        cmd,

        text=True,

        capture_output=True,

        env=env
    )

except Exception as exc:

    print(
        "\nCould not start Palace:"
    )

    print(exc)

    raise


# ============================================================
# PRINT OUTPUT
# ============================================================

print(
    "\n" + "=" * 80
)

print(
    "PALACE STDOUT"
)

print(
    "=" * 80
)

print(
    result.stdout
)


print(
    "\n" + "=" * 80
)

print(
    "PALACE STDERR"
)

print(
    "=" * 80
)

print(
    result.stderr
)


print(
    "\n" + "=" * 80
)

print(
    f"RETURN CODE: {result.returncode}"
)

print(
    "=" * 80
)


# ============================================================
# RESULT
# ============================================================

if result.returncode == 0:

    print(
        "\nSUCCESS!"
    )

    print(
        "Palace successfully read the conformal mesh "
        "and completed the 1-mode test."
    )

    print(
        "\nOutput directory:"
    )

    print(
        OUTPUT
    )

else:

    print(
        "\nPALACE TEST FAILED."
    )

    print(
        "\nThe important part of STDERR is:"
    )

    print(
        result.stderr[-5000:]
    )
# Out:
# ================================================================================
# PALACE MESH READ + 1 MODE TEST
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_conformal.msh
#
# Mesh file size: 1.31 GB
#
# Expected mesh:
#   Nodes    : ~3.69 million
#   Elements : ~25.97 million
#
# Configuration written:
# /content/palace_mesh_test.json
#
# ================================================================================
# STARTING PALACE
# ================================================================================
#
# Command:
# mpirun -n 1 --allow-run-as-root /content/drive/MyDrive/Palace6/build/bin/palace-x86_64.bin /content/palace_mesh_test.json
#
# ================================================================================
# PALACE STDOUT
# ================================================================================
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
# Git changeset ID: v0.17.0-194-g01f5d9bd1
# Running with 1 MPI process, 1 OpenMP thread
# Device configuration: omp,cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
#
# --> Warning!
# 51546 mesh faces with no associated boundary element exist on the domain boundary!
#
# Added 560 elements in 2 iterations of local bisection for under-resolved interior boundaries
# Added 1282892 duplicate vertices for interior boundaries in the mesh
# Added 2601563 duplicate boundary elements for interior boundaries in the mesh
# Added 51546 boundary elements for exterior boundaries to the mesh
# Added 358467 boundary elements for material interfaces to the mesh
#
# Characteristic length and time scales:
#  Lc = 1.400e-02 m, tc = 4.670e-02 ns
# Finished partitioning mesh into 1 subdomain
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-7.000e-03, -7.000e-03, -5.000e-04) m
#  (Xmax, Ymax, Zmax) = (+7.000e-03, +7.000e-03, +5.000e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices       4977513     4977513     4977513     4977513
#  edges         30491563    30491563    30491563    30491563
#  faces         48400728    48400728    48400728    48400728
#  elements      22886696    22886696    22886696    22886696
#  neighbors            0           0           0
#
#             minimum     maximum
#  h      1.19395e-05   0.0170539
#  kappa      1.00047     49589.2
#
# Estimated current per-rank memory usage is: Min. 11.7G, Max. 11.7G, Avg. 11.7G, Total 11.7G
# Estimated current per-node memory usage is: Min. 11.7G, Max. 11.7G, Avg. 11.7G, Total 11.7G
#
# Configuring Dirichlet PEC BC at attributes:
#  10
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 4977513, ND (p = 1): 30491563, RT (p = 1): 48400728
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
#
# Configuring SLEPc eigenvalue solver:
#
#
# ================================================================================
# PALACE STDERR
# ================================================================================
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# mpirun noticed that process rank 0 with PID 0 on node 3016f70c5375 exited on signal 9 (Killed).
# --------------------------------------------------------------------------
#
#
# ================================================================================
# RETURN CODE: 137
# ================================================================================
#
# PALACE TEST FAILED.
#
# The important part of STDERR is:
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# mpirun noticed that process rank 0 with PID 0 on node 3016f70c5375 exited on signal 9 (Killed).
# --------------------------------------------------------------------------

# %%
# !pip install gdspy
# Out:
# Collecting gdspy
#   Downloading gdspy-1.6.13.zip (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.9/157.9 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from gdspy) (1.26.4)
# Building wheels for collected packages: gdspy
#   Building wheel for gdspy (setup.py) ... done
#   Created wheel for gdspy: filename=gdspy-1.6.13-cp312-cp312-linux_x86_64.whl size=595854 sha256=3e1da8e840d15ad2cde6edf137efab5bd3917c3e8a355a108e328929a3598d75
#   Stored in directory: /root/.cache/pip/wheels/02/05/a3/c4b581f8330cedff4d7f4aa7134ae298e88232ccce6a2d4859
# Successfully built gdspy
# Installing collected packages: gdspy
# Successfully installed gdspy-1.6.13

# %%
# ============================================================
# STEP 5E — MEMORY-EFFICIENT CONFORMAL PALACE MESH
#
# Goal:
#   Reduce the ~26 million element mesh to a much smaller
#   Palace-compatible conformal mesh.
#
# Geometry:
#   4 concentric transmons
#   8 JJ locations
#   readout structures
#   couplers
#   drive / flux structures
#
# Strategy:
#
#   Bulk region              ~200 um
#   Metal/interface region    ~75 um
#   JJ neighborhoods          ~20 um
#
# IMPORTANT:
#   This is still a PEC-only sanity mesh.
#   Josephson inductances are NOT added yet.
# ============================================================

import os
import gdspy
import gmsh

from shapely.geometry import Polygon
from shapely.ops import unary_union


# ============================================================
# INPUT / OUTPUT
# ============================================================

GDS_PATH = "/content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds"

OUTPUT_MESH = (
    "/content/quantum_chip_mesh_reduced_conformal.msh"
)

TOP_CELL_NAME = "TOP_main_1"

METAL_LAYER = 1
METAL_DATATYPE = 0


# ============================================================
# CHIP GEOMETRY
# ============================================================

CHIP_X = 14.0
CHIP_Y = 14.0

SUBSTRATE_THICKNESS = 0.5
AIR_HEIGHT = 0.5


# ============================================================
# PHYSICAL GROUP IDS
# ============================================================

VACUUM_ID = 1
SILICON_ID = 2
PEC_ID = 10


# ============================================================
# MESH SIZES
#
# Units are mm because GDS coordinates are in mm.
# ============================================================

BULK_SIZE = 0.200       # 200 um

METAL_SIZE = 0.075      # 75 um

JJ_SIZE = 0.020         # 20 um


# ============================================================
# JJ LOCATIONS FROM YOUR GDS
#
# mm
# ============================================================

JJ_LOCATIONS = [

    (-1.1325,  0.0000),
    (-0.8675,  0.0000),

    ( 1.2675,  0.0000),
    ( 1.5325,  0.0000),

    (-1.1325, -2.7000),
    (-0.8675, -2.7000),

    ( 1.2675, -2.7000),
    ( 1.5325, -2.7000)
]


# ============================================================
# JJ REFINEMENT BOX
#
# 100 um × 100 um × full substrate/air height
# ============================================================

JJ_BOX_HALF = 0.075       # 75 um


# ============================================================
# READ GDS
# ============================================================

print("=" * 80)
print("MEMORY-EFFICIENT CONFORMAL PALACE MESH")
print("=" * 80)

print("\nReading GDS...")

lib = gdspy.GdsLibrary()

lib.read_gds(
    GDS_PATH
)

print(
    f"Loaded {len(lib.cells)} cells."
)


# ============================================================
# TOP CELL
# ============================================================

if TOP_CELL_NAME not in lib.cells:

    raise RuntimeError(
        f"Top cell not found: {TOP_CELL_NAME}"
    )

top = lib.cells[
    TOP_CELL_NAME
]

print(
    f"Using top cell: {TOP_CELL_NAME}"
)


# ============================================================
# EXTRACT METAL
# ============================================================

print(
    "\nExtracting Layer 1 / Datatype 0..."
)

polygons_by_spec = top.get_polygons(
    by_spec=True
)

raw_polygons = []


for spec, polygons in polygons_by_spec.items():

    layer, datatype = spec

    if layer != METAL_LAYER:
        continue

    if datatype != METAL_DATATYPE:
        continue

    for polygon in polygons:

        if len(polygon) < 3:
            continue

        points = []

        for p in polygon:

            point = (
                round(float(p[0]), 10),
                round(float(p[1]), 10)
            )

            if (
                not points
                or point != points[-1]
            ):

                points.append(point)


        if (
            len(points) > 1
            and points[0] == points[-1]
        ):

            points.pop()


        if len(set(points)) >= 3:

            raw_polygons.append(
                points
            )


print(
    f"Raw metal polygons: "
    f"{len(raw_polygons)}"
)


# ============================================================
# SHAPELY CLEANUP
# ============================================================

print(
    "\nCleaning metal geometry..."
)

shapes = []

for points in raw_polygons:

    try:

        poly = Polygon(points)

        if not poly.is_valid:

            poly = poly.buffer(0)

        if poly.is_empty:

            continue

        if poly.area <= 1e-12:

            continue

        shapes.append(poly)

    except Exception:

        continue


print(
    f"Valid polygons: "
    f"{len(shapes)}"
)


# ============================================================
# UNION
# ============================================================

print(
    "\nUniting overlapping metal polygons..."
)

metal_union = unary_union(
    shapes
)


if not metal_union.is_valid:

    metal_union = metal_union.buffer(0)


if metal_union.geom_type == "Polygon":

    unified_polygons = [
        metal_union
    ]

elif metal_union.geom_type == "MultiPolygon":

    unified_polygons = list(
        metal_union.geoms
    )

else:

    raise RuntimeError(
        "Unexpected metal geometry type: "
        + metal_union.geom_type
    )


print(
    f"Unified metal regions: "
    f"{len(unified_polygons)}"
)


# ============================================================
# INITIALIZE GMSH
# ============================================================

print(
    "\nInitializing Gmsh..."
)

gmsh.initialize()

gmsh.option.setNumber(
    "General.Terminal",
    1
)

gmsh.model.add(
    "four_qubit_reduced_conformal"
)


try:

    # ========================================================
    # SILICON
    # ========================================================

    print(
        "\nCreating silicon substrate..."
    )

    silicon = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        -SUBSTRATE_THICKNESS,

        CHIP_X,
        CHIP_Y,
        SUBSTRATE_THICKNESS
    )


    # ========================================================
    # VACUUM
    # ========================================================

    print(
        "Creating vacuum..."
    )

    vacuum = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        0.0,

        CHIP_X,
        CHIP_Y,
        AIR_HEIGHT
    )


    # ========================================================
    # POINT CACHE
    # ========================================================

    point_cache = {}


    def get_point(x, y):

        key = (
            round(float(x), 10),
            round(float(y), 10),
            0.0
        )

        if key not in point_cache:

            point_cache[key] = (
                gmsh.model.occ.addPoint(
                    key[0],
                    key[1],
                    key[2]
                )
            )

        return point_cache[key]


    # ========================================================
    # CREATE UNIFIED METAL SURFACES
    # ========================================================

    print(
        "\nCreating unified metal surfaces..."
    )

    metal_surfaces = []


    for index, poly in enumerate(
        unified_polygons
    ):

        # ----------------------------------------------------
        # EXTERIOR
        # ----------------------------------------------------

        exterior = list(
            poly.exterior.coords
        )

        exterior = exterior[:-1]


        outer_points = [

            get_point(x, y)

            for x, y in exterior
        ]


        outer_lines = []


        for i in range(
            len(outer_points)
        ):

            p1 = outer_points[i]

            p2 = outer_points[
                (i + 1)
                % len(outer_points)
            ]

            if p1 == p2:

                continue

            outer_lines.append(

                gmsh.model.occ.addLine(
                    p1,
                    p2
                )
            )


        outer_wire = (
            gmsh.model.occ.addWire(
                outer_lines
            )
        )


        # ----------------------------------------------------
        # HOLES
        # ----------------------------------------------------

        hole_wires = []


        for interior in poly.interiors:

            coords = list(
                interior.coords
            )

            coords = coords[:-1]


            hole_points = [

                get_point(x, y)

                for x, y in coords
            ]


            hole_lines = []


            for i in range(
                len(hole_points)
            ):

                p1 = hole_points[i]

                p2 = hole_points[
                    (i + 1)
                    % len(hole_points)
                ]

                if p1 == p2:

                    continue

                hole_lines.append(

                    gmsh.model.occ.addLine(
                        p1,
                        p2
                    )
                )


            if len(hole_lines) >= 3:

                hole_wires.append(

                    gmsh.model.occ.addWire(
                        hole_lines
                    )
                )


        # ----------------------------------------------------
        # SURFACE
        # ----------------------------------------------------

        wire_list = [
            outer_wire
        ] + hole_wires


        try:

            surface = (
                gmsh.model.occ.addPlaneSurface(
                    wire_list
                )
            )

            metal_surfaces.append(
                surface
            )

        except Exception as exc:

            print(
                f"Metal region {index} "
                f"failed: {exc}"
            )


    print(
        f"Unified metal surfaces created: "
        f"{len(metal_surfaces)}"
    )


    # ========================================================
    # SYNCHRONIZE
    # ========================================================

    gmsh.model.occ.synchronize()


    # ========================================================
    # REMOVE DUPLICATES
    # ========================================================

    print(
        "\nRemoving duplicate OCC geometry..."
    )

    gmsh.model.occ.removeAllDuplicates()

    gmsh.model.occ.synchronize()


    # ========================================================
    # FRAGMENT
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "FRAGMENTING VOLUMES WITH UNIFIED METAL"
    )

    print(
        "=" * 80
    )


    volume_objects = [

        (3, silicon),
        (3, vacuum)
    ]


    metal_objects = [

        (2, tag)

        for tag in metal_surfaces
    ]


    fragmented, fragment_map = (
        gmsh.model.occ.fragment(

            volume_objects,
            metal_objects
        )
    )


    print(
        f"Fragmentation produced "
        f"{len(fragmented)} entities."
    )


    # ========================================================
    # SYNCHRONIZE
    # ========================================================

    print(
        "\nSynchronizing fragmented geometry..."
    )

    gmsh.model.occ.synchronize()


    print(
        "Removing duplicate geometry..."
    )

    gmsh.model.occ.removeAllDuplicates()

    gmsh.model.occ.synchronize()


    # ========================================================
    # VOLUMES
    # ========================================================

    volumes = (
        gmsh.model.getEntities(3)
    )


    silicon_volumes = []

    vacuum_volumes = []


    for dim, tag in volumes:

        com = (
            gmsh.model.occ.getCenterOfMass(
                dim,
                tag
            )
        )


        if com[2] < -1e-8:

            silicon_volumes.append(
                tag
            )

        elif com[2] > 1e-8:

            vacuum_volumes.append(
                tag
            )


    print(
        "\n3D volumes:",
        len(volumes)
    )

    print(
        "Silicon volumes:",
        len(silicon_volumes)
    )

    print(
        "Vacuum volumes:",
        len(vacuum_volumes)
    )


    # ========================================================
    # RECOVER METAL SURFACE
    # ========================================================

    mapped_metal_surfaces = []


    for mapping in fragment_map[2:]:

        for dim, tag in mapping:

            if dim == 2:

                mapped_metal_surfaces.append(
                    tag
                )


    mapped_metal_surfaces = sorted(
        set(
            mapped_metal_surfaces
        )
    )


    print(
        "Recovered metal surfaces:",
        len(mapped_metal_surfaces)
    )


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nCreating physical groups..."
    )


    gmsh.model.addPhysicalGroup(

        3,

        vacuum_volumes,

        VACUUM_ID
    )

    gmsh.model.setPhysicalName(

        3,

        VACUUM_ID,

        "Vacuum"
    )


    gmsh.model.addPhysicalGroup(

        3,

        silicon_volumes,

        SILICON_ID
    )

    gmsh.model.setPhysicalName(

        3,

        SILICON_ID,

        "Silicon_Substrate"
    )


    gmsh.model.addPhysicalGroup(

        2,

        mapped_metal_surfaces,

        PEC_ID
    )

    gmsh.model.setPhysicalName(

        2,

        PEC_ID,

        "Superconducting_Metal"
    )


    # ========================================================
    # MESH SIZES
    # ========================================================

    print(
        "\nConfiguring reduced mesh..."
    )

    # Global coarse mesh.
    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMin",
        BULK_SIZE
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMax",
        BULK_SIZE
    )


    # ========================================================
    # METAL SURFACE REFINEMENT
    # ========================================================
    #
    # Use a distance field from the metal boundary.
    #
    # This makes the mesh finer near the superconducting
    # structure without forcing the entire chip to 75 um.
    # ========================================================

    print(
        "Creating metal-distance refinement..."
    )


    metal_boundary_curves = []


    for dim, tag in (
        gmsh.model.getBoundary(

            [
                (2, s)

                for s in
                mapped_metal_surfaces
            ],

            combined=True,

            oriented=False,

            recursive=False
        )
    ):

        if dim == 1:

            metal_boundary_curves.append(
                tag
            )


    metal_boundary_curves = sorted(
        set(
            metal_boundary_curves
        )
    )


    if metal_boundary_curves:

        metal_distance = (
            gmsh.model.mesh.field.add(
                "Distance"
            )
        )

        gmsh.model.mesh.field.setNumbers(

            metal_distance,

            "CurvesList",

            metal_boundary_curves
        )


        metal_threshold = (
            gmsh.model.mesh.field.add(
                "Threshold"
            )
        )


        gmsh.model.mesh.field.setNumber(

            metal_threshold,

            "InField",

            metal_distance
        )


        # Fine size close to conductor
        gmsh.model.mesh.field.setNumber(

            metal_threshold,

            "SizeMin",

            METAL_SIZE
        )


        # Coarse size far away
        gmsh.model.mesh.field.setNumber(

            metal_threshold,

            "SizeMax",

            BULK_SIZE
        )


        # Start changing mesh size within 150 um
        gmsh.model.mesh.field.setNumber(

            metal_threshold,

            "DistMin",

            0.05
        )


        gmsh.model.mesh.field.setNumber(

            metal_threshold,

            "DistMax",

            0.20
        )


        print(
            f"Metal refinement curves: "
            f"{len(metal_boundary_curves)}"
        )

    else:

        metal_threshold = None

        print(
            "No metal boundary curves found."
        )


    # ========================================================
    # JJ LOCAL REFINEMENT
    # ========================================================

    print(
        "\nCreating local JJ refinement..."
    )


    jj_fields = []


    for index, (x, y) in enumerate(
        JJ_LOCATIONS
    ):

        field = (
            gmsh.model.mesh.field.add(
                "Box"
            )
        )


        gmsh.model.mesh.field.setNumber(

            field,

            "VIn",

            JJ_SIZE
        )


        gmsh.model.mesh.field.setNumber(

            field,

            "VOut",

            BULK_SIZE
        )


        gmsh.model.mesh.field.setNumber(

            field,

            "XMin",

            x - JJ_BOX_HALF
        )


        gmsh.model.mesh.field.setNumber(

            field,

            "XMax",

            x + JJ_BOX_HALF
        )


        gmsh.model.mesh.field.setNumber(

            field,

            "YMin",

            y - JJ_BOX_HALF
        )


        gmsh.model.mesh.field.setNumber(

            field,

            "YMax",

            y + JJ_BOX_HALF
        )


        gmsh.model.mesh.field.setNumber(

            field,

            "ZMin",

            -SUBSTRATE_THICKNESS
        )


        gmsh.model.mesh.field.setNumber(

            field,

            "ZMax",

            AIR_HEIGHT
        )


        jj_fields.append(
            field
        )


        print(
            f"  JJ {index + 1}: "
            f"({x:.4f}, {y:.4f}) mm"
        )


    # ========================================================
    # COMBINE FIELDS
    # ========================================================

    all_fields = []


    if metal_threshold is not None:

        all_fields.append(
            metal_threshold
        )


    all_fields.extend(
        jj_fields
    )


    if all_fields:

        minimum_field = (
            gmsh.model.mesh.field.add(
                "Min"
            )
        )


        gmsh.model.mesh.field.setNumbers(

            minimum_field,

            "FieldsList",

            all_fields
        )


        gmsh.model.mesh.field.setAsBackgroundMesh(

            minimum_field
        )


    # ========================================================
    # 3D MESH SETTINGS
    # ========================================================

    gmsh.option.setNumber(
        "Mesh.Algorithm3D",
        1
    )

    gmsh.option.setNumber(
        "Mesh.Optimize",
        0
    )

    gmsh.option.setNumber(
        "Mesh.OptimizeNetgen",
        0
    )


    # ========================================================
    # GENERATE
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "GENERATING REDUCED CONFORMAL 3D MESH"
    )

    print(
        "=" * 80
    )

    print(
        f"Bulk size  : {BULK_SIZE * 1000:.0f} um"
    )

    print(
        f"Metal size : {METAL_SIZE * 1000:.0f} um"
    )

    print(
        f"JJ size    : {JJ_SIZE * 1000:.0f} um"
    )


    gmsh.model.mesh.generate(
        3
    )


    # ========================================================
    # CLEAN
    # ========================================================

    print(
        "\nRemoving duplicate mesh nodes..."
    )

    gmsh.model.mesh.removeDuplicateNodes()


    print(
        "Removing duplicate mesh elements..."
    )

    gmsh.model.mesh.removeDuplicateElements()


    # ========================================================
    # CONNECTIVITY CHECK
    # ========================================================

    print(
        "\nChecking element connectivity..."
    )


    element_types, element_tags, element_nodes = (
        gmsh.model.mesh.getElements()
    )


    bad_elements = 0

    total_elements = 0


    for etype, tags, nodes in zip(

        element_types,

        element_tags,

        element_nodes

    ):

        props = (
            gmsh.model.mesh.getElementProperties(
                etype
            )
        )

        num_nodes = props[3]

        total_elements += len(tags)


        for i in range(
            len(tags)
        ):

            connectivity = nodes[

                i * num_nodes:

                (i + 1) * num_nodes

            ]


            if (

                len(
                    set(
                        connectivity.tolist()
                    )
                )

                !=

                len(connectivity)

            ):

                bad_elements += 1


                if bad_elements <= 5:

                    print(
                        "Bad element:",
                        int(tags[i])
                    )


    print(
        f"\nTotal elements: "
        f"{total_elements:,}"
    )

    print(
        f"Degenerate elements: "
        f"{bad_elements}"
    )


    if bad_elements:

        raise RuntimeError(
            "Degenerate elements detected."
        )


    # ========================================================
    # NODE COUNT
    # ========================================================

    nodes, coords, _ = (
        gmsh.model.mesh.getNodes()
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "REDUCED MESH STATISTICS"
    )

    print(
        "=" * 80
    )

    print(
        f"Nodes    : {len(nodes):,}"
    )

    print(
        f"Elements : {total_elements:,}"
    )


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nPhysical groups:"
    )


    for dim, tag in (
        gmsh.model.getPhysicalGroups()
    ):

        name = gmsh.model.getPhysicalName(
            dim,
            tag
        )

        print(
            f"  Dimension={dim}, "
            f"Attribute={tag}, "
            f"Name={name}"
        )


    # ========================================================
    # WRITE MSH 2.2
    # ========================================================

    print(
        "\nWriting MSH 2.2..."
    )


    gmsh.option.setNumber(
        "Mesh.MshFileVersion",
        2.2
    )

    gmsh.option.setNumber(
        "Mesh.Binary",
        0
    )


    gmsh.write(
        OUTPUT_MESH
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "REDUCED CONFORMAL PALACE MESH CREATED"
    )

    print(
        "=" * 80
    )

    print(
        "\nMesh:"
    )

    print(
        OUTPUT_MESH
    )


finally:

    gmsh.finalize()

    print(
        "\nGmsh finalized."
    )
# Out:
# ================================================================================
# MEMORY-EFFICIENT CONFORMAL PALACE MESH
# ================================================================================
#
# Reading GDS...
# Loaded 19 cells.
# Using top cell: TOP_main_1
#
# Extracting Layer 1 / Datatype 0...
# Raw metal polygons: 2450
#
# Cleaning metal geometry...
# Valid polygons: 2450
#
# Uniting overlapping metal polygons...
# Unified metal regions: 1
#
# Initializing Gmsh...
#
# Creating silicon substrate...
# Creating vacuum...
#
# Creating unified metal surfaces...
# Unified metal surfaces created: 1
#
# Removing duplicate OCC geometry...
#
# ================================================================================
# FRAGMENTING VOLUMES WITH UNIFIED METAL
# ================================================================================
# Fragmentation produced 35 entities.
#
# Synchronizing fragmented geometry...
# Removing duplicate geometry...
#
# 3D volumes: 2
# Silicon volumes: 1
# Vacuum volumes: 1
# Recovered metal surfaces: 1
#
# Creating physical groups...
#
# Configuring reduced mesh...
# Creating metal-distance refinement...
# Metal refinement curves: 36280
#
# Creating local JJ refinement...
#   JJ 1: (-1.1325, 0.0000) mm
#   JJ 2: (-0.8675, 0.0000) mm
#   JJ 3: (1.2675, 0.0000) mm
#   JJ 4: (1.5325, 0.0000) mm
#   JJ 5: (-1.1325, -2.7000) mm
#   JJ 6: (-0.8675, -2.7000) mm
#   JJ 7: (1.2675, -2.7000) mm
#   JJ 8: (1.5325, -2.7000) mm
#
# ================================================================================
# GENERATING REDUCED CONFORMAL 3D MESH
# ================================================================================
# Bulk size  : 200 um
# Metal size : 75 um
# JJ size    : 20 um
#
# Removing duplicate mesh nodes...
# Removing duplicate mesh elements...
#
# Checking element connectivity...
#
# Total elements: 20,855,821
# Degenerate elements: 0
#
# ================================================================================
# REDUCED MESH STATISTICS
# ================================================================================
# Nodes    : 2,939,464
# Elements : 20,855,821
#
# Physical groups:
#   Dimension=2, Attribute=10, Name=Superconducting_Metal
#   Dimension=3, Attribute=1, Name=Vacuum
#   Dimension=3, Attribute=2, Name=Silicon_Substrate
#
# Writing MSH 2.2...
#
# ================================================================================
# REDUCED CONFORMAL PALACE MESH CREATED
# ================================================================================
#
# Mesh:
# /content/quantum_chip_mesh_reduced_conformal.msh
#
# Gmsh finalized.

# %%
import shutil
import os

# ==========================================
# STEP 20: Permanent Google Drive Archival of Mesh & GDS Files
# ==========================================
files_to_save = [
    "/content/quantum_chip_mesh_reduced_conformal.msh"
]

destination_dir = "/content/drive/MyDrive/Palace6/meshes"
os.makedirs(destination_dir, exist_ok=True)

print(f"Beginning permanent archival to Google Drive: {destination_dir}\n")

saved_count = 0
for file_path in files_to_save:
    if os.path.exists(file_path):
        file_name = os.path.basename(file_path)
        dest_path = os.path.join(destination_dir, file_name)
        shutil.copy2(file_path, dest_path)
        print(f"[SAVED] {file_name} -> {dest_path}")
        saved_count += 1
    else:
        print(f"[SKIPPED] File not found locally: {file_path}")

print(f"\nSuccessfully archived {saved_count} file(s) permanently to Google Drive.")
# Out:
# Beginning permanent archival to Google Drive: /content/drive/MyDrive/Palace6/meshes
#
# [SAVED] quantum_chip_mesh_reduced_conformal.msh -> /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_reduced_conformal.msh
#
# Successfully archived 1 file(s) permanently to Google Drive.

# %%
# ============================================================
# STEP 5F — ULTRA-REDUCED CONFORMAL PALACE MESH
#
# Purpose:
#   Produce a mesh small enough for Palace/Colab memory.
#
# Changes from STEP 5E:
#
#   1. Simplify redundant GDS boundary vertices
#   2. NO global metal-distance refinement
#   3. Coarser bulk mesh = 300 um
#   4. Local JJ refinement = 30 um
#
# IMPORTANT:
#   This is a SANITY mesh.
#   Do not use its final frequencies for device publication.
# ============================================================

import os
import gdspy
import gmsh

from shapely.geometry import Polygon
from shapely.ops import unary_union


# ============================================================
# INPUT
# ============================================================

GDS_PATH =  "/content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds"

OUTPUT_MESH = (
    "/content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_ultra_reduced.msh"
)

TOP_CELL_NAME = "TOP_main_1"

METAL_LAYER = 1
METAL_DATATYPE = 0


# ============================================================
# CHIP
# ============================================================

CHIP_X = 14.0
CHIP_Y = 14.0

SUBSTRATE_THICKNESS = 0.5
AIR_HEIGHT = 0.5


# ============================================================
# PHYSICAL GROUPS
# ============================================================

VACUUM_ID = 1
SILICON_ID = 2
PEC_ID = 10


# ============================================================
# MESH PARAMETERS
# ============================================================

# Global mesh
BULK_SIZE = 0.300       # 300 um

# JJ local mesh
JJ_SIZE = 0.030         # 30 um

# Size of JJ refinement box
JJ_BOX_HALF = 0.100     # 100 um

# Remove redundant boundary vertices
#
# 0.003 mm = 3 um
#
# This is ONLY for the sanity mesh.
SIMPLIFY_TOL = 0.003


# ============================================================
# JJ LOCATIONS
# ============================================================

JJ_LOCATIONS = [

    (-1.1325,  0.0000),
    (-0.8675,  0.0000),

    ( 1.2675,  0.0000),
    ( 1.5325,  0.0000),

    (-1.1325, -2.7000),
    (-0.8675, -2.7000),

    ( 1.2675, -2.7000),
    ( 1.5325, -2.7000)
]


# ============================================================
# HEADER
# ============================================================

print("=" * 80)
print("ULTRA-REDUCED CONFORMAL PALACE MESH")
print("=" * 80)

print(
    "\nTarget:"
)

print(
    f"  Bulk mesh     : {BULK_SIZE * 1000:.0f} um"
)

print(
    f"  JJ mesh       : {JJ_SIZE * 1000:.0f} um"
)

print(
    f"  Simplification: {SIMPLIFY_TOL * 1000:.1f} um"
)


# ============================================================
# READ GDS
# ============================================================

print(
    "\nReading GDS..."
)

lib = gdspy.GdsLibrary()

lib.read_gds(
    GDS_PATH
)

print(
    f"Loaded {len(lib.cells)} cells."
)


if TOP_CELL_NAME not in lib.cells:

    raise RuntimeError(
        f"Top cell not found: {TOP_CELL_NAME}"
    )


top = lib.cells[
    TOP_CELL_NAME
]

print(
    f"Using top cell: {TOP_CELL_NAME}"
)


# ============================================================
# EXTRACT METAL
# ============================================================

print(
    "\nExtracting Layer 1 / Datatype 0..."
)

polygons_by_spec = top.get_polygons(
    by_spec=True
)

raw_polygons = []


for spec, polygons in polygons_by_spec.items():

    layer, datatype = spec

    if layer != METAL_LAYER:
        continue

    if datatype != METAL_DATATYPE:
        continue

    for polygon in polygons:

        if len(polygon) < 3:
            continue

        points = []

        for p in polygon:

            point = (
                float(p[0]),
                float(p[1])
            )

            if (
                not points
                or point != points[-1]
            ):

                points.append(point)


        if (
            len(points) > 1
            and points[0] == points[-1]
        ):

            points.pop()


        if len(set(points)) >= 3:

            raw_polygons.append(
                points
            )


print(
    f"Raw polygons: "
    f"{len(raw_polygons)}"
)


# ============================================================
# SHAPELY CLEANUP
# ============================================================

print(
    "\nConverting to Shapely..."
)

shapes = []


for points in raw_polygons:

    try:

        poly = Polygon(points)

        if not poly.is_valid:

            poly = poly.buffer(0)

        if poly.is_empty:

            continue

        if poly.area <= 1e-12:

            continue

        shapes.append(poly)

    except Exception:

        pass


print(
    f"Valid polygons: "
    f"{len(shapes)}"
)


# ============================================================
# UNION
# ============================================================

print(
    "\nUniting metal geometry..."
)

metal_union = unary_union(
    shapes
)


if not metal_union.is_valid:

    metal_union = metal_union.buffer(0)


print(
    "Original union:",
    metal_union.geom_type
)


# ============================================================
# SIMPLIFY GEOMETRY
# ============================================================

print(
    "\nSimplifying redundant boundary vertices..."
)

original_area = metal_union.area

simplified_union = metal_union.simplify(
    SIMPLIFY_TOL,
    preserve_topology=True
)


if simplified_union.is_empty:

    raise RuntimeError(
        "Simplified metal geometry is empty."
    )


if not simplified_union.is_valid:

    print(
        "Simplified geometry invalid; repairing..."
    )

    simplified_union = (
        simplified_union.buffer(0)
    )


new_area = simplified_union.area


print(
    f"Original metal area : "
    f"{original_area:.6f} mm^2"
)

print(
    f"Simplified area     : "
    f"{new_area:.6f} mm^2"
)

print(
    f"Area change         : "
    f"{100.0 * abs(new_area-original_area) / original_area:.4f} %"
)


# ============================================================
# EXTRACT POLYGONS
# ============================================================

if simplified_union.geom_type == "Polygon":

    unified_polygons = [
        simplified_union
    ]

elif simplified_union.geom_type == "MultiPolygon":

    unified_polygons = list(
        simplified_union.geoms
    )

else:

    raise RuntimeError(
        "Unexpected geometry after simplification: "
        + simplified_union.geom_type
    )


print(
    f"Final metal regions: "
    f"{len(unified_polygons)}"
)


# ============================================================
# INITIALIZE GMSH
# ============================================================

print(
    "\nInitializing Gmsh..."
)

gmsh.initialize()

gmsh.option.setNumber(
    "General.Terminal",
    1
)

gmsh.model.add(
    "four_qubit_ultra_reduced"
)


try:

    # ========================================================
    # SUBSTRATE
    # ========================================================

    print(
        "\nCreating silicon..."
    )

    silicon = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        -SUBSTRATE_THICKNESS,

        CHIP_X,
        CHIP_Y,
        SUBSTRATE_THICKNESS
    )


    # ========================================================
    # VACUUM
    # ========================================================

    print(
        "Creating vacuum..."
    )

    vacuum = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        0.0,

        CHIP_X,
        CHIP_Y,
        AIR_HEIGHT
    )


    # ========================================================
    # POINT CACHE
    # ========================================================

    point_cache = {}


    def get_point(x, y):

        key = (
            round(float(x), 9),
            round(float(y), 9),
            0.0
        )

        if key not in point_cache:

            point_cache[key] = (
                gmsh.model.occ.addPoint(
                    key[0],
                    key[1],
                    key[2]
                )
            )

        return point_cache[key]


    # ========================================================
    # CREATE METAL SURFACE
    # ========================================================

    print(
        "\nCreating simplified metal surfaces..."
    )

    metal_surfaces = []


    for index, poly in enumerate(
        unified_polygons
    ):

        # ----------------------------------------------------
        # OUTER BOUNDARY
        # ----------------------------------------------------

        exterior = list(
            poly.exterior.coords
        )

        exterior = exterior[:-1]


        if len(exterior) < 3:

            continue


        outer_points = [

            get_point(x, y)

            for x, y in exterior
        ]


        outer_lines = []


        for i in range(
            len(outer_points)
        ):

            p1 = outer_points[i]

            p2 = outer_points[
                (i + 1)
                % len(outer_points)
            ]


            if p1 == p2:

                continue


            outer_lines.append(

                gmsh.model.occ.addLine(
                    p1,
                    p2
                )
            )


        if len(outer_lines) < 3:

            continue


        outer_wire = (
            gmsh.model.occ.addWire(
                outer_lines
            )
        )


        # ----------------------------------------------------
        # HOLES
        # ----------------------------------------------------

        hole_wires = []


        for interior in poly.interiors:

            coords = list(
                interior.coords
            )

            coords = coords[:-1]


            if len(coords) < 3:

                continue


            hole_points = [

                get_point(x, y)

                for x, y in coords
            ]


            hole_lines = []


            for i in range(
                len(hole_points)
            ):

                p1 = hole_points[i]

                p2 = hole_points[
                    (i + 1)
                    % len(hole_points)
                ]


                if p1 == p2:

                    continue


                hole_lines.append(

                    gmsh.model.occ.addLine(
                        p1,
                        p2
                    )
                )


            if len(hole_lines) >= 3:

                hole_wires.append(

                    gmsh.model.occ.addWire(
                        hole_lines
                    )
                )


        # ----------------------------------------------------
        # SURFACE
        # ----------------------------------------------------

        try:

            surface = (
                gmsh.model.occ.addPlaneSurface(

                    [outer_wire]
                    + hole_wires
                )
            )

            metal_surfaces.append(
                surface
            )

        except Exception as exc:

            print(
                f"Metal region {index} failed:"
            )

            print(exc)


    print(
        f"Metal surfaces created: "
        f"{len(metal_surfaces)}"
    )


    # ========================================================
    # OCC SYNC
    # ========================================================

    gmsh.model.occ.synchronize()


    print(
        "\nRemoving duplicate OCC geometry..."
    )

    gmsh.model.occ.removeAllDuplicates()

    gmsh.model.occ.synchronize()


    # ========================================================
    # FRAGMENT
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "FRAGMENTING SILICON / VACUUM"
    )

    print(
        "=" * 80
    )


    fragmented, fragment_map = (
        gmsh.model.occ.fragment(

            [
                (3, silicon),
                (3, vacuum)
            ],

            [
                (2, s)
                for s in metal_surfaces
            ]
        )
    )


    print(
        f"Fragmentation produced "
        f"{len(fragmented)} entities."
    )


    gmsh.model.occ.synchronize()


    # ========================================================
    # REMOVE DUPLICATES
    # ========================================================

    print(
        "\nRemoving duplicate geometry..."
    )

    gmsh.model.occ.removeAllDuplicates()

    gmsh.model.occ.synchronize()


    # ========================================================
    # FIND VOLUMES
    # ========================================================

    volumes = (
        gmsh.model.getEntities(3)
    )


    silicon_volumes = []
    vacuum_volumes = []


    for dim, tag in volumes:

        com = (
            gmsh.model.occ.getCenterOfMass(
                dim,
                tag
            )
        )


        if com[2] < -1e-8:

            silicon_volumes.append(tag)

        elif com[2] > 1e-8:

            vacuum_volumes.append(tag)


    print(
        "\n3D volumes:",
        len(volumes)
    )

    print(
        "Silicon volumes:",
        len(silicon_volumes)
    )

    print(
        "Vacuum volumes:",
        len(vacuum_volumes)
    )


    # ========================================================
    # RECOVER METAL
    # ========================================================

    mapped_metal_surfaces = []


    for mapping in fragment_map[2:]:

        for dim, tag in mapping:

            if dim == 2:

                mapped_metal_surfaces.append(
                    tag
                )


    mapped_metal_surfaces = sorted(
        set(mapped_metal_surfaces)
    )


    print(
        "Recovered metal surfaces:",
        len(mapped_metal_surfaces)
    )


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nCreating physical groups..."
    )


    gmsh.model.addPhysicalGroup(
        3,
        vacuum_volumes,
        VACUUM_ID
    )

    gmsh.model.setPhysicalName(
        3,
        VACUUM_ID,
        "Vacuum"
    )


    gmsh.model.addPhysicalGroup(
        3,
        silicon_volumes,
        SILICON_ID
    )

    gmsh.model.setPhysicalName(
        3,
        SILICON_ID,
        "Silicon_Substrate"
    )


    gmsh.model.addPhysicalGroup(
        2,
        mapped_metal_surfaces,
        PEC_ID
    )

    gmsh.model.setPhysicalName(
        2,
        PEC_ID,
        "Superconducting_Metal"
    )


    # ========================================================
    # MESH SIZE
    # ========================================================

    print(
        "\nSetting global mesh size..."
    )


    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMin",
        BULK_SIZE
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMax",
        BULK_SIZE
    )


    # ========================================================
    # JJ LOCAL REFINEMENT ONLY
    # ========================================================

    print(
        "\nCreating JJ local refinement..."
    )


    jj_fields = []


    for i, (x, y) in enumerate(
        JJ_LOCATIONS
    ):

        field = (
            gmsh.model.mesh.field.add(
                "Box"
            )
        )


        gmsh.model.mesh.field.setNumber(
            field,
            "VIn",
            JJ_SIZE
        )


        gmsh.model.mesh.field.setNumber(
            field,
            "VOut",
            BULK_SIZE
        )


        gmsh.model.mesh.field.setNumber(
            field,
            "XMin",
            x - JJ_BOX_HALF
        )


        gmsh.model.mesh.field.setNumber(
            field,
            "XMax",
            x + JJ_BOX_HALF
        )


        gmsh.model.mesh.field.setNumber(
            field,
            "YMin",
            y - JJ_BOX_HALF
        )


        gmsh.model.mesh.field.setNumber(
            field,
            "YMax",
            y + JJ_BOX_HALF
        )


        gmsh.model.mesh.field.setNumber(
            field,
            "ZMin",
            -SUBSTRATE_THICKNESS
        )


        gmsh.model.mesh.field.setNumber(
            field,
            "ZMax",
            AIR_HEIGHT
        )


        jj_fields.append(
            field
        )


        print(
            f"  JJ {i+1}: "
            f"({x:.4f}, {y:.4f}) mm"
        )


    # ========================================================
    # COMBINE JJ FIELDS
    # ========================================================

    if jj_fields:

        jj_min_field = (
            gmsh.model.mesh.field.add(
                "Min"
            )
        )


        gmsh.model.mesh.field.setNumbers(
            jj_min_field,
            "FieldsList",
            jj_fields
        )


        gmsh.model.mesh.field.setAsBackgroundMesh(
            jj_min_field
        )


    # ========================================================
    # 3D MESH SETTINGS
    # ========================================================

    gmsh.option.setNumber(
        "Mesh.Algorithm3D",
        1
    )

    gmsh.option.setNumber(
        "Mesh.Optimize",
        0
    )

    gmsh.option.setNumber(
        "Mesh.OptimizeNetgen",
        0
    )


    # ========================================================
    # GENERATE
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "GENERATING ULTRA-REDUCED 3D MESH"
    )

    print(
        "=" * 80
    )


    gmsh.model.mesh.generate(
        3
    )


    # ========================================================
    # CLEAN
    # ========================================================

    print(
        "\nRemoving duplicate nodes..."
    )

    gmsh.model.mesh.removeDuplicateNodes()


    print(
        "Removing duplicate elements..."
    )

    gmsh.model.mesh.removeDuplicateElements()


    # ========================================================
    # CHECK CONNECTIVITY
    # ========================================================

    print(
        "\nChecking element connectivity..."
    )


    element_types, element_tags, element_nodes = (
        gmsh.model.mesh.getElements()
    )


    total_elements = 0
    bad_elements = 0


    for etype, tags, nodes in zip(
        element_types,
        element_tags,
        element_nodes
    ):

        props = (
            gmsh.model.mesh.getElementProperties(
                etype
            )
        )

        num_nodes = props[3]

        total_elements += len(tags)


        for i in range(
            len(tags)
        ):

            conn = nodes[
                i * num_nodes:
                (i + 1) * num_nodes
            ]


            if (
                len(
                    set(
                        conn.tolist()
                    )
                )
                != len(conn)
            ):

                bad_elements += 1


    print(
        f"Total elements: "
        f"{total_elements:,}"
    )

    print(
        f"Degenerate elements: "
        f"{bad_elements}"
    )


    if bad_elements:

        raise RuntimeError(
            "Degenerate elements remain."
        )


    # ========================================================
    # STATISTICS
    # ========================================================

    node_tags, node_coords, _ = (
        gmsh.model.mesh.getNodes()
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "ULTRA-REDUCED MESH STATISTICS"
    )

    print(
        "=" * 80
    )

    print(
        f"Nodes    : "
        f"{len(node_tags):,}"
    )

    print(
        f"Elements : "
        f"{total_elements:,}"
    )


    print(
        "\nPhysical groups:"
    )


    for dim, tag in (
        gmsh.model.getPhysicalGroups()
    ):

        name = (
            gmsh.model.getPhysicalName(
                dim,
                tag
            )
        )

        print(
            f"  Dimension={dim}, "
            f"Attribute={tag}, "
            f"Name={name}"
        )


    # ========================================================
    # WRITE MSH 2.2
    # ========================================================

    print(
        "\nWriting MSH 2.2..."
    )


    gmsh.option.setNumber(
        "Mesh.MshFileVersion",
        2.2
    )

    gmsh.option.setNumber(
        "Mesh.Binary",
        0
    )


    gmsh.write(
        OUTPUT_MESH
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "ULTRA-REDUCED PALACE MESH CREATED"
    )

    print(
        "=" * 80
    )

    print(
        "\nMesh:"
    )

    print(
        OUTPUT_MESH
    )


finally:

    gmsh.finalize()

    print(
        "\nGmsh finalized."
    )
# Out:
# ================================================================================
# ULTRA-REDUCED CONFORMAL PALACE MESH
# ================================================================================
#
# Target:
#   Bulk mesh     : 300 um
#   JJ mesh       : 30 um
#   Simplification: 3.0 um
#
# Reading GDS...
# Loaded 19 cells.
# Using top cell: TOP_main_1
#
# Extracting Layer 1 / Datatype 0...
# Raw polygons: 2450
#
# Converting to Shapely...
# Valid polygons: 2450
#
# Uniting metal geometry...
# Original union: Polygon
#
# Simplifying redundant boundary vertices...
# Original metal area : 185.750737 mm^2
# Simplified area     : 185.752476 mm^2
# Area change         : 0.0009 %
# Final metal regions: 1
#
# Initializing Gmsh...
#
# Creating silicon...
# Creating vacuum...
#
# Creating simplified metal surfaces...
# Metal surfaces created: 1
#
# Removing duplicate OCC geometry...
#
# ================================================================================
# FRAGMENTING SILICON / VACUUM
# ================================================================================
# Fragmentation produced 35 entities.
#
# Removing duplicate geometry...
#
# 3D volumes: 2
# Silicon volumes: 1
# Vacuum volumes: 1
# Recovered metal surfaces: 1
#
# Creating physical groups...
#
# Setting global mesh size...
#
# Creating JJ local refinement...
#   JJ 1: (-1.1325, 0.0000) mm
#   JJ 2: (-0.8675, 0.0000) mm
#   JJ 3: (1.2675, 0.0000) mm
#   JJ 4: (1.5325, 0.0000) mm
#   JJ 5: (-1.1325, -2.7000) mm
#   JJ 6: (-0.8675, -2.7000) mm
#   JJ 7: (1.2675, -2.7000) mm
#   JJ 8: (1.5325, -2.7000) mm
#
# ================================================================================
# GENERATING ULTRA-REDUCED 3D MESH
# ================================================================================
#
# Removing duplicate nodes...
# Removing duplicate elements...
#
# Checking element connectivity...
# Total elements: 414,344
# Degenerate elements: 0
#
# ================================================================================
# ULTRA-REDUCED MESH STATISTICS
# ================================================================================
# Nodes    : 58,471
# Elements : 414,344
#
# Physical groups:
#   Dimension=2, Attribute=10, Name=Superconducting_Metal
#   Dimension=3, Attribute=1, Name=Vacuum
#   Dimension=3, Attribute=2, Name=Silicon_Substrate
#
# Writing MSH 2.2...
#
# ================================================================================
# ULTRA-REDUCED PALACE MESH CREATED
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_ultra_reduced.msh
#
# Gmsh finalized.

# %%
# ============================================================
# PALACE — ULTRA-REDUCED MESH + 1 EIGENMODE TEST
# ============================================================

import os
import json
import subprocess
import shutil


# ============================================================
# PATHS
# ============================================================

PALACE_DIR = (
    "/content/drive/MyDrive/Palace6/build"
)

PALACE_BIN = os.path.join(
    PALACE_DIR,
    "bin",
    "palace-x86_64.bin"
)

LIB_DIR = os.path.join(
    PALACE_DIR,
    "lib"
)

MESH = (
    "/content/drive/MyDrive/Palace6/"
    "meshes/quantum_chip_mesh_ultra_reduced.msh"
)

CONFIG = (
    "/content/palace_ultra_reduced_test.json"
)

OUTPUT = (
    "/content/palace_ultra_reduced_output"
)


# ============================================================
# CHECK FILES
# ============================================================

print("=" * 80)
print("PALACE — ULTRA-REDUCED MESH + 1 MODE TEST")
print("=" * 80)

if not os.path.exists(MESH):

    raise FileNotFoundError(
        f"Mesh not found:\n{MESH}"
    )

if not os.path.exists(PALACE_BIN):

    raise FileNotFoundError(
        f"Palace executable not found:\n{PALACE_BIN}"
    )


mesh_size_mb = (
    os.path.getsize(MESH)
    / (1024 ** 2)
)

print(
    "\nMesh:"
)

print(
    MESH
)

print(
    f"\nMesh file size: "
    f"{mesh_size_mb:.1f} MB"
)

print(
    "\nMesh statistics:"
)

print(
    "  Nodes    : 58,471"
)

print(
    "  Elements : 414,344"
)


# ============================================================
# CLEAN PREVIOUS OUTPUT
# ============================================================

if os.path.exists(OUTPUT):

    print(
        "\nRemoving previous Palace output..."
    )

    shutil.rmtree(
        OUTPUT
    )

os.makedirs(
    OUTPUT,
    exist_ok=True
)


# ============================================================
# ENVIRONMENT
# ============================================================

env = os.environ.copy()

env["LD_LIBRARY_PATH"] = (
    LIB_DIR
    + ":"
    + env.get(
        "LD_LIBRARY_PATH",
        ""
    )
)

env["OMPI_ALLOW_RUN_AS_ROOT"] = "1"

env[
    "OMPI_ALLOW_RUN_AS_ROOT_CONFIRM"
] = "1"


# ============================================================
# PALACE CONFIGURATION
# ============================================================

palace_config = {

    "Problem": {

        "Type": "Eigenmode",

        "Verbose": 2,

        "Output": OUTPUT
    },


    "Model": {

        "Mesh": MESH,

        # GDS/Gmsh geometry is in mm.
        # Palace physical units are meters.
        "L0": 1.0e-3
    },


    "Domains": {

        "Materials": [

            {
                # Physical volume 1
                # Vacuum
                "Attributes": [1],

                "Permittivity": 1.0,

                "Permeability": 1.0
            },


            {
                # Physical volume 2
                # Silicon
                "Attributes": [2],

                "Permittivity": 11.7,

                "Permeability": 1.0
            }
        ]
    },


    "Boundaries": {

        # Physical surface 10
        # Superconducting metal
        "PEC": {

            "Attributes": [10]
        }
    },


    "Solver": {

        # Lowest-order FEM
        "Order": 1,


        "Eigenmode": {

            # =================================================
            # ONLY ONE MODE
            # =================================================

            "N": 1,

            # Search around 5 GHz
            "Target": 5.0,

            # Relaxed tolerance for sanity test
            "Tol": 1.0e-6,

            "MaxIts": 100
        },


        "Linear": {

            "Type": "BoomerAMG",

            "Tol": 1.0e-6,

            "MaxIts": 50
        }
    }
}


# ============================================================
# WRITE CONFIG
# ============================================================

with open(
    CONFIG,
    "w"
) as f:

    json.dump(
        palace_config,
        f,
        indent=4
    )


print(
    "\nConfiguration:"
)

print(
    CONFIG
)


# ============================================================
# COMMAND
# ============================================================

cmd = [

    "mpirun",

    "-n",
    "1",

    "--allow-run-as-root",

    PALACE_BIN,

    CONFIG
]


print(
    "\n" + "=" * 80
)

print(
    "EXECUTING PALACE"
)

print(
    "=" * 80
)

print(
    "\nCommand:"
)

print(
    " ".join(cmd)
)


# ============================================================
# RUN
# ============================================================

result = subprocess.run(

    cmd,

    text=True,

    capture_output=True,

    env=env
)


# ============================================================
# OUTPUT
# ============================================================

print(
    "\n" + "=" * 80
)

print(
    "PALACE STDOUT"
)

print(
    "=" * 80
)

print(
    result.stdout
)


print(
    "\n" + "=" * 80
)

print(
    "PALACE STDERR"
)

print(
    "=" * 80
)

print(
    result.stderr
)


print(
    "\n" + "=" * 80
)

print(
    "RETURN CODE"
)

print(
    result.returncode
)

print(
    "=" * 80
)


# ============================================================
# RESULT
# ============================================================

if result.returncode == 0:

    print(
        "\n" + "=" * 80
    )

    print(
        "SUCCESS"
    )

    print(
        "=" * 80
    )

    print(
        "\nPalace successfully:"
    )

    print(
        "  ✓ Read the Gmsh mesh"
    )

    print(
        "  ✓ Constructed the MFEM mesh"
    )

    print(
        "  ✓ Applied the PEC boundary"
    )

    print(
        "  ✓ Completed the 1-mode eigenmode test"
    )

    print(
        "\nOutput:"
    )

    print(
        OUTPUT
    )

else:

    print(
        "\n" + "=" * 80
    )

    print(
        "PALACE TEST FAILED"
    )

    print(
        "=" * 80
    )

    print(
        "\nLast part of Palace STDERR:"
    )

    print(
        result.stderr[-6000:]
    )
# Out:
# ================================================================================
# PALACE — ULTRA-REDUCED MESH + 1 MODE TEST
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_ultra_reduced.msh
#
# Mesh file size: 16.8 MB
#
# Mesh statistics:
#   Nodes    : 58,471
#   Elements : 414,344
#
# Configuration:
# /content/palace_ultra_reduced_test.json
#
# ================================================================================
# EXECUTING PALACE
# ================================================================================
#
# Command:
# mpirun -n 1 --allow-run-as-root /content/drive/MyDrive/Palace6/build/bin/palace-x86_64.bin /content/palace_ultra_reduced_test.json
#
# ================================================================================
# PALACE STDOUT
# ================================================================================
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
# Git changeset ID: v0.17.0-194-g01f5d9bd1
# Running with 1 MPI process, 1 OpenMP thread
# Device configuration: omp,cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
#
# --> Warning!
# 11764 mesh faces with no associated boundary element exist on the domain boundary!
#
# Added 1221 elements in 2 iterations of local bisection for under-resolved interior boundaries
# Added 24153 duplicate vertices for interior boundaries in the mesh
# Added 51658 duplicate boundary elements for interior boundaries in the mesh
# Added 11764 boundary elements for exterior boundaries to the mesh
# Added 7096 boundary elements for material interfaces to the mesh
#
# Characteristic length and time scales:
#  Lc = 1.400e-02 m, tc = 4.670e-02 ns
# Finished partitioning mesh into 1 subdomain
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-7.000e-03, -7.000e-03, -5.000e-04) m
#  (Xmax, Ymax, Zmax) = (+7.000e-03, +7.000e-03, +5.000e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices         82862       82862       82862       82862
#  edges           478711      478711      478711      478711
#  faces           734122      734122      734122      734122
#  elements        338291      338291      338291      338291
#  neighbors            0           0           0
#
#             minimum     maximum
#  h       0.00022527   0.0330847
#  kappa      1.00014     70191.5
#
# Estimated current per-rank memory usage is: Min. 323.8M, Max. 323.8M, Avg. 323.8M, Total 323.8M
# Estimated current per-node memory usage is: Min. 323.8M, Max. 323.8M, Avg. 323.8M, Total 323.8M
#
# Configuring Dirichlet PEC BC at attributes:
#  10
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 82862, ND (p = 1): 478711, RT (p = 1): 734122
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
#
# Configuring SLEPc eigenvalue solver:
#  Scaling γ = 4.025e+03, δ = 3.938e-07
#  Configuring divergence-free projection
#  Using random starting vector
#  Shift-and-invert σ = 5.000e+00 GHz (1.467e+00)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 478711 unknowns
#  Level 0 (auxiliary) (p = 1): 82862 unknowns
#
# #PETSc Option Table entries:
# -eps_monitor # (source: code)
# #End of PETSc Option Table entries
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 3.184508e-07
#  1 (restart 0) KSP residual norm 1.212507e-07
#  2 (restart 0) KSP residual norm 7.443397e-08
#  3 (restart 0) KSP residual norm 5.695879e-08
#  4 (restart 0) KSP residual norm 5.097695e-08
#  5 (restart 0) KSP residual norm 4.783957e-08
#  6 (restart 0) KSP residual norm 4.568102e-08
#  7 (restart 0) KSP residual norm 4.404264e-08
#  8 (restart 0) KSP residual norm 4.282231e-08
#  9 (restart 0) KSP residual norm 4.228904e-08
# 10 (restart 0) KSP residual norm 4.228634e-08
# 11 (restart 0) KSP residual norm 4.186630e-08
# 12 (restart 0) KSP residual norm 4.105350e-08
# 13 (restart 0) KSP residual norm 4.030657e-08
# 14 (restart 0) KSP residual norm 3.974651e-08
# 15 (restart 0) KSP residual norm 3.938849e-08
# 16 (restart 0) KSP residual norm 3.925012e-08
# 17 (restart 0) KSP residual norm 3.924660e-08
# 18 (restart 0) KSP residual norm 3.921093e-08
# 19 (restart 0) KSP residual norm 3.903411e-08
# 20 (restart 0) KSP residual norm 3.880176e-08
# 21 (restart 0) KSP residual norm 3.863806e-08
# 22 (restart 0) KSP residual norm 3.855709e-08
# 23 (restart 0) KSP residual norm 3.854734e-08
# 24 (restart 0) KSP residual norm 3.852800e-08
# 25 (restart 0) KSP residual norm 3.842996e-08
# 26 (restart 0) KSP residual norm 3.823525e-08
# 27 (restart 0) KSP residual norm 3.801902e-08
# 28 (restart 0) KSP residual norm 3.782087e-08
# 29 (restart 0) KSP residual norm 3.768647e-08
# 30 (restart 0) KSP residual norm 3.764751e-08
# 31 (restart 0) KSP residual norm 3.764728e-08
# 32 (restart 0) KSP residual norm 3.762809e-08
# 33 (restart 0) KSP residual norm 3.757124e-08
# 34 (restart 0) KSP residual norm 3.746377e-08
# 35 (restart 0) KSP residual norm 3.729818e-08
# 36 (restart 0) KSP residual norm 3.712708e-08
# 37 (restart 0) KSP residual norm 3.698886e-08
# 38 (restart 0) KSP residual norm 3.690075e-08
# 39 (restart 0) KSP residual norm 3.686961e-08
# 40 (restart 0) KSP residual norm 3.686946e-08
# 41 (restart 0) KSP residual norm 3.682259e-08
# 42 (restart 0) KSP residual norm 3.669246e-08
# 43 (restart 0) KSP residual norm 3.652111e-08
# 44 (restart 0) KSP residual norm 3.634997e-08
# 45 (restart 0) KSP residual norm 3.622688e-08
# 46 (restart 0) KSP residual norm 3.617910e-08
# 47 (restart 0) KSP residual norm 3.617775e-08
# 48 (restart 0) KSP residual norm 3.616354e-08
# 49 (restart 0) KSP residual norm 3.610992e-08
# 50 (restart 1) KSP residual norm 3.601760e-08
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.573e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.131e-01 (norm(b) = 3.185e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 9.778165e-07
#  1 (restart 0) KSP residual norm 7.248029e-07
#  2 (restart 0) KSP residual norm 6.448951e-07
#  3 (restart 0) KSP residual norm 5.877407e-07
#  4 (restart 0) KSP residual norm 5.713570e-07
#  5 (restart 0) KSP residual norm 5.458288e-07
#  6 (restart 0) KSP residual norm 5.290495e-07
#  7 (restart 0) KSP residual norm 5.152193e-07
#  8 (restart 0) KSP residual norm 5.034175e-07
#  9 (restart 0) KSP residual norm 4.880028e-07
# 10 (restart 0) KSP residual norm 4.801153e-07
# 11 (restart 0) KSP residual norm 4.742291e-07
# 12 (restart 0) KSP residual norm 4.709423e-07
# 13 (restart 0) KSP residual norm 4.700685e-07
# 14 (restart 0) KSP residual norm 4.686986e-07
# 15 (restart 0) KSP residual norm 4.641264e-07
# 16 (restart 0) KSP residual norm 4.585478e-07
# 17 (restart 0) KSP residual norm 4.550104e-07
# 18 (restart 0) KSP residual norm 4.509556e-07
# 19 (restart 0) KSP residual norm 4.492489e-07
# 20 (restart 0) KSP residual norm 4.485833e-07
# 21 (restart 0) KSP residual norm 4.485711e-07
# 22 (restart 0) KSP residual norm 4.481935e-07
# 23 (restart 0) KSP residual norm 4.469244e-07
# 24 (restart 0) KSP residual norm 4.462540e-07
# 25 (restart 0) KSP residual norm 4.456197e-07
# 26 (restart 0) KSP residual norm 4.455496e-07
# 27 (restart 0) KSP residual norm 4.454977e-07
# 28 (restart 0) KSP residual norm 4.454277e-07
# 29 (restart 0) KSP residual norm 4.452987e-07
# 30 (restart 0) KSP residual norm 4.448304e-07
# 31 (restart 0) KSP residual norm 4.434862e-07
# 32 (restart 0) KSP residual norm 4.418931e-07
# 33 (restart 0) KSP residual norm 4.403686e-07
# 34 (restart 0) KSP residual norm 4.397936e-07
# 35 (restart 0) KSP residual norm 4.397907e-07
# 36 (restart 0) KSP residual norm 4.395807e-07
# 37 (restart 0) KSP residual norm 4.377327e-07
# 38 (restart 0) KSP residual norm 4.342553e-07
# 39 (restart 0) KSP residual norm 4.308025e-07
# 40 (restart 0) KSP residual norm 4.281858e-07
# 41 (restart 0) KSP residual norm 4.271823e-07
# 42 (restart 0) KSP residual norm 4.265341e-07
# 43 (restart 0) KSP residual norm 4.265167e-07
# 44 (restart 0) KSP residual norm 4.261022e-07
# 45 (restart 0) KSP residual norm 4.251406e-07
# 46 (restart 0) KSP residual norm 4.237247e-07
# 47 (restart 0) KSP residual norm 4.228822e-07
# 48 (restart 0) KSP residual norm 4.217431e-07
# 49 (restart 0) KSP residual norm 4.211781e-07
# 50 (restart 1) KSP residual norm 4.209256e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.833e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 4.305e-01 (norm(b) = 9.778e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.185038e-06
#  1 (restart 0) KSP residual norm 8.440590e-07
#  2 (restart 0) KSP residual norm 7.003435e-07
#  3 (restart 0) KSP residual norm 6.191308e-07
#  4 (restart 0) KSP residual norm 6.018648e-07
#  5 (restart 0) KSP residual norm 5.691676e-07
#  6 (restart 0) KSP residual norm 5.468827e-07
#  7 (restart 0) KSP residual norm 5.300451e-07
#  8 (restart 0) KSP residual norm 5.139673e-07
#  9 (restart 0) KSP residual norm 4.954867e-07
# 10 (restart 0) KSP residual norm 4.889886e-07
# 11 (restart 0) KSP residual norm 4.883408e-07
# 12 (restart 0) KSP residual norm 4.878918e-07
# 13 (restart 0) KSP residual norm 4.850081e-07
# 14 (restart 0) KSP residual norm 4.733149e-07
# 15 (restart 0) KSP residual norm 4.618918e-07
# 16 (restart 0) KSP residual norm 4.510438e-07
# 17 (restart 0) KSP residual norm 4.441975e-07
# 18 (restart 0) KSP residual norm 4.416048e-07
# 19 (restart 0) KSP residual norm 4.416006e-07
# 20 (restart 0) KSP residual norm 4.408307e-07
# 21 (restart 0) KSP residual norm 4.384509e-07
# 22 (restart 0) KSP residual norm 4.360549e-07
# 23 (restart 0) KSP residual norm 4.350038e-07
# 24 (restart 0) KSP residual norm 4.349724e-07
# 25 (restart 0) KSP residual norm 4.349663e-07
# 26 (restart 0) KSP residual norm 4.344186e-07
# 27 (restart 0) KSP residual norm 4.337924e-07
# 28 (restart 0) KSP residual norm 4.319531e-07
# 29 (restart 0) KSP residual norm 4.304107e-07
# 30 (restart 0) KSP residual norm 4.298624e-07
# 31 (restart 0) KSP residual norm 4.294751e-07
# 32 (restart 0) KSP residual norm 4.294535e-07
# 33 (restart 0) KSP residual norm 4.294533e-07
# 34 (restart 0) KSP residual norm 4.290382e-07
# 35 (restart 0) KSP residual norm 4.278115e-07
# 36 (restart 0) KSP residual norm 4.265377e-07
# 37 (restart 0) KSP residual norm 4.236870e-07
# 38 (restart 0) KSP residual norm 4.204595e-07
# 39 (restart 0) KSP residual norm 4.188457e-07
# 40 (restart 0) KSP residual norm 4.185191e-07
# 41 (restart 0) KSP residual norm 4.183572e-07
# 42 (restart 0) KSP residual norm 4.179363e-07
# 43 (restart 0) KSP residual norm 4.162435e-07
# 44 (restart 0) KSP residual norm 4.135465e-07
# 45 (restart 0) KSP residual norm 4.115648e-07
# 46 (restart 0) KSP residual norm 4.101272e-07
# 47 (restart 0) KSP residual norm 4.099749e-07
# 48 (restart 0) KSP residual norm 4.099710e-07
# 49 (restart 0) KSP residual norm 4.096704e-07
# 50 (restart 1) KSP residual norm 4.088910e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.789e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 3.450e-01 (norm(b) = 1.185e-06)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.356528e-06
#  1 (restart 0) KSP residual norm 8.806784e-07
#  2 (restart 0) KSP residual norm 6.982530e-07
#  3 (restart 0) KSP residual norm 6.152285e-07
#  4 (restart 0) KSP residual norm 5.974013e-07
#  5 (restart 0) KSP residual norm 5.596923e-07
#  6 (restart 0) KSP residual norm 5.276761e-07
#  7 (restart 0) KSP residual norm 5.041471e-07
#  8 (restart 0) KSP residual norm 4.821968e-07
#  9 (restart 0) KSP residual norm 4.647271e-07
# 10 (restart 0) KSP residual norm 4.624159e-07
# 11 (restart 0) KSP residual norm 4.615799e-07
# 12 (restart 0) KSP residual norm 4.550666e-07
# 13 (restart 0) KSP residual norm 4.464486e-07
# 14 (restart 0) KSP residual norm 4.291462e-07
# 15 (restart 0) KSP residual norm 4.150156e-07
# 16 (restart 0) KSP residual norm 4.040483e-07
# 17 (restart 0) KSP residual norm 3.988289e-07
# 18 (restart 0) KSP residual norm 3.983847e-07
# 19 (restart 0) KSP residual norm 3.968031e-07
# 20 (restart 0) KSP residual norm 3.922979e-07
# 21 (restart 0) KSP residual norm 3.875312e-07
# 22 (restart 0) KSP residual norm 3.835804e-07
# 23 (restart 0) KSP residual norm 3.817095e-07
# 24 (restart 0) KSP residual norm 3.815433e-07
# 25 (restart 0) KSP residual norm 3.815395e-07
# 26 (restart 0) KSP residual norm 3.805521e-07
# 27 (restart 0) KSP residual norm 3.787868e-07
# 28 (restart 0) KSP residual norm 3.751424e-07
# 29 (restart 0) KSP residual norm 3.723886e-07
# 30 (restart 0) KSP residual norm 3.717699e-07
# 31 (restart 0) KSP residual norm 3.713806e-07
# 32 (restart 0) KSP residual norm 3.713762e-07
# 33 (restart 0) KSP residual norm 3.712935e-07
# 34 (restart 0) KSP residual norm 3.701302e-07
# 35 (restart 0) KSP residual norm 3.679623e-07
# 36 (restart 0) KSP residual norm 3.656872e-07
# 37 (restart 0) KSP residual norm 3.624414e-07
# 38 (restart 0) KSP residual norm 3.595568e-07
# 39 (restart 0) KSP residual norm 3.588271e-07
# 40 (restart 0) KSP residual norm 3.587916e-07
# 41 (restart 0) KSP residual norm 3.581550e-07
# 42 (restart 0) KSP residual norm 3.571050e-07
# 43 (restart 0) KSP residual norm 3.546227e-07
# 44 (restart 0) KSP residual norm 3.515299e-07
# 45 (restart 0) KSP residual norm 3.499577e-07
# 46 (restart 0) KSP residual norm 3.489479e-07
# 47 (restart 0) KSP residual norm 3.489201e-07
# 48 (restart 0) KSP residual norm 3.488547e-07
# 49 (restart 0) KSP residual norm 3.478415e-07
# 50 (restart 1) KSP residual norm 3.460000e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.730e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.551e-01 (norm(b) = 1.357e-06)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.294269e-06
#  1 (restart 0) KSP residual norm 8.012941e-07
#  2 (restart 0) KSP residual norm 6.552949e-07
#  3 (restart 0) KSP residual norm 5.757980e-07
#  4 (restart 0) KSP residual norm 5.489323e-07
#  5 (restart 0) KSP residual norm 5.116949e-07
#  6 (restart 0) KSP residual norm 4.845528e-07
#  7 (restart 0) KSP residual norm 4.636364e-07
#  8 (restart 0) KSP residual norm 4.427617e-07
#  9 (restart 0) KSP residual norm 4.231966e-07
# 10 (restart 0) KSP residual norm 4.210196e-07
# 11 (restart 0) KSP residual norm 4.188847e-07
# 12 (restart 0) KSP residual norm 4.061706e-07
# 13 (restart 0) KSP residual norm 3.870443e-07
# 14 (restart 0) KSP residual norm 3.618255e-07
# 15 (restart 0) KSP residual norm 3.420567e-07
# 16 (restart 0) KSP residual norm 3.293504e-07
# 17 (restart 0) KSP residual norm 3.243431e-07
# 18 (restart 0) KSP residual norm 3.237102e-07
# 19 (restart 0) KSP residual norm 3.223430e-07
# 20 (restart 0) KSP residual norm 3.179703e-07
# 21 (restart 0) KSP residual norm 3.114787e-07
# 22 (restart 0) KSP residual norm 3.056942e-07
# 23 (restart 0) KSP residual norm 3.025377e-07
# 24 (restart 0) KSP residual norm 3.021599e-07
# 25 (restart 0) KSP residual norm 3.021507e-07
# 26 (restart 0) KSP residual norm 3.012649e-07
# 27 (restart 0) KSP residual norm 2.988950e-07
# 28 (restart 0) KSP residual norm 2.945103e-07
# 29 (restart 0) KSP residual norm 2.904807e-07
# 30 (restart 0) KSP residual norm 2.884650e-07
# 31 (restart 0) KSP residual norm 2.869774e-07
# 32 (restart 0) KSP residual norm 2.866128e-07
# 33 (restart 0) KSP residual norm 2.866126e-07
# 34 (restart 0) KSP residual norm 2.854996e-07
# 35 (restart 0) KSP residual norm 2.830733e-07
# 36 (restart 0) KSP residual norm 2.797727e-07
# 37 (restart 0) KSP residual norm 2.759196e-07
# 38 (restart 0) KSP residual norm 2.719164e-07
# 39 (restart 0) KSP residual norm 2.700457e-07
# 40 (restart 0) KSP residual norm 2.695098e-07
# 41 (restart 0) KSP residual norm 2.694681e-07
# 42 (restart 0) KSP residual norm 2.687232e-07
# 43 (restart 0) KSP residual norm 2.657193e-07
# 44 (restart 0) KSP residual norm 2.617321e-07
# 45 (restart 0) KSP residual norm 2.590721e-07
# 46 (restart 0) KSP residual norm 2.575709e-07
# 47 (restart 0) KSP residual norm 2.574124e-07
# 48 (restart 0) KSP residual norm 2.574107e-07
# 49 (restart 0) KSP residual norm 2.568528e-07
# 50 (restart 1) KSP residual norm 2.557439e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.681e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.976e-01 (norm(b) = 1.294e-06)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.070946e-06
#  1 (restart 0) KSP residual norm 6.985796e-07
#  2 (restart 0) KSP residual norm 6.131703e-07
#  3 (restart 0) KSP residual norm 5.537050e-07
#  4 (restart 0) KSP residual norm 5.263804e-07
#  5 (restart 0) KSP residual norm 4.947092e-07
#  6 (restart 0) KSP residual norm 4.765157e-07
#  7 (restart 0) KSP residual norm 4.637816e-07
#  8 (restart 0) KSP residual norm 4.510694e-07
#  9 (restart 0) KSP residual norm 4.306828e-07
# 10 (restart 0) KSP residual norm 4.251531e-07
# 11 (restart 0) KSP residual norm 4.250720e-07
# 12 (restart 0) KSP residual norm 4.168298e-07
# 13 (restart 0) KSP residual norm 4.002465e-07
# 14 (restart 0) KSP residual norm 3.813657e-07
# 15 (restart 0) KSP residual norm 3.646467e-07
# 16 (restart 0) KSP residual norm 3.507670e-07
# 17 (restart 0) KSP residual norm 3.435191e-07
# 18 (restart 0) KSP residual norm 3.397279e-07
# 19 (restart 0) KSP residual norm 3.397278e-07
# 20 (restart 0) KSP residual norm 3.380109e-07
# 21 (restart 0) KSP residual norm 3.317738e-07
# 22 (restart 0) KSP residual norm 3.250077e-07
# 23 (restart 0) KSP residual norm 3.194457e-07
# 24 (restart 0) KSP residual norm 3.174615e-07
# 25 (restart 0) KSP residual norm 3.166179e-07
# 26 (restart 0) KSP residual norm 3.166100e-07
# 27 (restart 0) KSP residual norm 3.160244e-07
# 28 (restart 0) KSP residual norm 3.140238e-07
# 29 (restart 0) KSP residual norm 3.110525e-07
# 30 (restart 0) KSP residual norm 3.083954e-07
# 31 (restart 0) KSP residual norm 3.057169e-07
# 32 (restart 0) KSP residual norm 3.037368e-07
# 33 (restart 0) KSP residual norm 3.027884e-07
# 34 (restart 0) KSP residual norm 3.027744e-07
# 35 (restart 0) KSP residual norm 3.020537e-07
# 36 (restart 0) KSP residual norm 3.000628e-07
# 37 (restart 0) KSP residual norm 2.962379e-07
# 38 (restart 0) KSP residual norm 2.909094e-07
# 39 (restart 0) KSP residual norm 2.863938e-07
# 40 (restart 0) KSP residual norm 2.844737e-07
# 41 (restart 0) KSP residual norm 2.843379e-07
# 42 (restart 0) KSP residual norm 2.842229e-07
# 43 (restart 0) KSP residual norm 2.829694e-07
# 44 (restart 0) KSP residual norm 2.796802e-07
# 45 (restart 0) KSP residual norm 2.761731e-07
# 46 (restart 0) KSP residual norm 2.733889e-07
# 47 (restart 0) KSP residual norm 2.722821e-07
# 48 (restart 0) KSP residual norm 2.717721e-07
# 49 (restart 0) KSP residual norm 2.717534e-07
# 50 (restart 1) KSP residual norm 2.713076e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.729e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.533e-01 (norm(b) = 1.071e-06)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.375592e-07
#  1 (restart 0) KSP residual norm 5.778357e-07
#  2 (restart 0) KSP residual norm 5.310864e-07
#  3 (restart 0) KSP residual norm 4.873161e-07
#  4 (restart 0) KSP residual norm 4.646519e-07
#  5 (restart 0) KSP residual norm 4.441738e-07
#  6 (restart 0) KSP residual norm 4.335749e-07
#  7 (restart 0) KSP residual norm 4.233335e-07
#  8 (restart 0) KSP residual norm 4.148099e-07
#  9 (restart 0) KSP residual norm 3.988424e-07
# 10 (restart 0) KSP residual norm 3.924998e-07
# 11 (restart 0) KSP residual norm 3.921609e-07
# 12 (restart 0) KSP residual norm 3.886815e-07
# 13 (restart 0) KSP residual norm 3.792419e-07
# 14 (restart 0) KSP residual norm 3.663727e-07
# 15 (restart 0) KSP residual norm 3.537187e-07
# 16 (restart 0) KSP residual norm 3.414354e-07
# 17 (restart 0) KSP residual norm 3.342646e-07
# 18 (restart 0) KSP residual norm 3.272987e-07
# 19 (restart 0) KSP residual norm 3.246168e-07
# 20 (restart 0) KSP residual norm 3.243427e-07
# 21 (restart 0) KSP residual norm 3.222276e-07
# 22 (restart 0) KSP residual norm 3.177395e-07
# 23 (restart 0) KSP residual norm 3.121366e-07
# 24 (restart 0) KSP residual norm 3.089997e-07
# 25 (restart 0) KSP residual norm 3.065275e-07
# 26 (restart 0) KSP residual norm 3.058347e-07
# 27 (restart 0) KSP residual norm 3.056321e-07
# 28 (restart 0) KSP residual norm 3.056205e-07
# 29 (restart 0) KSP residual norm 3.052239e-07
# 30 (restart 0) KSP residual norm 3.035394e-07
# 31 (restart 0) KSP residual norm 3.004658e-07
# 32 (restart 0) KSP residual norm 2.974248e-07
# 33 (restart 0) KSP residual norm 2.950122e-07
# 34 (restart 0) KSP residual norm 2.940871e-07
# 35 (restart 0) KSP residual norm 2.940682e-07
# 36 (restart 0) KSP residual norm 2.938577e-07
# 37 (restart 0) KSP residual norm 2.928515e-07
# 38 (restart 0) KSP residual norm 2.905313e-07
# 39 (restart 0) KSP residual norm 2.870348e-07
# 40 (restart 0) KSP residual norm 2.849916e-07
# 41 (restart 0) KSP residual norm 2.842272e-07
# 42 (restart 0) KSP residual norm 2.838801e-07
# 43 (restart 0) KSP residual norm 2.838681e-07
# 44 (restart 0) KSP residual norm 2.836467e-07
# 45 (restart 0) KSP residual norm 2.826936e-07
# 46 (restart 0) KSP residual norm 2.812209e-07
# 47 (restart 0) KSP residual norm 2.798356e-07
# 48 (restart 0) KSP residual norm 2.785694e-07
# 49 (restart 0) KSP residual norm 2.780594e-07
# 50 (restart 1) KSP residual norm 2.777001e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.782e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 3.316e-01 (norm(b) = 8.376e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.484836e-07
#  1 (restart 0) KSP residual norm 6.071962e-07
#  2 (restart 0) KSP residual norm 5.515239e-07
#  3 (restart 0) KSP residual norm 4.981265e-07
#  4 (restart 0) KSP residual norm 4.688447e-07
#  5 (restart 0) KSP residual norm 4.392155e-07
#  6 (restart 0) KSP residual norm 4.250302e-07
#  7 (restart 0) KSP residual norm 4.149221e-07
#  8 (restart 0) KSP residual norm 4.081545e-07
#  9 (restart 0) KSP residual norm 3.959581e-07
# 10 (restart 0) KSP residual norm 3.874020e-07
# 11 (restart 0) KSP residual norm 3.827352e-07
# 12 (restart 0) KSP residual norm 3.824897e-07
# 13 (restart 0) KSP residual norm 3.813244e-07
# 14 (restart 0) KSP residual norm 3.766320e-07
# 15 (restart 0) KSP residual norm 3.713445e-07
# 16 (restart 0) KSP residual norm 3.656195e-07
# 17 (restart 0) KSP residual norm 3.626392e-07
# 18 (restart 0) KSP residual norm 3.601673e-07
# 19 (restart 0) KSP residual norm 3.599266e-07
# 20 (restart 0) KSP residual norm 3.595313e-07
# 21 (restart 0) KSP residual norm 3.563140e-07
# 22 (restart 0) KSP residual norm 3.531425e-07
# 23 (restart 0) KSP residual norm 3.495664e-07
# 24 (restart 0) KSP residual norm 3.483188e-07
# 25 (restart 0) KSP residual norm 3.476330e-07
# 26 (restart 0) KSP residual norm 3.475538e-07
# 27 (restart 0) KSP residual norm 3.475498e-07
# 28 (restart 0) KSP residual norm 3.473991e-07
# 29 (restart 0) KSP residual norm 3.469967e-07
# 30 (restart 0) KSP residual norm 3.457227e-07
# 31 (restart 0) KSP residual norm 3.441223e-07
# 32 (restart 0) KSP residual norm 3.428749e-07
# 33 (restart 0) KSP residual norm 3.419251e-07
# 34 (restart 0) KSP residual norm 3.415062e-07
# 35 (restart 0) KSP residual norm 3.414899e-07
# 36 (restart 0) KSP residual norm 3.410692e-07
# 37 (restart 0) KSP residual norm 3.397107e-07
# 38 (restart 0) KSP residual norm 3.374787e-07
# 39 (restart 0) KSP residual norm 3.349479e-07
# 40 (restart 0) KSP residual norm 3.336201e-07
# 41 (restart 0) KSP residual norm 3.332953e-07
# 42 (restart 0) KSP residual norm 3.332833e-07
# 43 (restart 0) KSP residual norm 3.331255e-07
# 44 (restart 0) KSP residual norm 3.323740e-07
# 45 (restart 0) KSP residual norm 3.308041e-07
# 46 (restart 0) KSP residual norm 3.295098e-07
# 47 (restart 0) KSP residual norm 3.288180e-07
# 48 (restart 0) KSP residual norm 3.281385e-07
# 49 (restart 0) KSP residual norm 3.281185e-07
# 50 (restart 1) KSP residual norm 3.281007e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.812e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 3.867e-01 (norm(b) = 8.485e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.568700e-07
#  1 (restart 0) KSP residual norm 5.742779e-07
#  2 (restart 0) KSP residual norm 4.984038e-07
#  3 (restart 0) KSP residual norm 4.485488e-07
#  4 (restart 0) KSP residual norm 4.241816e-07
#  5 (restart 0) KSP residual norm 3.956135e-07
#  6 (restart 0) KSP residual norm 3.766285e-07
#  7 (restart 0) KSP residual norm 3.596647e-07
#  8 (restart 0) KSP residual norm 3.485675e-07
#  9 (restart 0) KSP residual norm 3.361697e-07
# 10 (restart 0) KSP residual norm 3.266526e-07
# 11 (restart 0) KSP residual norm 3.200461e-07
# 12 (restart 0) KSP residual norm 3.179323e-07
# 13 (restart 0) KSP residual norm 3.179298e-07
# 14 (restart 0) KSP residual norm 3.157240e-07
# 15 (restart 0) KSP residual norm 3.113603e-07
# 16 (restart 0) KSP residual norm 3.064504e-07
# 17 (restart 0) KSP residual norm 3.036556e-07
# 18 (restart 0) KSP residual norm 3.022824e-07
# 19 (restart 0) KSP residual norm 3.022795e-07
# 20 (restart 0) KSP residual norm 3.009720e-07
# 21 (restart 0) KSP residual norm 2.971142e-07
# 22 (restart 0) KSP residual norm 2.930400e-07
# 23 (restart 0) KSP residual norm 2.901822e-07
# 24 (restart 0) KSP residual norm 2.891569e-07
# 25 (restart 0) KSP residual norm 2.888082e-07
# 26 (restart 0) KSP residual norm 2.887356e-07
# 27 (restart 0) KSP residual norm 2.881343e-07
# 28 (restart 0) KSP residual norm 2.864924e-07
# 29 (restart 0) KSP residual norm 2.841806e-07
# 30 (restart 0) KSP residual norm 2.816494e-07
# 31 (restart 0) KSP residual norm 2.797848e-07
# 32 (restart 0) KSP residual norm 2.790134e-07
# 33 (restart 0) KSP residual norm 2.788775e-07
# 34 (restart 0) KSP residual norm 2.788472e-07
# 35 (restart 0) KSP residual norm 2.781953e-07
# 36 (restart 0) KSP residual norm 2.768258e-07
# 37 (restart 0) KSP residual norm 2.747400e-07
# 38 (restart 0) KSP residual norm 2.724759e-07
# 39 (restart 0) KSP residual norm 2.704205e-07
# 40 (restart 0) KSP residual norm 2.692965e-07
# 41 (restart 0) KSP residual norm 2.689686e-07
# 42 (restart 0) KSP residual norm 2.689289e-07
# 43 (restart 0) KSP residual norm 2.688318e-07
# 44 (restart 0) KSP residual norm 2.683670e-07
# 45 (restart 0) KSP residual norm 2.674980e-07
# 46 (restart 0) KSP residual norm 2.666528e-07
# 47 (restart 0) KSP residual norm 2.659783e-07
# 48 (restart 0) KSP residual norm 2.655234e-07
# 49 (restart 0) KSP residual norm 2.654792e-07
# 50 (restart 1) KSP residual norm 2.654710e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.768e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 3.098e-01 (norm(b) = 8.569e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 9.798921e-07
#  1 (restart 0) KSP residual norm 6.205899e-07
#  2 (restart 0) KSP residual norm 5.234225e-07
#  3 (restart 0) KSP residual norm 4.670451e-07
#  4 (restart 0) KSP residual norm 4.409367e-07
#  5 (restart 0) KSP residual norm 4.140150e-07
#  6 (restart 0) KSP residual norm 3.971108e-07
#  7 (restart 0) KSP residual norm 3.767985e-07
#  8 (restart 0) KSP residual norm 3.586400e-07
#  9 (restart 0) KSP residual norm 3.406994e-07
# 10 (restart 0) KSP residual norm 3.308155e-07
# 11 (restart 0) KSP residual norm 3.276090e-07
# 12 (restart 0) KSP residual norm 3.272318e-07
# 13 (restart 0) KSP residual norm 3.212820e-07
# 14 (restart 0) KSP residual norm 3.104645e-07
# 15 (restart 0) KSP residual norm 3.011448e-07
# 16 (restart 0) KSP residual norm 2.947558e-07
# 17 (restart 0) KSP residual norm 2.931354e-07
# 18 (restart 0) KSP residual norm 2.930553e-07
# 19 (restart 0) KSP residual norm 2.902420e-07
# 20 (restart 0) KSP residual norm 2.852125e-07
# 21 (restart 0) KSP residual norm 2.787066e-07
# 22 (restart 0) KSP residual norm 2.735836e-07
# 23 (restart 0) KSP residual norm 2.705106e-07
# 24 (restart 0) KSP residual norm 2.696313e-07
# 25 (restart 0) KSP residual norm 2.696294e-07
# 26 (restart 0) KSP residual norm 2.687229e-07
# 27 (restart 0) KSP residual norm 2.663818e-07
# 28 (restart 0) KSP residual norm 2.624850e-07
# 29 (restart 0) KSP residual norm 2.585281e-07
# 30 (restart 0) KSP residual norm 2.554810e-07
# 31 (restart 0) KSP residual norm 2.535439e-07
# 32 (restart 0) KSP residual norm 2.530170e-07
# 33 (restart 0) KSP residual norm 2.530158e-07
# 34 (restart 0) KSP residual norm 2.527037e-07
# 35 (restart 0) KSP residual norm 2.512775e-07
# 36 (restart 0) KSP residual norm 2.489549e-07
# 37 (restart 0) KSP residual norm 2.456697e-07
# 38 (restart 0) KSP residual norm 2.419976e-07
# 39 (restart 0) KSP residual norm 2.383048e-07
# 40 (restart 0) KSP residual norm 2.360783e-07
# 41 (restart 0) KSP residual norm 2.351289e-07
# 42 (restart 0) KSP residual norm 2.348467e-07
# 43 (restart 0) KSP residual norm 2.348439e-07
# 44 (restart 0) KSP residual norm 2.345962e-07
# 45 (restart 0) KSP residual norm 2.337912e-07
# 46 (restart 0) KSP residual norm 2.324885e-07
# 47 (restart 0) KSP residual norm 2.310841e-07
# 48 (restart 0) KSP residual norm 2.295678e-07
# 49 (restart 0) KSP residual norm 2.285199e-07
# 50 (restart 1) KSP residual norm 2.277874e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.712e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.325e-01 (norm(b) = 9.799e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 9.734583e-07
#  1 (restart 0) KSP residual norm 5.928814e-07
#  2 (restart 0) KSP residual norm 4.973997e-07
#  3 (restart 0) KSP residual norm 4.465560e-07
#  4 (restart 0) KSP residual norm 4.233530e-07
#  5 (restart 0) KSP residual norm 3.993046e-07
#  6 (restart 0) KSP residual norm 3.824248e-07
#  7 (restart 0) KSP residual norm 3.635810e-07
#  8 (restart 0) KSP residual norm 3.476760e-07
#  9 (restart 0) KSP residual norm 3.355317e-07
# 10 (restart 0) KSP residual norm 3.321911e-07
# 11 (restart 0) KSP residual norm 3.321909e-07
# 12 (restart 0) KSP residual norm 3.279754e-07
# 13 (restart 0) KSP residual norm 3.191781e-07
# 14 (restart 0) KSP residual norm 3.092144e-07
# 15 (restart 0) KSP residual norm 3.024074e-07
# 16 (restart 0) KSP residual norm 2.986344e-07
# 17 (restart 0) KSP residual norm 2.981206e-07
# 18 (restart 0) KSP residual norm 2.977287e-07
# 19 (restart 0) KSP residual norm 2.943200e-07
# 20 (restart 0) KSP residual norm 2.898673e-07
# 21 (restart 0) KSP residual norm 2.853732e-07
# 22 (restart 0) KSP residual norm 2.823404e-07
# 23 (restart 0) KSP residual norm 2.803196e-07
# 24 (restart 0) KSP residual norm 2.799101e-07
# 25 (restart 0) KSP residual norm 2.799088e-07
# 26 (restart 0) KSP residual norm 2.791452e-07
# 27 (restart 0) KSP residual norm 2.771819e-07
# 28 (restart 0) KSP residual norm 2.742320e-07
# 29 (restart 0) KSP residual norm 2.713961e-07
# 30 (restart 0) KSP residual norm 2.688474e-07
# 31 (restart 0) KSP residual norm 2.666792e-07
# 32 (restart 0) KSP residual norm 2.657074e-07
# 33 (restart 0) KSP residual norm 2.656302e-07
# 34 (restart 0) KSP residual norm 2.653795e-07
# 35 (restart 0) KSP residual norm 2.638744e-07
# 36 (restart 0) KSP residual norm 2.610036e-07
# 37 (restart 0) KSP residual norm 2.568083e-07
# 38 (restart 0) KSP residual norm 2.522446e-07
# 39 (restart 0) KSP residual norm 2.482891e-07
# 40 (restart 0) KSP residual norm 2.456036e-07
# 41 (restart 0) KSP residual norm 2.442547e-07
# 42 (restart 0) KSP residual norm 2.439041e-07
# 43 (restart 0) KSP residual norm 2.438864e-07
# 44 (restart 0) KSP residual norm 2.433633e-07
# 45 (restart 0) KSP residual norm 2.424170e-07
# 46 (restart 0) KSP residual norm 2.409798e-07
# 47 (restart 0) KSP residual norm 2.393976e-07
# 48 (restart 0) KSP residual norm 2.376982e-07
# 49 (restart 0) KSP residual norm 2.369999e-07
# 50 (restart 1) KSP residual norm 2.368748e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.721e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.433e-01 (norm(b) = 9.735e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.820158e-07
#  1 (restart 0) KSP residual norm 5.477194e-07
#  2 (restart 0) KSP residual norm 4.639682e-07
#  3 (restart 0) KSP residual norm 4.149757e-07
#  4 (restart 0) KSP residual norm 3.929938e-07
#  5 (restart 0) KSP residual norm 3.687146e-07
#  6 (restart 0) KSP residual norm 3.510479e-07
#  7 (restart 0) KSP residual norm 3.328615e-07
#  8 (restart 0) KSP residual norm 3.199819e-07
#  9 (restart 0) KSP residual norm 3.121900e-07
# 10 (restart 0) KSP residual norm 3.114239e-07
# 11 (restart 0) KSP residual norm 3.103261e-07
# 12 (restart 0) KSP residual norm 3.041625e-07
# 13 (restart 0) KSP residual norm 2.973359e-07
# 14 (restart 0) KSP residual norm 2.908826e-07
# 15 (restart 0) KSP residual norm 2.864161e-07
# 16 (restart 0) KSP residual norm 2.834416e-07
# 17 (restart 0) KSP residual norm 2.827843e-07
# 18 (restart 0) KSP residual norm 2.827675e-07
# 19 (restart 0) KSP residual norm 2.811018e-07
# 20 (restart 0) KSP residual norm 2.779739e-07
# 21 (restart 0) KSP residual norm 2.741266e-07
# 22 (restart 0) KSP residual norm 2.713937e-07
# 23 (restart 0) KSP residual norm 2.693708e-07
# 24 (restart 0) KSP residual norm 2.686929e-07
# 25 (restart 0) KSP residual norm 2.685306e-07
# 26 (restart 0) KSP residual norm 2.683478e-07
# 27 (restart 0) KSP residual norm 2.673120e-07
# 28 (restart 0) KSP residual norm 2.649453e-07
# 29 (restart 0) KSP residual norm 2.622330e-07
# 30 (restart 0) KSP residual norm 2.592113e-07
# 31 (restart 0) KSP residual norm 2.570437e-07
# 32 (restart 0) KSP residual norm 2.559387e-07
# 33 (restart 0) KSP residual norm 2.557488e-07
# 34 (restart 0) KSP residual norm 2.556997e-07
# 35 (restart 0) KSP residual norm 2.548207e-07
# 36 (restart 0) KSP residual norm 2.527784e-07
# 37 (restart 0) KSP residual norm 2.492403e-07
# 38 (restart 0) KSP residual norm 2.455014e-07
# 39 (restart 0) KSP residual norm 2.422287e-07
# 40 (restart 0) KSP residual norm 2.399004e-07
# 41 (restart 0) KSP residual norm 2.389030e-07
# 42 (restart 0) KSP residual norm 2.386947e-07
# 43 (restart 0) KSP residual norm 2.386084e-07
# 44 (restart 0) KSP residual norm 2.379480e-07
# 45 (restart 0) KSP residual norm 2.366678e-07
# 46 (restart 0) KSP residual norm 2.351679e-07
# 47 (restart 0) KSP residual norm 2.340344e-07
# 48 (restart 0) KSP residual norm 2.331732e-07
# 49 (restart 0) KSP residual norm 2.329310e-07
# 50 (restart 1) KSP residual norm 2.328984e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.737e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.641e-01 (norm(b) = 8.820e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.539241e-07
#  1 (restart 0) KSP residual norm 5.585388e-07
#  2 (restart 0) KSP residual norm 4.851111e-07
#  3 (restart 0) KSP residual norm 4.282101e-07
#  4 (restart 0) KSP residual norm 3.964324e-07
#  5 (restart 0) KSP residual norm 3.657002e-07
#  6 (restart 0) KSP residual norm 3.472490e-07
#  7 (restart 0) KSP residual norm 3.318744e-07
#  8 (restart 0) KSP residual norm 3.209002e-07
#  9 (restart 0) KSP residual norm 3.130924e-07
# 10 (restart 0) KSP residual norm 3.122799e-07
# 11 (restart 0) KSP residual norm 3.113850e-07
# 12 (restart 0) KSP residual norm 3.051600e-07
# 13 (restart 0) KSP residual norm 2.966333e-07
# 14 (restart 0) KSP residual norm 2.874467e-07
# 15 (restart 0) KSP residual norm 2.794235e-07
# 16 (restart 0) KSP residual norm 2.727945e-07
# 17 (restart 0) KSP residual norm 2.687278e-07
# 18 (restart 0) KSP residual norm 2.674714e-07
# 19 (restart 0) KSP residual norm 2.672361e-07
# 20 (restart 0) KSP residual norm 2.642435e-07
# 21 (restart 0) KSP residual norm 2.585154e-07
# 22 (restart 0) KSP residual norm 2.522461e-07
# 23 (restart 0) KSP residual norm 2.467033e-07
# 24 (restart 0) KSP residual norm 2.430295e-07
# 25 (restart 0) KSP residual norm 2.411440e-07
# 26 (restart 0) KSP residual norm 2.407666e-07
# 27 (restart 0) KSP residual norm 2.407500e-07
# 28 (restart 0) KSP residual norm 2.398274e-07
# 29 (restart 0) KSP residual norm 2.375981e-07
# 30 (restart 0) KSP residual norm 2.344110e-07
# 31 (restart 0) KSP residual norm 2.303226e-07
# 32 (restart 0) KSP residual norm 2.266728e-07
# 33 (restart 0) KSP residual norm 2.246512e-07
# 34 (restart 0) KSP residual norm 2.240197e-07
# 35 (restart 0) KSP residual norm 2.240180e-07
# 36 (restart 0) KSP residual norm 2.234500e-07
# 37 (restart 0) KSP residual norm 2.211894e-07
# 38 (restart 0) KSP residual norm 2.174592e-07
# 39 (restart 0) KSP residual norm 2.134704e-07
# 40 (restart 0) KSP residual norm 2.102704e-07
# 41 (restart 0) KSP residual norm 2.087285e-07
# 42 (restart 0) KSP residual norm 2.082844e-07
# 43 (restart 0) KSP residual norm 2.082828e-07
# 44 (restart 0) KSP residual norm 2.080224e-07
# 45 (restart 0) KSP residual norm 2.070178e-07
# 46 (restart 0) KSP residual norm 2.053903e-07
# 47 (restart 0) KSP residual norm 2.037906e-07
# 48 (restart 0) KSP residual norm 2.025402e-07
# 49 (restart 0) KSP residual norm 2.020962e-07
# 50 (restart 1) KSP residual norm 2.020018e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.716e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.366e-01 (norm(b) = 8.539e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.729590e-07
#  1 (restart 0) KSP residual norm 5.876322e-07
#  2 (restart 0) KSP residual norm 5.237634e-07
#  3 (restart 0) KSP residual norm 4.737403e-07
#  4 (restart 0) KSP residual norm 4.517520e-07
#  5 (restart 0) KSP residual norm 4.275471e-07
#  6 (restart 0) KSP residual norm 4.087920e-07
#  7 (restart 0) KSP residual norm 3.883960e-07
#  8 (restart 0) KSP residual norm 3.735751e-07
#  9 (restart 0) KSP residual norm 3.601881e-07
# 10 (restart 0) KSP residual norm 3.578714e-07
# 11 (restart 0) KSP residual norm 3.574150e-07
# 12 (restart 0) KSP residual norm 3.493547e-07
# 13 (restart 0) KSP residual norm 3.372568e-07
# 14 (restart 0) KSP residual norm 3.228538e-07
# 15 (restart 0) KSP residual norm 3.107852e-07
# 16 (restart 0) KSP residual norm 3.003464e-07
# 17 (restart 0) KSP residual norm 2.931126e-07
# 18 (restart 0) KSP residual norm 2.863649e-07
# 19 (restart 0) KSP residual norm 2.822596e-07
# 20 (restart 0) KSP residual norm 2.810916e-07
# 21 (restart 0) KSP residual norm 2.810465e-07
# 22 (restart 0) KSP residual norm 2.792400e-07
# 23 (restart 0) KSP residual norm 2.753747e-07
# 24 (restart 0) KSP residual norm 2.719853e-07
# 25 (restart 0) KSP residual norm 2.693877e-07
# 26 (restart 0) KSP residual norm 2.682013e-07
# 27 (restart 0) KSP residual norm 2.679406e-07
# 28 (restart 0) KSP residual norm 2.677247e-07
# 29 (restart 0) KSP residual norm 2.667500e-07
# 30 (restart 0) KSP residual norm 2.647075e-07
# 31 (restart 0) KSP residual norm 2.612442e-07
# 32 (restart 0) KSP residual norm 2.577338e-07
# 33 (restart 0) KSP residual norm 2.556391e-07
# 34 (restart 0) KSP residual norm 2.546460e-07
# 35 (restart 0) KSP residual norm 2.545131e-07
# 36 (restart 0) KSP residual norm 2.544770e-07
# 37 (restart 0) KSP residual norm 2.538548e-07
# 38 (restart 0) KSP residual norm 2.520553e-07
# 39 (restart 0) KSP residual norm 2.494967e-07
# 40 (restart 0) KSP residual norm 2.473167e-07
# 41 (restart 0) KSP residual norm 2.462090e-07
# 42 (restart 0) KSP residual norm 2.458253e-07
# 43 (restart 0) KSP residual norm 2.458197e-07
# 44 (restart 0) KSP residual norm 2.455504e-07
# 45 (restart 0) KSP residual norm 2.445722e-07
# 46 (restart 0) KSP residual norm 2.428991e-07
# 47 (restart 0) KSP residual norm 2.405930e-07
# 48 (restart 0) KSP residual norm 2.377878e-07
# 49 (restart 0) KSP residual norm 2.357290e-07
# 50 (restart 1) KSP residual norm 2.342063e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.740e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.683e-01 (norm(b) = 8.730e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.652802e-07
#  1 (restart 0) KSP residual norm 5.735851e-07
#  2 (restart 0) KSP residual norm 5.028001e-07
#  3 (restart 0) KSP residual norm 4.449541e-07
#  4 (restart 0) KSP residual norm 4.168706e-07
#  5 (restart 0) KSP residual norm 3.859055e-07
#  6 (restart 0) KSP residual norm 3.653703e-07
#  7 (restart 0) KSP residual norm 3.463545e-07
#  8 (restart 0) KSP residual norm 3.338783e-07
#  9 (restart 0) KSP residual norm 3.248728e-07
# 10 (restart 0) KSP residual norm 3.233131e-07
# 11 (restart 0) KSP residual norm 3.225085e-07
# 12 (restart 0) KSP residual norm 3.152587e-07
# 13 (restart 0) KSP residual norm 3.052351e-07
# 14 (restart 0) KSP residual norm 2.951637e-07
# 15 (restart 0) KSP residual norm 2.867951e-07
# 16 (restart 0) KSP residual norm 2.795736e-07
# 17 (restart 0) KSP residual norm 2.747479e-07
# 18 (restart 0) KSP residual norm 2.706950e-07
# 19 (restart 0) KSP residual norm 2.682936e-07
# 20 (restart 0) KSP residual norm 2.679416e-07
# 21 (restart 0) KSP residual norm 2.675754e-07
# 22 (restart 0) KSP residual norm 2.656653e-07
# 23 (restart 0) KSP residual norm 2.631532e-07
# 24 (restart 0) KSP residual norm 2.620554e-07
# 25 (restart 0) KSP residual norm 2.616915e-07
# 26 (restart 0) KSP residual norm 2.616829e-07
# 27 (restart 0) KSP residual norm 2.614189e-07
# 28 (restart 0) KSP residual norm 2.604074e-07
# 29 (restart 0) KSP residual norm 2.584230e-07
# 30 (restart 0) KSP residual norm 2.554100e-07
# 31 (restart 0) KSP residual norm 2.525754e-07
# 32 (restart 0) KSP residual norm 2.508865e-07
# 33 (restart 0) KSP residual norm 2.501493e-07
# 34 (restart 0) KSP residual norm 2.501084e-07
# 35 (restart 0) KSP residual norm 2.497964e-07
# 36 (restart 0) KSP residual norm 2.486020e-07
# 37 (restart 0) KSP residual norm 2.461591e-07
# 38 (restart 0) KSP residual norm 2.433417e-07
# 39 (restart 0) KSP residual norm 2.409873e-07
# 40 (restart 0) KSP residual norm 2.396725e-07
# 41 (restart 0) KSP residual norm 2.392106e-07
# 42 (restart 0) KSP residual norm 2.391740e-07
# 43 (restart 0) KSP residual norm 2.389642e-07
# 44 (restart 0) KSP residual norm 2.383139e-07
# 45 (restart 0) KSP residual norm 2.372833e-07
# 46 (restart 0) KSP residual norm 2.362755e-07
# 47 (restart 0) KSP residual norm 2.353758e-07
# 48 (restart 0) KSP residual norm 2.346278e-07
# 49 (restart 0) KSP residual norm 2.344782e-07
# 50 (restart 1) KSP residual norm 2.344679e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.742e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.710e-01 (norm(b) = 8.653e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.692515e-07
#  1 (restart 0) KSP residual norm 5.648605e-07
#  2 (restart 0) KSP residual norm 4.919139e-07
#  3 (restart 0) KSP residual norm 4.445675e-07
#  4 (restart 0) KSP residual norm 4.229544e-07
#  5 (restart 0) KSP residual norm 3.944774e-07
#  6 (restart 0) KSP residual norm 3.757971e-07
#  7 (restart 0) KSP residual norm 3.599598e-07
#  8 (restart 0) KSP residual norm 3.492115e-07
#  9 (restart 0) KSP residual norm 3.386594e-07
# 10 (restart 0) KSP residual norm 3.346695e-07
# 11 (restart 0) KSP residual norm 3.346074e-07
# 12 (restart 0) KSP residual norm 3.309083e-07
# 13 (restart 0) KSP residual norm 3.231828e-07
# 14 (restart 0) KSP residual norm 3.141388e-07
# 15 (restart 0) KSP residual norm 3.073936e-07
# 16 (restart 0) KSP residual norm 3.017690e-07
# 17 (restart 0) KSP residual norm 2.980735e-07
# 18 (restart 0) KSP residual norm 2.958832e-07
# 19 (restart 0) KSP residual norm 2.958313e-07
# 20 (restart 0) KSP residual norm 2.945818e-07
# 21 (restart 0) KSP residual norm 2.906022e-07
# 22 (restart 0) KSP residual norm 2.859016e-07
# 23 (restart 0) KSP residual norm 2.822925e-07
# 24 (restart 0) KSP residual norm 2.807982e-07
# 25 (restart 0) KSP residual norm 2.806151e-07
# 26 (restart 0) KSP residual norm 2.803640e-07
# 27 (restart 0) KSP residual norm 2.792493e-07
# 28 (restart 0) KSP residual norm 2.763320e-07
# 29 (restart 0) KSP residual norm 2.726624e-07
# 30 (restart 0) KSP residual norm 2.689900e-07
# 31 (restart 0) KSP residual norm 2.663334e-07
# 32 (restart 0) KSP residual norm 2.653377e-07
# 33 (restart 0) KSP residual norm 2.652752e-07
# 34 (restart 0) KSP residual norm 2.651767e-07
# 35 (restart 0) KSP residual norm 2.642638e-07
# 36 (restart 0) KSP residual norm 2.622426e-07
# 37 (restart 0) KSP residual norm 2.595674e-07
# 38 (restart 0) KSP residual norm 2.563200e-07
# 39 (restart 0) KSP residual norm 2.532075e-07
# 40 (restart 0) KSP residual norm 2.513378e-07
# 41 (restart 0) KSP residual norm 2.505829e-07
# 42 (restart 0) KSP residual norm 2.504799e-07
# 43 (restart 0) KSP residual norm 2.504194e-07
# 44 (restart 0) KSP residual norm 2.499682e-07
# 45 (restart 0) KSP residual norm 2.489226e-07
# 46 (restart 0) KSP residual norm 2.478496e-07
# 47 (restart 0) KSP residual norm 2.469827e-07
# 48 (restart 0) KSP residual norm 2.464066e-07
# 49 (restart 0) KSP residual norm 2.461587e-07
# 50 (restart 1) KSP residual norm 2.460952e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.751e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.831e-01 (norm(b) = 8.693e-07)!
#
#   1 EPS nconv=0 first unconverged value (error) 0.00238663+5.88474e-07i (9.73419103e-05)
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.921513e-07
#  1 (restart 0) KSP residual norm 5.659166e-07
#  2 (restart 0) KSP residual norm 4.811901e-07
#  3 (restart 0) KSP residual norm 4.344957e-07
#  4 (restart 0) KSP residual norm 4.160992e-07
#  5 (restart 0) KSP residual norm 3.935405e-07
#  6 (restart 0) KSP residual norm 3.779713e-07
#  7 (restart 0) KSP residual norm 3.608957e-07
#  8 (restart 0) KSP residual norm 3.457827e-07
#  9 (restart 0) KSP residual norm 3.314979e-07
# 10 (restart 0) KSP residual norm 3.240183e-07
# 11 (restart 0) KSP residual norm 3.213850e-07
# 12 (restart 0) KSP residual norm 3.211340e-07
# 13 (restart 0) KSP residual norm 3.169005e-07
# 14 (restart 0) KSP residual norm 3.076245e-07
# 15 (restart 0) KSP residual norm 2.994946e-07
# 16 (restart 0) KSP residual norm 2.937066e-07
# 17 (restart 0) KSP residual norm 2.913639e-07
# 18 (restart 0) KSP residual norm 2.911664e-07
# 19 (restart 0) KSP residual norm 2.905009e-07
# 20 (restart 0) KSP residual norm 2.877511e-07
# 21 (restart 0) KSP residual norm 2.840042e-07
# 22 (restart 0) KSP residual norm 2.808549e-07
# 23 (restart 0) KSP residual norm 2.787658e-07
# 24 (restart 0) KSP residual norm 2.779287e-07
# 25 (restart 0) KSP residual norm 2.779278e-07
# 26 (restart 0) KSP residual norm 2.770524e-07
# 27 (restart 0) KSP residual norm 2.750469e-07
# 28 (restart 0) KSP residual norm 2.722622e-07
# 29 (restart 0) KSP residual norm 2.696141e-07
# 30 (restart 0) KSP residual norm 2.671932e-07
# 31 (restart 0) KSP residual norm 2.658495e-07
# 32 (restart 0) KSP residual norm 2.655280e-07
# 33 (restart 0) KSP residual norm 2.655241e-07
# 34 (restart 0) KSP residual norm 2.652988e-07
# 35 (restart 0) KSP residual norm 2.643141e-07
# 36 (restart 0) KSP residual norm 2.627110e-07
# 37 (restart 0) KSP residual norm 2.605192e-07
# 38 (restart 0) KSP residual norm 2.580861e-07
# 39 (restart 0) KSP residual norm 2.555334e-07
# 40 (restart 0) KSP residual norm 2.541063e-07
# 41 (restart 0) KSP residual norm 2.532558e-07
# 42 (restart 0) KSP residual norm 2.528532e-07
# 43 (restart 0) KSP residual norm 2.528382e-07
# 44 (restart 0) KSP residual norm 2.527553e-07
# 45 (restart 0) KSP residual norm 2.522047e-07
# 46 (restart 0) KSP residual norm 2.512186e-07
# 47 (restart 0) KSP residual norm 2.499047e-07
# 48 (restart 0) KSP residual norm 2.486781e-07
# 49 (restart 0) KSP residual norm 2.482232e-07
# 50 (restart 1) KSP residual norm 2.481565e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.747e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.782e-01 (norm(b) = 8.922e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 9.844067e-07
#  1 (restart 0) KSP residual norm 5.695442e-07
#  2 (restart 0) KSP residual norm 4.654153e-07
#  3 (restart 0) KSP residual norm 4.159463e-07
#  4 (restart 0) KSP residual norm 3.958245e-07
#  5 (restart 0) KSP residual norm 3.742520e-07
#  6 (restart 0) KSP residual norm 3.596532e-07
#  7 (restart 0) KSP residual norm 3.440678e-07
#  8 (restart 0) KSP residual norm 3.312508e-07
#  9 (restart 0) KSP residual norm 3.201855e-07
# 10 (restart 0) KSP residual norm 3.163163e-07
# 11 (restart 0) KSP residual norm 3.161313e-07
# 12 (restart 0) KSP residual norm 3.139850e-07
# 13 (restart 0) KSP residual norm 3.085796e-07
# 14 (restart 0) KSP residual norm 3.017773e-07
# 15 (restart 0) KSP residual norm 2.963607e-07
# 16 (restart 0) KSP residual norm 2.926061e-07
# 17 (restart 0) KSP residual norm 2.916006e-07
# 18 (restart 0) KSP residual norm 2.915941e-07
# 19 (restart 0) KSP residual norm 2.901224e-07
# ...
# 13 (restart 0) KSP residual norm 2.815999e-07
# 14 (restart 0) KSP residual norm 2.755187e-07
# 15 (restart 0) KSP residual norm 2.695785e-07
# 16 (restart 0) KSP residual norm 2.640493e-07
# 17 (restart 0) KSP residual norm 2.595757e-07
# 18 (restart 0) KSP residual norm 2.557536e-07
# 19 (restart 0) KSP residual norm 2.539155e-07
# 20 (restart 0) KSP residual norm 2.537385e-07
# 21 (restart 0) KSP residual norm 2.532599e-07
# 22 (restart 0) KSP residual norm 2.512721e-07
# 23 (restart 0) KSP residual norm 2.477816e-07
# 24 (restart 0) KSP residual norm 2.445178e-07
# 25 (restart 0) KSP residual norm 2.412638e-07
# 26 (restart 0) KSP residual norm 2.392657e-07
# 27 (restart 0) KSP residual norm 2.384502e-07
# 28 (restart 0) KSP residual norm 2.384119e-07
# 29 (restart 0) KSP residual norm 2.382864e-07
# 30 (restart 0) KSP residual norm 2.374870e-07
# 31 (restart 0) KSP residual norm 2.360176e-07
# 32 (restart 0) KSP residual norm 2.341604e-07
# 33 (restart 0) KSP residual norm 2.323447e-07
# 34 (restart 0) KSP residual norm 2.311777e-07
# 35 (restart 0) KSP residual norm 2.307385e-07
# 36 (restart 0) KSP residual norm 2.307357e-07
# 37 (restart 0) KSP residual norm 2.302450e-07
# 38 (restart 0) KSP residual norm 2.291052e-07
# 39 (restart 0) KSP residual norm 2.271168e-07
# 40 (restart 0) KSP residual norm 2.251371e-07
# 41 (restart 0) KSP residual norm 2.237802e-07
# 42 (restart 0) KSP residual norm 2.230809e-07
# 43 (restart 0) KSP residual norm 2.229105e-07
# 44 (restart 0) KSP residual norm 2.229085e-07
# 45 (restart 0) KSP residual norm 2.227246e-07
# 46 (restart 0) KSP residual norm 2.220134e-07
# 47 (restart 0) KSP residual norm 2.210115e-07
# 48 (restart 0) KSP residual norm 2.197580e-07
# 49 (restart 0) KSP residual norm 2.188020e-07
# 50 (restart 1) KSP residual norm 2.181550e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.779e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 3.276e-01 (norm(b) = 6.658e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 8.174836e-07
#  1 (restart 0) KSP residual norm 5.733403e-07
#  2 (restart 0) KSP residual norm 5.072255e-07
#  3 (restart 0) KSP residual norm 4.590043e-07
#  4 (restart 0) KSP residual norm 4.343774e-07
#  5 (restart 0) KSP residual norm 4.033299e-07
#  6 (restart 0) KSP residual norm 3.798867e-07
#  7 (restart 0) KSP residual norm 3.581010e-07
#  8 (restart 0) KSP residual norm 3.420548e-07
#  9 (restart 0) KSP residual norm 3.297497e-07
# 10 (restart 0) KSP residual norm 3.232127e-07
# 11 (restart 0) KSP residual norm 3.177458e-07
# 12 (restart 0) KSP residual norm 3.155120e-07
# 13 (restart 0) KSP residual norm 3.152812e-07
# 14 (restart 0) KSP residual norm 3.141550e-07
# 15 (restart 0) KSP residual norm 3.111691e-07
# 16 (restart 0) KSP residual norm 3.074499e-07
# 17 (restart 0) KSP residual norm 3.049087e-07
# 18 (restart 0) KSP residual norm 3.027474e-07
# 19 (restart 0) KSP residual norm 3.022538e-07
# 20 (restart 0) KSP residual norm 3.021735e-07
# 21 (restart 0) KSP residual norm 3.008724e-07
# 22 (restart 0) KSP residual norm 2.987181e-07
# 23 (restart 0) KSP residual norm 2.961500e-07
# 24 (restart 0) KSP residual norm 2.939952e-07
# 25 (restart 0) KSP residual norm 2.926615e-07
# 26 (restart 0) KSP residual norm 2.925311e-07
# 27 (restart 0) KSP residual norm 2.924582e-07
# 28 (restart 0) KSP residual norm 2.915561e-07
# 29 (restart 0) KSP residual norm 2.902725e-07
# 30 (restart 0) KSP residual norm 2.880799e-07
# 31 (restart 0) KSP residual norm 2.854146e-07
# 32 (restart 0) KSP residual norm 2.837683e-07
# 33 (restart 0) KSP residual norm 2.833567e-07
# 34 (restart 0) KSP residual norm 2.833483e-07
# 35 (restart 0) KSP residual norm 2.832033e-07
# 36 (restart 0) KSP residual norm 2.826259e-07
# 37 (restart 0) KSP residual norm 2.809345e-07
# 38 (restart 0) KSP residual norm 2.785196e-07
# 39 (restart 0) KSP residual norm 2.758311e-07
# 40 (restart 0) KSP residual norm 2.738599e-07
# 41 (restart 0) KSP residual norm 2.732113e-07
# 42 (restart 0) KSP residual norm 2.731422e-07
# 43 (restart 0) KSP residual norm 2.728913e-07
# 44 (restart 0) KSP residual norm 2.720245e-07
# 45 (restart 0) KSP residual norm 2.707372e-07
# 46 (restart 0) KSP residual norm 2.693584e-07
# 47 (restart 0) KSP residual norm 2.685300e-07
# 48 (restart 0) KSP residual norm 2.678072e-07
# 49 (restart 0) KSP residual norm 2.676738e-07
# 50 (restart 1) KSP residual norm 2.676720e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.779e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 3.274e-01 (norm(b) = 8.175e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 9.205115e-07
#  1 (restart 0) KSP residual norm 6.211563e-07
#  2 (restart 0) KSP residual norm 5.389288e-07
#  3 (restart 0) KSP residual norm 4.812033e-07
#  4 (restart 0) KSP residual norm 4.480847e-07
#  5 (restart 0) KSP residual norm 4.139109e-07
#  6 (restart 0) KSP residual norm 3.915030e-07
#  7 (restart 0) KSP residual norm 3.690902e-07
#  8 (restart 0) KSP residual norm 3.513655e-07
#  9 (restart 0) KSP residual norm 3.377377e-07
# 10 (restart 0) KSP residual norm 3.290408e-07
# 11 (restart 0) KSP residual norm 3.205434e-07
# 12 (restart 0) KSP residual norm 3.154109e-07
# 13 (restart 0) KSP residual norm 3.142366e-07
# 14 (restart 0) KSP residual norm 3.136241e-07
# 15 (restart 0) KSP residual norm 3.097458e-07
# 16 (restart 0) KSP residual norm 3.038221e-07
# 17 (restart 0) KSP residual norm 2.984780e-07
# 18 (restart 0) KSP residual norm 2.949327e-07
# 19 (restart 0) KSP residual norm 2.943079e-07
# 20 (restart 0) KSP residual norm 2.939883e-07
# 21 (restart 0) KSP residual norm 2.914183e-07
# 22 (restart 0) KSP residual norm 2.877654e-07
# 23 (restart 0) KSP residual norm 2.846435e-07
# 24 (restart 0) KSP residual norm 2.832054e-07
# 25 (restart 0) KSP residual norm 2.831750e-07
# 26 (restart 0) KSP residual norm 2.823822e-07
# 27 (restart 0) KSP residual norm 2.802246e-07
# 28 (restart 0) KSP residual norm 2.772058e-07
# 29 (restart 0) KSP residual norm 2.743622e-07
# 30 (restart 0) KSP residual norm 2.717042e-07
# 31 (restart 0) KSP residual norm 2.697346e-07
# 32 (restart 0) KSP residual norm 2.691667e-07
# 33 (restart 0) KSP residual norm 2.691647e-07
# 34 (restart 0) KSP residual norm 2.689142e-07
# 35 (restart 0) KSP residual norm 2.677809e-07
# 36 (restart 0) KSP residual norm 2.658474e-07
# 37 (restart 0) KSP residual norm 2.630155e-07
# 38 (restart 0) KSP residual norm 2.601653e-07
# 39 (restart 0) KSP residual norm 2.579573e-07
# 40 (restart 0) KSP residual norm 2.567931e-07
# 41 (restart 0) KSP residual norm 2.565845e-07
# 42 (restart 0) KSP residual norm 2.565837e-07
# 43 (restart 0) KSP residual norm 2.561759e-07
# 44 (restart 0) KSP residual norm 2.549972e-07
# 45 (restart 0) KSP residual norm 2.537000e-07
# 46 (restart 0) KSP residual norm 2.526175e-07
# 47 (restart 0) KSP residual norm 2.521012e-07
# 48 (restart 0) KSP residual norm 2.518980e-07
# 49 (restart 0) KSP residual norm 2.518943e-07
# 50 (restart 1) KSP residual norm 2.518080e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.744e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.736e-01 (norm(b) = 9.205e-07)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.054071e-06
#  1 (restart 0) KSP residual norm 5.846432e-07
#  2 (restart 0) KSP residual norm 4.695335e-07
#  3 (restart 0) KSP residual norm 4.123338e-07
#  4 (restart 0) KSP residual norm 3.840999e-07
#  5 (restart 0) KSP residual norm 3.577179e-07
#  6 (restart 0) KSP residual norm 3.402493e-07
#  7 (restart 0) KSP residual norm 3.208978e-07
#  8 (restart 0) KSP residual norm 3.025921e-07
#  9 (restart 0) KSP residual norm 2.832334e-07
# 10 (restart 0) KSP residual norm 2.705287e-07
# 11 (restart 0) KSP residual norm 2.639604e-07
# 12 (restart 0) KSP residual norm 2.631127e-07
# 13 (restart 0) KSP residual norm 2.617810e-07
# 14 (restart 0) KSP residual norm 2.546963e-07
# 15 (restart 0) KSP residual norm 2.462468e-07
# 16 (restart 0) KSP residual norm 2.403430e-07
# 17 (restart 0) KSP residual norm 2.384343e-07
# 18 (restart 0) KSP residual norm 2.384337e-07
# 19 (restart 0) KSP residual norm 2.367011e-07
# 20 (restart 0) KSP residual norm 2.334239e-07
# 21 (restart 0) KSP residual norm 2.305042e-07
# 22 (restart 0) KSP residual norm 2.290767e-07
# 23 (restart 0) KSP residual norm 2.288055e-07
# 24 (restart 0) KSP residual norm 2.286210e-07
# 25 (restart 0) KSP residual norm 2.271976e-07
# 26 (restart 0) KSP residual norm 2.236274e-07
# 27 (restart 0) KSP residual norm 2.197703e-07
# 28 (restart 0) KSP residual norm 2.162864e-07
# 29 (restart 0) KSP residual norm 2.139461e-07
# 30 (restart 0) KSP residual norm 2.128951e-07
# 31 (restart 0) KSP residual norm 2.127044e-07
# 32 (restart 0) KSP residual norm 2.126430e-07
# 33 (restart 0) KSP residual norm 2.118536e-07
# 34 (restart 0) KSP residual norm 2.101591e-07
# 35 (restart 0) KSP residual norm 2.073045e-07
# 36 (restart 0) KSP residual norm 2.042840e-07
# 37 (restart 0) KSP residual norm 2.012544e-07
# 38 (restart 0) KSP residual norm 1.985028e-07
# 39 (restart 0) KSP residual norm 1.966486e-07
# 40 (restart 0) KSP residual norm 1.958374e-07
# 41 (restart 0) KSP residual norm 1.957664e-07
# 42 (restart 0) KSP residual norm 1.956760e-07
# 43 (restart 0) KSP residual norm 1.947313e-07
# 44 (restart 0) KSP residual norm 1.931259e-07
# 45 (restart 0) KSP residual norm 1.912741e-07
# 46 (restart 0) KSP residual norm 1.897550e-07
# 47 (restart 0) KSP residual norm 1.889483e-07
# 48 (restart 0) KSP residual norm 1.886728e-07
# 49 (restart 0) KSP residual norm 1.886664e-07
# 50 (restart 1) KSP residual norm 1.883919e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.661e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.787e-01 (norm(b) = 1.054e-06)!
#
#  Residual norms for GMRES solve
#  0 (restart 0) KSP residual norm 1.108654e-06
#  1 (restart 0) KSP residual norm 7.007801e-07
#  2 (restart 0) KSP residual norm 6.030582e-07
#  3 (restart 0) KSP residual norm 5.387299e-07
#  4 (restart 0) KSP residual norm 5.056452e-07
#  5 (restart 0) KSP residual norm 4.701114e-07
#  6 (restart 0) KSP residual norm 4.451087e-07
#  7 (restart 0) KSP residual norm 4.160576e-07
#  8 (restart 0) KSP residual norm 3.890678e-07
#  9 (restart 0) KSP residual norm 3.631853e-07
# 10 (restart 0) KSP residual norm 3.474092e-07
# 11 (restart 0) KSP residual norm 3.385464e-07
# 12 (restart 0) KSP residual norm 3.367412e-07
# 13 (restart 0) KSP residual norm 3.358574e-07
# 14 (restart 0) KSP residual norm 3.290167e-07
# 15 (restart 0) KSP residual norm 3.187292e-07
# 16 (restart 0) KSP residual norm 3.101368e-07
# 17 (restart 0) KSP residual norm 3.055791e-07
# 18 (restart 0) KSP residual norm 3.042971e-07
# 19 (restart 0) KSP residual norm 3.038417e-07
# 20 (restart 0) KSP residual norm 2.999843e-07
# 21 (restart 0) KSP residual norm 2.929118e-07
# 22 (restart 0) KSP residual norm 2.873046e-07
# 23 (restart 0) KSP residual norm 2.845902e-07
# 24 (restart 0) KSP residual norm 2.841610e-07
# 25 (restart 0) KSP residual norm 2.840679e-07
# 26 (restart 0) KSP residual norm 2.824275e-07
# 27 (restart 0) KSP residual norm 2.790820e-07
# 28 (restart 0) KSP residual norm 2.741726e-07
# 29 (restart 0) KSP residual norm 2.693968e-07
# 30 (restart 0) KSP residual norm 2.662638e-07
# 31 (restart 0) KSP residual norm 2.642740e-07
# 32 (restart 0) KSP residual norm 2.639130e-07
# 33 (restart 0) KSP residual norm 2.638314e-07
# 34 (restart 0) KSP residual norm 2.627733e-07
# 35 (restart 0) KSP residual norm 2.597005e-07
# 36 (restart 0) KSP residual norm 2.558263e-07
# 37 (restart 0) KSP residual norm 2.507980e-07
# 38 (restart 0) KSP residual norm 2.453968e-07
# 39 (restart 0) KSP residual norm 2.421375e-07
# 40 (restart 0) KSP residual norm 2.406023e-07
# 41 (restart 0) KSP residual norm 2.403614e-07
# 42 (restart 0) KSP residual norm 2.403333e-07
# 43 (restart 0) KSP residual norm 2.395223e-07
# 44 (restart 0) KSP residual norm 2.374910e-07
# 45 (restart 0) KSP residual norm 2.348603e-07
# 46 (restart 0) KSP residual norm 2.327877e-07
# 47 (restart 0) KSP residual norm 2.318120e-07
# 48 (restart 0) KSP residual norm 2.314096e-07
# 49 (restart 0) KSP residual norm 2.314051e-07
# 50 (restart 1) KSP residual norm 2.310524e-07
# GMRES solver did NOT converge in 50 iterations (avg. reduction factor: 9.691e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.084e-01 (norm(b) = 1.109e-06)!
#
#   2 EPS nconv=1 first unconverged value (error) 0.00260463+1.21224e-06i (1.04697638e-05)
#
#  Linear eigensolve converged (1 eigenpair) due to CONVERGED_TOL; iterations 2
#  Total number of linear systems solved: 24
#  Total number of linear solver iterations: 1200
#  Found 1 converged eigenvalue (first = 9.607e+00+2.372e-03i)
#
# Computing solution error estimates and performing postprocessing
#
#      m,        Re{f} (GHz),        Im{f} (GHz),                  Q,      Error (Bkwd.),       Error (Abs.)
#      1,      +1.056328e+01,      +1.304374e-03,      +4.049176e+03,      +1.895840e-07,      +9.651077e-01
#
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 8.591e-01, global unknowns = 478711
#  Max. iterations = 0, tol. = 1.000e-02
#
# Estimated peak per-rank memory usage is: Min. 3.3G, Max. 3.3G, Avg. 3.3G, Total 3.3G
# Estimated peak per-node memory usage is: Min. 3.3G, Max. 3.3G, Avg. 3.3G, Total 3.3G
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   3.568       3.568       3.568
#   Mesh Preprocessing            30.107      30.107      30.107
# Operator Construction           25.059      25.059      25.059
# Linear Solve                  1431.055    1431.055    1431.055
#   Setup                         13.397      13.397      13.397
#   Preconditioner               755.691     755.691     755.691
# Eigenvalue Solve                16.461      16.461      16.461
# Div.-Free Projection           517.152     517.152     517.152
# Estimation                       2.076       2.076       2.076
#   Construction                  76.535      76.535      76.535
#   Solve                        317.630     317.630     317.630
# Postprocessing                   4.203       4.203       4.203
# Disk IO                          6.015       6.015       6.015
# --------------------------------------------------------------
# Total                         3199.265    3199.265    3199.265
#
# Peak Memory                   Per-Node       Total   Total HWM
# ==============================================================
# Initialization                    1.5M        1.5M        1.5M
#   Mesh Preprocessing            200.0M      200.0M      201.5M
# Operator Construction           532.7M      532.7M      734.2M
# Linear Solve                     16.9M       16.9M      751.0M
#   Setup                         943.8M      943.8M        1.7G
#   Preconditioner                388.8M      388.8M        2.0G
# Eigenvalue Solve                  2.2M        2.2M        2.0G
# Div.-Free Projection            188.4M      188.4M        2.2G
# Estimation                      312.3M      312.3M        2.5G
#   Construction                    0.0K        0.0K        2.5G
#   Solve                         315.0M      315.0M        2.8G
# Postprocessing                  296.6M      296.6M        3.1G
# Disk IO                         110.9M      110.9M        3.2G
# --------------------------------------------------------------
# Total                             3.2G        3.2G        3.2G
#
#
#
# ================================================================================
# PALACE STDERR
# ================================================================================
#
#
# ================================================================================
# RETURN CODE
# 0
# ================================================================================
#
# ================================================================================
# SUCCESS
# ================================================================================
#
# Palace successfully:
#   ✓ Read the Gmsh mesh
#   ✓ Constructed the MFEM mesh
#   ✓ Applied the PEC boundary
#   ✓ Completed the 1-mode eigenmode test
#
# Output:
# /content/palace_ultra_reduced_output

# %%
import psutil

ram = psutil.virtual_memory()

print(f"Total RAM     : {ram.total / 1024**3:.2f} GB")
print(f"Available RAM : {ram.available / 1024**3:.2f} GB")
print(f"Used RAM      : {ram.used / 1024**3:.2f} GB")
# Out:
# Total RAM     : 12.67 GB
# Available RAM : 11.18 GB
# Used RAM      : 1.18 GB

# %%
import shutil
import os

# ==========================================
# STEP 20: Permanent Google Drive Archival (Directory)
# ==========================================
source_dir = "/content/palace_ultra_reduced_output"
destination_dir = "/content/drive/MyDrive/Palace6/palace_ultra_reduced_output"

print(f"Beginning permanent archival directory to Google Drive: {destination_dir}\n")

if os.path.exists(source_dir):
    # dirs_exist_ok=True prevents errors if the folder already exists in Drive
    shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)
    print(f"[SAVED] Directory successfully archived to {destination_dir}")
else:
    print(f"[SKIPPED] Directory not found locally: {source_dir}")
# Out:
# Beginning permanent archival directory to Google Drive: /content/drive/MyDrive/Palace6/palace_ultra_reduced_output
#
# [SAVED] Directory successfully archived to /content/drive/MyDrive/Palace6/palace_ultra_reduced_output

# %%
# ============================================================
# COMPLETE 4-QUBIT PALACE EIGENMODE RUN
#
# Current geometry:
#   - 4 concentric transmons
#   - 8 JJ locations geometrically present
#   - 4 qubit-qubit couplers
#   - 4 readout resonators/feedlines
#   - 4 readout finger capacitors
#   - 4 XY drive lines
#   - 4 flux-bias lines
#   - ground plane
#   - silicon substrate
#   - vacuum
#
# IMPORTANT:
#   JJs are currently PEC geometry only.
#   Josephson inductance is NOT included yet.
#
# Purpose:
#   Obtain the first 10 electromagnetic eigenmodes
#   of the complete chip geometry.
# ============================================================

import os
import json
import subprocess
import shutil
import psutil
import time


# ============================================================
# PATHS
# ============================================================

PALACE_DIR = (
    "/content/drive/MyDrive/Palace6/build"
)

PALACE_BIN = os.path.join(
    PALACE_DIR,
    "bin",
    "palace-x86_64.bin"
)

LIB_DIR = os.path.join(
    PALACE_DIR,
    "lib"
)

MESH = (
    "/content/drive/MyDrive/Palace6/"
    "meshes/quantum_chip_mesh_ultra_reduced.msh"
)


CONFIG = (
     "/content/drive/MyDrive/Palace6/mode10/palace_complete_4qubit.json"
)

OUTPUT = (
     "/content/drive/MyDrive/Palace6/mode10/palace_complete_4qubit_output"
)


# ============================================================
# SIMULATION PARAMETERS
# ============================================================

NUMBER_OF_MODES = 10

TARGET_GHZ = 5.0

FEM_ORDER = 1

LINEAR_TOL = 1.0e-8

LINEAR_MAX_ITS = 300

EIGEN_TOL = 1.0e-6

EIGEN_MAX_ITS = 200


# ============================================================
# HEADER
# ============================================================

print("=" * 80)
print("COMPLETE 4-QUBIT PALACE EIGENMODE RUN")
print("=" * 80)


# ============================================================
# RAM CHECK
# ============================================================

ram = psutil.virtual_memory()

print("\nCurrent Colab RAM:")

print(
    f"  Total     : "
    f"{ram.total / 1024**3:.2f} GB"
)

print(
    f"  Available : "
    f"{ram.available / 1024**3:.2f} GB"
)

print(
    f"  Used      : "
    f"{ram.used / 1024**3:.2f} GB"
)


# ============================================================
# FILE CHECKS
# ============================================================

print("\nChecking files...")


if not os.path.isfile(MESH):

    raise FileNotFoundError(
        f"\nMesh not found:\n{MESH}"
    )


if not os.path.isfile(PALACE_BIN):

    raise FileNotFoundError(
        f"\nPalace executable not found:\n{PALACE_BIN}"
    )


mesh_size_mb = (
    os.path.getsize(MESH)
    / (1024 ** 2)
)


print(
    f"Mesh size: "
    f"{mesh_size_mb:.2f} MB"
)

print(
    "Mesh elements: ~414,344"
)

print(
    "Mesh nodes: ~58,471"
)


# ============================================================
# CLEAN OUTPUT
# ============================================================

if os.path.exists(OUTPUT):

    print(
        "\nRemoving previous output directory..."
    )

    shutil.rmtree(
        OUTPUT
    )


os.makedirs(
    OUTPUT,
    exist_ok=True
)


# ============================================================
# ENVIRONMENT
# ============================================================

env = os.environ.copy()

env["LD_LIBRARY_PATH"] = (
    LIB_DIR
    + ":"
    + env.get(
        "LD_LIBRARY_PATH",
        ""
    )
)

env["OMPI_ALLOW_RUN_AS_ROOT"] = "1"

env[
    "OMPI_ALLOW_RUN_AS_ROOT_CONFIRM"
] = "1"


# ============================================================
# PALACE CONFIGURATION
# ============================================================

palace_config = {

    # --------------------------------------------------------
    # PROBLEM
    # --------------------------------------------------------

    "Problem": {

        "Type": "Eigenmode",

        "Verbose": 2,

        "Output": OUTPUT
    },


    # --------------------------------------------------------
    # MODEL
    # --------------------------------------------------------

    "Model": {

        "Mesh": MESH,

        # GDS/Gmsh coordinates are mm.
        # Convert to SI meters.
        "L0": 1.0e-3
    },


    # --------------------------------------------------------
    # MATERIALS
    # --------------------------------------------------------

    "Domains": {

        "Materials": [

            {
                # Attribute 1
                # Vacuum

                "Attributes": [1],

                "Permittivity": 1.0,

                "Permeability": 1.0
            },


            {
                # Attribute 2
                # Silicon

                "Attributes": [2],

                "Permittivity": 11.7,

                "Permeability": 1.0
            }
        ]
    },


    # --------------------------------------------------------
    # BOUNDARY CONDITIONS
    # --------------------------------------------------------

    "Boundaries": {

        # Attribute 10
        # Superconducting metal

        "PEC": {

            "Attributes": [10]
        }
    },


    # --------------------------------------------------------
    # SOLVER
    # --------------------------------------------------------

    "Solver": {

        # Keep Order 1 for Colab RAM.
        "Order": FEM_ORDER,


        # ----------------------------------------------------
        # EIGENMODE SOLVER
        # ----------------------------------------------------

        "Eigenmode": {

            # Request 10 modes.
            "N": NUMBER_OF_MODES,

            # Search around 5 GHz.
            "Target": TARGET_GHZ,

            # Eigenvalue tolerance.
            "Tol": EIGEN_TOL,

            "MaxIts": EIGEN_MAX_ITS
        },


        # ----------------------------------------------------
        # LINEAR SOLVER
        # ----------------------------------------------------

        "Linear": {

            "Type": "BoomerAMG",

            # Better than previous 1e-6.
            "Tol": LINEAR_TOL,

            # Previous 50 iterations was insufficient.
            "MaxIts": LINEAR_MAX_ITS
        }
    }
}


# ============================================================
# WRITE CONFIG
# ============================================================

with open(
    CONFIG,
    "w"
) as f:

    json.dump(
        palace_config,
        f,
        indent=4
    )


print(
    "\nConfiguration:"
)

print(
    CONFIG
)


# ============================================================
# PRINT SIMULATION SUMMARY
# ============================================================

print(
    "\n" + "=" * 80
)

print(
    "SIMULATION SETTINGS"
)

print(
    "=" * 80
)

print(
    f"Modes requested : {NUMBER_OF_MODES}"
)

print(
    f"Target          : {TARGET_GHZ} GHz"
)

print(
    f"FEM order       : {FEM_ORDER}"
)

print(
    f"Eigen tolerance  : {EIGEN_TOL}"
)

print(
    f"Linear tolerance : {LINEAR_TOL}"
)

print(
    f"Linear max its   : {LINEAR_MAX_ITS}"
)

print(
    "\nPhysics:"
)

print(
    "  Superconducting metal = PEC"
)

print(
    "  Josephson inductance  = NOT included"
)

print(
    "  Readout/drive/flux lines = passive geometry"
)

print(
    "  Qubit couplers = passive geometry"
)


# ============================================================
# COMMAND
# ============================================================

cmd = [

    "mpirun",

    "-n",
    "1",

    "--allow-run-as-root",

    PALACE_BIN,

    CONFIG
]


print(
    "\n" + "=" * 80
)

print(
    "EXECUTING PALACE"
)

print(
    "=" * 80
)

print(
    "\n"
    + " ".join(cmd)
)


# ============================================================
# START TIME
# ============================================================

start_time = time.time()


# ============================================================
# RUN
# ============================================================

try:

    result = subprocess.run(

        cmd,

        text=True,

        capture_output=True,

        env=env
    )

except Exception as exc:

    print(
        "\nFailed to start Palace:"
    )

    print(exc)

    raise


elapsed = (
    time.time()
    - start_time
)


# ============================================================
# OUTPUT
# ============================================================

print(
    "\n" + "=" * 80
)

print(
    "PALACE STDOUT"
)

print(
    "=" * 80
)

print(
    result.stdout
)


print(
    "\n" + "=" * 80
)

print(
    "PALACE STDERR"
)

print(
    "=" * 80
)

print(
    result.stderr
)


# ============================================================
# FINAL RAM
# ============================================================

ram = psutil.virtual_memory()

print(
    "\n" + "=" * 80
)

print(
    "RUN SUMMARY"
)

print(
    "=" * 80
)

print(
    f"Return code : {result.returncode}"
)

print(
    f"Runtime     : "
    f"{elapsed / 60:.2f} minutes"
)

print(
    f"RAM used    : "
    f"{ram.used / 1024**3:.2f} GB"
)

print(
    f"RAM free    : "
    f"{ram.available / 1024**3:.2f} GB"
)


# ============================================================
# SUCCESS / FAILURE
# ============================================================

if result.returncode == 0:

    print(
        "\n" + "=" * 80
    )

    print(
        "PALACE 10-MODE RUN COMPLETED"
    )

    print(
        "=" * 80
    )

    print(
        "\nOutput directory:"
    )

    print(
        OUTPUT
    )

    print(
        "\nNext:"
    )

    print(
        "Extract the 10 eigenfrequencies and identify"
        " qubit/readout/coupler-like modes."
    )

else:

    print(
        "\n" + "=" * 80
    )

    print(
        "PALACE RUN FAILED"
    )

    print(
        "=" * 80
    )

    print(
        "\nLast 8000 characters of STDERR:"
    )

    print(
        result.stderr[-8000:]
    )

    raise RuntimeError(
        "Palace eigenmode simulation failed."
    )
# Out:
# Streaming output truncated to the last 5000 lines.
#   5 (restart 0) KSP residual norm 3.805993e-07
#   6 (restart 0) KSP residual norm 3.634225e-07
#   7 (restart 0) KSP residual norm 3.455362e-07
#   8 (restart 0) KSP residual norm 3.302723e-07
#   9 (restart 0) KSP residual norm 3.163363e-07
#  10 (restart 0) KSP residual norm 3.075676e-07
#  11 (restart 0) KSP residual norm 3.008833e-07
#  12 (restart 0) KSP residual norm 2.966287e-07
#  13 (restart 0) KSP residual norm 2.938911e-07
#  14 (restart 0) KSP residual norm 2.934442e-07
#  15 (restart 0) KSP residual norm 2.932655e-07
#  16 (restart 0) KSP residual norm 2.912553e-07
#  17 (restart 0) KSP residual norm 2.882348e-07
#  18 (restart 0) KSP residual norm 2.844619e-07
#  19 (restart 0) KSP residual norm 2.827634e-07
#  20 (restart 0) KSP residual norm 2.824095e-07
#  21 (restart 0) KSP residual norm 2.819543e-07
#  22 (restart 0) KSP residual norm 2.802747e-07
#  23 (restart 0) KSP residual norm 2.775972e-07
#  24 (restart 0) KSP residual norm 2.758554e-07
#  25 (restart 0) KSP residual norm 2.739956e-07
#  26 (restart 0) KSP residual norm 2.734463e-07
#  27 (restart 0) KSP residual norm 2.733753e-07
#  28 (restart 0) KSP residual norm 2.732797e-07
#  29 (restart 0) KSP residual norm 2.726792e-07
#  30 (restart 0) KSP residual norm 2.711233e-07
#  31 (restart 0) KSP residual norm 2.689964e-07
#  32 (restart 0) KSP residual norm 2.670194e-07
#  33 (restart 0) KSP residual norm 2.661454e-07
#  34 (restart 0) KSP residual norm 2.660082e-07
#  35 (restart 0) KSP residual norm 2.659855e-07
#  36 (restart 0) KSP residual norm 2.656232e-07
#  37 (restart 0) KSP residual norm 2.641720e-07
#  38 (restart 0) KSP residual norm 2.620944e-07
#  39 (restart 0) KSP residual norm 2.597043e-07
#  40 (restart 0) KSP residual norm 2.576517e-07
#  41 (restart 0) KSP residual norm 2.568120e-07
#  42 (restart 0) KSP residual norm 2.564766e-07
#  43 (restart 0) KSP residual norm 2.564630e-07
#  44 (restart 0) KSP residual norm 2.561230e-07
#  45 (restart 0) KSP residual norm 2.554091e-07
#  46 (restart 0) KSP residual norm 2.542174e-07
#  47 (restart 0) KSP residual norm 2.531618e-07
#  48 (restart 0) KSP residual norm 2.521786e-07
#  49 (restart 0) KSP residual norm 2.518537e-07
#  50 (restart 0) KSP residual norm 2.517520e-07
#  51 (restart 0) KSP residual norm 2.517237e-07
#  52 (restart 0) KSP residual norm 2.515132e-07
#  53 (restart 0) KSP residual norm 2.508397e-07
#  54 (restart 0) KSP residual norm 2.495759e-07
#  55 (restart 0) KSP residual norm 2.480300e-07
#  56 (restart 0) KSP residual norm 2.464574e-07
#  57 (restart 0) KSP residual norm 2.454424e-07
#  58 (restart 0) KSP residual norm 2.451570e-07
#  59 (restart 0) KSP residual norm 2.451567e-07
#  60 (restart 0) KSP residual norm 2.449208e-07
#  61 (restart 0) KSP residual norm 2.442544e-07
#  62 (restart 0) KSP residual norm 2.430940e-07
#  63 (restart 0) KSP residual norm 2.420072e-07
#  64 (restart 0) KSP residual norm 2.406091e-07
#  65 (restart 0) KSP residual norm 2.394292e-07
#  66 (restart 0) KSP residual norm 2.386280e-07
#  67 (restart 0) KSP residual norm 2.383478e-07
#  68 (restart 0) KSP residual norm 2.382967e-07
#  69 (restart 0) KSP residual norm 2.382849e-07
#  70 (restart 0) KSP residual norm 2.380800e-07
#  71 (restart 0) KSP residual norm 2.373707e-07
#  72 (restart 0) KSP residual norm 2.365154e-07
#  73 (restart 0) KSP residual norm 2.357454e-07
#  74 (restart 0) KSP residual norm 2.352568e-07
#  75 (restart 0) KSP residual norm 2.350528e-07
#  76 (restart 0) KSP residual norm 2.350324e-07
#  77 (restart 0) KSP residual norm 2.350042e-07
#  78 (restart 0) KSP residual norm 2.348678e-07
#  79 (restart 0) KSP residual norm 2.346638e-07
#  80 (restart 0) KSP residual norm 2.343446e-07
#  81 (restart 0) KSP residual norm 2.339644e-07
#  82 (restart 0) KSP residual norm 2.337106e-07
#  83 (restart 0) KSP residual norm 2.335418e-07
#  84 (restart 0) KSP residual norm 2.334609e-07
#  85 (restart 0) KSP residual norm 2.334149e-07
#  86 (restart 0) KSP residual norm 2.333882e-07
#  87 (restart 0) KSP residual norm 2.333799e-07
#  88 (restart 0) KSP residual norm 2.333781e-07
#  89 (restart 0) KSP residual norm 2.333337e-07
#  90 (restart 0) KSP residual norm 2.331995e-07
#  91 (restart 0) KSP residual norm 2.329413e-07
#  92 (restart 0) KSP residual norm 2.324567e-07
#  93 (restart 0) KSP residual norm 2.318653e-07
#  94 (restart 0) KSP residual norm 2.313659e-07
#  95 (restart 0) KSP residual norm 2.311375e-07
#  96 (restart 0) KSP residual norm 2.310931e-07
#  97 (restart 0) KSP residual norm 2.310894e-07
#  98 (restart 0) KSP residual norm 2.310316e-07
#  99 (restart 0) KSP residual norm 2.309635e-07
# 100 (restart 0) KSP residual norm 2.307148e-07
# 101 (restart 0) KSP residual norm 2.304084e-07
# 102 (restart 0) KSP residual norm 2.300042e-07
# 103 (restart 0) KSP residual norm 2.293726e-07
# 104 (restart 0) KSP residual norm 2.289409e-07
# 105 (restart 0) KSP residual norm 2.287622e-07
# 106 (restart 0) KSP residual norm 2.287201e-07
# 107 (restart 0) KSP residual norm 2.287182e-07
# 108 (restart 0) KSP residual norm 2.286779e-07
# 109 (restart 0) KSP residual norm 2.284740e-07
# 110 (restart 0) KSP residual norm 2.280326e-07
# 111 (restart 0) KSP residual norm 2.275871e-07
# 112 (restart 0) KSP residual norm 2.272904e-07
# 113 (restart 0) KSP residual norm 2.270640e-07
# 114 (restart 0) KSP residual norm 2.269017e-07
# 115 (restart 0) KSP residual norm 2.267947e-07
# 116 (restart 0) KSP residual norm 2.267656e-07
# 117 (restart 0) KSP residual norm 2.267507e-07
# 118 (restart 0) KSP residual norm 2.267096e-07
# 119 (restart 0) KSP residual norm 2.265955e-07
# 120 (restart 0) KSP residual norm 2.263773e-07
# 121 (restart 0) KSP residual norm 2.261066e-07
# 122 (restart 0) KSP residual norm 2.258220e-07
# 123 (restart 0) KSP residual norm 2.255420e-07
# 124 (restart 0) KSP residual norm 2.252864e-07
# 125 (restart 0) KSP residual norm 2.251802e-07
# 126 (restart 0) KSP residual norm 2.251697e-07
# 127 (restart 0) KSP residual norm 2.251299e-07
# 128 (restart 0) KSP residual norm 2.249726e-07
# 129 (restart 0) KSP residual norm 2.247459e-07
# 130 (restart 0) KSP residual norm 2.244194e-07
# 131 (restart 0) KSP residual norm 2.240305e-07
# 132 (restart 0) KSP residual norm 2.236785e-07
# 133 (restart 0) KSP residual norm 2.234319e-07
# 134 (restart 0) KSP residual norm 2.232800e-07
# 135 (restart 0) KSP residual norm 2.231955e-07
# 136 (restart 0) KSP residual norm 2.231906e-07
# 137 (restart 0) KSP residual norm 2.231442e-07
# 138 (restart 0) KSP residual norm 2.230150e-07
# 139 (restart 0) KSP residual norm 2.228428e-07
# 140 (restart 0) KSP residual norm 2.225776e-07
# 141 (restart 0) KSP residual norm 2.222266e-07
# 142 (restart 0) KSP residual norm 2.218771e-07
# 143 (restart 0) KSP residual norm 2.216159e-07
# 144 (restart 0) KSP residual norm 2.214410e-07
# 145 (restart 0) KSP residual norm 2.213838e-07
# 146 (restart 0) KSP residual norm 2.213704e-07
# 147 (restart 0) KSP residual norm 2.213478e-07
# 148 (restart 0) KSP residual norm 2.211829e-07
# 149 (restart 0) KSP residual norm 2.208742e-07
# 150 (restart 0) KSP residual norm 2.204597e-07
# 151 (restart 0) KSP residual norm 2.199661e-07
# 152 (restart 0) KSP residual norm 2.195513e-07
# 153 (restart 0) KSP residual norm 2.192065e-07
# 154 (restart 0) KSP residual norm 2.190740e-07
# 155 (restart 0) KSP residual norm 2.190542e-07
# 156 (restart 0) KSP residual norm 2.190337e-07
# 157 (restart 0) KSP residual norm 2.188268e-07
# 158 (restart 0) KSP residual norm 2.185036e-07
# 159 (restart 0) KSP residual norm 2.181010e-07
# 160 (restart 0) KSP residual norm 2.176891e-07
# 161 (restart 0) KSP residual norm 2.173363e-07
# 162 (restart 0) KSP residual norm 2.170938e-07
# 163 (restart 0) KSP residual norm 2.168692e-07
# 164 (restart 0) KSP residual norm 2.168052e-07
# 165 (restart 0) KSP residual norm 2.168045e-07
# 166 (restart 0) KSP residual norm 2.167910e-07
# 167 (restart 0) KSP residual norm 2.166536e-07
# 168 (restart 0) KSP residual norm 2.164390e-07
# 169 (restart 0) KSP residual norm 2.161509e-07
# 170 (restart 0) KSP residual norm 2.158609e-07
# 171 (restart 0) KSP residual norm 2.156812e-07
# 172 (restart 0) KSP residual norm 2.155981e-07
# 173 (restart 0) KSP residual norm 2.155439e-07
# 174 (restart 0) KSP residual norm 2.155318e-07
# 175 (restart 0) KSP residual norm 2.155209e-07
# 176 (restart 0) KSP residual norm 2.154844e-07
# 177 (restart 0) KSP residual norm 2.153432e-07
# 178 (restart 0) KSP residual norm 2.152115e-07
# 179 (restart 0) KSP residual norm 2.150551e-07
# 180 (restart 0) KSP residual norm 2.148055e-07
# 181 (restart 0) KSP residual norm 2.145987e-07
# 182 (restart 0) KSP residual norm 2.144559e-07
# 183 (restart 0) KSP residual norm 2.144357e-07
# 184 (restart 0) KSP residual norm 2.144338e-07
# 185 (restart 0) KSP residual norm 2.144028e-07
# 186 (restart 0) KSP residual norm 2.142947e-07
# 187 (restart 0) KSP residual norm 2.141335e-07
# 188 (restart 0) KSP residual norm 2.138693e-07
# 189 (restart 0) KSP residual norm 2.135837e-07
# 190 (restart 0) KSP residual norm 2.133373e-07
# 191 (restart 0) KSP residual norm 2.131294e-07
# 192 (restart 0) KSP residual norm 2.130167e-07
# 193 (restart 0) KSP residual norm 2.130052e-07
# 194 (restart 0) KSP residual norm 2.129838e-07
# 195 (restart 0) KSP residual norm 2.128643e-07
# 196 (restart 0) KSP residual norm 2.126632e-07
# 197 (restart 0) KSP residual norm 2.124424e-07
# 198 (restart 0) KSP residual norm 2.122019e-07
# 199 (restart 0) KSP residual norm 2.120558e-07
# 200 (restart 0) KSP residual norm 2.119552e-07
# 201 (restart 0) KSP residual norm 2.118628e-07
# 202 (restart 0) KSP residual norm 2.118213e-07
# 203 (restart 0) KSP residual norm 2.118080e-07
# 204 (restart 0) KSP residual norm 2.118035e-07
# 205 (restart 0) KSP residual norm 2.117839e-07
# 206 (restart 0) KSP residual norm 2.117358e-07
# 207 (restart 0) KSP residual norm 2.116580e-07
# 208 (restart 0) KSP residual norm 2.116022e-07
# 209 (restart 0) KSP residual norm 2.115292e-07
# 210 (restart 0) KSP residual norm 2.114407e-07
# 211 (restart 0) KSP residual norm 2.113704e-07
# 212 (restart 0) KSP residual norm 2.113394e-07
# 213 (restart 0) KSP residual norm 2.113070e-07
# 214 (restart 0) KSP residual norm 2.112986e-07
# 215 (restart 0) KSP residual norm 2.112985e-07
# 216 (restart 0) KSP residual norm 2.112940e-07
# 217 (restart 0) KSP residual norm 2.112509e-07
# 218 (restart 0) KSP residual norm 2.111579e-07
# 219 (restart 0) KSP residual norm 2.110423e-07
# 220 (restart 0) KSP residual norm 2.109232e-07
# 221 (restart 0) KSP residual norm 2.108245e-07
# 222 (restart 0) KSP residual norm 2.107389e-07
# 223 (restart 0) KSP residual norm 2.106711e-07
# 224 (restart 0) KSP residual norm 2.106283e-07
# 225 (restart 0) KSP residual norm 2.106090e-07
# 226 (restart 0) KSP residual norm 2.106046e-07
# 227 (restart 0) KSP residual norm 2.105961e-07
# 228 (restart 0) KSP residual norm 2.105603e-07
# 229 (restart 0) KSP residual norm 2.104308e-07
# 230 (restart 0) KSP residual norm 2.102485e-07
# 231 (restart 0) KSP residual norm 2.100268e-07
# 232 (restart 0) KSP residual norm 2.098597e-07
# 233 (restart 0) KSP residual norm 2.097104e-07
# 234 (restart 0) KSP residual norm 2.096519e-07
# 235 (restart 0) KSP residual norm 2.096405e-07
# 236 (restart 0) KSP residual norm 2.096383e-07
# 237 (restart 0) KSP residual norm 2.096092e-07
# 238 (restart 0) KSP residual norm 2.095425e-07
# 239 (restart 0) KSP residual norm 2.094481e-07
# 240 (restart 0) KSP residual norm 2.093377e-07
# 241 (restart 0) KSP residual norm 2.091620e-07
# 242 (restart 0) KSP residual norm 2.089521e-07
# 243 (restart 0) KSP residual norm 2.087651e-07
# 244 (restart 0) KSP residual norm 2.085910e-07
# 245 (restart 0) KSP residual norm 2.085036e-07
# 246 (restart 0) KSP residual norm 2.084922e-07
# 247 (restart 0) KSP residual norm 2.084857e-07
# 248 (restart 0) KSP residual norm 2.084446e-07
# 249 (restart 0) KSP residual norm 2.083871e-07
# 250 (restart 0) KSP residual norm 2.083002e-07
# 251 (restart 0) KSP residual norm 2.082322e-07
# 252 (restart 0) KSP residual norm 2.081413e-07
# 253 (restart 0) KSP residual norm 2.079716e-07
# 254 (restart 0) KSP residual norm 2.078040e-07
# 255 (restart 0) KSP residual norm 2.076886e-07
# 256 (restart 0) KSP residual norm 2.075910e-07
# 257 (restart 0) KSP residual norm 2.075359e-07
# 258 (restart 0) KSP residual norm 2.075318e-07
# 259 (restart 0) KSP residual norm 2.075209e-07
# 260 (restart 0) KSP residual norm 2.074853e-07
# 261 (restart 0) KSP residual norm 2.073599e-07
# 262 (restart 0) KSP residual norm 2.071846e-07
# 263 (restart 0) KSP residual norm 2.069288e-07
# 264 (restart 0) KSP residual norm 2.065974e-07
# 265 (restart 0) KSP residual norm 2.063214e-07
# 266 (restart 0) KSP residual norm 2.060984e-07
# 267 (restart 0) KSP residual norm 2.060055e-07
# 268 (restart 0) KSP residual norm 2.060013e-07
# 269 (restart 0) KSP residual norm 2.059693e-07
# 270 (restart 0) KSP residual norm 2.058558e-07
# 271 (restart 0) KSP residual norm 2.056527e-07
# 272 (restart 0) KSP residual norm 2.053900e-07
# 273 (restart 0) KSP residual norm 2.050928e-07
# 274 (restart 0) KSP residual norm 2.049430e-07
# 275 (restart 0) KSP residual norm 2.048021e-07
# 276 (restart 0) KSP residual norm 2.046771e-07
# 277 (restart 0) KSP residual norm 2.046155e-07
# 278 (restart 0) KSP residual norm 2.046084e-07
# 279 (restart 0) KSP residual norm 2.046011e-07
# 280 (restart 0) KSP residual norm 2.045578e-07
# 281 (restart 0) KSP residual norm 2.044915e-07
# 282 (restart 0) KSP residual norm 2.043868e-07
# 283 (restart 0) KSP residual norm 2.042967e-07
# 284 (restart 0) KSP residual norm 2.041930e-07
# 285 (restart 0) KSP residual norm 2.041045e-07
# 286 (restart 0) KSP residual norm 2.040493e-07
# 287 (restart 0) KSP residual norm 2.040017e-07
# 288 (restart 0) KSP residual norm 2.039760e-07
# 289 (restart 0) KSP residual norm 2.039538e-07
# 290 (restart 0) KSP residual norm 2.039511e-07
# 291 (restart 0) KSP residual norm 2.039420e-07
# 292 (restart 0) KSP residual norm 2.039174e-07
# 293 (restart 0) KSP residual norm 2.038564e-07
# 294 (restart 0) KSP residual norm 2.037446e-07
# 295 (restart 0) KSP residual norm 2.035535e-07
# 296 (restart 0) KSP residual norm 2.033922e-07
# 297 (restart 0) KSP residual norm 2.032902e-07
# 298 (restart 0) KSP residual norm 2.032231e-07
# 299 (restart 0) KSP residual norm 2.032097e-07
# 300 (restart 1) KSP residual norm 2.032061e-07
# GMRES solver did NOT converge in 300 iterations (avg. reduction factor: 9.959e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.874e-01 (norm(b) = 7.069e-07)!
#
#   Residual norms for GMRES solve
#   0 (restart 0) KSP residual norm 6.943309e-07
#   1 (restart 0) KSP residual norm 4.961188e-07
#   2 (restart 0) KSP residual norm 4.425998e-07
#   3 (restart 0) KSP residual norm 3.963663e-07
#   4 (restart 0) KSP residual norm 3.732294e-07
#   5 (restart 0) KSP residual norm 3.442405e-07
#   6 (restart 0) KSP residual norm 3.249995e-07
#   7 (restart 0) KSP residual norm 3.090876e-07
#   8 (restart 0) KSP residual norm 2.987716e-07
#   9 (restart 0) KSP residual norm 2.873788e-07
#  10 (restart 0) KSP residual norm 2.790206e-07
#  11 (restart 0) KSP residual norm 2.719104e-07
#  12 (restart 0) KSP residual norm 2.676559e-07
#  13 (restart 0) KSP residual norm 2.660856e-07
#  14 (restart 0) KSP residual norm 2.660606e-07
#  15 (restart 0) KSP residual norm 2.645170e-07
#  16 (restart 0) KSP residual norm 2.607608e-07
#  17 (restart 0) KSP residual norm 2.573581e-07
#  18 (restart 0) KSP residual norm 2.533399e-07
#  19 (restart 0) KSP residual norm 2.517484e-07
#  20 (restart 0) KSP residual norm 2.517072e-07
#  21 (restart 0) KSP residual norm 2.505319e-07
#  22 (restart 0) KSP residual norm 2.475479e-07
#  23 (restart 0) KSP residual norm 2.433656e-07
#  24 (restart 0) KSP residual norm 2.408435e-07
#  25 (restart 0) KSP residual norm 2.393071e-07
#  26 (restart 0) KSP residual norm 2.389351e-07
#  27 (restart 0) KSP residual norm 2.389328e-07
#  28 (restart 0) KSP residual norm 2.385439e-07
#  29 (restart 0) KSP residual norm 2.373978e-07
#  30 (restart 0) KSP residual norm 2.355610e-07
#  31 (restart 0) KSP residual norm 2.334201e-07
#  32 (restart 0) KSP residual norm 2.315603e-07
#  33 (restart 0) KSP residual norm 2.306244e-07
#  34 (restart 0) KSP residual norm 2.302979e-07
#  35 (restart 0) KSP residual norm 2.302868e-07
#  36 (restart 0) KSP residual norm 2.295859e-07
#  37 (restart 0) KSP residual norm 2.273886e-07
#  38 (restart 0) KSP residual norm 2.241212e-07
#  39 (restart 0) KSP residual norm 2.209194e-07
#  40 (restart 0) KSP residual norm 2.187316e-07
#  41 (restart 0) KSP residual norm 2.177889e-07
#  42 (restart 0) KSP residual norm 2.176400e-07
#  43 (restart 0) KSP residual norm 2.175865e-07
#  44 (restart 0) KSP residual norm 2.170747e-07
#  45 (restart 0) KSP residual norm 2.160647e-07
#  46 (restart 0) KSP residual norm 2.147004e-07
#  47 (restart 0) KSP residual norm 2.134191e-07
#  48 (restart 0) KSP residual norm 2.122975e-07
#  49 (restart 0) KSP residual norm 2.117437e-07
#  50 (restart 0) KSP residual norm 2.116287e-07
#  51 (restart 0) KSP residual norm 2.115752e-07
#  52 (restart 0) KSP residual norm 2.110921e-07
#  53 (restart 0) KSP residual norm 2.099369e-07
#  54 (restart 0) KSP residual norm 2.081103e-07
#  55 (restart 0) KSP residual norm 2.056618e-07
#  56 (restart 0) KSP residual norm 2.033140e-07
#  57 (restart 0) KSP residual norm 2.017463e-07
#  58 (restart 0) KSP residual norm 2.009407e-07
#  59 (restart 0) KSP residual norm 2.006050e-07
#  60 (restart 0) KSP residual norm 2.005990e-07
#  61 (restart 0) KSP residual norm 2.003246e-07
#  62 (restart 0) KSP residual norm 1.989917e-07
#  63 (restart 0) KSP residual norm 1.966890e-07
#  64 (restart 0) KSP residual norm 1.935904e-07
#  65 (restart 0) KSP residual norm 1.908768e-07
#  66 (restart 0) KSP residual norm 1.889216e-07
#  67 (restart 0) KSP residual norm 1.878645e-07
#  68 (restart 0) KSP residual norm 1.873617e-07
#  69 (restart 0) KSP residual norm 1.872922e-07
#  70 (restart 0) KSP residual norm 1.872400e-07
#  71 (restart 0) KSP residual norm 1.867095e-07
#  72 (restart 0) KSP residual norm 1.855481e-07
#  73 (restart 0) KSP residual norm 1.838703e-07
#  74 (restart 0) KSP residual norm 1.825592e-07
#  75 (restart 0) KSP residual norm 1.815946e-07
#  76 (restart 0) KSP residual norm 1.811780e-07
#  77 (restart 0) KSP residual norm 1.810834e-07
#  78 (restart 0) KSP residual norm 1.810817e-07
#  79 (restart 0) KSP residual norm 1.809457e-07
#  80 (restart 0) KSP residual norm 1.805569e-07
#  81 (restart 0) KSP residual norm 1.798971e-07
#  82 (restart 0) KSP residual norm 1.791295e-07
#  83 (restart 0) KSP residual norm 1.783477e-07
#  84 (restart 0) KSP residual norm 1.776087e-07
#  85 (restart 0) KSP residual norm 1.770931e-07
#  86 (restart 0) KSP residual norm 1.766111e-07
#  87 (restart 0) KSP residual norm 1.764189e-07
#  88 (restart 0) KSP residual norm 1.763876e-07
#  89 (restart 0) KSP residual norm 1.763635e-07
#  90 (restart 0) KSP residual norm 1.761492e-07
#  91 (restart 0) KSP residual norm 1.754758e-07
#  92 (restart 0) KSP residual norm 1.742481e-07
#  93 (restart 0) KSP residual norm 1.728328e-07
#  94 (restart 0) KSP residual norm 1.718483e-07
#  95 (restart 0) KSP residual norm 1.713163e-07
#  96 (restart 0) KSP residual norm 1.710482e-07
#  97 (restart 0) KSP residual norm 1.709745e-07
#  98 (restart 0) KSP residual norm 1.709720e-07
#  99 (restart 0) KSP residual norm 1.708491e-07
# 100 (restart 0) KSP residual norm 1.702454e-07
# 101 (restart 0) KSP residual norm 1.691134e-07
# 102 (restart 0) KSP residual norm 1.676546e-07
# 103 (restart 0) KSP residual norm 1.661925e-07
# 104 (restart 0) KSP residual norm 1.650944e-07
# 105 (restart 0) KSP residual norm 1.646508e-07
# 106 (restart 0) KSP residual norm 1.644775e-07
# 107 (restart 0) KSP residual norm 1.644748e-07
# 108 (restart 0) KSP residual norm 1.643714e-07
# 109 (restart 0) KSP residual norm 1.639639e-07
# 110 (restart 0) KSP residual norm 1.633005e-07
# 111 (restart 0) KSP residual norm 1.625429e-07
# 112 (restart 0) KSP residual norm 1.617847e-07
# 113 (restart 0) KSP residual norm 1.611132e-07
# 114 (restart 0) KSP residual norm 1.606946e-07
# 115 (restart 0) KSP residual norm 1.604624e-07
# 116 (restart 0) KSP residual norm 1.603737e-07
# 117 (restart 0) KSP residual norm 1.603651e-07
# 118 (restart 0) KSP residual norm 1.602776e-07
# 119 (restart 0) KSP residual norm 1.600606e-07
# 120 (restart 0) KSP residual norm 1.595714e-07
# 121 (restart 0) KSP residual norm 1.590099e-07
# 122 (restart 0) KSP residual norm 1.584029e-07
# 123 (restart 0) KSP residual norm 1.578406e-07
# 124 (restart 0) KSP residual norm 1.574463e-07
# 125 (restart 0) KSP residual norm 1.572906e-07
# 126 (restart 0) KSP residual norm 1.572751e-07
# 127 (restart 0) KSP residual norm 1.572400e-07
# 128 (restart 0) KSP residual norm 1.570457e-07
# 129 (restart 0) KSP residual norm 1.567118e-07
# 130 (restart 0) KSP residual norm 1.561915e-07
# 131 (restart 0) KSP residual norm 1.555872e-07
# 132 (restart 0) KSP residual norm 1.550252e-07
# 133 (restart 0) KSP residual norm 1.546431e-07
# 134 (restart 0) KSP residual norm 1.543607e-07
# 135 (restart 0) KSP residual norm 1.542047e-07
# 136 (restart 0) KSP residual norm 1.541807e-07
# 137 (restart 0) KSP residual norm 1.541612e-07
# 138 (restart 0) KSP residual norm 1.540478e-07
# 139 (restart 0) KSP residual norm 1.538070e-07
# 140 (restart 0) KSP residual norm 1.533642e-07
# 141 (restart 0) KSP residual norm 1.529218e-07
# 142 (restart 0) KSP residual norm 1.523937e-07
# 143 (restart 0) KSP residual norm 1.520198e-07
# 144 (restart 0) KSP residual norm 1.518311e-07
# 145 (restart 0) KSP residual norm 1.517683e-07
# 146 (restart 0) KSP residual norm 1.517623e-07
# 147 (restart 0) KSP residual norm 1.517309e-07
# 148 (restart 0) KSP residual norm 1.515078e-07
# 149 (restart 0) KSP residual norm 1.510838e-07
# 150 (restart 0) KSP residual norm 1.505556e-07
# 151 (restart 0) KSP residual norm 1.499988e-07
# 152 (restart 0) KSP residual norm 1.494929e-07
# 153 (restart 0) KSP residual norm 1.491559e-07
# 154 (restart 0) KSP residual norm 1.489653e-07
# 155 (restart 0) KSP residual norm 1.488989e-07
# 156 (restart 0) KSP residual norm 1.488979e-07
# 157 (restart 0) KSP residual norm 1.488287e-07
# 158 (restart 0) KSP residual norm 1.486565e-07
# 159 (restart 0) KSP residual norm 1.483309e-07
# 160 (restart 0) KSP residual norm 1.478607e-07
# 161 (restart 0) KSP residual norm 1.473039e-07
# 162 (restart 0) KSP residual norm 1.466581e-07
# 163 (restart 0) KSP residual norm 1.460675e-07
# 164 (restart 0) KSP residual norm 1.457209e-07
# 165 (restart 0) KSP residual norm 1.455677e-07
# 166 (restart 0) KSP residual norm 1.455459e-07
# 167 (restart 0) KSP residual norm 1.455315e-07
# 168 (restart 0) KSP residual norm 1.453814e-07
# 169 (restart 0) KSP residual norm 1.450508e-07
# 170 (restart 0) KSP residual norm 1.446048e-07
# 171 (restart 0) KSP residual norm 1.442007e-07
# 172 (restart 0) KSP residual norm 1.438106e-07
# 173 (restart 0) KSP residual norm 1.435614e-07
# 174 (restart 0) KSP residual norm 1.434638e-07
# 175 (restart 0) KSP residual norm 1.434519e-07
# 176 (restart 0) KSP residual norm 1.434401e-07
# 177 (restart 0) KSP residual norm 1.433556e-07
# 178 (restart 0) KSP residual norm 1.431551e-07
# 179 (restart 0) KSP residual norm 1.428361e-07
# 180 (restart 0) KSP residual norm 1.424553e-07
# 181 (restart 0) KSP residual norm 1.421545e-07
# 182 (restart 0) KSP residual norm 1.419695e-07
# 183 (restart 0) KSP residual norm 1.418752e-07
# 184 (restart 0) KSP residual norm 1.418353e-07
# 185 (restart 0) KSP residual norm 1.418211e-07
# 186 (restart 0) KSP residual norm 1.417832e-07
# 187 (restart 0) KSP residual norm 1.415927e-07
# 188 (restart 0) KSP residual norm 1.412418e-07
# 189 (restart 0) KSP residual norm 1.407723e-07
# 190 (restart 0) KSP residual norm 1.402690e-07
# 191 (restart 0) KSP residual norm 1.398850e-07
# 192 (restart 0) KSP residual norm 1.396938e-07
# 193 (restart 0) KSP residual norm 1.396280e-07
# 194 (restart 0) KSP residual norm 1.396162e-07
# 195 (restart 0) KSP residual norm 1.395247e-07
# 196 (restart 0) KSP residual norm 1.393044e-07
# 197 (restart 0) KSP residual norm 1.388936e-07
# 198 (restart 0) KSP residual norm 1.384076e-07
# 199 (restart 0) KSP residual norm 1.379578e-07
# 200 (restart 0) KSP residual norm 1.376218e-07
# 201 (restart 0) KSP residual norm 1.373982e-07
# 202 (restart 0) KSP residual norm 1.372679e-07
# 203 (restart 0) KSP residual norm 1.372464e-07
# 204 (restart 0) KSP residual norm 1.372384e-07
# 205 (restart 0) KSP residual norm 1.371867e-07
# 206 (restart 0) KSP residual norm 1.370752e-07
# 207 (restart 0) KSP residual norm 1.368854e-07
# 208 (restart 0) KSP residual norm 1.366288e-07
# 209 (restart 0) KSP residual norm 1.363531e-07
# 210 (restart 0) KSP residual norm 1.361658e-07
# 211 (restart 0) KSP residual norm 1.360237e-07
# 212 (restart 0) KSP residual norm 1.359573e-07
# 213 (restart 0) KSP residual norm 1.359338e-07
# 214 (restart 0) KSP residual norm 1.359307e-07
# 215 (restart 0) KSP residual norm 1.359255e-07
# 216 (restart 0) KSP residual norm 1.358986e-07
# 217 (restart 0) KSP residual norm 1.358208e-07
# 218 (restart 0) KSP residual norm 1.356879e-07
# 219 (restart 0) KSP residual norm 1.354921e-07
# 220 (restart 0) KSP residual norm 1.352948e-07
# 221 (restart 0) KSP residual norm 1.351950e-07
# 222 (restart 0) KSP residual norm 1.351214e-07
# 223 (restart 0) KSP residual norm 1.350807e-07
# 224 (restart 0) KSP residual norm 1.350634e-07
# 225 (restart 0) KSP residual norm 1.350559e-07
# 226 (restart 0) KSP residual norm 1.350552e-07
# 227 (restart 0) KSP residual norm 1.350347e-07
# 228 (restart 0) KSP residual norm 1.349790e-07
# 229 (restart 0) KSP residual norm 1.347989e-07
# 230 (restart 0) KSP residual norm 1.345797e-07
# 231 (restart 0) KSP residual norm 1.343933e-07
# 232 (restart 0) KSP residual norm 1.342613e-07
# 233 (restart 0) KSP residual norm 1.341341e-07
# 234 (restart 0) KSP residual norm 1.340542e-07
# 235 (restart 0) KSP residual norm 1.340324e-07
# 236 (restart 0) KSP residual norm 1.340266e-07
# 237 (restart 0) KSP residual norm 1.339906e-07
# 238 (restart 0) KSP residual norm 1.339045e-07
# 239 (restart 0) KSP residual norm 1.338057e-07
# 240 (restart 0) KSP residual norm 1.336701e-07
# 241 (restart 0) KSP residual norm 1.334859e-07
# 242 (restart 0) KSP residual norm 1.333264e-07
# 243 (restart 0) KSP residual norm 1.331942e-07
# 244 (restart 0) KSP residual norm 1.331173e-07
# 245 (restart 0) KSP residual norm 1.330671e-07
# 246 (restart 0) KSP residual norm 1.330575e-07
# 247 (restart 0) KSP residual norm 1.330397e-07
# 248 (restart 0) KSP residual norm 1.329725e-07
# 249 (restart 0) KSP residual norm 1.328428e-07
# 250 (restart 0) KSP residual norm 1.327147e-07
# 251 (restart 0) KSP residual norm 1.326240e-07
# 252 (restart 0) KSP residual norm 1.325545e-07
# 253 (restart 0) KSP residual norm 1.324815e-07
# 254 (restart 0) KSP residual norm 1.324205e-07
# 255 (restart 0) KSP residual norm 1.323846e-07
# 256 (restart 0) KSP residual norm 1.323805e-07
# 257 (restart 0) KSP residual norm 1.323803e-07
# 258 (restart 0) KSP residual norm 1.323733e-07
# 259 (restart 0) KSP residual norm 1.323365e-07
# 260 (restart 0) KSP residual norm 1.322805e-07
# 261 (restart 0) KSP residual norm 1.322206e-07
# 262 (restart 0) KSP residual norm 1.321588e-07
# 263 (restart 0) KSP residual norm 1.320870e-07
# 264 (restart 0) KSP residual norm 1.320282e-07
# 265 (restart 0) KSP residual norm 1.319713e-07
# 266 (restart 0) KSP residual norm 1.319297e-07
# 267 (restart 0) KSP residual norm 1.319167e-07
# 268 (restart 0) KSP residual norm 1.319128e-07
# 269 (restart 0) KSP residual norm 1.319076e-07
# 270 (restart 0) KSP residual norm 1.318703e-07
# 271 (restart 0) KSP residual norm 1.318128e-07
# 272 (restart 0) KSP residual norm 1.317403e-07
# 273 (restart 0) KSP residual norm 1.316512e-07
# 274 (restart 0) KSP residual norm 1.315809e-07
# 275 (restart 0) KSP residual norm 1.315272e-07
# 276 (restart 0) KSP residual norm 1.314986e-07
# 277 (restart 0) KSP residual norm 1.314842e-07
# 278 (restart 0) KSP residual norm 1.314781e-07
# 279 (restart 0) KSP residual norm 1.314767e-07
# 280 (restart 0) KSP residual norm 1.314744e-07
# 281 (restart 0) KSP residual norm 1.314702e-07
# 282 (restart 0) KSP residual norm 1.314493e-07
# 283 (restart 0) KSP residual norm 1.314121e-07
# 284 (restart 0) KSP residual norm 1.313457e-07
# 285 (restart 0) KSP residual norm 1.312623e-07
# 286 (restart 0) KSP residual norm 1.311930e-07
# 287 (restart 0) KSP residual norm 1.311454e-07
# 288 (restart 0) KSP residual norm 1.311114e-07
# 289 (restart 0) KSP residual norm 1.310770e-07
# 290 (restart 0) KSP residual norm 1.310701e-07
# 291 (restart 0) KSP residual norm 1.310640e-07
# 292 (restart 0) KSP residual norm 1.310494e-07
# 293 (restart 0) KSP residual norm 1.310149e-07
# 294 (restart 0) KSP residual norm 1.309427e-07
# 295 (restart 0) KSP residual norm 1.308189e-07
# 296 (restart 0) KSP residual norm 1.307031e-07
# 297 (restart 0) KSP residual norm 1.305856e-07
# 298 (restart 0) KSP residual norm 1.304835e-07
# 299 (restart 0) KSP residual norm 1.304325e-07
# 300 (restart 1) KSP residual norm 1.304202e-07
# GMRES solver did NOT converge in 300 iterations (avg. reduction factor: 9.944e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 1.878e-01 (norm(b) = 6.943e-07)!
#
#   Residual norms for GMRES solve
#   0 (restart 0) KSP residual norm 7.967266e-07
#   1 (restart 0) KSP residual norm 5.499763e-07
#   2 (restart 0) KSP residual norm 4.860467e-07
#   3 (restart 0) KSP residual norm 4.371059e-07
#   4 (restart 0) KSP residual norm 4.132341e-07
#   5 (restart 0) KSP residual norm 3.813016e-07
#   6 (restart 0) KSP residual norm 3.580245e-07
#   7 (restart 0) KSP residual norm 3.386686e-07
#   8 (restart 0) KSP residual norm 3.251940e-07
#   9 (restart 0) KSP residual norm 3.122867e-07
#  10 (restart 0) KSP residual norm 3.042845e-07
#  11 (restart 0) KSP residual norm 2.980864e-07
#  12 (restart 0) KSP residual norm 2.948975e-07
#  13 (restart 0) KSP residual norm 2.942209e-07
#  14 (restart 0) KSP residual norm 2.937675e-07
#  15 (restart 0) KSP residual norm 2.911820e-07
#  16 (restart 0) KSP residual norm 2.873815e-07
#  17 (restart 0) KSP residual norm 2.844237e-07
#  18 (restart 0) KSP residual norm 2.816162e-07
#  19 (restart 0) KSP residual norm 2.810557e-07
#  20 (restart 0) KSP residual norm 2.809223e-07
#  21 (restart 0) KSP residual norm 2.784919e-07
#  22 (restart 0) KSP residual norm 2.751250e-07
#  23 (restart 0) KSP residual norm 2.721441e-07
#  24 (restart 0) KSP residual norm 2.706025e-07
#  25 (restart 0) KSP residual norm 2.698599e-07
#  26 (restart 0) KSP residual norm 2.698022e-07
#  27 (restart 0) KSP residual norm 2.697101e-07
#  28 (restart 0) KSP residual norm 2.688388e-07
#  29 (restart 0) KSP residual norm 2.670941e-07
#  30 (restart 0) KSP residual norm 2.643107e-07
#  31 (restart 0) KSP residual norm 2.617025e-07
#  32 (restart 0) KSP residual norm 2.603871e-07
#  33 (restart 0) KSP residual norm 2.601359e-07
#  34 (restart 0) KSP residual norm 2.601279e-07
#  35 (restart 0) KSP residual norm 2.595291e-07
#  36 (restart 0) KSP residual norm 2.580294e-07
#  37 (restart 0) KSP residual norm 2.551671e-07
#  38 (restart 0) KSP residual norm 2.519924e-07
#  39 (restart 0) KSP residual norm 2.494277e-07
#  40 (restart 0) KSP residual norm 2.481591e-07
#  41 (restart 0) KSP residual norm 2.479903e-07
#  42 (restart 0) KSP residual norm 2.479901e-07
#  43 (restart 0) KSP residual norm 2.475824e-07
#  44 (restart 0) KSP residual norm 2.463839e-07
#  45 (restart 0) KSP residual norm 2.450553e-07
#  46 (restart 0) KSP residual norm 2.440030e-07
#  47 (restart 0) KSP residual norm 2.434321e-07
#  48 (restart 0) KSP residual norm 2.432179e-07
#  49 (restart 0) KSP residual norm 2.432161e-07
#  50 (restart 0) KSP residual norm 2.432081e-07
#  51 (restart 0) KSP residual norm 2.430578e-07
#  52 (restart 0) KSP residual norm 2.427012e-07
#  53 (restart 0) KSP residual norm 2.419962e-07
#  54 (restart 0) KSP residual norm 2.406057e-07
#  55 (restart 0) KSP residual norm 2.385821e-07
#  56 (restart 0) KSP residual norm 2.362778e-07
#  57 (restart 0) KSP residual norm 2.346324e-07
#  58 (restart 0) KSP residual norm 2.339109e-07
#  59 (restart 0) KSP residual norm 2.338297e-07
#  60 (restart 0) KSP residual norm 2.337483e-07
#  61 (restart 0) KSP residual norm 2.330650e-07
#  62 (restart 0) KSP residual norm 2.314060e-07
#  63 (restart 0) KSP residual norm 2.291213e-07
#  64 (restart 0) KSP residual norm 2.264289e-07
#  65 (restart 0) KSP residual norm 2.242318e-07
#  66 (restart 0) KSP residual norm 2.226083e-07
#  67 (restart 0) KSP residual norm 2.218854e-07
#  68 (restart 0) KSP residual norm 2.217048e-07
#  69 (restart 0) KSP residual norm 2.216998e-07
#  70 (restart 0) KSP residual norm 2.214487e-07
#  71 (restart 0) KSP residual norm 2.207989e-07
#  72 (restart 0) KSP residual norm 2.197596e-07
#  73 (restart 0) KSP residual norm 2.186486e-07
#  74 (restart 0) KSP residual norm 2.179135e-07
#  75 (restart 0) KSP residual norm 2.175161e-07
#  76 (restart 0) KSP residual norm 2.174625e-07
#  77 (restart 0) KSP residual norm 2.174589e-07
#  78 (restart 0) KSP residual norm 2.172651e-07
#  79 (restart 0) KSP residual norm 2.167768e-07
#  80 (restart 0) KSP residual norm 2.160513e-07
#  81 (restart 0) KSP residual norm 2.154667e-07
#  82 (restart 0) KSP residual norm 2.150945e-07
#  83 (restart 0) KSP residual norm 2.148384e-07
#  84 (restart 0) KSP residual norm 2.147085e-07
#  85 (restart 0) KSP residual norm 2.145659e-07
#  86 (restart 0) KSP residual norm 2.145025e-07
#  87 (restart 0) KSP residual norm 2.144942e-07
#  88 (restart 0) KSP residual norm 2.144680e-07
#  89 (restart 0) KSP residual norm 2.143478e-07
#  90 (restart 0) KSP residual norm 2.140444e-07
#  91 (restart 0) KSP residual norm 2.134565e-07
#  92 (restart 0) KSP residual norm 2.127108e-07
#  93 (restart 0) KSP residual norm 2.121145e-07
#  94 (restart 0) KSP residual norm 2.118032e-07
#  95 (restart 0) KSP residual norm 2.116883e-07
#  96 (restart 0) KSP residual norm 2.116730e-07
#  97 (restart 0) KSP residual norm 2.116407e-07
#  98 (restart 0) KSP residual norm 2.115282e-07
#  99 (restart 0) KSP residual norm 2.112907e-07
# 100 (restart 0) KSP residual norm 2.107055e-07
# 101 (restart 0) KSP residual norm 2.099805e-07
# 102 (restart 0) KSP residual norm 2.091173e-07
# 103 (restart 0) KSP residual norm 2.083620e-07
# 104 (restart 0) KSP residual norm 2.078939e-07
# 105 (restart 0) KSP residual norm 2.077978e-07
# 106 (restart 0) KSP residual norm 2.077976e-07
# 107 (restart 0) KSP residual norm 2.077095e-07
# 108 (restart 0) KSP residual norm 2.074942e-07
# 109 (restart 0) KSP residual norm 2.071479e-07
# 110 (restart 0) KSP residual norm 2.067357e-07
# 111 (restart 0) KSP residual norm 2.063337e-07
# 112 (restart 0) KSP residual norm 2.059745e-07
# 113 (restart 0) KSP residual norm 2.056887e-07
# 114 (restart 0) KSP residual norm 2.055413e-07
# 115 (restart 0) KSP residual norm 2.054245e-07
# 116 (restart 0) KSP residual norm 2.053834e-07
# 117 (restart 0) KSP residual norm 2.053818e-07
# 118 (restart 0) KSP residual norm 2.053550e-07
# 119 (restart 0) KSP residual norm 2.051761e-07
# 120 (restart 0) KSP residual norm 2.047939e-07
# 121 (restart 0) KSP residual norm 2.042763e-07
# 122 (restart 0) KSP residual norm 2.035843e-07
# 123 (restart 0) KSP residual norm 2.029712e-07
# 124 (restart 0) KSP residual norm 2.025399e-07
# 125 (restart 0) KSP residual norm 2.024256e-07
# 126 (restart 0) KSP residual norm 2.024195e-07
# 127 (restart 0) KSP residual norm 2.022532e-07
# 128 (restart 0) KSP residual norm 2.018170e-07
# 129 (restart 0) KSP residual norm 2.011405e-07
# 130 (restart 0) KSP residual norm 2.004663e-07
# 131 (restart 0) KSP residual norm 1.998973e-07
# 132 (restart 0) KSP residual norm 1.994333e-07
# 133 (restart 0) KSP residual norm 1.991883e-07
# 134 (restart 0) KSP residual norm 1.991218e-07
# 135 (restart 0) KSP residual norm 1.991180e-07
# 136 (restart 0) KSP residual norm 1.990961e-07
# 137 (restart 0) KSP residual norm 1.989689e-07
# 138 (restart 0) KSP residual norm 1.987455e-07
# 139 (restart 0) KSP residual norm 1.984476e-07
# 140 (restart 0) KSP residual norm 1.980699e-07
# 141 (restart 0) KSP residual norm 1.977619e-07
# 142 (restart 0) KSP residual norm 1.974680e-07
# 143 (restart 0) KSP residual norm 1.972634e-07
# 144 (restart 0) KSP residual norm 1.971807e-07
# 145 (restart 0) KSP residual norm 1.971774e-07
# 146 (restart 0) KSP residual norm 1.971393e-07
# 147 (restart 0) KSP residual norm 1.969827e-07
# 148 (restart 0) KSP residual norm 1.966341e-07
# 149 (restart 0) KSP residual norm 1.961627e-07
# 150 (restart 0) KSP residual norm 1.957222e-07
# 151 (restart 0) KSP residual norm 1.953072e-07
# 152 (restart 0) KSP residual norm 1.950352e-07
# 153 (restart 0) KSP residual norm 1.947988e-07
# 154 (restart 0) KSP residual norm 1.947194e-07
# 155 (restart 0) KSP residual norm 1.946951e-07
# 156 (restart 0) KSP residual norm 1.946701e-07
# 157 (restart 0) KSP residual norm 1.944467e-07
# 158 (restart 0) KSP residual norm 1.940920e-07
# 159 (restart 0) KSP residual norm 1.935123e-07
# 160 (restart 0) KSP residual norm 1.927581e-07
# 161 (restart 0) KSP residual norm 1.921498e-07
# 162 (restart 0) KSP residual norm 1.916694e-07
# 163 (restart 0) KSP residual norm 1.913740e-07
# 164 (restart 0) KSP residual norm 1.913129e-07
# 165 (restart 0) KSP residual norm 1.913109e-07
# 166 (restart 0) KSP residual norm 1.912457e-07
# 167 (restart 0) KSP residual norm 1.909872e-07
# 168 (restart 0) KSP residual norm 1.906023e-07
# 169 (restart 0) KSP residual norm 1.901483e-07
# 170 (restart 0) KSP residual norm 1.897637e-07
# 171 (restart 0) KSP residual norm 1.895654e-07
# 172 (restart 0) KSP residual norm 1.894819e-07
# 173 (restart 0) KSP residual norm 1.894449e-07
# 174 (restart 0) KSP residual norm 1.894364e-07
# 175 (restart 0) KSP residual norm 1.894341e-07
# 176 (restart 0) KSP residual norm 1.894213e-07
# 177 (restart 0) KSP residual norm 1.893219e-07
# 178 (restart 0) KSP residual norm 1.890857e-07
# 179 (restart 0) KSP residual norm 1.886912e-07
# 180 (restart 0) KSP residual norm 1.882517e-07
# 181 (restart 0) KSP residual norm 1.879347e-07
# 182 (restart 0) KSP residual norm 1.877965e-07
# 183 (restart 0) KSP residual norm 1.877879e-07
# 184 (restart 0) KSP residual norm 1.877728e-07
# 185 (restart 0) KSP residual norm 1.876627e-07
# 186 (restart 0) KSP residual norm 1.874062e-07
# 187 (restart 0) KSP residual norm 1.869862e-07
# 188 (restart 0) KSP residual norm 1.864734e-07
# 189 (restart 0) KSP residual norm 1.859978e-07
# 190 (restart 0) KSP residual norm 1.856996e-07
# 191 (restart 0) KSP residual norm 1.855351e-07
# 192 (restart 0) KSP residual norm 1.855152e-07
# 193 (restart 0) KSP residual norm 1.855060e-07
# 194 (restart 0) KSP residual norm 1.854259e-07
# 195 (restart 0) KSP residual norm 1.852151e-07
# 196 (restart 0) KSP residual norm 1.849240e-07
# 197 (restart 0) KSP residual norm 1.845708e-07
# 198 (restart 0) KSP residual norm 1.841116e-07
# 199 (restart 0) KSP residual norm 1.837653e-07
# 200 (restart 0) KSP residual norm 1.835662e-07
# 201 (restart 0) KSP residual norm 1.834710e-07
# 202 (restart 0) KSP residual norm 1.834529e-07
# 203 (restart 0) KSP residual norm 1.834452e-07
# 204 (restart 0) KSP residual norm 1.833532e-07
# 205 (restart 0) KSP residual norm 1.832273e-07
# 206 (restart 0) KSP residual norm 1.830436e-07
# 207 (restart 0) KSP residual norm 1.827892e-07
# 208 (restart 0) KSP residual norm 1.824805e-07
# 209 (restart 0) KSP residual norm 1.822867e-07
# 210 (restart 0) KSP residual norm 1.822071e-07
# 211 (restart 0) KSP residual norm 1.821742e-07
# 212 (restart 0) KSP residual norm 1.821653e-07
# 213 (restart 0) KSP residual norm 1.821651e-07
# 214 (restart 0) KSP residual norm 1.821592e-07
# 215 (restart 0) KSP residual norm 1.821215e-07
# 216 (restart 0) KSP residual norm 1.820040e-07
# 217 (restart 0) KSP residual norm 1.817666e-07
# 218 (restart 0) KSP residual norm 1.814599e-07
# 219 (restart 0) KSP residual norm 1.812198e-07
# 220 (restart 0) KSP residual norm 1.810889e-07
# 221 (restart 0) KSP residual norm 1.810471e-07
# 222 (restart 0) KSP residual norm 1.810460e-07
# 223 (restart 0) KSP residual norm 1.810317e-07
# 224 (restart 0) KSP residual norm 1.809867e-07
# 225 (restart 0) KSP residual norm 1.808926e-07
# 226 (restart 0) KSP residual norm 1.807753e-07
# 227 (restart 0) KSP residual norm 1.806687e-07
# 228 (restart 0) KSP residual norm 1.806092e-07
# 229 (restart 0) KSP residual norm 1.805360e-07
# 230 (restart 0) KSP residual norm 1.804793e-07
# 231 (restart 0) KSP residual norm 1.804088e-07
# 232 (restart 0) KSP residual norm 1.803646e-07
# 233 (restart 0) KSP residual norm 1.803307e-07
# 234 (restart 0) KSP residual norm 1.803274e-07
# 235 (restart 0) KSP residual norm 1.803178e-07
# 236 (restart 0) KSP residual norm 1.802698e-07
# 237 (restart 0) KSP residual norm 1.801824e-07
# 238 (restart 0) KSP residual norm 1.800314e-07
# 239 (restart 0) KSP residual norm 1.798990e-07
# 240 (restart 0) KSP residual norm 1.797904e-07
# 241 (restart 0) KSP residual norm 1.796823e-07
# 242 (restart 0) KSP residual norm 1.796115e-07
# 243 (restart 0) KSP residual norm 1.795596e-07
# 244 (restart 0) KSP residual norm 1.795470e-07
# 245 (restart 0) KSP residual norm 1.795459e-07
# 246 (restart 0) KSP residual norm 1.795043e-07
# 247 (restart 0) KSP residual norm 1.793882e-07
# 248 (restart 0) KSP residual norm 1.792074e-07
# 249 (restart 0) KSP residual norm 1.790346e-07
# 250 (restart 0) KSP residual norm 1.789191e-07
# 251 (restart 0) KSP residual norm 1.788753e-07
# 252 (restart 0) KSP residual norm 1.788389e-07
# 253 (restart 0) KSP residual norm 1.788253e-07
# 254 (restart 0) KSP residual norm 1.788234e-07
# 255 (restart 0) KSP residual norm 1.788234e-07
# 256 (restart 0) KSP residual norm 1.788188e-07
# 257 (restart 0) KSP residual norm 1.788113e-07
# 258 (restart 0) KSP residual norm 1.787859e-07
# 259 (restart 0) KSP residual norm 1.787524e-07
# 260 (restart 0) KSP residual norm 1.786987e-07
# 261 (restart 0) KSP residual norm 1.786269e-07
# 262 (restart 0) KSP residual norm 1.785607e-07
# 263 (restart 0) KSP residual norm 1.784877e-07
# 264 (restart 0) KSP residual norm 1.784358e-07
# 265 (restart 0) KSP residual norm 1.783893e-07
# 266 (restart 0) KSP residual norm 1.783624e-07
# 267 (restart 0) KSP residual norm 1.783541e-07
# 268 (restart 0) KSP residual norm 1.783539e-07
# 269 (restart 0) KSP residual norm 1.783465e-07
# 270 (restart 0) KSP residual norm 1.782674e-07
# 271 (restart 0) KSP residual norm 1.781085e-07
# 272 (restart 0) KSP residual norm 1.779389e-07
# 273 (restart 0) KSP residual norm 1.777719e-07
# 274 (restart 0) KSP residual norm 1.776147e-07
# 275 (restart 0) KSP residual norm 1.775211e-07
# 276 (restart 0) KSP residual norm 1.774654e-07
# 277 (restart 0) KSP residual norm 1.774605e-07
# 278 (restart 0) KSP residual norm 1.774551e-07
# 279 (restart 0) KSP residual norm 1.774081e-07
# 280 (restart 0) KSP residual norm 1.773027e-07
# 281 (restart 0) KSP residual norm 1.771600e-07
# 282 (restart 0) KSP residual norm 1.770159e-07
# 283 (restart 0) KSP residual norm 1.768882e-07
# 284 (restart 0) KSP residual norm 1.767459e-07
# 285 (restart 0) KSP residual norm 1.766452e-07
# 286 (restart 0) KSP residual norm 1.765990e-07
# 287 (restart 0) KSP residual norm 1.765866e-07
# 288 (restart 0) KSP residual norm 1.765848e-07
# 289 (restart 0) KSP residual norm 1.765726e-07
# 290 (restart 0) KSP residual norm 1.765374e-07
# 291 (restart 0) KSP residual norm 1.764996e-07
# 292 (restart 0) KSP residual norm 1.764390e-07
# 293 (restart 0) KSP residual norm 1.763704e-07
# 294 (restart 0) KSP residual norm 1.763210e-07
# 295 (restart 0) KSP residual norm 1.762602e-07
# 296 (restart 0) KSP residual norm 1.762158e-07
# 297 (restart 0) KSP residual norm 1.761814e-07
# 298 (restart 0) KSP residual norm 1.761627e-07
# 299 (restart 0) KSP residual norm 1.761574e-07
# 300 (restart 1) KSP residual norm 1.761526e-07
# GMRES solver did NOT converge in 300 iterations (avg. reduction factor: 9.950e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.211e-01 (norm(b) = 7.967e-07)!
#
#   Residual norms for GMRES solve
#   0 (restart 0) KSP residual norm 8.255077e-07
#   1 (restart 0) KSP residual norm 5.733622e-07
#   2 (restart 0) KSP residual norm 5.043359e-07
#   3 (restart 0) KSP residual norm 4.591279e-07
#   4 (restart 0) KSP residual norm 4.419862e-07
#   5 (restart 0) KSP residual norm 4.153300e-07
#   6 (restart 0) KSP residual norm 3.938198e-07
#   7 (restart 0) KSP residual norm 3.724992e-07
#   8 (restart 0) KSP residual norm 3.555168e-07
#   9 (restart 0) KSP residual norm 3.385776e-07
#  10 (restart 0) KSP residual norm 3.283316e-07
#  11 (restart 0) KSP residual norm 3.221341e-07
#  12 (restart 0) KSP residual norm 3.197500e-07
#  13 (restart 0) KSP residual norm 3.196139e-07
#  14 (restart 0) KSP residual norm 3.183177e-07
#  15 (restart 0) KSP residual norm 3.149350e-07
#  16 (restart 0) KSP residual norm 3.109118e-07
#  17 (restart 0) KSP residual norm 3.083346e-07
#  18 (restart 0) KSP residual norm 3.066110e-07
#  19 (restart 0) KSP residual norm 3.065051e-07
#  20 (restart 0) KSP residual norm 3.058590e-07
#  21 (restart 0) KSP residual norm 3.035134e-07
#  22 (restart 0) KSP residual norm 3.008903e-07
#  23 (restart 0) KSP residual norm 2.987175e-07
#  24 (restart 0) KSP residual norm 2.979910e-07
#  25 (restart 0) KSP residual norm 2.976719e-07
#  26 (restart 0) KSP residual norm 2.976279e-07
#  27 (restart 0) KSP residual norm 2.971689e-07
#  28 (restart 0) KSP residual norm 2.959972e-07
#  29 (restart 0) KSP residual norm 2.945689e-07
#  30 (restart 0) KSP residual norm 2.929739e-07
#  31 (restart 0) KSP residual norm 2.919240e-07
#  32 (restart 0) KSP residual norm 2.913695e-07
#  33 (restart 0) KSP residual norm 2.912911e-07
#  34 (restart 0) KSP residual norm 2.912617e-07
#  35 (restart 0) KSP residual norm 2.908418e-07
#  36 (restart 0) KSP residual norm 2.896583e-07
#  37 (restart 0) KSP residual norm 2.873417e-07
#  38 (restart 0) KSP residual norm 2.851002e-07
#  39 (restart 0) KSP residual norm 2.836164e-07
#  40 (restart 0) KSP residual norm 2.828971e-07
#  41 (restart 0) KSP residual norm 2.828048e-07
#  42 (restart 0) KSP residual norm 2.828012e-07
#  43 (restart 0) KSP residual norm 2.823770e-07
#  44 (restart 0) KSP residual norm 2.814240e-07
#  45 (restart 0) KSP residual norm 2.805126e-07
#  46 (restart 0) KSP residual norm 2.794913e-07
#  47 (restart 0) KSP residual norm 2.790358e-07
#  48 (restart 0) KSP residual norm 2.788302e-07
#  49 (restart 0) KSP residual norm 2.788256e-07
#  50 (restart 0) KSP residual norm 2.787128e-07
#  51 (restart 0) KSP residual norm 2.781084e-07
#  52 (restart 0) KSP residual norm 2.773876e-07
#  53 (restart 0) KSP residual norm 2.763396e-07
#  54 (restart 0) KSP residual norm 2.750646e-07
#  55 (restart 0) KSP residual norm 2.739218e-07
#  56 (restart 0) KSP residual norm 2.730301e-07
#  57 (restart 0) KSP residual norm 2.727308e-07
#  58 (restart 0) KSP residual norm 2.726432e-07
#  59 (restart 0) KSP residual norm 2.726312e-07
#  60 (restart 0) KSP residual norm 2.724002e-07
#  61 (restart 0) KSP residual norm 2.716945e-07
#  62 (restart 0) KSP residual norm 2.704961e-07
#  63 (restart 0) KSP residual norm 2.692434e-07
#  64 (restart 0) KSP residual norm 2.678942e-07
#  65 (restart 0) KSP residual norm 2.667906e-07
#  66 (restart 0) KSP residual norm 2.662143e-07
#  67 (restart 0) KSP residual norm 2.660591e-07
#  68 (restart 0) KSP residual norm 2.660228e-07
#  69 (restart 0) KSP residual norm 2.659661e-07
#  70 (restart 0) KSP residual norm 2.656513e-07
#  71 (restart 0) KSP residual norm 2.648372e-07
#  72 (restart 0) KSP residual norm 2.639336e-07
#  73 (restart 0) KSP residual norm 2.632606e-07
#  74 (restart 0) KSP residual norm 2.629232e-07
#  75 (restart 0) KSP residual norm 2.628369e-07
#  76 (restart 0) KSP residual norm 2.628313e-07
#  77 (restart 0) KSP residual norm 2.626857e-07
#  78 (restart 0) KSP residual norm 2.623470e-07
#  79 (restart 0) KSP residual norm 2.618942e-07
#  80 (restart 0) KSP residual norm 2.614539e-07
#  81 (restart 0) KSP residual norm 2.610585e-07
#  82 (restart 0) KSP residual norm 2.607861e-07
#  83 (restart 0) KSP residual norm 2.606037e-07
#  84 (restart 0) KSP residual norm 2.604812e-07
#  85 (restart 0) KSP residual norm 2.604677e-07
#  86 (restart 0) KSP residual norm 2.604607e-07
#  87 (restart 0) KSP residual norm 2.604140e-07
#  88 (restart 0) KSP residual norm 2.601741e-07
#  89 (restart 0) KSP residual norm 2.599261e-07
#  90 (restart 0) KSP residual norm 2.595386e-07
#  91 (restart 0) KSP residual norm 2.591327e-07
#  92 (restart 0) KSP residual norm 2.586823e-07
#  93 (restart 0) KSP residual norm 2.583371e-07
#  94 (restart 0) KSP residual norm 2.581724e-07
#  95 (restart 0) KSP residual norm 2.581560e-07
#  96 (restart 0) KSP residual norm 2.581379e-07
#  97 (restart 0) KSP residual norm 2.580391e-07
#  98 (restart 0) KSP residual norm 2.577957e-07
#  99 (restart 0) KSP residual norm 2.574093e-07
# 100 (restart 0) KSP residual norm 2.567931e-07
# 101 (restart 0) KSP residual norm 2.561019e-07
# 102 (restart 0) KSP residual norm 2.556380e-07
# 103 (restart 0) KSP residual norm 2.551526e-07
# 104 (restart 0) KSP residual norm 2.548983e-07
# 105 (restart 0) KSP residual norm 2.548740e-07
# 106 (restart 0) KSP residual norm 2.548527e-07
# 107 (restart 0) KSP residual norm 2.546467e-07
# ...
#  79 (restart 0) KSP residual norm 1.800224e-07
#  80 (restart 0) KSP residual norm 1.798385e-07
#  81 (restart 0) KSP residual norm 1.795446e-07
#  82 (restart 0) KSP residual norm 1.791872e-07
#  83 (restart 0) KSP residual norm 1.788370e-07
#  84 (restart 0) KSP residual norm 1.785756e-07
#  85 (restart 0) KSP residual norm 1.783816e-07
#  86 (restart 0) KSP residual norm 1.782714e-07
#  87 (restart 0) KSP residual norm 1.782432e-07
#  88 (restart 0) KSP residual norm 1.782359e-07
#  89 (restart 0) KSP residual norm 1.781651e-07
#  90 (restart 0) KSP residual norm 1.779541e-07
#  91 (restart 0) KSP residual norm 1.776209e-07
#  92 (restart 0) KSP residual norm 1.771649e-07
#  93 (restart 0) KSP residual norm 1.766703e-07
#  94 (restart 0) KSP residual norm 1.762569e-07
#  95 (restart 0) KSP residual norm 1.759488e-07
#  96 (restart 0) KSP residual norm 1.757632e-07
#  97 (restart 0) KSP residual norm 1.757191e-07
#  98 (restart 0) KSP residual norm 1.757148e-07
#  99 (restart 0) KSP residual norm 1.756993e-07
# 100 (restart 0) KSP residual norm 1.755460e-07
# 101 (restart 0) KSP residual norm 1.752236e-07
# 102 (restart 0) KSP residual norm 1.747967e-07
# 103 (restart 0) KSP residual norm 1.741779e-07
# 104 (restart 0) KSP residual norm 1.736295e-07
# 105 (restart 0) KSP residual norm 1.732380e-07
# 106 (restart 0) KSP residual norm 1.730990e-07
# 107 (restart 0) KSP residual norm 1.730744e-07
# 108 (restart 0) KSP residual norm 1.730650e-07
# 109 (restart 0) KSP residual norm 1.729478e-07
# 110 (restart 0) KSP residual norm 1.727046e-07
# 111 (restart 0) KSP residual norm 1.723732e-07
# 112 (restart 0) KSP residual norm 1.720959e-07
# 113 (restart 0) KSP residual norm 1.718304e-07
# 114 (restart 0) KSP residual norm 1.716576e-07
# 115 (restart 0) KSP residual norm 1.715349e-07
# 116 (restart 0) KSP residual norm 1.714763e-07
# 117 (restart 0) KSP residual norm 1.714631e-07
# 118 (restart 0) KSP residual norm 1.714515e-07
# 119 (restart 0) KSP residual norm 1.713315e-07
# 120 (restart 0) KSP residual norm 1.710960e-07
# 121 (restart 0) KSP residual norm 1.708111e-07
# 122 (restart 0) KSP residual norm 1.705511e-07
# 123 (restart 0) KSP residual norm 1.703472e-07
# 124 (restart 0) KSP residual norm 1.702261e-07
# 125 (restart 0) KSP residual norm 1.701921e-07
# 126 (restart 0) KSP residual norm 1.701920e-07
# 127 (restart 0) KSP residual norm 1.701813e-07
# 128 (restart 0) KSP residual norm 1.701369e-07
# 129 (restart 0) KSP residual norm 1.700318e-07
# 130 (restart 0) KSP residual norm 1.698273e-07
# 131 (restart 0) KSP residual norm 1.695397e-07
# 132 (restart 0) KSP residual norm 1.691724e-07
# 133 (restart 0) KSP residual norm 1.688418e-07
# 134 (restart 0) KSP residual norm 1.686428e-07
# 135 (restart 0) KSP residual norm 1.685626e-07
# 136 (restart 0) KSP residual norm 1.685427e-07
# 137 (restart 0) KSP residual norm 1.685378e-07
# 138 (restart 0) KSP residual norm 1.684817e-07
# 139 (restart 0) KSP residual norm 1.683587e-07
# 140 (restart 0) KSP residual norm 1.681421e-07
# 141 (restart 0) KSP residual norm 1.678754e-07
# 142 (restart 0) KSP residual norm 1.676656e-07
# 143 (restart 0) KSP residual norm 1.675042e-07
# 144 (restart 0) KSP residual norm 1.674122e-07
# 145 (restart 0) KSP residual norm 1.673803e-07
# 146 (restart 0) KSP residual norm 1.673772e-07
# 147 (restart 0) KSP residual norm 1.673735e-07
# 148 (restart 0) KSP residual norm 1.673494e-07
# 149 (restart 0) KSP residual norm 1.672780e-07
# 150 (restart 0) KSP residual norm 1.671224e-07
# 151 (restart 0) KSP residual norm 1.669140e-07
# 152 (restart 0) KSP residual norm 1.666594e-07
# 153 (restart 0) KSP residual norm 1.663411e-07
# 154 (restart 0) KSP residual norm 1.661330e-07
# 155 (restart 0) KSP residual norm 1.660321e-07
# 156 (restart 0) KSP residual norm 1.660160e-07
# 157 (restart 0) KSP residual norm 1.660080e-07
# 158 (restart 0) KSP residual norm 1.659608e-07
# 159 (restart 0) KSP residual norm 1.658286e-07
# 160 (restart 0) KSP residual norm 1.656187e-07
# 161 (restart 0) KSP residual norm 1.653598e-07
# 162 (restart 0) KSP residual norm 1.651520e-07
# 163 (restart 0) KSP residual norm 1.649266e-07
# 164 (restart 0) KSP residual norm 1.647903e-07
# 165 (restart 0) KSP residual norm 1.647691e-07
# 166 (restart 0) KSP residual norm 1.647673e-07
# 167 (restart 0) KSP residual norm 1.647298e-07
# 168 (restart 0) KSP residual norm 1.646270e-07
# 169 (restart 0) KSP residual norm 1.644539e-07
# 170 (restart 0) KSP residual norm 1.642547e-07
# 171 (restart 0) KSP residual norm 1.641188e-07
# 172 (restart 0) KSP residual norm 1.639976e-07
# 173 (restart 0) KSP residual norm 1.639233e-07
# 174 (restart 0) KSP residual norm 1.638637e-07
# 175 (restart 0) KSP residual norm 1.638202e-07
# 176 (restart 0) KSP residual norm 1.638115e-07
# 177 (restart 0) KSP residual norm 1.638009e-07
# 178 (restart 0) KSP residual norm 1.637515e-07
# 179 (restart 0) KSP residual norm 1.636553e-07
# 180 (restart 0) KSP residual norm 1.634918e-07
# 181 (restart 0) KSP residual norm 1.632734e-07
# 182 (restart 0) KSP residual norm 1.630815e-07
# 183 (restart 0) KSP residual norm 1.629636e-07
# 184 (restart 0) KSP residual norm 1.628947e-07
# 185 (restart 0) KSP residual norm 1.628727e-07
# 186 (restart 0) KSP residual norm 1.628650e-07
# 187 (restart 0) KSP residual norm 1.628059e-07
# 188 (restart 0) KSP residual norm 1.626516e-07
# 189 (restart 0) KSP residual norm 1.624009e-07
# 190 (restart 0) KSP residual norm 1.620651e-07
# 191 (restart 0) KSP residual norm 1.617357e-07
# 192 (restart 0) KSP residual norm 1.615045e-07
# 193 (restart 0) KSP residual norm 1.614281e-07
# 194 (restart 0) KSP residual norm 1.614166e-07
# 195 (restart 0) KSP residual norm 1.614102e-07
# 196 (restart 0) KSP residual norm 1.613450e-07
# 197 (restart 0) KSP residual norm 1.612061e-07
# 198 (restart 0) KSP residual norm 1.610403e-07
# 199 (restart 0) KSP residual norm 1.608690e-07
# 200 (restart 0) KSP residual norm 1.607339e-07
# 201 (restart 0) KSP residual norm 1.606043e-07
# 202 (restart 0) KSP residual norm 1.604947e-07
# 203 (restart 0) KSP residual norm 1.604318e-07
# 204 (restart 0) KSP residual norm 1.604219e-07
# 205 (restart 0) KSP residual norm 1.604147e-07
# 206 (restart 0) KSP residual norm 1.603778e-07
# 207 (restart 0) KSP residual norm 1.602824e-07
# 208 (restart 0) KSP residual norm 1.601703e-07
# 209 (restart 0) KSP residual norm 1.600364e-07
# 210 (restart 0) KSP residual norm 1.599341e-07
# 211 (restart 0) KSP residual norm 1.598529e-07
# 212 (restart 0) KSP residual norm 1.597799e-07
# 213 (restart 0) KSP residual norm 1.597253e-07
# 214 (restart 0) KSP residual norm 1.597032e-07
# 215 (restart 0) KSP residual norm 1.597015e-07
# 216 (restart 0) KSP residual norm 1.596856e-07
# 217 (restart 0) KSP residual norm 1.595785e-07
# 218 (restart 0) KSP residual norm 1.593778e-07
# 219 (restart 0) KSP residual norm 1.591975e-07
# 220 (restart 0) KSP residual norm 1.590550e-07
# 221 (restart 0) KSP residual norm 1.589377e-07
# 222 (restart 0) KSP residual norm 1.588571e-07
# 223 (restart 0) KSP residual norm 1.588168e-07
# 224 (restart 0) KSP residual norm 1.587964e-07
# 225 (restart 0) KSP residual norm 1.587890e-07
# 226 (restart 0) KSP residual norm 1.587773e-07
# 227 (restart 0) KSP residual norm 1.587463e-07
# 228 (restart 0) KSP residual norm 1.586969e-07
# 229 (restart 0) KSP residual norm 1.585572e-07
# 230 (restart 0) KSP residual norm 1.583811e-07
# 231 (restart 0) KSP residual norm 1.582286e-07
# 232 (restart 0) KSP residual norm 1.581068e-07
# 233 (restart 0) KSP residual norm 1.579581e-07
# 234 (restart 0) KSP residual norm 1.578968e-07
# 235 (restart 0) KSP residual norm 1.578871e-07
# 236 (restart 0) KSP residual norm 1.578815e-07
# 237 (restart 0) KSP residual norm 1.578696e-07
# 238 (restart 0) KSP residual norm 1.578206e-07
# 239 (restart 0) KSP residual norm 1.577433e-07
# 240 (restart 0) KSP residual norm 1.576311e-07
# 241 (restart 0) KSP residual norm 1.575272e-07
# 242 (restart 0) KSP residual norm 1.574374e-07
# 243 (restart 0) KSP residual norm 1.573507e-07
# 244 (restart 0) KSP residual norm 1.573034e-07
# 245 (restart 0) KSP residual norm 1.572720e-07
# 246 (restart 0) KSP residual norm 1.572697e-07
# 247 (restart 0) KSP residual norm 1.572638e-07
# 248 (restart 0) KSP residual norm 1.572139e-07
# 249 (restart 0) KSP residual norm 1.571285e-07
# 250 (restart 0) KSP residual norm 1.570282e-07
# 251 (restart 0) KSP residual norm 1.568991e-07
# 252 (restart 0) KSP residual norm 1.567684e-07
# 253 (restart 0) KSP residual norm 1.566470e-07
# 254 (restart 0) KSP residual norm 1.565711e-07
# 255 (restart 0) KSP residual norm 1.565211e-07
# 256 (restart 0) KSP residual norm 1.565092e-07
# 257 (restart 0) KSP residual norm 1.565083e-07
# 258 (restart 0) KSP residual norm 1.564905e-07
# 259 (restart 0) KSP residual norm 1.564435e-07
# 260 (restart 0) KSP residual norm 1.563470e-07
# 261 (restart 0) KSP residual norm 1.562144e-07
# 262 (restart 0) KSP residual norm 1.560604e-07
# 263 (restart 0) KSP residual norm 1.558918e-07
# 264 (restart 0) KSP residual norm 1.557732e-07
# 265 (restart 0) KSP residual norm 1.557121e-07
# 266 (restart 0) KSP residual norm 1.556955e-07
# 267 (restart 0) KSP residual norm 1.556948e-07
# 268 (restart 0) KSP residual norm 1.556798e-07
# 269 (restart 0) KSP residual norm 1.556654e-07
# 270 (restart 0) KSP residual norm 1.556229e-07
# 271 (restart 0) KSP residual norm 1.555553e-07
# 272 (restart 0) KSP residual norm 1.554778e-07
# 273 (restart 0) KSP residual norm 1.553807e-07
# 274 (restart 0) KSP residual norm 1.553227e-07
# 275 (restart 0) KSP residual norm 1.552814e-07
# 276 (restart 0) KSP residual norm 1.552578e-07
# 277 (restart 0) KSP residual norm 1.552446e-07
# 278 (restart 0) KSP residual norm 1.552433e-07
# 279 (restart 0) KSP residual norm 1.552425e-07
# 280 (restart 0) KSP residual norm 1.552411e-07
# 281 (restart 0) KSP residual norm 1.552338e-07
# 282 (restart 0) KSP residual norm 1.552166e-07
# 283 (restart 0) KSP residual norm 1.551746e-07
# 284 (restart 0) KSP residual norm 1.551152e-07
# 285 (restart 0) KSP residual norm 1.550273e-07
# 286 (restart 0) KSP residual norm 1.549353e-07
# 287 (restart 0) KSP residual norm 1.548820e-07
# 288 (restart 0) KSP residual norm 1.548532e-07
# 289 (restart 0) KSP residual norm 1.548465e-07
# 290 (restart 0) KSP residual norm 1.548450e-07
# 291 (restart 0) KSP residual norm 1.548347e-07
# 292 (restart 0) KSP residual norm 1.547991e-07
# 293 (restart 0) KSP residual norm 1.547460e-07
# 294 (restart 0) KSP residual norm 1.546687e-07
# 295 (restart 0) KSP residual norm 1.545793e-07
# 296 (restart 0) KSP residual norm 1.544775e-07
# 297 (restart 0) KSP residual norm 1.543785e-07
# 298 (restart 0) KSP residual norm 1.543121e-07
# 299 (restart 0) KSP residual norm 1.542934e-07
# 300 (restart 1) KSP residual norm 1.542909e-07
# GMRES solver did NOT converge in 300 iterations (avg. reduction factor: 9.950e-01)
#
# --> Warning!
# Linear solver did not converge, norm(Ax-b)/norm(b) = 2.197e-01 (norm(b) = 7.021e-07)!
#
#   3 EPS nconv=15 first unconverged value (error) 0.00338258+3.62807e-05i (2.04779313e-02)
#
#  Linear eigensolve converged (15 eigenpairs) due to CONVERGED_TOL; iterations 3
#  Total number of linear systems solved: 46
#  Total number of linear solver iterations: 13800
#  Found 15 converged eigenvalues (first = 5.340e+00+4.312e-03i)
#
# Computing solution error estimates and performing postprocessing
#
#      m,        Re{f} (GHz),        Im{f} (GHz),                  Q,      Error (Bkwd.),       Error (Abs.)
#      1,      +7.875377e+00,      +3.179910e-03,      +1.238302e+03,      +2.030093e-08,      +1.032358e-01
#      2,      +8.096933e+00,      -5.552227e-03,      +7.291611e+02,      +2.849053e-08,      +1.448931e-01
#      3,      +8.465983e+00,      -3.888373e-03,      +1.088628e+03,      +8.034549e-08,      +4.086631e-01
#      4,      +8.799874e+00,      -1.022591e-02,      +4.302735e+02,      +8.071629e-08,      +4.105997e-01
#      5,      +9.075208e+00,      -4.494267e-04,      +1.009643e+04,      +7.100706e-08,      +3.612473e-01
#      6,      +9.234440e+00,      -1.879828e-03,      +2.456193e+03,      +8.980172e-08,      +4.568933e-01
#      7,      +9.364398e+00,      -3.471296e-02,      +1.348843e+02,      +7.391082e-08,      +3.760629e-01
#      8,      +9.460056e+00,      -3.596442e-02,      +1.315206e+02,      +7.273348e-08,      +3.700868e-01
#      9,      +9.532120e+00,      +5.520004e-02,      +8.634305e+01,      +7.566768e-08,      +3.850280e-01
#     10,      +9.536686e+00,      -4.224792e-02,      +1.128669e+02,      +7.010672e-08,      +3.567322e-01
#     11,      +9.583658e+00,      +1.361775e-01,      +3.519166e+01,      +7.993952e-08,      +4.067736e-01
#     12,      +9.958838e+00,      -1.470606e-02,      +3.385967e+02,      +1.096780e-07,      +5.581856e-01
#     13,      +1.062336e+01,      +2.894708e-02,      +1.834969e+02,      +1.125348e-07,      +5.728918e-01
#     14,      +1.086666e+01,      -2.864231e-02,      +1.896967e+02,      +9.186076e-08,      +4.676967e-01
#     15,      +1.128759e+01,      -6.105569e-02,      +9.243821e+01,      +1.538233e-07,      +7.833263e-01
#
# Completed 0 iterations of adaptive mesh refinement (AMR):
#  Indicator norm = 8.504e-01, global unknowns = 478711
#  Max. iterations = 0, tol. = 1.000e-02
#
# Estimated peak per-rank memory usage is: Min. 5.1G, Max. 5.1G, Avg. 5.1G, Total 5.1G
# Estimated peak per-node memory usage is: Min. 5.1G, Max. 5.1G, Avg. 5.1G, Total 5.1G
#
# Elapsed Time Report (s)           Min.        Max.        Avg.
# ==============================================================
# Initialization                   2.636       2.636       2.636
#   Mesh Preprocessing            35.951      35.951      35.951
# Operator Construction           22.765      22.765      22.765
# Linear Solve                 25371.878   25371.878   25371.878
#   Setup                         11.031      11.031      11.031
#   Preconditioner              8538.994    8538.994    8538.994
# Eigenvalue Solve                50.238      50.238      50.238
# Div.-Free Projection           984.912     984.912     984.912
# Estimation                      10.855      10.855      10.855
#   Construction                  77.804      77.804      77.804
#   Solve                       3430.630    3430.630    3430.630
# Postprocessing                  45.941      45.941      45.941
# Disk IO                          5.916       5.916       5.916
# --------------------------------------------------------------
# Total                        38590.177   38590.177   38590.177
#
# Peak Memory                   Per-Node       Total   Total HWM
# ==============================================================
# Initialization                    1.2M        1.2M        1.2M
#   Mesh Preprocessing            200.3M      200.3M      201.6M
# Operator Construction           532.0M      532.0M      733.6M
# Linear Solve                     48.4M       48.4M      782.0M
#   Setup                         946.3M      946.3M        1.7G
#   Preconditioner                  2.2G        2.2G        3.9G
# Eigenvalue Solve                 27.6M       27.6M        3.9G
# Div.-Free Projection            188.7M      188.7M        4.1G
# Estimation                      316.1M      316.1M        4.4G
#   Construction                    0.0K        0.0K        4.4G
#   Solve                         314.9M      314.9M        4.7G
# Postprocessing                  296.6M      296.6M        5.0G
# Disk IO                         111.9M      111.9M        5.1G
# --------------------------------------------------------------
# Total                             5.1G        5.1G        5.1G
#
#
#
# ================================================================================
# PALACE STDERR
# ================================================================================
#
#
# ================================================================================
# RUN SUMMARY
# ================================================================================
# Return code : 0
# Runtime     : 643.19 minutes
# RAM used    : 0.73 GB
# RAM free    : 11.62 GB
#
# ================================================================================
# PALACE 10-MODE RUN COMPLETED
# ================================================================================
#
# Output directory:
# /content/drive/MyDrive/Palace6/mode10/palace_complete_4qubit_output
#
# Next:
# Extract the 10 eigenfrequencies and identify qubit/readout/coupler-like modes.

# %%
# !pip install gdspy
# Out:
# Collecting gdspy
#   Downloading gdspy-1.6.13.zip (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.9/157.9 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from gdspy) (1.26.4)
# Building wheels for collected packages: gdspy
#   Building wheel for gdspy (setup.py) ... done
#   Created wheel for gdspy: filename=gdspy-1.6.13-cp312-cp312-linux_x86_64.whl size=595857 sha256=bc69ab86dce8f34e5d21575fa2cb8206d26ea32dbd264ac81404861438d03141
#   Stored in directory: /root/.cache/pip/wheels/02/05/a3/c4b581f8330cedff4d7f4aa7134ae298e88232ccce6a2d4859
# Successfully built gdspy
# Installing collected packages: gdspy
# Successfully installed gdspy-1.6.13

# %%
# ============================================================
# 8-JJ PALACE MESH
#
# Creates:
#
#   Attribute 10 : superconducting PEC metal
#   Attribute 20 : Q1_JJ1
#   Attribute 21 : Q1_JJ2
#   Attribute 22 : Q2_JJ1
#   Attribute 23 : Q2_JJ2
#   Attribute 24 : Q3_JJ1
#   Attribute 25 : Q3_JJ2
#   Attribute 26 : Q4_JJ1
#   Attribute 27 : Q4_JJ2
#
# The JJ attributes are subsequently used by Palace
# LumpedPort elements.
# ============================================================

import os
import gdspy
import gmsh

from shapely.geometry import Polygon
from shapely.ops import unary_union


# ============================================================
# PATHS
# ============================================================

GDS_PATH = "/content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds"

OUTPUT_MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ.msh"
)

TOP_CELL_NAME = "TOP_main_1"


# ============================================================
# GDS METAL
# ============================================================

METAL_LAYER = 1
METAL_DATATYPE = 0


# ============================================================
# CHIP
# ============================================================

CHIP_X = 14.0
CHIP_Y = 14.0

SUBSTRATE_THICKNESS = 0.5
AIR_HEIGHT = 0.5


# ============================================================
# PHYSICAL ATTRIBUTES
# ============================================================

VACUUM_ID = 1
SILICON_ID = 2

PEC_ID = 10

JJ_ATTRIBUTE_START = 20


# ============================================================
# MESH
# ============================================================

BULK_SIZE = 0.300       # 300 um
JJ_SIZE = 0.020         # 20 um

# JJ port dimensions.
#
# The actual JJ element should be small compared with
# the electromagnetic wavelength.
#
# These are NOT the physical oxide dimensions.
# They define the lumped-port integration surface.
JJ_W = 0.010            # 10 um
JJ_H = 0.006            # 6 um


# ============================================================
# EXACT JJ LOCATIONS FROM YOUR GDS
# ============================================================

JJ_LOCATIONS = [

    # Q1
    (-1.1325,  0.0000),
    (-0.8675,  0.0000),

    # Q2
    ( 1.2675,  0.0000),
    ( 1.5325,  0.0000),

    # Q3
    (-1.1325, -2.7000),
    (-0.8675, -2.7000),

    # Q4
    ( 1.2675, -2.7000),
    ( 1.5325, -2.7000)
]


# ============================================================
# HEADER
# ============================================================

print("=" * 80)
print("8-JJ PALACE MESH GENERATOR")
print("=" * 80)

print("\nJJ locations:")

for i, (x, y) in enumerate(JJ_LOCATIONS):

    print(
        f"  JJ{i+1}: "
        f"({x:.4f}, {y:.4f}) mm"
    )


# ============================================================
# READ GDS
# ============================================================

print("\nReading GDS...")

lib = gdspy.GdsLibrary()

lib.read_gds(
    GDS_PATH
)

print(
    f"Loaded {len(lib.cells)} cells."
)

top = lib.cells[
    TOP_CELL_NAME
]

print(
    f"Using top cell: {TOP_CELL_NAME}"
)


# ============================================================
# EXTRACT METAL
# ============================================================

print(
    "\nExtracting Layer 1 / Datatype 0..."
)

polygons_by_spec = (
    top.get_polygons(
        by_spec=True
    )
)

raw_polygons = []


for spec, polygons in polygons_by_spec.items():

    layer, datatype = spec

    if layer != METAL_LAYER:
        continue

    if datatype != METAL_DATATYPE:
        continue

    for polygon in polygons:

        if len(polygon) < 3:
            continue

        pts = []

        for p in polygon:

            point = (
                float(p[0]),
                float(p[1])
            )

            if (
                not pts
                or point != pts[-1]
            ):

                pts.append(point)


        if (
            len(pts) > 1
            and pts[0] == pts[-1]
        ):

            pts.pop()


        if len(set(pts)) >= 3:

            raw_polygons.append(
                pts
            )


print(
    f"Raw metal polygons: "
    f"{len(raw_polygons)}"
)


# ============================================================
# SHAPELY CLEANUP
# ============================================================

print(
    "\nCleaning metal geometry..."
)

shapes = []


for pts in raw_polygons:

    try:

        poly = Polygon(pts)

        if not poly.is_valid:

            poly = poly.buffer(0)

        if poly.is_empty:

            continue

        if poly.area <= 1e-12:

            continue

        shapes.append(poly)

    except Exception:

        pass


print(
    f"Valid polygons: "
    f"{len(shapes)}"
)


# ============================================================
# UNION
# ============================================================

print(
    "\nUniting metal polygons..."
)

metal_union = unary_union(
    shapes
)


if not metal_union.is_valid:

    metal_union = metal_union.buffer(0)


print(
    "Metal union:",
    metal_union.geom_type
)


# ============================================================
# SIMPLIFY
# ============================================================

print(
    "\nSimplifying metal boundary..."
)

metal_union = metal_union.simplify(
    0.003,
    preserve_topology=True
)

if not metal_union.is_valid:

    metal_union = metal_union.buffer(0)


# ============================================================
# GMSH
# ============================================================

print(
    "\nInitializing Gmsh..."
)

gmsh.initialize()

gmsh.option.setNumber(
    "General.Terminal",
    1
)

gmsh.model.add(
    "four_qubit_8JJ"
)


try:

    # ========================================================
    # SUBSTRATE
    # ========================================================

    print(
        "\nCreating silicon..."
    )

    silicon = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        -SUBSTRATE_THICKNESS,

        CHIP_X,
        CHIP_Y,
        SUBSTRATE_THICKNESS
    )


    # ========================================================
    # VACUUM
    # ========================================================

    print(
        "Creating vacuum..."
    )

    vacuum = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        0,

        CHIP_X,
        CHIP_Y,
        AIR_HEIGHT
    )


    # ========================================================
    # METAL POLYGON
    # ========================================================

    if metal_union.geom_type == "Polygon":

        metal_polys = [
            metal_union
        ]

    elif metal_union.geom_type == "MultiPolygon":

        metal_polys = list(
            metal_union.geoms
        )

    else:

        raise RuntimeError(
            "Unexpected metal geometry type."
        )


    print(
        f"\nCreating "
        f"{len(metal_polys)} metal surface(s)..."
    )


    # ========================================================
    # POINT CACHE
    # ========================================================

    point_cache = {}


    def point(x, y, z=0.0):

        key = (
            round(float(x), 9),
            round(float(y), 9),
            round(float(z), 9)
        )

        if key not in point_cache:

            point_cache[key] = (
                gmsh.model.occ.addPoint(
                    key[0],
                    key[1],
                    key[2]
                )
            )

        return point_cache[key]


    # ========================================================
    # CREATE METAL SURFACES
    # ========================================================

    metal_surfaces = []


    for poly in metal_polys:

        coords = list(
            poly.exterior.coords
        )[:-1]


        if len(coords) < 3:

            continue


        pts = [
            point(x, y)
            for x, y in coords
        ]


        lines = []


        for i in range(
            len(pts)
        ):

            p1 = pts[i]

            p2 = pts[
                (i + 1) % len(pts)
            ]

            if p1 != p2:

                lines.append(
                    gmsh.model.occ.addLine(
                        p1,
                        p2
                    )
                )


        if len(lines) < 3:

            continue


        wire = (
            gmsh.model.occ.addWire(
                lines
            )
        )


        holes = []


        for interior in poly.interiors:

            hcoords = list(
                interior.coords
            )[:-1]


            hpts = [
                point(x, y)
                for x, y in hcoords
            ]


            hlines = []


            for i in range(
                len(hpts)
            ):

                hlines.append(
                    gmsh.model.occ.addLine(
                        hpts[i],
                        hpts[
                            (i + 1)
                            % len(hpts)
                        ]
                    )
                )


            if len(hlines) >= 3:

                holes.append(
                    gmsh.model.occ.addWire(
                        hlines
                    )
                )


        surface = (
            gmsh.model.occ.addPlaneSurface(
                [wire] + holes
            )
        )


        metal_surfaces.append(
            surface
        )


    # ========================================================
    # JJ PORT SURFACES
    # ========================================================

    print(
        "\nCreating 8 JJ port surfaces..."
    )


    jj_surfaces = []


    for i, (x, y) in enumerate(
        JJ_LOCATIONS
    ):

        x1 = x - JJ_W / 2
        x2 = x + JJ_W / 2

        y1 = y - JJ_H / 2
        y2 = y + JJ_H / 2


        p1 = point(x1, y1)
        p2 = point(x2, y1)
        p3 = point(x2, y2)
        p4 = point(x1, y2)


        l1 = gmsh.model.occ.addLine(
            p1, p2
        )

        l2 = gmsh.model.occ.addLine(
            p2, p3
        )

        l3 = gmsh.model.occ.addLine(
            p3, p4
        )

        l4 = gmsh.model.occ.addLine(
            p4, p1
        )


        wire = gmsh.model.occ.addWire(
            [l1, l2, l3, l4]
        )


        surf = (
            gmsh.model.occ.addPlaneSurface(
                [wire]
            )
        )


        jj_surfaces.append(
            surf
        )


        print(
            f"  JJ{i+1}: "
            f"surface={surf}"
        )


    # ========================================================
    # SYNCHRONIZE
    # ========================================================

    gmsh.model.occ.synchronize()


    # ========================================================
    # REMOVE DUPLICATES
    # ========================================================

    print(
        "\nRemoving duplicate geometry..."
    )

    gmsh.model.occ.removeAllDuplicates()

    gmsh.model.occ.synchronize()


    # ========================================================
    # FRAGMENT VOLUMES
    # ========================================================

    print(
        "\nFragmenting silicon/vacuum..."
    )


    fragmented, mapping = (
        gmsh.model.occ.fragment(

            [
                (3, silicon),
                (3, vacuum)
            ],

            [
                (2, s)
                for s in metal_surfaces
            ]
        )
    )


    gmsh.model.occ.synchronize()

    gmsh.model.occ.removeAllDuplicates()

    gmsh.model.occ.synchronize()


    # ========================================================
    # FIND VOLUMES
    # ========================================================

    volumes = (
        gmsh.model.getEntities(3)
    )


    silicon_volumes = []
    vacuum_volumes = []


    for dim, tag in volumes:

        com = (
            gmsh.model.occ.getCenterOfMass(
                dim,
                tag
            )
        )


        if com[2] < 0:

            silicon_volumes.append(tag)

        elif com[2] > 0:

            vacuum_volumes.append(tag)


    print(
        "\nVolumes:",
        len(volumes)
    )

    print(
        "Silicon:",
        silicon_volumes
    )

    print(
        "Vacuum:",
        vacuum_volumes
    )


    # ========================================================
    # RECOVER METAL
    # ========================================================

    metal_faces = []


    for dim, tag in (
        gmsh.model.getEntities(2)
    ):

        bbox = (
            gmsh.model.getBoundingBox(
                dim,
                tag
            )
        )


        # Metal lies at z = 0.
        zmin = bbox[2]
        zmax = bbox[5]


        if (
            abs(zmin) < 1e-8
            and abs(zmax) < 1e-8
        ):

            metal_faces.append(
                tag
            )


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nCreating physical groups..."
    )


    gmsh.model.addPhysicalGroup(
        3,
        vacuum_volumes,
        VACUUM_ID
    )

    gmsh.model.setPhysicalName(
        3,
        VACUUM_ID,
        "Vacuum"
    )


    gmsh.model.addPhysicalGroup(
        3,
        silicon_volumes,
        SILICON_ID
    )

    gmsh.model.setPhysicalName(
        3,
        SILICON_ID,
        "Silicon_Substrate"
    )


    # --------------------------------------------------------
    # PEC
    # --------------------------------------------------------

    gmsh.model.addPhysicalGroup(
        2,
        metal_faces,
        PEC_ID
    )

    gmsh.model.setPhysicalName(
        2,
        PEC_ID,
        "Superconducting_Metal"
    )


    # --------------------------------------------------------
    # JJ ATTRIBUTES
    # --------------------------------------------------------

    for i, surf in enumerate(
        jj_surfaces
    ):

        attr = (
            JJ_ATTRIBUTE_START
            + i
        )


        gmsh.model.addPhysicalGroup(
            2,
            [surf],
            attr
        )


        gmsh.model.setPhysicalName(
            2,
            attr,
            f"JJ{i+1}"
        )


        print(
            f"  Attribute {attr}: "
            f"JJ{i+1}"
        )


    # ========================================================
    # MESH
    # ========================================================

    print(
        "\nConfiguring mesh..."
    )


    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMin",
        BULK_SIZE
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMax",
        BULK_SIZE
    )


    # ========================================================
    # JJ REFINEMENT
    # ========================================================

    print(
        "\nApplying local JJ refinement..."
    )


    fields = []


    for i, (x, y) in enumerate(
        JJ_LOCATIONS
    ):

        f = (
            gmsh.model.mesh.field.add(
                "Box"
            )
        )


        gmsh.model.mesh.field.setNumber(
            f,
            "VIn",
            JJ_SIZE
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "VOut",
            BULK_SIZE
        )


        gmsh.model.mesh.field.setNumber(
            f,
            "XMin",
            x - 0.100
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "XMax",
            x + 0.100
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "YMin",
            y - 0.100
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "YMax",
            y + 0.100
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "ZMin",
            -SUBSTRATE_THICKNESS
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "ZMax",
            AIR_HEIGHT
        )


        fields.append(f)


    if fields:

        fmin = (
            gmsh.model.mesh.field.add(
                "Min"
            )
        )


        gmsh.model.mesh.field.setNumbers(
            fmin,
            "FieldsList",
            fields
        )


        gmsh.model.mesh.field.setAsBackgroundMesh(
            fmin
        )


    # ========================================================
    # 3D MESH
    # ========================================================

    print(
        "\nGenerating 3D mesh..."
    )


    gmsh.option.setNumber(
        "Mesh.Algorithm3D",
        1
    )

    gmsh.option.setNumber(
        "Mesh.Optimize",
        0
    )

    gmsh.option.setNumber(
        "Mesh.OptimizeNetgen",
        0
    )


    gmsh.model.mesh.generate(
        3
    )


    # ========================================================
    # CLEAN
    # ========================================================

    gmsh.model.mesh.removeDuplicateNodes()

    gmsh.model.mesh.removeDuplicateElements()


    # ========================================================
    # STATISTICS
    # ========================================================

    nodes, coords, _ = (
        gmsh.model.mesh.getNodes()
    )


    types, tags, conn = (
        gmsh.model.mesh.getElements()
    )


    total = sum(
        len(t)
        for t in tags
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "8-JJ MESH STATISTICS"
    )

    print(
        "=" * 80
    )

    print(
        f"Nodes    : "
        f"{len(nodes):,}"
    )

    print(
        f"Elements : "
        f"{total:,}"
    )


    print(
        "\nPhysical groups:"
    )


    for dim, tag in (
        gmsh.model.getPhysicalGroups()
    ):

        name = (
            gmsh.model.getPhysicalName(
                dim,
                tag
            )
        )

        print(
            f"  Dimension={dim}, "
            f"Attribute={tag}, "
            f"Name={name}"
        )


    # ========================================================
    # WRITE
    # ========================================================

    print(
        "\nWriting MSH 2.2..."
    )


    gmsh.option.setNumber(
        "Mesh.MshFileVersion",
        2.2
    )

    gmsh.option.setNumber(
        "Mesh.Binary",
        0
    )


    gmsh.write(
        OUTPUT_MESH
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "8-JJ PALACE MESH CREATED"
    )

    print(
        "=" * 80
    )

    print(
        "\nMesh:"
    )

    print(
        OUTPUT_MESH
    )


finally:

    gmsh.finalize()

    print(
        "\nGmsh finalized."
    )
# Out:
# ================================================================================
# 8-JJ PALACE MESH GENERATOR
# ================================================================================
#
# JJ locations:
#   JJ1: (-1.1325, 0.0000) mm
#   JJ2: (-0.8675, 0.0000) mm
#   JJ3: (1.2675, 0.0000) mm
#   JJ4: (1.5325, 0.0000) mm
#   JJ5: (-1.1325, -2.7000) mm
#   JJ6: (-0.8675, -2.7000) mm
#   JJ7: (1.2675, -2.7000) mm
#   JJ8: (1.5325, -2.7000) mm
#
# Reading GDS...
# Loaded 19 cells.
# Using top cell: TOP_main_1
#
# Extracting Layer 1 / Datatype 0...
# Raw metal polygons: 2450
#
# Cleaning metal geometry...
# Valid polygons: 2450
#
# Uniting metal polygons...
# Metal union: Polygon
#
# Simplifying metal boundary...
#
# Initializing Gmsh...
#
# Creating silicon...
# Creating vacuum...
#
# Creating 1 metal surface(s)...
#
# Creating 8 JJ port surfaces...
#   JJ1: surface=14
#   JJ2: surface=15
#   JJ3: surface=16
#   JJ4: surface=17
#   JJ5: surface=18
#   JJ6: surface=19
#   JJ7: surface=20
#   JJ8: surface=21
#
# Removing duplicate geometry...
#
# Fragmenting silicon/vacuum...
#
# Volumes: 2
# Silicon: [1]
# Vacuum: [2]
#
# Creating physical groups...
#   Attribute 20: JJ1
#   Attribute 21: JJ2
#   Attribute 22: JJ3
#   Attribute 23: JJ4
#   Attribute 24: JJ5
#   Attribute 25: JJ6
#   Attribute 26: JJ7
#   Attribute 27: JJ8
#
# Configuring mesh...
#
# Applying local JJ refinement...
#
# Generating 3D mesh...
#
# ================================================================================
# 8-JJ MESH STATISTICS
# ================================================================================
# Nodes    : 58,511
# Elements : 414,440
#
# Physical groups:
#   Dimension=2, Attribute=20, Name=JJ1
#   Dimension=2, Attribute=21, Name=JJ2
#   Dimension=2, Attribute=22, Name=JJ3
#   Dimension=2, Attribute=23, Name=JJ4
#   Dimension=2, Attribute=24, Name=JJ5
#   Dimension=2, Attribute=25, Name=JJ6
#   Dimension=2, Attribute=26, Name=JJ7
#   Dimension=2, Attribute=27, Name=JJ8
#   Dimension=3, Attribute=1, Name=Vacuum
#   Dimension=3, Attribute=2, Name=Silicon_Substrate
#
# Writing MSH 2.2...
#
# ================================================================================
# 8-JJ PALACE MESH CREATED
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ.msh
#
# Gmsh finalized.

# %%
# ============================================================
# CHECK 8-JJ MESH PHYSICAL GROUPS
# ============================================================

import gmsh
import os

MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ.msh"
)

print("=" * 80)
print("CHECKING 8-JJ PALACE MESH")
print("=" * 80)

print("\nMesh:")
print(MESH)

if not os.path.exists(MESH):
    raise FileNotFoundError(MESH)

gmsh.initialize()

try:

    gmsh.option.setNumber(
        "General.Terminal",
        1
    )

    gmsh.open(MESH)

    print("\nPhysical groups found:")

    groups = gmsh.model.getPhysicalGroups()

    if not groups:
        print("WARNING: No physical groups found!")

    for dim, tag in groups:

        name = gmsh.model.getPhysicalName(
            dim,
            tag
        )

        entities = gmsh.model.getEntitiesForPhysicalGroup(
            dim,
            tag
        )

        print(
            f"  Dimension={dim:1d}, "
            f"Attribute={tag:2d}, "
            f"Name={name:25s}, "
            f"Entities={len(entities)}"
        )

    print("\nRequired groups:")

    required = {
        1: "Vacuum",
        2: "Silicon_Substrate",
        10: "Superconducting_Metal",
        20: "JJ1",
        21: "JJ2",
        22: "JJ3",
        23: "JJ4",
        24: "JJ5",
        25: "JJ6",
        26: "JJ7",
        27: "JJ8",
    }

    found = {
        tag: name
        for dim, tag in groups
    }

    for tag, expected in required.items():

        if tag in found:

            print(
                f"  PASS  {tag:2d} -> "
                f"{found[tag]}"
            )

        else:

            print(
                f"  FAIL  {tag:2d} -> "
                f"{expected} MISSING"
            )

    # --------------------------------------------------------
    # Check element counts by physical group
    # --------------------------------------------------------

    print(
        "\nPhysical-group element counts:"
    )

    for dim, tag in groups:

        name = gmsh.model.getPhysicalName(
            dim,
            tag
        )

        entities = (
            gmsh.model.getEntitiesForPhysicalGroup(
                dim,
                tag
            )
        )

        total = 0

        for entity_tag in entities:

            types, elem_tags, _ = (
                gmsh.model.mesh.getElements(
                    dim,
                    entity_tag
                )
            )

            for etags in elem_tags:
                total += len(etags)

        print(
            f"  {tag:2d} "
            f"{name:25s} "
            f"{total:,} elements"
        )

finally:

    gmsh.finalize()

print("\nDone.")
# Out:
# ================================================================================
# CHECKING 8-JJ PALACE MESH
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ.msh
#
# Physical groups found:
#   Dimension=2, Attribute=20, Name=JJ1                      , Entities=1
#   Dimension=2, Attribute=21, Name=JJ2                      , Entities=1
#   Dimension=2, Attribute=22, Name=JJ3                      , Entities=1
#   Dimension=2, Attribute=23, Name=JJ4                      , Entities=1
#   Dimension=2, Attribute=24, Name=JJ5                      , Entities=1
#   Dimension=2, Attribute=25, Name=JJ6                      , Entities=1
#   Dimension=2, Attribute=26, Name=JJ7                      , Entities=1
#   Dimension=2, Attribute=27, Name=JJ8                      , Entities=1
#   Dimension=3, Attribute= 1, Name=Vacuum                   , Entities=1
#   Dimension=3, Attribute= 2, Name=Silicon_Substrate        , Entities=1
#
# Required groups:
#   PASS   1 -> Silicon_Substrate
#   PASS   2 -> Silicon_Substrate
#   FAIL  10 -> Superconducting_Metal MISSING
#   PASS  20 -> Silicon_Substrate
#   PASS  21 -> Silicon_Substrate
#   PASS  22 -> Silicon_Substrate
#   PASS  23 -> Silicon_Substrate
#   PASS  24 -> Silicon_Substrate
#   PASS  25 -> Silicon_Substrate
#   PASS  26 -> Silicon_Substrate
#   PASS  27 -> Silicon_Substrate
#
# Physical-group element counts:
#   20 JJ1                       4 elements
#   21 JJ2                       4 elements
#   22 JJ3                       4 elements
#   23 JJ4                       4 elements
#   24 JJ5                       4 elements
#   25 JJ6                       4 elements
#   26 JJ7                       4 elements
#   27 JJ8                       4 elements
#    1 Vacuum                    168,533 elements
#    2 Silicon_Substrate         168,537 elements
#
# Done.

# %%
# function KeepAlive() {
#     console.log("Colab Keep-Alive Triggered");
#     document.querySelector("colab-connect-button")?.shadowRoot.querySelector("#connect")?.click();
# }
# setInterval(KeepAlive, 60000);

# %%
# ============================================================
# ROBUST 8-JJ PALACE MESH
#
# Uses:
#   Layer 1 / Datatype 0  -> superconducting metal
#   Layer 53 / Datatype 0 -> JJ geometry reference
#
# Physical groups:
#
#   1  = Vacuum
#   2  = Silicon_Substrate
#   10 = Superconducting_Metal
#   20 = JJ1
#   21 = JJ2
#   22 = JJ3
#   23 = JJ4
#   24 = JJ5
#   25 = JJ6
#   26 = JJ7
#   27 = JJ8
#
# ============================================================

import os
import gdspy
import gmsh

from shapely.geometry import Polygon
from shapely.ops import unary_union


# ============================================================
# PATHS
# ============================================================

GDS_PATH = "/content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds"

OUTPUT_MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ_v2.msh"
)

TOP_CELL_NAME = "TOP_main_1"


# ============================================================
# GDS LAYERS
# ============================================================

METAL_LAYER = 1
METAL_DATATYPE = 0

JJ_LAYER = 53
JJ_DATATYPE = 0


# ============================================================
# CHIP
# ============================================================

CHIP_X = 14.0
CHIP_Y = 14.0

SUBSTRATE_THICKNESS = 0.5
AIR_HEIGHT = 0.5


# ============================================================
# PHYSICAL ATTRIBUTES
# ============================================================

VACUUM_ID = 1
SILICON_ID = 2
PEC_ID = 10

JJ_START_ID = 20


# ============================================================
# MESH
# ============================================================

BULK_SIZE = 0.300
JJ_SIZE = 0.025

JJ_REFINE_HALF = 0.100


# ============================================================
# JJ LOCATIONS
# ============================================================

JJ_LOCATIONS = [

    (-1.1325,  0.0000),
    (-0.8675,  0.0000),

    ( 1.2675,  0.0000),
    ( 1.5325,  0.0000),

    (-1.1325, -2.7000),
    (-0.8675, -2.7000),

    ( 1.2675, -2.7000),
    ( 1.5325, -2.7000)
]


# ============================================================
# HEADER
# ============================================================

print("=" * 80)
print("ROBUST 8-JJ PALACE MESH V2")
print("=" * 80)


# ============================================================
# READ GDS
# ============================================================

print("\nReading GDS...")

lib = gdspy.GdsLibrary()

lib.read_gds(
    GDS_PATH
)

print(
    f"Loaded {len(lib.cells)} cells."
)


if TOP_CELL_NAME not in lib.cells:

    raise RuntimeError(
        f"Missing top cell: {TOP_CELL_NAME}"
    )


top = lib.cells[
    TOP_CELL_NAME
]

print(
    f"Using top cell: {TOP_CELL_NAME}"
)


# ============================================================
# EXTRACT METAL
# ============================================================

print(
    "\nExtracting superconducting metal..."
)

polygons_by_spec = (
    top.get_polygons(
        by_spec=True
    )
)

metal_polygons = []


for spec, polygons in polygons_by_spec.items():

    layer, datatype = spec

    if layer != METAL_LAYER:
        continue

    if datatype != METAL_DATATYPE:
        continue

    for p in polygons:

        if len(p) < 3:
            continue

        pts = [
            (
                float(x),
                float(y)
            )
            for x, y in p
        ]

        if (
            len(pts) > 1
            and pts[0] == pts[-1]
        ):

            pts.pop()

        if len(set(pts)) >= 3:

            metal_polygons.append(
                Polygon(pts)
            )


print(
    f"Metal polygons: "
    f"{len(metal_polygons)}"
)


# ============================================================
# CLEAN METAL
# ============================================================

clean_metal = []


for poly in metal_polygons:

    try:

        if not poly.is_valid:

            poly = poly.buffer(0)

        if (
            not poly.is_empty
            and poly.area > 1e-12
        ):

            clean_metal.append(
                poly
            )

    except Exception:
        pass


print(
    f"Valid metal polygons: "
    f"{len(clean_metal)}"
)


# ============================================================
# UNION METAL
# ============================================================

print(
    "\nUniting metal..."
)

metal_union = unary_union(
    clean_metal
)

if not metal_union.is_valid:

    metal_union = metal_union.buffer(0)


print(
    "Metal type:",
    metal_union.geom_type
)

print(
    f"Metal area: "
    f"{metal_union.area:.6f} mm^2"
)


# ============================================================
# SIMPLIFY
# ============================================================

metal_union = metal_union.simplify(
    0.003,
    preserve_topology=True
)

if not metal_union.is_valid:

    metal_union = metal_union.buffer(0)


# ============================================================
# EXTRACT ACTUAL JJ GEOMETRY
# ============================================================

print(
    "\nExtracting JJ geometry from "
    f"Layer {JJ_LAYER} / Datatype {JJ_DATATYPE}..."
)

jj_polygons = []


for spec, polygons in polygons_by_spec.items():

    layer, datatype = spec

    if layer != JJ_LAYER:
        continue

    if datatype != JJ_DATATYPE:
        continue

    for p in polygons:

        if len(p) < 3:
            continue

        pts = [
            (
                float(x),
                float(y)
            )
            for x, y in p
        ]

        if (
            len(pts) > 1
            and pts[0] == pts[-1]
        ):

            pts.pop()

        if len(set(pts)) >= 3:

            try:

                poly = Polygon(pts)

                if not poly.is_valid:

                    poly = poly.buffer(0)

                if (
                    not poly.is_empty
                    and poly.area > 1e-12
                ):

                    jj_polygons.append(
                        poly
                    )

            except Exception:
                pass


print(
    f"Layer-53 JJ polygons found: "
    f"{len(jj_polygons)}"
)


# ============================================================
# FIND THE JJ POLYGON NEAREST EACH EXPECTED LOCATION
# ============================================================

print(
    "\nMatching actual JJ polygons "
    "to the eight JJ locations..."
)

matched_jj = []


for i, (x, y) in enumerate(
    JJ_LOCATIONS
):

    target_x = x
    target_y = y


    best = None
    best_distance = float("inf")


    for poly in jj_polygons:

        centroid = poly.centroid

        dx = (
            centroid.x
            - target_x
        )

        dy = (
            centroid.y
            - target_y
        )

        distance = (
            dx * dx
            + dy * dy
        ) ** 0.5


        if distance < best_distance:

            best_distance = distance
            best = poly


    if best is None:

        raise RuntimeError(
            f"Could not find JJ{i+1}"
        )


    # 100 um matching tolerance
    if best_distance > 0.100:

        raise RuntimeError(
            f"JJ{i+1} matched too far away: "
            f"{best_distance:.6f} mm"
        )


    matched_jj.append(
        best
    )


    print(
        f"  JJ{i+1}: "
        f"centroid=("
        f"{best.centroid.x:.6f}, "
        f"{best.centroid.y:.6f}) mm, "
        f"distance={best_distance*1000:.3f} um"
    )


# ============================================================
# INITIALIZE GMSH
# ============================================================

print(
    "\nInitializing Gmsh..."
)

gmsh.initialize()

gmsh.option.setNumber(
    "General.Terminal",
    1
)

gmsh.model.add(
    "four_qubit_8JJ_v2"
)


try:

    # ========================================================
    # SUBSTRATE
    # ========================================================

    print(
        "\nCreating silicon..."
    )

    silicon = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        -SUBSTRATE_THICKNESS,

        CHIP_X,
        CHIP_Y,
        SUBSTRATE_THICKNESS
    )


    # ========================================================
    # VACUUM
    # ========================================================

    print(
        "Creating vacuum..."
    )

    vacuum = gmsh.model.occ.addBox(

        -CHIP_X / 2,
        -CHIP_Y / 2,
        0.0,

        CHIP_X,
        CHIP_Y,
        AIR_HEIGHT
    )


    # ========================================================
    # POINT CACHE
    # ========================================================

    point_cache = {}


    def get_point(
        x,
        y,
        z=0.0
    ):

        key = (
            round(float(x), 9),
            round(float(y), 9),
            round(float(z), 9)
        )

        if key not in point_cache:

            point_cache[key] = (
                gmsh.model.occ.addPoint(
                    key[0],
                    key[1],
                    key[2]
                )
            )

        return point_cache[key]


    # ========================================================
    # POLYGON → SURFACE
    # ========================================================

    def make_surface(poly):

        exterior = list(
            poly.exterior.coords
        )[:-1]


        if len(exterior) < 3:

            return None


        pts = [
            get_point(x, y)
            for x, y in exterior
        ]


        lines = []


        for i in range(
            len(pts)
        ):

            p1 = pts[i]

            p2 = pts[
                (i + 1) % len(pts)
            ]


            if p1 != p2:

                lines.append(
                    gmsh.model.occ.addLine(
                        p1,
                        p2
                    )
                )


        if len(lines) < 3:

            return None


        wire = (
            gmsh.model.occ.addWire(
                lines
            )
        )


        # Holes
        holes = []


        for interior in poly.interiors:

            coords = list(
                interior.coords
            )[:-1]


            if len(coords) < 3:

                continue


            hp = [
                get_point(x, y)
                for x, y in coords
            ]


            hl = []


            for i in range(
                len(hp)
            ):

                hl.append(
                    gmsh.model.occ.addLine(
                        hp[i],
                        hp[
                            (i + 1)
                            % len(hp)
                        ]
                    )
                )


            if len(hl) >= 3:

                holes.append(
                    gmsh.model.occ.addWire(
                        hl
                    )
                )


        return (
            gmsh.model.occ.addPlaneSurface(
                [wire] + holes
            )
        )


    # ========================================================
    # METAL SURFACE
    # ========================================================

    print(
        "\nCreating metal surface..."
    )


    if metal_union.geom_type == "Polygon":

        metal_regions = [
            metal_union
        ]

    else:

        metal_regions = list(
            metal_union.geoms
        )


    metal_surfaces = []


    for poly in metal_regions:

        s = make_surface(
            poly
        )

        if s is not None:

            metal_surfaces.append(
                s
            )


    print(
        f"Metal surfaces: "
        f"{len(metal_surfaces)}"
    )


    # ========================================================
    # JJ SURFACES
    # ========================================================

    print(
        "\nCreating JJ surfaces..."
    )


    jj_surfaces = []


    for i, poly in enumerate(
        matched_jj
    ):

        s = make_surface(
            poly
        )

        if s is None:

            raise RuntimeError(
                f"Failed JJ{i+1}"
            )


        jj_surfaces.append(
            s
        )


        print(
            f"  JJ{i+1}: "
            f"surface={s}"
        )


    # ========================================================
    # SYNCHRONIZE
    # ========================================================

    gmsh.model.occ.synchronize()


    # ========================================================
    # DO NOT FRAGMENT
    #
    # The metal/JJ surfaces are deliberately retained.
    # ========================================================

    print(
        "\nKeeping metal/JJ surfaces "
        "without OCC volume fragmentation..."
    )


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nCreating physical groups..."
    )


    # Vacuum
    gmsh.model.addPhysicalGroup(
        3,
        [vacuum],
        VACUUM_ID
    )

    gmsh.model.setPhysicalName(
        3,
        VACUUM_ID,
        "Vacuum"
    )


    # Silicon
    gmsh.model.addPhysicalGroup(
        3,
        [silicon],
        SILICON_ID
    )

    gmsh.model.setPhysicalName(
        3,
        SILICON_ID,
        "Silicon_Substrate"
    )


    # PEC
    gmsh.model.addPhysicalGroup(
        2,
        metal_surfaces,
        PEC_ID
    )

    gmsh.model.setPhysicalName(
        2,
        PEC_ID,
        "Superconducting_Metal"
    )


    # JJ1 ... JJ8
    for i, surface in enumerate(
        jj_surfaces
    ):

        attr = (
            JJ_START_ID
            + i
        )


        gmsh.model.addPhysicalGroup(
            2,
            [surface],
            attr
        )

        gmsh.model.setPhysicalName(
            2,
            attr,
            f"JJ{i+1}"
        )


    # ========================================================
    # MESH SIZE
    # ========================================================

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMin",
        BULK_SIZE
    )

    gmsh.option.setNumber(
        "Mesh.CharacteristicLengthMax",
        BULK_SIZE
    )


    # ========================================================
    # JJ REFINEMENT
    # ========================================================

    print(
        "\nApplying JJ refinement..."
    )


    fields = []


    for x, y in JJ_LOCATIONS:

        f = (
            gmsh.model.mesh.field.add(
                "Box"
            )
        )


        gmsh.model.mesh.field.setNumber(
            f,
            "VIn",
            JJ_SIZE
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "VOut",
            BULK_SIZE
        )


        gmsh.model.mesh.field.setNumber(
            f,
            "XMin",
            x - JJ_REFINE_HALF
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "XMax",
            x + JJ_REFINE_HALF
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "YMin",
            y - JJ_REFINE_HALF
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "YMax",
            y + JJ_REFINE_HALF
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "ZMin",
            -SUBSTRATE_THICKNESS
        )

        gmsh.model.mesh.field.setNumber(
            f,
            "ZMax",
            AIR_HEIGHT
        )


        fields.append(
            f
        )


    if fields:

        fmin = (
            gmsh.model.mesh.field.add(
                "Min"
            )
        )

        gmsh.model.mesh.field.setNumbers(
            fmin,
            "FieldsList",
            fields
        )

        gmsh.model.mesh.field.setAsBackgroundMesh(
            fmin
        )


    # ========================================================
    # 3D MESH
    # ========================================================

    print(
        "\n" + "=" * 80
    )

    print(
        "GENERATING 3D MESH"
    )

    print(
        "=" * 80
    )


    gmsh.option.setNumber(
        "Mesh.Algorithm3D",
        1
    )


    gmsh.option.setNumber(
        "Mesh.Optimize",
        0
    )


    gmsh.option.setNumber(
        "Mesh.OptimizeNetgen",
        0
    )


    gmsh.model.mesh.generate(
        3
    )


    # ========================================================
    # CLEAN
    # ========================================================

    gmsh.model.mesh.removeDuplicateNodes()

    gmsh.model.mesh.removeDuplicateElements()


    # ========================================================
    # STATISTICS
    # ========================================================

    node_tags, _, _ = (
        gmsh.model.mesh.getNodes()
    )

    types, tags, _ = (
        gmsh.model.mesh.getElements()
    )


    total_elements = sum(
        len(t)
        for t in tags
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "MESH STATISTICS"
    )

    print(
        "=" * 80
    )

    print(
        f"Nodes    : "
        f"{len(node_tags):,}"
    )

    print(
        f"Elements : "
        f"{total_elements:,}"
    )


    # ========================================================
    # PHYSICAL GROUPS
    # ========================================================

    print(
        "\nPhysical groups:"
    )


    for dim, tag in (
        gmsh.model.getPhysicalGroups()
    ):

        name = (
            gmsh.model.getPhysicalName(
                dim,
                tag
            )
        )


        entities = (
            gmsh.model.getEntitiesForPhysicalGroup(
                dim,
                tag
            )
        )


        print(
            f"  Dimension={dim}, "
            f"Attribute={tag}, "
            f"Name={name}, "
            f"Entities={len(entities)}"
        )


    # ========================================================
    # WRITE
    # ========================================================

    print(
        "\nWriting MSH 2.2..."
    )


    gmsh.option.setNumber(
        "Mesh.MshFileVersion",
        2.2
    )

    gmsh.option.setNumber(
        "Mesh.Binary",
        0
    )


    gmsh.write(
        OUTPUT_MESH
    )


    print(
        "\n" + "=" * 80
    )

    print(
        "8-JJ V2 MESH CREATED"
    )

    print(
        "=" * 80
    )

    print(
        "\nMesh:"
    )

    print(
        OUTPUT_MESH
    )


finally:

    gmsh.finalize()

    print(
        "\nGmsh finalized."
    )
# Out:
# ================================================================================
# ROBUST 8-JJ PALACE MESH V2
# ================================================================================
#
# Reading GDS...
# Loaded 19 cells.
# Using top cell: TOP_main_1
#
# Extracting superconducting metal...
# Metal polygons: 2450
# Valid metal polygons: 2450
#
# Uniting metal...
# Metal type: Polygon
# Metal area: 185.750737 mm^2
#
# Extracting JJ geometry from Layer 53 / Datatype 0...
# Layer-53 JJ polygons found: 8
#
# Matching actual JJ polygons to the eight JJ locations...
#   JJ1: centroid=(-1.132500, 0.000000) mm, distance=0.000 um
#   JJ2: centroid=(-0.867500, -0.000000) mm, distance=0.000 um
#   JJ3: centroid=(1.267500, 0.000000) mm, distance=0.000 um
#   JJ4: centroid=(1.532500, -0.000000) mm, distance=0.000 um
#   JJ5: centroid=(-1.132500, -2.700000) mm, distance=0.000 um
#   JJ6: centroid=(-0.867500, -2.700000) mm, distance=0.000 um
#   JJ7: centroid=(1.267500, -2.700000) mm, distance=0.000 um
#   JJ8: centroid=(1.532500, -2.700000) mm, distance=0.000 um
#
# Initializing Gmsh...
#
# Creating silicon...
# Creating vacuum...
#
# Creating metal surface...
# Metal surfaces: 1
#
# Creating JJ surfaces...
#   JJ1: surface=14
#   JJ2: surface=15
#   JJ3: surface=16
#   JJ4: surface=17
#   JJ5: surface=18
#   JJ6: surface=19
#   JJ7: surface=20
#   JJ8: surface=21
#
# Keeping metal/JJ surfaces without OCC volume fragmentation...
#
# Creating physical groups...
#
# Applying JJ refinement...
#
# ================================================================================
# GENERATING 3D MESH
# ================================================================================
#
# ================================================================================
# MESH STATISTICS
# ================================================================================
# Nodes    : 38,670
# Elements : 128,248
#
# Physical groups:
#   Dimension=2, Attribute=10, Name=Superconducting_Metal, Entities=1
#   Dimension=2, Attribute=20, Name=JJ1, Entities=1
#   Dimension=2, Attribute=21, Name=JJ2, Entities=1
#   Dimension=2, Attribute=22, Name=JJ3, Entities=1
#   Dimension=2, Attribute=23, Name=JJ4, Entities=1
#   Dimension=2, Attribute=24, Name=JJ5, Entities=1
#   Dimension=2, Attribute=25, Name=JJ6, Entities=1
#   Dimension=2, Attribute=26, Name=JJ7, Entities=1
#   Dimension=2, Attribute=27, Name=JJ8, Entities=1
#   Dimension=3, Attribute=1, Name=Vacuum, Entities=1
#   Dimension=3, Attribute=2, Name=Silicon_Substrate, Entities=1
#
# Writing MSH 2.2...
#
# ================================================================================
# 8-JJ V2 MESH CREATED
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v2.msh
#
# Gmsh finalized.

# %%
# ============================================================
# ROBUST 8-JJ PALACE MESH GENERATOR - V11
#
# Fixes V10:
#   - robust polygon vertex cleanup
#   - removes duplicate/near-duplicate vertices
#   - removes zero-length edges
#   - handles Polygon / MultiPolygon safely
#   - handles interior holes
#   - globally reuses OCC points
#   - does NOT automatically run Palace
#
# Target:
#   4 qubits
#   8 Josephson junctions
# ============================================================

import os
import math
import gdspy
import gmsh

from shapely.geometry import Polygon, MultiPolygon, box
from shapely.ops import unary_union


# ============================================================
# PATHS
# ============================================================

GDS_PATH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_export_manuscript.gds"
)

OUTPUT_MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ_v11.msh"
)


# ============================================================
# GDS LAYERS
# ============================================================

METAL_LAYER = 1
METAL_DATATYPE = 0

PAD_LAYER = 1
PAD_DATATYPE = 10

JJ_LAYER = 53
JJ_DATATYPE = 0


# ============================================================
# JJ LOCATIONS
# ============================================================

JJ_LOCATIONS = [
    (-1.1325,  0.0000),
    (-0.8675,  0.0000),

    ( 1.2675,  0.0000),
    ( 1.5325,  0.0000),

    (-1.1325, -2.7000),
    (-0.8675, -2.7000),

    ( 1.2675, -2.7000),
    ( 1.5325, -2.7000),
]


# ============================================================
# PHYSICAL JJ DIMENSIONS
# ============================================================

JJ_WIDTH = 0.020       # mm = 20 um
JJ_HEIGHT = 0.005      # mm = 5 um

CUT_TOL = 0.0005       # mm = 0.5 um


# ============================================================
# CHIP
# ============================================================

CHIP_HALF = 7.0

Z_SI_BOTTOM = -0.5
Z_INTERFACE = 0.0
Z_VAC_TOP = 0.5


# ============================================================
# MESH
# ============================================================

BULK_SIZE = 0.30       # 300 um
JJ_SIZE = 0.030        # 30 um
JJ_RADIUS = 0.10       # 100 um


# ============================================================
# PHYSICAL IDS
# ============================================================

VACUUM_ID = 1
SILICON_ID = 2
PEC_ID = 10
JJ_ID_START = 20


# ============================================================
# GEOMETRY TOLERANCES
# ============================================================

POINT_TOL = 1e-9
AREA_TOL = 1e-12


print("=" * 80)
print("ROBUST 8-JJ PALACE MESH GENERATOR - V11")
print("=" * 80)

print("\nGDS:")
print(GDS_PATH)

print("\nOutput:")
print(OUTPUT_MESH)


# ============================================================
# CHECK INPUT
# ============================================================

if not os.path.isfile(GDS_PATH):
    raise FileNotFoundError(GDS_PATH)


# ============================================================
# READ GDS
# ============================================================

print("\n" + "=" * 80)
print("READING GDS")
print("=" * 80)

lib = gdspy.GdsLibrary()
lib.read_gds(GDS_PATH)

print(f"Loaded {len(lib.cells)} cells.")

TOP_CELL = "TOP_main_1"

if TOP_CELL not in lib.cells:
    raise RuntimeError(
        f"Top cell {TOP_CELL} not found."
    )

top = lib.cells[TOP_CELL]

print(
    f"Using top cell: {TOP_CELL}"
)


# ============================================================
# GET POLYGONS
# ============================================================

polygons_by_spec = top.get_polygons(
    by_spec=True
)


# ============================================================
# SHAPELY CLEANER
# ============================================================

def clean_polygon(points):

    if points is None:
        return None

    if len(points) < 3:
        return None

    try:

        p = Polygon(points)

        if p.is_empty:
            return None

        if not p.is_valid:
            p = p.buffer(0)

        if p.is_empty:
            return None

        if p.geom_type == "MultiPolygon":

            parts = [
                g
                for g in p.geoms
                if g.area > AREA_TOL
            ]

            if not parts:
                return None

            p = max(
                parts,
                key=lambda g: g.area
            )

        if p.area <= AREA_TOL:
            return None

        return p

    except Exception:
        return None


# ============================================================
# MAIN METAL
# ============================================================

print("\n" + "=" * 80)
print("EXTRACTING MAIN SUPERCONDUCTING METAL")
print("=" * 80)

main_polygons = []

for spec, polys in polygons_by_spec.items():

    layer, datatype = spec

    if (
        layer == METAL_LAYER
        and datatype == METAL_DATATYPE
    ):

        for pts in polys:

            p = clean_polygon(pts)

            if p is not None:
                main_polygons.append(p)


print(
    f"Main metal polygons: "
    f"{len(main_polygons)}"
)

if not main_polygons:
    raise RuntimeError(
        "No main metal polygons found."
    )


print("Uniting main metal...")

main_metal = unary_union(
    main_polygons
)

if not main_metal.is_valid:
    main_metal = main_metal.buffer(0)

print(
    "Metal geometry:",
    main_metal.geom_type
)

print(
    f"Metal area: "
    f"{main_metal.area:.12f} mm²"
)


# ============================================================
# PAD POLYGONS
# ============================================================

print("\n" + "=" * 80)
print("EXTRACTING JJ ELECTRODE PADS")
print("=" * 80)

pad_polygons = []

for spec, polys in polygons_by_spec.items():

    layer, datatype = spec

    if (
        layer == PAD_LAYER
        and datatype == PAD_DATATYPE
    ):

        for pts in polys:

            p = clean_polygon(pts)

            if p is not None:
                pad_polygons.append(p)


print(
    f"Pad polygons: "
    f"{len(pad_polygons)}"
)


# ============================================================
# JJ REFERENCES
# ============================================================

print("\n" + "=" * 80)
print("EXTRACTING JJ REFERENCES")
print("=" * 80)

jj_refs = []

for spec, polys in polygons_by_spec.items():

    layer, datatype = spec

    if (
        layer == JJ_LAYER
        and datatype == JJ_DATATYPE
    ):

        for pts in polys:

            p = clean_polygon(pts)

            if p is not None:
                jj_refs.append(p)


print(
    f"JJ polygons: "
    f"{len(jj_refs)}"
)

if len(jj_refs) != 8:

    raise RuntimeError(
        f"Expected 8 JJ polygons, "
        f"found {len(jj_refs)}."
    )


# ============================================================
# MATCH JJ REFERENCES
# ============================================================

print("\n" + "=" * 80)
print("MATCHING JJ REFERENCES")
print("=" * 80)

unused = list(jj_refs)
matched_jjs = []

for i, (jx, jy) in enumerate(
    JJ_LOCATIONS,
    1
):

    best = None
    best_idx = None
    best_d = float("inf")

    for k, p in enumerate(unused):

        c = p.centroid

        d = math.hypot(
            c.x - jx,
            c.y - jy
        )

        if d < best_d:

            best = p
            best_idx = k
            best_d = d

    if best is None:

        raise RuntimeError(
            f"Cannot match JJ{i}."
        )

    if best_d > 0.050:

        raise RuntimeError(
            f"JJ{i} mismatch: "
            f"{best_d * 1000:.3f} um"
        )

    matched_jjs.append(best)

    unused.pop(best_idx)

    print(
        f"JJ{i}: "
        f"centroid=("
        f"{best.centroid.x:.6f}, "
        f"{best.centroid.y:.6f}) mm, "
        f"error={best_d*1000:.3f} um"
    )


# ============================================================
# FIND PAD PAIRS
# ============================================================

print("\n" + "=" * 80)
print("IDENTIFYING JJ ELECTRODE PAIRS")
print("=" * 80)

jj_pad_pairs = []
used_pad_indices = set()

for i, (jx, jy) in enumerate(
    JJ_LOCATIONS,
    1
):

    candidates = []

    for k, p in enumerate(
        pad_polygons
    ):

        if k in used_pad_indices:
            continue

        c = p.centroid

        d = math.hypot(
            c.x - jx,
            c.y - jy
        )

        if d < 0.080:

            candidates.append(
                (d, k, p)
            )

    left = [
        x for x in candidates
        if x[2].centroid.x < jx
    ]

    right = [
        x for x in candidates
        if x[2].centroid.x > jx
    ]

    if not left or not right:

        raise RuntimeError(
            f"JJ{i}: could not identify "
            "left/right electrodes."
        )

    L = min(
        left,
        key=lambda x: x[0]
    )

    R = min(
        right,
        key=lambda x: x[0]
    )

    _, li, lp = L
    _, ri, rp = R

    used_pad_indices.add(li)
    used_pad_indices.add(ri)

    jj_pad_pairs.append(
        (lp, rp)
    )

    print(
        f"\nJJ{i}"
    )

    print(
        "  LEFT :",
        lp.bounds
    )

    print(
        "  RIGHT:",
        rp.bounds
    )


# ============================================================
# BUILD PHYSICAL JJ GAPS
# ============================================================

print("\n" + "=" * 80)
print("BUILDING JJ GAPS")
print("=" * 80)

jj_physical_gaps = []
jj_cut_gaps = []

for i, (lp, rp) in enumerate(
    jj_pad_pairs,
    1
):

    lx1, ly1, lx2, ly2 = lp.bounds
    rx1, ry1, rx2, ry2 = rp.bounds

    minx = lx2
    maxx = rx1

    miny = max(
        ly1,
        ry1
    )

    maxy = min(
        ly2,
        ry2
    )

    width = maxx - minx
    height = maxy - miny

    print(
        f"JJ{i}: "
        f"{width*1000:.3f} x "
        f"{height*1000:.3f} um"
    )

    if width <= 0 or height <= 0:

        raise RuntimeError(
            f"JJ{i}: invalid gap."
        )

    if abs(width - JJ_WIDTH) > 0.002:

        raise RuntimeError(
            f"JJ{i}: unexpected width."
        )

    if abs(height - JJ_HEIGHT) > 0.002:

        raise RuntimeError(
            f"JJ{i}: unexpected height."
        )

    # Exact physical JJ gap

    physical_gap = box(
        minx,
        miny,
        maxx,
        maxy
    )

    # Slightly extended cut region.
    # This guarantees the PEC geometry is actually
    # separated from the JJ surface.

    cut_gap = box(
        minx - CUT_TOL,
        miny - CUT_TOL,
        maxx + CUT_TOL,
        maxy + CUT_TOL
    )

    jj_physical_gaps.append(
        physical_gap
    )

    jj_cut_gaps.append(
        cut_gap
    )


# ============================================================
# COMBINE METAL + PADS
# ============================================================

print("\n" + "=" * 80)
print("COMBINING METAL AND JJ ELECTRODES")
print("=" * 80)

metal_components = [
    main_metal
]

for lp, rp in jj_pad_pairs:

    metal_components.append(lp)
    metal_components.append(rp)


combined_metal = unary_union(
    metal_components
)

if not combined_metal.is_valid:
    combined_metal = combined_metal.buffer(0)


print(
    "Combined metal:",
    combined_metal.geom_type
)

print(
    f"Combined metal area: "
    f"{combined_metal.area:.12f} mm²"
)


# ============================================================
# CUT GAPS
# ============================================================

print("\n" + "=" * 80)
print("CUTTING JJ GAPS FROM METAL")
print("=" * 80)

final_metal = combined_metal

for i, gap in enumerate(
    jj_cut_gaps,
    1
):

    before = final_metal.area

    overlap = (
        final_metal.intersection(
            gap
        )
    )

    overlap_area = overlap.area

    print(
        f"JJ{i}: "
        f"metal overlap="
        f"{overlap_area:.12e} mm²"
    )

    if overlap_area <= 1e-12:

        raise RuntimeError(
            f"JJ{i}: gap does not "
            "intersect metal."
        )

    candidate = (
        final_metal.difference(
            gap
        )
    )

    if not candidate.is_valid:
        candidate = candidate.buffer(0)

    removed = (
        before -
        candidate.area
    )

    print(
        f"     removed="
        f"{removed:.12e} mm²"
    )

    if removed <= 1e-12:

        raise RuntimeError(
            f"JJ{i}: Boolean cut failed."
        )

    final_metal = candidate


# ============================================================
# NORMALIZE METAL INTO POLYGONS
# ============================================================

if final_metal.geom_type == "Polygon":

    metal_regions = [
        final_metal
    ]

elif final_metal.geom_type == "MultiPolygon":

    metal_regions = list(
        final_metal.geoms
    )

else:

    raise RuntimeError(
        f"Unexpected final metal type: "
        f"{final_metal.geom_type}"
    )


metal_regions = [
    p
    for p in metal_regions
    if p.area > AREA_TOL
]


print(
    f"\nFinal metal regions: "
    f"{len(metal_regions)}"
)


# ============================================================
# ROBUST RING CLEANER
# ============================================================

def clean_ring(coords):

    cleaned = []

    for x, y in coords:

        if not (
            math.isfinite(x)
            and math.isfinite(y)
        ):
            continue

        if not cleaned:

            cleaned.append(
                (x, y)
            )

            continue

        px, py = cleaned[-1]

        d = math.hypot(
            x - px,
            y - py
        )

        if d > POINT_TOL:

            cleaned.append(
                (x, y)
            )

    # Remove closing duplicate

    if len(cleaned) >= 2:

        if math.hypot(
            cleaned[0][0] - cleaned[-1][0],
            cleaned[0][1] - cleaned[-1][1]
        ) <= POINT_TOL:

            cleaned.pop()

    return cleaned


# ============================================================
# INITIALIZE GMSH
# ============================================================

print("\n" + "=" * 80)
print("INITIALIZING GMSH")
print("=" * 80)

gmsh.initialize()

gmsh.option.setNumber(
    "General.Terminal",
    1
)

gmsh.model.add(
    "4Q_8JJ_PALACE_V11"
)


# ============================================================
# GLOBAL OCC POINT CACHE
#
# THIS IS THE IMPORTANT FIX FOR V10.
# ============================================================

point_cache = {}


def get_point(x, y, z):

    key = (
        round(x, 9),
        round(y, 9),
        round(z, 9)
    )

    if key in point_cache:

        return point_cache[key]

    tag = gmsh.model.occ.addPoint(
        x,
        y,
        z
    )

    point_cache[key] = tag

    return tag


# ============================================================
# ROBUST OCC RING
# ============================================================

def make_ring(coords):

    pts = clean_ring(
        coords
    )

    if len(pts) < 3:

        raise RuntimeError(
            "Polygon ring has fewer "
            "than 3 unique vertices."
        )

    line_tags = []

    for k in range(
        len(pts)
    ):

        x1, y1 = pts[k]

        x2, y2 = pts[
            (k + 1) % len(pts)
        ]

        distance = math.hypot(
            x2 - x1,
            y2 - y1
        )

        if distance <= POINT_TOL:

            continue

        p1 = get_point(
            x1,
            y1,
            Z_INTERFACE
        )

        p2 = get_point(
            x2,
            y2,
            Z_INTERFACE
        )

        if p1 == p2:

            continue

        try:

            line = (
                gmsh.model.occ.addLine(
                    p1,
                    p2
                )
            )

        except Exception as exc:

            raise RuntimeError(
                "Could not create OCC line.\n"
                f"p1={p1}, p2={p2}\n"
                f"({x1},{y1}) -> "
                f"({x2},{y2})\n"
                f"distance={distance}\n"
                f"Original error: {exc}"
            )

        line_tags.append(
            line
        )

    if len(line_tags) < 3:

        raise RuntimeError(
            "Ring produced fewer than "
            "3 valid lines."
        )

    try:

        return gmsh.model.occ.addWire(
            line_tags
        )

    except Exception as exc:

        raise RuntimeError(
            f"Could not create wire "
            f"from {len(line_tags)} lines: "
            f"{exc}"
        )


# ============================================================
# POLYGON -> OCC SURFACE
# ============================================================

def polygon_to_surface(poly):

    if poly.is_empty:
        return None

    if poly.geom_type != "Polygon":

        raise RuntimeError(
            "polygon_to_surface received "
            f"{poly.geom_type}"
        )

    exterior = make_ring(
        list(
            poly.exterior.coords
        )
    )

    holes = []

    for interior in poly.interiors:

        ring = make_ring(
            list(
                interior.coords
            )
        )

        holes.append(
            ring
        )

    loops = [
        exterior
    ] + holes

    try:

        return (
            gmsh.model.occ.addPlaneSurface(
                loops
            )
        )

    except Exception as exc:

        raise RuntimeError(
            "Could not create plane surface.\n"
            f"Exterior vertices="
            f"{len(list(poly.exterior.coords))}\n"
            f"Holes={len(holes)}\n"
            f"Area={poly.area}\n"
            f"Error={exc}"
        )


# ============================================================
# CREATE SILICON
# ============================================================

print(
    "\nCreating silicon volume..."
)

silicon = gmsh.model.occ.addBox(
    -CHIP_HALF,
    -CHIP_HALF,
    Z_SI_BOTTOM,
    2 * CHIP_HALF,
    2 * CHIP_HALF,
    -Z_SI_BOTTOM
)


# ============================================================
# CREATE VACUUM
# ============================================================

print(
    "Creating vacuum volume..."
)

vacuum = gmsh.model.occ.addBox(
    -CHIP_HALF,
    -CHIP_HALF,
    Z_INTERFACE,
    2 * CHIP_HALF,
    2 * CHIP_HALF,
    Z_VAC_TOP
)


# ============================================================
# CREATE PEC SURFACES
# ============================================================

print(
    "\nCreating superconducting metal surfaces..."
)

pec_surfaces = []

for i, poly in enumerate(
    metal_regions,
    1
):

    print(
        f"  Metal region {i}/"
        f"{len(metal_regions)} "
        f"area={poly.area:.6e} mm²"
    )

    s = polygon_to_surface(
        poly
    )

    if s is not None:

        pec_surfaces.append(
            s
        )


print(
    f"PEC surfaces created: "
    f"{len(pec_surfaces)}"
)


# ============================================================
# CREATE JJ SURFACES
# ============================================================

print(
    "\nCreating physical JJ surfaces..."
)

jj_surfaces = []

for i, gap in enumerate(
    jj_physical_gaps,
    1
):

    minx, miny, maxx, maxy = (
        gap.bounds
    )

    coords = [
        (minx, miny),
        (maxx, miny),
        (maxx, maxy),
        (minx, maxy)
    ]

    wire = make_ring(
        coords
    )

    surface = (
        gmsh.model.occ.addPlaneSurface(
            [wire]
        )
    )

    jj_surfaces.append(
        surface
    )

    print(
        f"JJ{i}: "
        f"surface={surface}, "
        f"size="
        f"{(maxx-minx)*1000:.3f} x "
        f"{(maxy-miny)*1000:.3f} um"
    )


# ============================================================
# SYNCHRONIZE
# ============================================================

print(
    "\nSynchronizing OCC..."
)

gmsh.model.occ.synchronize()


# ============================================================
# FRAGMENT VOLUMES WITH INTERFACE
# ============================================================

print("\n" + "=" * 80)
print("CONFORMAL SILICON / VACUUM FRAGMENTATION")
print("=" * 80)

interface_surfaces = (
    pec_surfaces +
    jj_surfaces
)

objects = [
    (3, silicon),
    (3, vacuum)
]

tools = [
    (2, s)
    for s in interface_surfaces
]


print(
    f"Volumes: {len(objects)}"
)

print(
    f"Interface surfaces: "
    f"{len(tools)}"
)


fragmented, mapping = (
    gmsh.model.occ.fragment(
        objects,
        tools
    )
)

gmsh.model.occ.synchronize()


print(
    f"Fragmented entities: "
    f"{len(fragmented)}"
)


# ============================================================
# DO NOT CALL removeAllDuplicates()
#
# It can destroy the surface identity that we need
# for PEC/JJ classification.
# ============================================================

print(
    "Skipping aggressive OCC duplicate removal."
)


# ============================================================
# IDENTIFY VOLUMES
# ============================================================

volumes = (
    gmsh.model.getEntities(
        3
    )
)

print(
    f"\n3D volumes: "
    f"{len(volumes)}"
)

silicon_volumes = []
vacuum_volumes = []

for dim, tag in volumes:

    cx, cy, cz = (
        gmsh.model.occ.getCenterOfMass(
            3,
            tag
        )
    )

    vol = (
        gmsh.model.occ.getMass(
            3,
            tag
        )
    )

    print(
        f"Volume {tag}: "
        f"center=({cx:.6f}, "
        f"{cy:.6f}, "
        f"{cz:.6f}), "
        f"V={vol:.6e} mm³"
    )

    if cz < 0:

        silicon_volumes.append(
            tag
        )

    elif cz > 0:

        vacuum_volumes.append(
            tag
        )


if not silicon_volumes:

    raise RuntimeError(
        "No silicon volume found."
    )

if not vacuum_volumes:

    raise RuntimeError(
        "No vacuum volume found."
    )


print(
    "\nPASS: silicon and vacuum "
    "volumes identified."
)


# ============================================================
# GET INTERFACE FACES
# ============================================================

all_faces = (
    gmsh.model.getEntities(
        2
    )
)

interface_faces = []

for dim, tag in all_faces:

    try:

        cx, cy, cz = (
            gmsh.model.occ.getCenterOfMass(
                2,
                tag
            )
        )

    except Exception:

        continue

    if abs(cz) < 1e-7:

        interface_faces.append(
            tag
        )


print(
    f"\nInterface faces at z=0: "
    f"{len(interface_faces)}"
)


# ============================================================
# IDENTIFY JJ FACES
# ============================================================

print(
    "\nIdentifying JJ faces..."
)

final_jj_faces = []

for i, (jx, jy) in enumerate(
    JJ_LOCATIONS,
    1
):

    candidates = []

    for tag in interface_faces:

        try:

            cx, cy, cz = (
                gmsh.model.occ.getCenterOfMass(
                    2,
                    tag
                )
            )

            area = (
                gmsh.model.occ.getMass(
                    2,
                    tag
                )
            )

        except Exception:

            continue

        d = math.hypot(
            cx - jx,
            cy - jy
        )

        # Expected JJ area:
        # 20 um * 5 um = 100 um²
        # = 1e-4 mm²

        if (
            d < 0.002
            and
            2e-5 < area < 5e-4
        ):

            candidates.append(
                (d, tag, area)
            )


    if not candidates:

        raise RuntimeError(
            f"Could not identify JJ{i}."
        )


    candidates.sort(
        key=lambda x: x[0]
    )

    d, tag, area = candidates[0]

    final_jj_faces.append(
        tag
    )

    print(
        f"JJ{i}: "
        f"face={tag}, "
        f"distance={d*1000:.3f} um, "
        f"area={area:.6e} mm²"
    )


if len(
    set(final_jj_faces)
) != 8:

    raise RuntimeError(
        "JJ faces are not unique."
    )


print(
    "PASS: 8 unique JJ faces found."
)


# ============================================================
# PEC FACES
# ============================================================

jj_set = set(
    final_jj_faces
)

pec_faces = []

for tag in interface_faces:

    if tag in jj_set:
        continue

    try:

        area = (
            gmsh.model.occ.getMass(
                2,
                tag
            )
        )

    except Exception:

        continue

    if area > 1e-9:

        pec_faces.append(
            tag
        )


print(
    f"PEC faces: "
    f"{len(pec_faces)}"
)

if not pec_faces:

    raise RuntimeError(
        "No PEC faces found."
    )


print(
    "PASS: PEC faces identified."
)


# ============================================================
# PHYSICAL GROUPS
# ============================================================

print(
    "\nCreating physical groups..."
)

gmsh.model.addPhysicalGroup(
    3,
    silicon_volumes,
    SILICON_ID
)

gmsh.model.setPhysicalName(
    3,
    SILICON_ID,
    "Silicon_Substrate"
)


gmsh.model.addPhysicalGroup(
    3,
    vacuum_volumes,
    VACUUM_ID
)

gmsh.model.setPhysicalName(
    3,
    VACUUM_ID,
    "Vacuum"
)


gmsh.model.addPhysicalGroup(
    2,
    pec_faces,
    PEC_ID
)

gmsh.model.setPhysicalName(
    2,
    PEC_ID,
    "Superconducting_Metal"
)


for i, face in enumerate(
    final_jj_faces,
    1
):

    gid = (
        JJ_ID_START +
        i -
        1
    )

    gmsh.model.addPhysicalGroup(
        2,
        [face],
        gid
    )

    gmsh.model.setPhysicalName(
        2,
        gid,
        f"JJ{i}"
    )


# ============================================================
# MESH SETTINGS
# ============================================================

print(
    "\nConfiguring mesh..."
)

gmsh.option.setNumber(
    "Mesh.MshFileVersion",
    2.2
)

gmsh.option.setNumber(
    "Mesh.Binary",
    0
)

gmsh.option.setNumber(
    "Mesh.CharacteristicLengthMin",
    JJ_SIZE
)

gmsh.option.setNumber(
    "Mesh.CharacteristicLengthMax",
    BULK_SIZE
)

gmsh.option.setNumber(
    "Mesh.Optimize",
    0
)

gmsh.option.setNumber(
    "Mesh.OptimizeNetgen",
    0
)


# ============================================================
# JJ REFINEMENT
# ============================================================

print(
    "Applying JJ refinement..."
)

fields = []

for x, y in JJ_LOCATIONS:

    f = (
        gmsh.model.mesh.field.add(
            "Box"
        )
    )

    gmsh.model.mesh.field.setNumber(
        f,
        "VIn",
        JJ_SIZE
    )

    gmsh.model.mesh.field.setNumber(
        f,
        "VOut",
        BULK_SIZE
    )

    gmsh.model.mesh.field.setNumber(
        f,
        "XMin",
        x - JJ_RADIUS
    )

    gmsh.model.mesh.field.setNumber(
        f,
        "XMax",
        x + JJ_RADIUS
    )

    gmsh.model.mesh.field.setNumber(
        f,
        "YMin",
        y - JJ_RADIUS
    )

    gmsh.model.mesh.field.setNumber(
        f,
        "YMax",
        y + JJ_RADIUS
    )

    gmsh.model.mesh.field.setNumber(
        f,
        "ZMin",
        Z_SI_BOTTOM
    )

    gmsh.model.mesh.field.setNumber(
        f,
        "ZMax",
        Z_VAC_TOP
    )

    fields.append(f)


if fields:

    fmin = (
        gmsh.model.mesh.field.add(
            "Min"
        )
    )

    gmsh.model.mesh.field.setNumbers(
        fmin,
        "FieldsList",
        fields
    )

    gmsh.model.mesh.field.setAsBackgroundMesh(
        fmin
    )


# ============================================================
# GENERATE MESH
# ============================================================

print("\n" + "=" * 80)
print("GENERATING 3D TETRAHEDRAL MESH")
print("=" * 80)

gmsh.model.mesh.generate(
    3
)


# ============================================================
# CLEAN MESH
# ============================================================

print(
    "\nRemoving duplicate nodes..."
)

gmsh.model.mesh.removeDuplicateNodes()

print(
    "Removing duplicate elements..."
)

gmsh.model.mesh.removeDuplicateElements()


# ============================================================
# BASIC MESH STATISTICS
# ============================================================

nodes, _, _ = (
    gmsh.model.mesh.getNodes()
)

types, element_tags, element_nodes = (
    gmsh.model.mesh.getElements()
)

total_elements = 0
degenerate = 0
tetrahedra = 0

for etype, tags, conn in zip(
    types,
    element_tags,
    element_nodes
):

    total_elements += len(tags)

    if etype == 4:

        tetrahedra += len(tags)

        for k in range(
            0,
            len(conn),
            4
        ):

            verts = conn[
                k:k+4
            ]

            if len(
                set(verts)
            ) != 4:

                degenerate += 1


print(
    "\n" + "=" * 80
)

print(
    "MESH STATISTICS"
)

print(
    "=" * 80
)

print(
    f"Nodes        : "
    f"{len(nodes):,}"
)

print(
    f"Total elements: "
    f"{total_elements:,}"
)

print(
    f"Tetrahedra   : "
    f"{tetrahedra:,}"
)

print(
    f"Degenerate   : "
    f"{degenerate:,}"
)


if degenerate != 0:

    raise RuntimeError(
        "Degenerate tetrahedral elements found."
    )


# ============================================================
# PHYSICAL GROUP CHECK
# ============================================================

print(
    "\n" + "=" * 80
)

print(
    "PHYSICAL GROUP VALIDATION"
)

print(
    "=" * 80
)

required = {
    1: "Vacuum",
    2: "Silicon_Substrate",
    10: "Superconducting_Metal",
    20: "JJ1",
    21: "JJ2",
    22: "JJ3",
    23: "JJ4",
    24: "JJ5",
    25: "JJ6",
    26: "JJ7",
    27: "JJ8",
}

groups = (
    gmsh.model.getPhysicalGroups()
)

group_dict = {}

for dim, tag in groups:

    group_dict[tag] = (
        dim,
        gmsh.model.getPhysicalName(
            dim,
            tag
        )
    )


for gid, expected in required.items():

    if gid not in group_dict:

        raise RuntimeError(
            f"Missing group {gid}: "
            f"{expected}"
        )

    dim, name = group_dict[gid]

    print(
        f"PASS  "
        f"dim={dim}, "
        f"id={gid}: "
        f"{name}"
    )


# ============================================================
# WRITE MESH
# ============================================================

print(
    "\n" + "=" * 80
)

print(
    "WRITING MSH 2.2"
)

print(
    "=" * 80
)

gmsh.write(
    OUTPUT_MESH
)


# ============================================================
# FINAL FILE CHECK
# ============================================================

if not os.path.isfile(
    OUTPUT_MESH
):

    raise RuntimeError(
        "Mesh file was not written."
    )


size_gb = (
    os.path.getsize(
        OUTPUT_MESH
    )
    /
    (1024**3)
)


# ============================================================
# SUCCESS
# ============================================================

print(
    "\n" + "=" * 80
)

print(
    "SUCCESS"
)

print(
    "=" * 80
)

print(
    f"Mesh:"
)

print(
    OUTPUT_MESH
)

print(
    f"\nFile size: "
    f"{size_gb:.3f} GB"
)

print(
    f"Nodes: "
    f"{len(nodes):,}"
)

print(
    f"Elements: "
    f"{total_elements:,}"
)

print(
    "\nPhysical groups:"
)

print(
    "  1  -> Vacuum"
)

print(
    "  2  -> Silicon_Substrate"
)

print(
    "  10 -> Superconducting_Metal"
)

for i in range(1, 9):

    print(
        f"  {19+i:2d} -> JJ{i}"
    )


print(
    "\nDO NOT RUN PALACE YET."
)

print(
    "First test Palace mesh reading only."
)


# ============================================================
# FINALIZE
# ============================================================

gmsh.finalize()

print(
    "\nGmsh finalized."
)
# Out:
# ================================================================================
# ROBUST 8-JJ PALACE MESH GENERATOR - V11
# ================================================================================
#
# GDS:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds
#
# Output:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v11.msh
#
# ================================================================================
# READING GDS
# ================================================================================
# Loaded 19 cells.
# Using top cell: TOP_main_1
#
# ================================================================================
# EXTRACTING MAIN SUPERCONDUCTING METAL
# ================================================================================
# Main metal polygons: 2450
# Uniting main metal...
# Metal geometry: MultiPolygon
# Metal area: 185.737968344919 mm²
#
# ================================================================================
# EXTRACTING JJ ELECTRODE PADS
# ================================================================================
# Pad polygons: 90
#
# ================================================================================
# EXTRACTING JJ REFERENCES
# ================================================================================
# JJ polygons: 8
#
# ================================================================================
# MATCHING JJ REFERENCES
# ================================================================================
# JJ1: centroid=(-1.132500, 0.000000) mm, error=0.000 um
# JJ2: centroid=(-0.867500, -0.000000) mm, error=0.000 um
# JJ3: centroid=(1.267500, 0.000000) mm, error=0.000 um
# JJ4: centroid=(1.532500, -0.000000) mm, error=0.000 um
# JJ5: centroid=(-1.132500, -2.700000) mm, error=0.000 um
# JJ6: centroid=(-0.867500, -2.700000) mm, error=0.000 um
# JJ7: centroid=(1.267500, -2.700000) mm, error=0.000 um
# JJ8: centroid=(1.532500, -2.700000) mm, error=0.000 um
#
# ================================================================================
# IDENTIFYING JJ ELECTRODE PAIRS
# ================================================================================
#
# JJ1
#   LEFT : (-1.15, -0.0024999999999999988, -1.1424999999999998, 0.0025000000000000022)
#   RIGHT: (-1.1224999999999998, -0.0025000000000000022, -1.1149999999999998, 0.0024999999999999988)
#
# JJ2
#   LEFT : (-0.8849999999999999, -0.0025, -0.8775, 0.0025)
#   RIGHT: (-0.8574999999999999, -0.0025, -0.85, 0.0025)
#
# JJ3
#   LEFT : (1.2499999999999998, -0.0024999999999999988, 1.2574999999999998, 0.0025000000000000022)
#   RIGHT: (1.2774999999999999, -0.0025000000000000022, 1.285, 0.0024999999999999988)
#
# JJ4
#   LEFT : (1.515, -0.0025, 1.5225, 0.0025)
#   RIGHT: (1.5425, -0.0025, 1.55, 0.0025)
#
# JJ5
#   LEFT : (-1.15, -2.7024999999999997, -1.1424999999999998, -2.6975)
#   RIGHT: (-1.1224999999999998, -2.7024999999999997, -1.1149999999999998, -2.6975)
#
# JJ6
#   LEFT : (-0.8849999999999999, -2.7024999999999997, -0.8775, -2.6975)
#   RIGHT: (-0.8574999999999999, -2.7024999999999997, -0.85, -2.6975)
#
# JJ7
#   LEFT : (1.2499999999999998, -2.7024999999999997, 1.2574999999999998, -2.6975)
#   RIGHT: (1.2774999999999999, -2.7024999999999997, 1.285, -2.6975)
#
# JJ8
#   LEFT : (1.515, -2.7024999999999997, 1.5225, -2.6975)
#   RIGHT: (1.5425, -2.7024999999999997, 1.55, -2.6975)
#
# ================================================================================
# BUILDING JJ GAPS
# ================================================================================
# JJ1: 20.000 x 5.000 um
# JJ2: 20.000 x 5.000 um
# JJ3: 20.000 x 5.000 um
# JJ4: 20.000 x 5.000 um
# JJ5: 20.000 x 5.000 um
# JJ6: 20.000 x 5.000 um
# JJ7: 20.000 x 5.000 um
# JJ8: 20.000 x 5.000 um
#
# ================================================================================
# COMBINING METAL AND JJ ELECTRODES
# ================================================================================
# Combined metal: MultiPolygon
# Combined metal area: 185.738568344919 mm²
#
# ================================================================================
# CUTTING JJ GAPS FROM METAL
# ================================================================================
# JJ1: metal overlap=4.999999999999e-06 mm²
#      removed=5.000000015798e-06 mm²
# JJ2: metal overlap=4.999999999999e-06 mm²
#      removed=4.999999987376e-06 mm²
# JJ3: metal overlap=4.999999999999e-06 mm²
#      removed=4.999999987376e-06 mm²
# JJ4: metal overlap=4.999999999999e-06 mm²
#      removed=5.000000015798e-06 mm²
# JJ5: metal overlap=4.999999999999e-06 mm²
#      removed=4.999999987376e-06 mm²
# JJ6: metal overlap=4.999999999999e-06 mm²
#      removed=5.000000044220e-06 mm²
# JJ7: metal overlap=4.999999999999e-06 mm²
#      removed=4.999999958955e-06 mm²
# JJ8: metal overlap=4.999999999999e-06 mm²
#      removed=5.000000015798e-06 mm²
#
# Final metal regions: 22
#
# ================================================================================
# INITIALIZING GMSH
# ================================================================================
#
# Creating silicon volume...
# Creating vacuum volume...
#
# Creating superconducting metal surfaces...
#   Metal region 1/22 area=1.012356e-01 mm²
#   Metal region 2/22 area=1.031874e-01 mm²
#   Metal region 3/22 area=1.031874e-01 mm²
#   Metal region 4/22 area=1.031874e-01 mm²
#   Metal region 5/22 area=1.031874e-01 mm²
#   Metal region 6/22 area=3.500000e-05 mm²
#   Metal region 7/22 area=3.500000e-05 mm²
#   Metal region 8/22 area=3.500000e-05 mm²
#   Metal region 9/22 area=3.500000e-05 mm²
#   Metal region 10/22 area=3.500000e-05 mm²
#   Metal region 11/22 area=3.500000e-05 mm²
#   Metal region 12/22 area=3.500000e-05 mm²
#   Metal region 13/22 area=3.500000e-05 mm²
#   Metal region 14/22 area=3.500000e-05 mm²
#   Metal region 15/22 area=3.500000e-05 mm²
#   Metal region 16/22 area=3.500000e-05 mm²
#   Metal region 17/22 area=3.500000e-05 mm²
#   Metal region 18/22 area=3.500000e-05 mm²
#   Metal region 19/22 area=1.852240e+02 mm²
#   Metal region 20/22 area=3.500000e-05 mm²
#   Metal region 21/22 area=3.500000e-05 mm²
#   Metal region 22/22 area=3.500000e-05 mm²
# PEC surfaces created: 22
#
# Creating physical JJ surfaces...
# JJ1: surface=35, size=20.000 x 5.000 um
# JJ2: surface=36, size=20.000 x 5.000 um
# JJ3: surface=37, size=20.000 x 5.000 um
# JJ4: surface=38, size=20.000 x 5.000 um
# JJ5: surface=39, size=20.000 x 5.000 um
# JJ6: surface=40, size=20.000 x 5.000 um
# JJ7: surface=41, size=20.000 x 5.000 um
# JJ8: surface=42, size=20.000 x 5.000 um
#
# Synchronizing OCC...
#
# ================================================================================
# CONFORMAL SILICON / VACUUM FRAGMENTATION
# ================================================================================
# Volumes: 2
# Interface surfaces: 30
# Fragmented entities: 122
# Skipping aggressive OCC duplicate removal.
#
# 3D volumes: 2
# Volume 1: center=(0.000000, 0.000000, -0.250000), V=9.800000e+01 mm³
# Volume 2: center=(0.000000, 0.000000, 0.250000), V=9.800000e+01 mm³
#
# PASS: silicon and vacuum volumes identified.
#
# Interface faces at z=0: 50
#
# Identifying JJ faces...
# JJ1: face=35, distance=0.000 um, area=1.000000e-04 mm²
# JJ2: face=36, distance=0.000 um, area=1.000000e-04 mm²
# JJ3: face=37, distance=0.000 um, area=1.000000e-04 mm²
# JJ4: face=38, distance=0.000 um, area=1.000000e-04 mm²
# JJ5: face=39, distance=0.000 um, area=1.000000e-04 mm²
# JJ6: face=40, distance=0.000 um, area=1.000000e-04 mm²
# JJ7: face=41, distance=0.000 um, area=1.000000e-04 mm²
# JJ8: face=42, distance=0.000 um, area=1.000000e-04 mm²
# PASS: 8 unique JJ faces found.
# PEC faces: 42
# PASS: PEC faces identified.
#
# Creating physical groups...
#
# Configuring mesh...
# Applying JJ refinement...
#
# ================================================================================
# GENERATING 3D TETRAHEDRAL MESH
# ================================================================================
#
# Removing duplicate nodes...
# Removing duplicate elements...
#
# ================================================================================
# MESH STATISTICS
# ================================================================================
# Nodes        : 2,320,521
# Total elements: 16,521,981
# Tetrahedra   : 13,873,263
# Degenerate   : 0
#
# ================================================================================
# PHYSICAL GROUP VALIDATION
# ================================================================================
# PASS  dim=3, id=1: Vacuum
# PASS  dim=3, id=2: Silicon_Substrate
# PASS  dim=2, id=10: Superconducting_Metal
# PASS  dim=2, id=20: JJ1
# PASS  dim=2, id=21: JJ2
# PASS  dim=2, id=22: JJ3
# PASS  dim=2, id=23: JJ4
# PASS  dim=2, id=24: JJ5
# PASS  dim=2, id=25: JJ6
# PASS  dim=2, id=26: JJ7
# PASS  dim=2, id=27: JJ8
#
# ================================================================================
# WRITING MSH 2.2
# ================================================================================
#
# ================================================================================
# SUCCESS
# ================================================================================
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v11.msh
#
# File size: 0.819 GB
# Nodes: 2,320,521
# Elements: 16,521,981
#
# Physical groups:
#   1  -> Vacuum
#   2  -> Silicon_Substrate
#   10 -> Superconducting_Metal
#   20 -> JJ1
#   21 -> JJ2
#   22 -> JJ3
#   23 -> JJ4
#   24 -> JJ5
#   25 -> JJ6
#   26 -> JJ7
#   27 -> JJ8
#
# DO NOT RUN PALACE YET.
# First test Palace mesh reading only.
#
# Gmsh finalized.

# %%
# config_file_path = 'palace_config.json'
# with open(config_file_path, 'w') as f:
#     json.dump(palace_config, f, indent=4)


# # ==========================================
# # STEP 5: Robust 3D Meshing Handler for GDS
# # ==========================================
# def generate_palace_mesh(gds_path, msh_output_path):
#     import gmsh
#     print(f"Initializing Gmsh for 3D volumetric extrusion pipeline...")
#     gmsh.initialize()
#     gmsh.option.setNumber("General.Terminal", 1)
#     gmsh.model.add("quantum_chip_3d_model")

#     if not os.path.exists(gds_path):
#         raise FileNotFoundError(f"GDS file missing: {gds_path}")

#     # Note: To parse GDS layouts directly into Gmsh solid volumes,
#     # pipelines like `meshwell` or `gds2palace` convert polygons to STEP/OpenCASCADE shapes.
#     # Below is the direct structural handler pattern once shapes are loaded into Gmsh OpenCASCADE:

#     try:
#         # Creating standard substrate bounding box representation fallback for automated script flow
#         # (Substrate Box: 14mm x 14mm x 500um thickness)
#         substrate = gmsh.model.occ.addBox(-7.0, -7.0, -0.5, 14.0, 14.0, 0.5, tag=1)
#         # Vacuum Box overlay (Air boundary for 3D full-wave containment)
#         airbox = gmsh.model.occ.addBox(-7.0, -7.0, 0.0, 14.0, 14.0, 3.0, tag=2)

#         gmsh.model.occ.synchronize()

#         # Set mesh sizing constraints near fine superconducting features
#         gmsh.option.setNumber("Mesh.CharacteristicLengthMin", 2.0)
#         gmsh.option.setNumber("Mesh.CharacteristicLengthMax", 40.0)

#         print("Executing 3D Tetrahedral Volumetric Generation...")
#         gmsh.model.mesh.generate(3)
#         gmsh.write(msh_output_path)
#         print(f"Successfully generated mesh: {msh_output_path}")

#     except Exception as e:
#         print(f"Meshing routine warning/error handled: {e}")
#     finally:
#         gmsh.finalize()

# generate_palace_mesh(output_gds_path, 'quantum_chip_mesh.msh')

# %%
import os
import stat
import shutil

validator = "/content/drive/MyDrive/Palace6/build/bin/validate-config"

print("Validator exists:", os.path.exists(validator))
print("Current permissions:", oct(os.stat(validator).st_mode))

# Add executable permission
os.chmod(
    validator,
    os.stat(validator).st_mode | stat.S_IXUSR | stat.S_IXGRP | stat.S_IXOTH
)

print("New permissions:", oct(os.stat(validator).st_mode))

# %%
# ============================================================
# PALACE V11 — MINIMAL CONFIGURATION VALIDATION
# ============================================================
#
# IMPORTANT:
#   This ONLY validates the JSON configuration.
#   It does NOT run the 8-JJ simulation.
#
# ============================================================

import os
import json
import subprocess

PALACE = (
    "/content/drive/MyDrive/Palace6/"
    "build/bin/palace-x86_64.bin"
)

VALIDATOR = (
    "/content/drive/MyDrive/Palace6/"
    "build/bin/validate-config"
)

MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ_v11.msh"
)

CONFIG = "/content/palace_8jj_validation_v3.json"


print("=" * 80)
print("PALACE V11 — MINIMAL CONFIGURATION VALIDATION")
print("=" * 80)

# ------------------------------------------------------------
# Check files
# ------------------------------------------------------------

if not os.path.isfile(MESH):
    raise FileNotFoundError(
        f"Mesh not found:\n{MESH}"
    )

if not os.path.isfile(VALIDATOR):
    raise FileNotFoundError(
        f"Palace validator not found:\n{VALIDATOR}"
    )

mesh_size = os.path.getsize(MESH) / (1024**3)

print("\nMesh:")
print(MESH)

print(f"\nMesh size: {mesh_size:.3f} GB")


# ============================================================
# MINIMAL PALACE CONFIGURATION
# ============================================================

config = {

    # --------------------------------------------------------
    # PROBLEM
    # --------------------------------------------------------

    "Problem": {
        "Type": "Eigenmode",
        "Output": "/content/palace_8jj_validation_output",
        "Verbose": 2
    },


    # --------------------------------------------------------
    # MODEL
    # --------------------------------------------------------
    #
    # Your Gmsh mesh coordinates are in mm.
    #
    # Therefore:
    #
    #       1 mesh unit = 1 mm = 1e-3 m
    #
    # Palace uses L0 to convert mesh units to SI.
    #
    # --------------------------------------------------------

    "Model": {
        "Mesh": MESH,
        "L0": 1.0e-3
    },


    # --------------------------------------------------------
    # DOMAINS
    # --------------------------------------------------------
    #
    # Attribute 1 = Vacuum
    # Attribute 2 = Silicon_Substrate
    #
    # --------------------------------------------------------

    "Domains": {
        "Materials": [

            {
                "Attributes": [1],
                "Permittivity": 1.0,
                "Permeability": 1.0
            },

            {
                "Attributes": [2],
                "Permittivity": 11.45,
                "Permeability": 1.0
            }
        ]
    },


    # --------------------------------------------------------
    # BOUNDARIES
    # --------------------------------------------------------
    #
    # Attribute 10 = superconducting metal
    #
    # For this validation we only need to confirm that
    # Palace accepts the PEC boundary definition.
    #
    # --------------------------------------------------------

    "Boundaries": {
        "PEC": {
            "Attributes": [10]
        }
    },


    # --------------------------------------------------------
    # SOLVER
    # --------------------------------------------------------
    #
    # Keep this minimal.
    #
    # Do NOT add guessed fields such as:
    #   Linear
    #   NodeOrder
    #   MaxIts
    #
    # until the configuration itself is validated.
    #
    # --------------------------------------------------------

    "Solver": {

        "Order": 1,

        "Eigenmode": {
            "N": 1,
            "Target": 5.0,
            "Tol": 1.0e-8
        }
    }
}


# ============================================================
# WRITE CONFIG
# ============================================================

with open(CONFIG, "w") as f:
    json.dump(
        config,
        f,
        indent=4
    )


print("\nConfiguration written:")
print(CONFIG)


# ============================================================
# DISPLAY CONFIGURATION
# ============================================================

print("\n" + "=" * 80)
print("CONFIGURATION")
print("=" * 80)

print(
    json.dumps(
        config,
        indent=4
    )
)


# ============================================================
# VALIDATE ONLY
# ============================================================

print("\n" + "=" * 80)
print("RUNNING PALACE CONFIGURATION VALIDATOR")
print("=" * 80)

validation = subprocess.run(
    [
        VALIDATOR,
        CONFIG
    ],
    capture_output=True,
    text=True
)


print("\nValidator stdout:")
print(validation.stdout)

print("\nValidator stderr:")
print(validation.stderr)

print(
    f"\nValidator return code: {validation.returncode}"
)


# ============================================================
# STOP ON ERROR
# ============================================================

if validation.returncode != 0:

    raise RuntimeError(
        "\n"
        "PALACE CONFIGURATION VALIDATION FAILED.\n"
        "\n"
        "DO NOT RUN PALACE.\n"
        "\n"
        "The V11 mesh has NOT been modified."
    )


# ============================================================
# SUCCESS
# ============================================================

print("\n" + "=" * 80)
print("PASS")
print("=" * 80)

print("""
Palace configuration validation succeeded.

The V11 mesh itself has NOT been simulated.

Next step:
    Palace mesh-read-only test
    ↓
    1 eigenmode sanity test
    ↓
    only then full 8-JJ simulation
""")
# Out:
# ================================================================================
# PALACE V11 — MINIMAL CONFIGURATION VALIDATION
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v11.msh
#
# Mesh size: 0.819 GB
#
# Configuration written:
# /content/palace_8jj_validation_v3.json
#
# ================================================================================
# CONFIGURATION
# ================================================================================
# {
#     "Problem": {
#         "Type": "Eigenmode",
#         "Output": "/content/palace_8jj_validation_output",
#         "Verbose": 2
#     },
#     "Model": {
#         "Mesh": "/content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v11.msh",
#         "L0": 0.001
#     },
#     "Domains": {
#         "Materials": [
#             {
#                 "Attributes": [
#                     1
#                 ],
#                 "Permittivity": 1.0,
#                 "Permeability": 1.0
#             },
#             {
#                 "Attributes": [
#                     2
#                 ],
#                 "Permittivity": 11.45,
#                 "Permeability": 1.0
#             }
#         ]
#     },
#     "Boundaries": {
#         "PEC": {
#             "Attributes": [
#                 10
#             ]
#         }
#     },
#     "Solver": {
#         "Order": 1,
#         "Eigenmode": {
#             "N": 1,
#             "Target": 5.0,
#             "Tol": 1e-08
#         }
#     }
# }
#
# ================================================================================
# RUNNING PALACE CONFIGURATION VALIDATOR
# ================================================================================
#
# Validator stdout:
# Dry-run: No errors detected in configuration file "/content/palace_8jj_validation_v3.json"
#
#
# Validator stderr:
#   Activating new project at `/tmp/jl_WRDUAZ`
#    Resolving package versions...
#     Updating `/tmp/jl_WRDUAZ/Project.toml`
#   [682c06a0] + JSON v1.7.1
#   [7d188eb4] + JSONSchema v1.5.0
#     Updating `/tmp/jl_WRDUAZ/Manifest.toml`
#   [682c06a0] + JSON v1.7.1
#   [7d188eb4] + JSONSchema v1.5.0
#   [69de0a69] + Parsers v2.8.7
#   [aea7be01] + PrecompileTools v1.3.4
#   [21216c6a] + Preferences v1.5.2
#   [ec057cc2] + StructUtils v2.8.5
#   [5c2747f8] + URIs v1.6.3
#   [0dad84c5] + ArgTools v1.1.2
#   [56f22d72] + Artifacts v1.11.0
#   [ade2ca70] + Dates v1.11.0
#   [f43a241f] + Downloads v1.7.0
#   [7b1f6079] + FileWatching v1.11.0
#   [b27032c2] + LibCURL v0.6.4
#   [8f399da3] + Libdl v1.11.0
#   [56ddb016] + Logging v1.11.0
#   [ca575930] + NetworkOptions v1.3.0
#   [de0858da] + Printf v1.11.0
#   [9a3f8284] + Random v1.11.0
#   [ea8e919c] + SHA v0.7.0
#   [fa267f1f] + TOML v1.0.3
#   [cf7118a7] + UUIDs v1.11.0
#   [4ec0a83e] + Unicode v1.11.0
#   [deac9b47] + LibCURL_jll v8.15.0+0
#   [29816b5a] + LibSSH2_jll v1.11.3+1
#   [14a3606d] + MozillaCACerts_jll v2025.11.4
#   [458c3c95] + OpenSSL_jll v3.5.4+0
#   [83775a58] + Zlib_jll v1.3.1+2
#   [8e850ede] + nghttp2_jll v1.64.0+1
#
#
# Validator return code: 0
#
# ================================================================================
# PASS
# ================================================================================
#
# Palace configuration validation succeeded.
#
# The V11 mesh itself has NOT been simulated.
#
# Next step:
#     Palace mesh-read-only test
#     ↓
#     1 eigenmode sanity test
#     ↓
#     only then full 8-JJ simulation

# %%
import os
import subprocess

PALACE = "/content/drive/MyDrive/Palace6/build/bin/palace-x86_64.bin"
LIBDIR = "/content/drive/MyDrive/Palace6/build/lib"

print("=" * 80)
print("PALACE SHARED-LIBRARY VERIFICATION")
print("=" * 80)

# ------------------------------------------------------------
# 1. Check libraries
# ------------------------------------------------------------

required = [
    "libceed.so",
    "libxsmm.so",
    "libxsmmgen.so",
]

print("\nChecking required libraries:")

for name in required:
    path = os.path.join(LIBDIR, name)

    if os.path.exists(path):
        print(f"  [PASS] {path}")
    else:
        print(f"  [FAIL] {path}")

# ------------------------------------------------------------
# 2. Check Palace executable
# ------------------------------------------------------------

print("\nChecking Palace executable:")

if os.path.isfile(PALACE):
    print("  [PASS] Palace executable exists")
else:
    raise RuntimeError("Palace executable not found.")

if os.access(PALACE, os.X_OK):
    print("  [PASS] Palace executable permission")
else:
    raise RuntimeError(
        "Palace executable is not executable."
    )

# ------------------------------------------------------------
# 3. Set LD_LIBRARY_PATH
# ------------------------------------------------------------

env = os.environ.copy()

old = env.get("LD_LIBRARY_PATH", "")

if old:
    env["LD_LIBRARY_PATH"] = (
        LIBDIR + ":" + old
    )
else:
    env["LD_LIBRARY_PATH"] = LIBDIR

print("\nLD_LIBRARY_PATH:")
print(env["LD_LIBRARY_PATH"])

# ------------------------------------------------------------
# 4. Run ldd
# ------------------------------------------------------------

print("\n" + "=" * 80)
print("LDD CHECK")
print("=" * 80)

ldd = subprocess.run(
    ["ldd", PALACE],
    capture_output=True,
    text=True,
    env=env
)

print(ldd.stdout)

missing = []

for line in ldd.stdout.splitlines():

    if "not found" in line:
        missing.append(line)

if missing:

    print("\n" + "=" * 80)
    print("MISSING LIBRARIES")
    print("=" * 80)

    for line in missing:
        print(line)

    raise RuntimeError(
        "\nPalace still has unresolved shared libraries."
    )

print("\nPASS: No missing shared libraries detected.")

# ------------------------------------------------------------
# 5. Test direct Palace startup
# ------------------------------------------------------------

print("\n" + "=" * 80)
print("PALACE STARTUP TEST")
print("=" * 80)

test = subprocess.run(
    [PALACE, "--help"],
    capture_output=True,
    text=True,
    env=env
)

print("\nSTDOUT:")
print(test.stdout[:5000])

print("\nSTDERR:")
print(test.stderr[:5000])

print("\nReturn code:", test.returncode)

if test.returncode != 0:

    raise RuntimeError(
        "\nPalace executable could not start correctly."
    )

print("\n" + "=" * 80)
print("PALACE INSTALLATION: PASS")
print("=" * 80)

print("""
libCEED is visible.
Palace shared libraries are resolved.
Palace executable starts successfully.

NEXT:
Run the V11 1-mode mesh test.
Do NOT run the full 8-JJ simulation yet.
""")
# Out:
# ================================================================================
# PALACE SHARED-LIBRARY VERIFICATION
# ================================================================================
#
# Checking required libraries:
#   [PASS] /content/drive/MyDrive/Palace6/build/lib/libceed.so
#   [PASS] /content/drive/MyDrive/Palace6/build/lib/libxsmm.so
#   [PASS] /content/drive/MyDrive/Palace6/build/lib/libxsmmgen.so
#
# Checking Palace executable:
#   [PASS] Palace executable exists
#   [PASS] Palace executable permission
#
# LD_LIBRARY_PATH:
# /content/drive/MyDrive/Palace6/build/lib
#
# ================================================================================
# LDD CHECK
# ================================================================================
# 	linux-vdso.so.1 (0x00007ffed0d48000)
# 	libmpi_cxx.so.40 => /lib/x86_64-linux-gnu/libmpi_cxx.so.40 (0x00007fc7704e8000)
# 	libmpi.so.40 => /lib/x86_64-linux-gnu/libmpi.so.40 (0x00007fc76cac9000)
# 	libstdc++.so.6 => /lib/x86_64-linux-gnu/libstdc++.so.6 (0x00007fc76c89d000)
# 	libceed.so => /content/drive/MyDrive/Palace6/build/lib/libceed.so (0x00007fc76c400000)
# 	libz.so.1 => /lib/x86_64-linux-gnu/libz.so.1 (0x00007fc7704cc000)
# 	libopenblas.so.0 => /lib/x86_64-linux-gnu/libopenblas.so.0 (0x00007fc769fb0000)
# 	libgomp.so.1 => /lib/x86_64-linux-gnu/libgomp.so.1 (0x00007fc770480000)
# 	libm.so.6 => /lib/x86_64-linux-gnu/libm.so.6 (0x00007fc769ec9000)
# 	libgcc_s.so.1 => /lib/x86_64-linux-gnu/libgcc_s.so.1 (0x00007fc770460000)
# 	libc.so.6 => /lib/x86_64-linux-gnu/libc.so.6 (0x00007fc769ca0000)
# 	/lib64/ld-linux-x86-64.so.2 (0x00007fc770512000)
# 	libopen-pal.so.40 => /lib/x86_64-linux-gnu/libopen-pal.so.40 (0x00007fc769bed000)
# 	libopen-rte.so.40 => /lib/x86_64-linux-gnu/libopen-rte.so.40 (0x00007fc769b30000)
# 	libhwloc.so.15 => /usr/local/lib/libhwloc.so.15 (0x00007fc769800000)
# 	libxsmm.so.1 => /content/drive/MyDrive/Palace6/build/lib/libxsmm.so.1 (0x00007fc769613000)
# 	libgfortran.so.5 => /lib/x86_64-linux-gnu/libgfortran.so.5 (0x00007fc769338000)
# 	libevent_core-2.1.so.7 => /lib/x86_64-linux-gnu/libevent_core-2.1.so.7 (0x00007fc770429000)
# 	libevent_pthreads-2.1.so.7 => /lib/x86_64-linux-gnu/libevent_pthreads-2.1.so.7 (0x00007fc770422000)
# 	libquadmath.so.0 => /lib/x86_64-linux-gnu/libquadmath.so.0 (0x00007fc76c855000)
#
#
# PASS: No missing shared libraries detected.
#
# ================================================================================
# PALACE STARTUP TEST
# ================================================================================
#
# STDOUT:
#
# Usage: palace-x86_64.bin [OPTIONS] CONFIG_FILE
#
# Options:
#   -h, --help           Show this help message and exit
#   --version            Show version information and exit
#   -dry-run, --dry-run  Parse configuration file for errors and exit
#
#
#
# STDERR:
#
#
# Return code: 0
#
# ================================================================================
# PALACE INSTALLATION: PASS
# ================================================================================
#
# libCEED is visible.
# Palace shared libraries are resolved.
# Palace executable starts successfully.
#
# NEXT:
# Run the V11 1-mode mesh test.
# Do NOT run the full 8-JJ simulation yet.

# %%
# ============================================================
# PALACE V11 — 1-MODE MESH SANITY TEST
# ============================================================

import os
import subprocess
import time
import shutil

PALACE = (
    "/content/drive/MyDrive/Palace6/"
    "build/bin/palace-x86_64.bin"
)

MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ_v11.msh"
)

CONFIG = (
    "/content/palace_8jj_mesh_read_test_v4.json"
)

OUTPUT = (
    "/content/palace_8jj_mesh_read_test_output"
)

LIBDIR = (
    "/content/drive/MyDrive/Palace6/build/lib"
)


# ============================================================
# CHECK FILES
# ============================================================

print("=" * 80)
print("PALACE V11 — 1 MODE MESH SANITY TEST")
print("=" * 80)

for path in [PALACE, MESH, CONFIG]:

    if not os.path.isfile(path):
        raise FileNotFoundError(
            f"\nRequired file not found:\n{path}"
        )

print("\nAll required files found.")

print(f"\nMesh size: {os.path.getsize(MESH)/(1024**3):.3f} GB")


# ============================================================
# RAM CHECK
# ============================================================

try:

    import psutil

    mem = psutil.virtual_memory()

    print("\nRAM before Palace:")
    print(f"  Total     : {mem.total/(1024**3):.2f} GB")
    print(f"  Available : {mem.available/(1024**3):.2f} GB")
    print(f"  Used      : {mem.used/(1024**3):.2f} GB")

except Exception:

    print("\nRAM information unavailable.")


# ============================================================
# CLEAN OLD OUTPUT
# ============================================================

if os.path.isdir(OUTPUT):

    print("\nRemoving previous test output...")
    shutil.rmtree(OUTPUT)

os.makedirs(OUTPUT, exist_ok=True)


# ============================================================
# ENVIRONMENT
# ============================================================

env = os.environ.copy()

env["LD_LIBRARY_PATH"] = (
    LIBDIR + ":" +
    env.get("LD_LIBRARY_PATH", "")
)

# Keep this test strictly single-process.
env["OMP_NUM_THREADS"] = "1"


print("\nLD_LIBRARY_PATH:")
print(env["LD_LIBRARY_PATH"])

print("\nOMP_NUM_THREADS:")
print(env["OMP_NUM_THREADS"])


# ============================================================
# COMMAND
# ============================================================

cmd = [
    "mpirun",
    "-n", "1",
    "--allow-run-as-root",
    PALACE,
    CONFIG
]

print("\n" + "=" * 80)
print("COMMAND")
print("=" * 80)

print(" ".join(cmd))


# ============================================================
# RUN
# ============================================================

print("\n" + "=" * 80)
print("STARTING PALACE")
print("=" * 80)

start = time.time()

process = subprocess.Popen(
    cmd,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
    env=env
)

try:

    for line in process.stdout:
        print(line, end="", flush=True)

except KeyboardInterrupt:

    print("\n\nInterrupted by user.")

    process.terminate()

    try:
        process.wait(timeout=10)
    except subprocess.TimeoutExpired:
        process.kill()

    raise

return_code = process.wait()

elapsed = time.time() - start


# ============================================================
# FINAL STATUS
# ============================================================

print("\n" + "=" * 80)
print("PALACE 1-MODE TEST RESULT")
print("=" * 80)

print(f"\nReturn code : {return_code}")
print(f"Runtime     : {elapsed/60:.2f} minutes")

print(f"\nOutput:")
print(OUTPUT)


# ============================================================
# RAM AFTER RUN
# ============================================================

try:

    mem = psutil.virtual_memory()

    print("\nRAM after Palace:")
    print(f"  Total     : {mem.total/(1024**3):.2f} GB")
    print(f"  Available : {mem.available/(1024**3):.2f} GB")
    print(f"  Used      : {mem.used/(1024**3):.2f} GB")

except Exception:
    pass


# ============================================================
# RESULT
# ============================================================

if return_code != 0:

    raise RuntimeError(
        "\n"
        "PALACE 1-MODE TEST FAILED.\n"
        "\n"
        "DO NOT RUN THE FULL 8-JJ SIMULATION.\n"
        "Paste the Palace error output."
    )


print("""
============================================================
SUCCESS
============================================================

The V11 mesh passed the Palace 1-mode runtime test.

Next we should inspect:

  1. Eigenfrequency
  2. Solver convergence
  3. Physical-group handling
  4. PEC/JJ treatment
  5. Peak RAM

Only after that should we increase the eigenmode count.
""")
# Out:
# ================================================================================
# PALACE V11 — 1 MODE MESH SANITY TEST
# ================================================================================
#
# All required files found.
#
# Mesh size: 0.819 GB
#
# RAM before Palace:
#   Total     : 50.99 GB
#   Available : 48.95 GB
#   Used      : 1.43 GB
#
# Removing previous test output...
#
# LD_LIBRARY_PATH:
# /content/drive/MyDrive/Palace6/build/lib:
#
# OMP_NUM_THREADS:
# 1
#
# ================================================================================
# COMMAND
# ================================================================================
# mpirun -n 1 --allow-run-as-root /content/drive/MyDrive/Palace6/build/bin/palace-x86_64.bin /content/palace_8jj_mesh_read_test_v4.json
#
# ================================================================================
# STARTING PALACE
# ================================================================================
#
# _____________     _______
# _____   __   \____ __   /____ ____________
# ____   /_/  /  __ ` /  /  __ ` /  ___/  _ \
# ___   _____/  /_/  /  /  /_/  /  /__/  ___/
#   /__/     \___,__/__/\___,__/\_____\_____/
#
# Git changeset ID: v0.17.0-194-g01f5d9bd1
# Running with 1 MPI process, 1 OpenMP thread
# Device configuration: omp,cpu
# Memory configuration: host-std
# libCEED backend: /cpu/self/xsmm/blocked
#
#
# --> Warning!
# 14780 mesh faces with no associated boundary element exist on the domain boundary!
#
# Added 1280585 duplicate vertices for interior boundaries in the mesh
# Added 2560758 duplicate boundary elements for interior boundaries in the mesh
# Added 14780 boundary elements for exterior boundaries to the mesh
#
# Characteristic length and time scales:
#  Lc = 1.400e-02 m, tc = 4.670e-02 ns
# Finished partitioning mesh into 1 subdomain
#
# Mesh curvature order: 1
# Mesh bounding box:
#  (Xmin, Ymin, Zmin) = (-7.000e-03, -7.000e-03, -5.000e-04) m
#  (Xmax, Ymax, Zmax) = (+7.000e-03, +7.000e-03, +5.000e-04) m
#
# Parallel Mesh Stats:
#
#                 minimum     average     maximum       total
#  vertices       3601106     3601106     3601106     3601106
#  edges         20042523    20042523    20042523    20042523
#  faces         30314674    30314674    30314674    30314674
#  elements      13873263    13873263    13873263    13873263
#  neighbors            0           0           0
#
#             minimum     maximum
#  h      1.28214e-05   0.0329914
#  kappa      1.00002     57118.3
#
# Estimated current per-rank memory usage is: Min. 8.1G, Max. 8.1G, Avg. 8.1G, Total 8.1G
# Estimated current per-node memory usage is: Min. 8.1G, Max. 8.1G, Avg. 8.1G, Total 8.1G
#
# Configuring Dirichlet PEC BC at attributes:
#  10
#
# Assembling system matrices, number of global unknowns:
#  H1 (p = 1): 3601106, ND (p = 1): 20042523, RT (p = 1): 30314674
#  Operator assembly level: Partial
#  Mesh geometries:
#   Tetrahedron: P = 6, Q = 4 (quadrature order = 2)
#
# Configuring SLEPc eigenvalue solver:
#  Scaling γ = 9.373e+04, δ = 1.721e-08
#  Configuring divergence-free projection
#  Using random starting vector
#  Shift-and-invert σ = 5.000e+00 GHz (1.467e+00)
#
# Assembling multigrid hierarchy:
#  Level 0 (p = 1): 20042523 unknowns
#  Level 0 (auxiliary) (p = 1): 3601106 unknowns
# --------------------------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code. Per user-direction, the job has been aborted.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# mpirun noticed that process rank 0 with PID 0 on node 83891458f6fe exited on signal 9 (Killed).
# --------------------------------------------------------------------------
#
# ================================================================================
# PALACE 1-MODE TEST RESULT
# ================================================================================
#
# Return code : 137
# Runtime     : 48.17 minutes
#
# Output:
# /content/palace_8jj_mesh_read_test_output
#
# RAM after Palace:
#   Total     : 50.99 GB
#   Available : 49.62 GB
#   Used      : 0.84 GB
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_60066/1873848298.py in <cell line: 0>()
#     204 if return_code != 0:
#     205
# --> 206     raise RuntimeError(
#     207         "\n"
#     208         "PALACE 1-MODE TEST FAILED.\n"
#
# RuntimeError:
# PALACE 1-MODE TEST FAILED.
#
# DO NOT RUN THE FULL 8-JJ SIMULATION.
# Paste the Palace error output.

# %%
# =============================================================================
# 8-JJ GEOMETRY-ONLY VALIDATION
# =============================================================================
# SAFE TEST:
#   - Reads GDS only
#   - Does NOT initialize Gmsh
#   - Does NOT generate a 3D mesh
#   - Does NOT run Palace
#   - Verifies the actual electrode gaps around all 8 JJs
#
# Expected:
#   Each JJ:
#       gap width  ~= 20 um
#       gap height ~= 5 um
#       left/right electrodes on opposite sides of JJ
#       JJ reference centered inside the gap
# =============================================================================

import gdspy
import numpy as np
from shapely.geometry import Polygon, box
from shapely.ops import unary_union

# -----------------------------------------------------------------------------
# PATH
# -----------------------------------------------------------------------------

GDS_FILE = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_export_manuscript.gds"
)

# -----------------------------------------------------------------------------
# JJ LOCATIONS (mm)
# -----------------------------------------------------------------------------

JJ_TARGETS = np.array([
    [-1.132500,  0.000000],   # JJ1
    [-0.867500,  0.000000],   # JJ2
    [ 1.267500,  0.000000],   # JJ3
    [ 1.532500,  0.000000],   # JJ4
    [-1.132500, -2.700000],   # JJ5
    [-0.867500, -2.700000],   # JJ6
    [ 1.267500, -2.700000],   # JJ7
    [ 1.532500, -2.700000],   # JJ8
])

# -----------------------------------------------------------------------------
# PARAMETERS
# -----------------------------------------------------------------------------

# GDS coordinates are converted to mm.
# Do not use the JJ rectangle as a metal subtraction.
#
# We search the actual Layer-1/datatype-10 electrode polygons.

PAD_LAYER = 1
PAD_DATATYPE = 10

JJ_LAYER = 53
JJ_DATATYPE = 0

SEARCH_X = 0.080       # mm
SEARCH_Y = 0.020       # mm

EXPECTED_GAP_X = 0.020 # 20 um
EXPECTED_GAP_Y = 0.005 # 5 um

TOL = 2e-6             # 2 um geometry tolerance

print("=" * 80)
print("8-JJ GDS ELECTRODE/GAP GEOMETRY VALIDATION")
print("=" * 80)

print("\nGDS:")
print(GDS_FILE)

# -----------------------------------------------------------------------------
# READ GDS
# -----------------------------------------------------------------------------

print("\nReading GDS...")

gds = gdspy.GdsLibrary(infile=GDS_FILE)

print(f"Loaded {len(gds.cells)} cells.")

# Find top-level cell
top_cells = gds.top_level()

if len(top_cells) == 0:
    raise RuntimeError("No top-level GDS cell found.")

top = top_cells[0]

print(f"Using top cell: {top.name}")

# -----------------------------------------------------------------------------
# EXTRACT POLYGONS
# -----------------------------------------------------------------------------

print("\nExtracting Layer 1 / datatype 10 electrode polygons...")

raw_pad_polys = []

for polyset in top.get_polygons(
    by_spec=True
).get((PAD_LAYER, PAD_DATATYPE), []):
    pass
# Out:
# ================================================================================
# 8-JJ GDS ELECTRODE/GAP GEOMETRY VALIDATION
# ================================================================================
#
# GDS:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds
#
# Reading GDS...
# Loaded 19 cells.
# Using top cell: FakeJunction_01
#
# Extracting Layer 1 / datatype 10 electrode polygons...

# %%
# =============================================================================
# 8-JJ GDS ELECTRODE/GAP VALIDATION - CORRECT TOP CELL
# =============================================================================
# SAFE:
#   - GDS geometry inspection only
#   - NO Gmsh
#   - NO 3D mesh
#   - NO Palace
#
# Purpose:
#   Verify the REAL 20 um x 5 um JJ gaps using the actual electrode geometry.
# =============================================================================

import gdspy
import numpy as np
from shapely.geometry import Polygon, box
from shapely.ops import unary_union

# -----------------------------------------------------------------------------
# FILE
# -----------------------------------------------------------------------------

GDS_FILE = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_export_manuscript.gds"
)

# -----------------------------------------------------------------------------
# IMPORTANT: ACTUAL CHIP TOP CELL
# -----------------------------------------------------------------------------

TOP_CELL_NAME = "TOP_main_1"

# -----------------------------------------------------------------------------
# LAYER INFORMATION
# -----------------------------------------------------------------------------

MAIN_LAYER = 1
MAIN_DATATYPE = 0

PAD_LAYER = 1
PAD_DATATYPE = 10

JJ_LAYER = 53
JJ_DATATYPE = 0

# -----------------------------------------------------------------------------
# EXPECTED JJ LOCATIONS (mm)
# -----------------------------------------------------------------------------

JJ_TARGETS = np.array([
    [-1.132500,  0.000000],   # JJ1
    [-0.867500,  0.000000],   # JJ2
    [ 1.267500,  0.000000],   # JJ3
    [ 1.532500,  0.000000],   # JJ4
    [-1.132500, -2.700000],   # JJ5
    [-0.867500, -2.700000],   # JJ6
    [ 1.267500, -2.700000],   # JJ7
    [ 1.532500, -2.700000],   # JJ8
])

EXPECTED_GAP_X = 0.020   # mm = 20 um
EXPECTED_GAP_Y = 0.005   # mm = 5 um

JJ_TOL = 0.005           # mm = 5 um
PAD_SEARCH_X = 0.060     # mm
PAD_SEARCH_Y = 0.020     # mm

print("=" * 80)
print("8-JJ GDS ELECTRODE/GAP GEOMETRY VALIDATION")
print("=" * 80)

print("\nGDS:")
print(GDS_FILE)

# =============================================================================
# READ GDS
# =============================================================================

print("\nReading GDS...")

gds = gdspy.GdsLibrary(infile=GDS_FILE)

print(f"Loaded {len(gds.cells)} cells.")

# =============================================================================
# SHOW TOP-LEVEL CELLS
# =============================================================================

print("\nAvailable top-level cells:")

top_cells = gds.top_level()

for c in top_cells:
    print("  ", c.name)

# =============================================================================
# FORCE CORRECT CHIP CELL
# =============================================================================

if TOP_CELL_NAME not in gds.cells:
    raise RuntimeError(
        f"Required chip cell '{TOP_CELL_NAME}' was not found.\n"
        f"Available cells include:\n"
        + "\n".join(sorted(gds.cells.keys()))
    )

top = gds.cells[TOP_CELL_NAME]

print("\nUsing chip cell:")
print(" ", top.name)

if top.name != TOP_CELL_NAME:
    raise RuntimeError("Wrong GDS cell selected.")

# =============================================================================
# EXTRACT POLYGONS INCLUDING REFERENCES
# =============================================================================
#
# get_polygons(by_spec=True) resolves cell references when called on the
# selected top cell.
# =============================================================================

print("\nExtracting polygons from TOP_main_1...")

polys_by_spec = top.get_polygons(
    by_spec=True,
    depth=None
)

print(f"Number of layer/datatype specifications: {len(polys_by_spec)}")

# =============================================================================
# HELPER
# =============================================================================

def get_polygons(spec):
    """Return polygons for a given (layer, datatype)."""
    arr = polys_by_spec.get(spec, [])

    result = []

    for p in arr:
        p = np.asarray(p, dtype=float)

        if len(p) < 3:
            continue

        try:
            shp = Polygon(p)

            if not shp.is_valid:
                shp = shp.buffer(0)

            if not shp.is_empty and shp.area > 0:
                result.append(shp)

        except Exception:
            continue

    return result


# =============================================================================
# MAIN METAL
# =============================================================================

main_polys = get_polygons(
    (MAIN_LAYER, MAIN_DATATYPE)
)

print("\nMain metal polygons:")
print(" ", len(main_polys))

if len(main_polys) == 0:
    raise RuntimeError(
        "No Layer 1 / datatype 0 polygons found in TOP_main_1."
    )

main_union = unary_union(main_polys)

print("Main metal geometry:", main_union.geom_type)
print(
    "Main metal area:",
    f"{main_union.area:.12f}",
    "mm²"
)

# =============================================================================
# PAD POLYGONS
# =============================================================================

pad_polys = get_polygons(
    (PAD_LAYER, PAD_DATATYPE)
)

print("\nLayer 1 / datatype 10 polygons:")
print(" ", len(pad_polys))

if len(pad_polys) == 0:
    raise RuntimeError(
        "No Layer 1 / datatype 10 electrode polygons found."
    )

# =============================================================================
# JJ POLYGONS
# =============================================================================

jj_polys = get_polygons(
    (JJ_LAYER, JJ_DATATYPE)
)

print("\nLayer 53 / datatype 0 polygons:")
print(" ", len(jj_polys))

if len(jj_polys) != 8:
    raise RuntimeError(
        f"Expected 8 JJ polygons, found {len(jj_polys)}."
    )

# =============================================================================
# MATCH JJ POLYGONS TO EXPECTED LOCATIONS
# =============================================================================

print("\n" + "=" * 80)
print("MATCHING JJ REFERENCES")
print("=" * 80)

matched_jj = []

unused = list(jj_polys)

for i, target in enumerate(JJ_TARGETS):

    best = None
    best_dist = float("inf")

    for poly in unused:

        c = poly.centroid

        d = np.hypot(
            c.x - target[0],
            c.y - target[1]
        )

        if d < best_dist:
            best_dist = d
            best = poly

    if best is None:
        raise RuntimeError(
            f"Could not match JJ{i+1}."
        )

    if best_dist > JJ_TOL:
        raise RuntimeError(
            f"JJ{i+1} mismatch: "
            f"{best_dist*1000:.3f} um"
        )

    unused.remove(best)

    matched_jj.append(best)

    c = best.centroid

    print(
        f"JJ{i+1}: "
        f"centroid=({c.x:.6f}, {c.y:.6f}) mm, "
        f"error={best_dist*1000:.3f} um, "
        f"area={best.area:.9e} mm²"
    )

# =============================================================================
# FIND TWO ACTUAL ELECTRODE PADS FOR EACH JJ
# =============================================================================

print("\n" + "=" * 80)
print("IDENTIFYING ACTUAL JJ ELECTRODE PAIRS")
print("=" * 80)

all_results = []

for i, (jj, target) in enumerate(
    zip(matched_jj, JJ_TARGETS),
    start=1
):

    x0, y0 = target

    candidates = []

    # Search only actual pad polygons near the JJ.
    for pad in pad_polys:

        minx, miny, maxx, maxy = pad.bounds

        cx = pad.centroid.x
        cy = pad.centroid.y

        if (
            abs(cx - x0) <= PAD_SEARCH_X
            and abs(cy - y0) <= PAD_SEARCH_Y
        ):
            candidates.append(pad)

    print(f"\nJJ{i}: {len(candidates)} nearby pad candidates")

    # -------------------------------------------------------------------------
    # For these JJs the electrodes are horizontal and separated in X.
    # -------------------------------------------------------------------------

    left_candidates = [
        p for p in candidates
        if p.centroid.x < x0
    ]

    right_candidates = [
        p for p in candidates
        if p.centroid.x > x0
    ]

    if len(left_candidates) == 0:
        raise RuntimeError(
            f"JJ{i}: no left electrode candidate found."
        )

    if len(right_candidates) == 0:
        raise RuntimeError(
            f"JJ{i}: no right electrode candidate found."
        )

    # Closest electrode to JJ center
    left = min(
        left_candidates,
        key=lambda p: abs(p.centroid.x - x0)
    )

    right = min(
        right_candidates,
        key=lambda p: abs(p.centroid.x - x0)
    )

    lb = left.bounds
    rb = right.bounds

    # -------------------------------------------------------------------------
    # Actual gap
    # -------------------------------------------------------------------------

    gap_left = lb[2]
    gap_right = rb[0]

    gap_bottom = max(lb[1], rb[1])
    gap_top = min(lb[3], rb[3])

    gap_width = gap_right - gap_left
    gap_height = gap_top - gap_bottom

    print("  LEFT electrode :")
    print("   ", lb)

    print("  RIGHT electrode:")
    print("   ", rb)

    print(
        f"  Actual gap width : {gap_width*1000:.3f} um"
    )

    print(
        f"  Actual gap height: {gap_height*1000:.3f} um"
    )

    # =============================================================================
    # CRITICAL CHECKS
    # =============================================================================

    if gap_width <= 0:
        raise RuntimeError(
            f"JJ{i}: electrodes overlap in X."
        )

    if gap_height <= 0:
        raise RuntimeError(
            f"JJ{i}: electrodes do not overlap in Y."
        )

    # Gap center
    gap_cx = 0.5 * (gap_left + gap_right)
    gap_cy = 0.5 * (gap_bottom + gap_top)

    center_error = np.hypot(
        gap_cx - x0,
        gap_cy - y0
    )

    print(
        f"  Gap center: "
        f"({gap_cx:.6f}, {gap_cy:.6f}) mm"
    )

    print(
        f"  Gap-center error: "
        f"{center_error*1000:.3f} um"
    )

    # -------------------------------------------------------------------------
    # Expected dimensions
    # -------------------------------------------------------------------------

    width_error = abs(
        gap_width - EXPECTED_GAP_X
    )

    height_error = abs(
        gap_height - EXPECTED_GAP_Y
    )

    if width_error > 2e-6:
        raise RuntimeError(
            f"JJ{i}: gap width is "
            f"{gap_width*1000:.3f} um, "
            f"not approximately 20 um."
        )

    if height_error > 2e-6:
        raise RuntimeError(
            f"JJ{i}: gap height is "
            f"{gap_height*1000:.3f} um, "
            f"not approximately 5 um."
        )

    if center_error > 2e-6:
        raise RuntimeError(
            f"JJ{i}: JJ is not centered in the actual electrode gap."
        )

    # =============================================================================
    # MOST IMPORTANT TEST:
    # CHECK THAT THE GAP ITSELF IS EMPTY OF MAIN METAL
    # =============================================================================

    gap_region = box(
        gap_left,
        gap_bottom,
        gap_right,
        gap_top
    )

    metal_inside_gap = main_union.intersection(
        gap_region
    ).area

    print(
        f"  Main-metal area inside gap: "
        f"{metal_inside_gap:.9e} mm²"
    )

    # Tiny floating-point intersection is acceptable.
    if metal_inside_gap > 1e-10:
        raise RuntimeError(
            f"JJ{i}: main metal exists inside the physical JJ gap."
        )

    print("  PASS: actual electrode gap verified.")

    all_results.append({
        "jj": i,
        "left": left,
        "right": right,
        "gap": gap_region,
        "gap_width": gap_width,
        "gap_height": gap_height,
        "center_error": center_error,
    })

# =============================================================================
# FINAL SUMMARY
# =============================================================================

print("\n")
print("=" * 80)
print("FINAL 8-JJ GEOMETRY VALIDATION")
print("=" * 80)

print()

for r in all_results:

    print(
        f"JJ{r['jj']}: "
        f"gap={r['gap_width']*1000:.3f} x "
        f"{r['gap_height']*1000:.3f} um, "
        f"center error={r['center_error']*1000:.3f} um"
    )

print("\n" + "=" * 80)
print("RESULT")
print("=" * 80)

print("""
PASS: All 8 JJ locations match the GDS.

PASS: All 8 JJs have two real electrode pads.

PASS: The electrode gaps are determined from the actual
      GDS electrode geometry rather than artificially subtracting
      a rectangle from the unified metal.

PASS: Main superconducting metal does not occupy the physical
      JJ gaps.

PASS: Geometry is suitable for the NEXT stage:
      constructing conformal silicon/vacuum + PEC + JJ surfaces.

IMPORTANT:
Do NOT run Palace yet.
Do NOT generate a 3D mesh yet.

The next mesh generator should use these actual gap polygons
directly as JJ surfaces.
""")
# Out:
# ================================================================================
# 8-JJ GDS ELECTRODE/GAP GEOMETRY VALIDATION
# ================================================================================
#
# GDS:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds
#
# Reading GDS...
# Loaded 19 cells.
#
# Available top-level cells:
#    TOP
#    FakeJunction_02
#    FakeJunction_01
#
# Using chip cell:
#   TOP_main_1
#
# Extracting polygons from TOP_main_1...
# Number of layer/datatype specifications: 7
#
# Main metal polygons:
#   2450
# Main metal geometry: Polygon
# Main metal area: 185.750736791720 mm²
#
# Layer 1 / datatype 10 polygons:
#   90
#
# Layer 53 / datatype 0 polygons:
#   8
#
# ================================================================================
# MATCHING JJ REFERENCES
# ================================================================================
# JJ1: centroid=(-1.132500, 0.000000) mm, error=0.000 um, area=9.000000000e-05 mm²
# JJ2: centroid=(-0.867500, -0.000000) mm, error=0.000 um, area=9.000000000e-05 mm²
# JJ3: centroid=(1.267500, 0.000000) mm, error=0.000 um, area=9.000000000e-05 mm²
# JJ4: centroid=(1.532500, -0.000000) mm, error=0.000 um, area=9.000000000e-05 mm²
# JJ5: centroid=(-1.132500, -2.700000) mm, error=0.000 um, area=9.000000000e-05 mm²
# JJ6: centroid=(-0.867500, -2.700000) mm, error=0.000 um, area=9.000000000e-05 mm²
# JJ7: centroid=(1.267500, -2.700000) mm, error=0.000 um, area=9.000000000e-05 mm²
# JJ8: centroid=(1.532500, -2.700000) mm, error=0.000 um, area=9.000000000e-05 mm²
#
# ================================================================================
# IDENTIFYING ACTUAL JJ ELECTRODE PAIRS
# ================================================================================
#
# JJ1: 2 nearby pad candidates
#   LEFT electrode :
#     (-1.15, -0.0024999999999999988, -1.1424999999999998, 0.0025000000000000022)
#   RIGHT electrode:
#     (-1.1224999999999998, -0.0025000000000000022, -1.1149999999999998, 0.0024999999999999988)
#   Actual gap width : 20.000 um
#   Actual gap height: 5.000 um
#   Gap center: (-1.132500, 0.000000) mm
#   Gap-center error: 0.000 um
#   Main-metal area inside gap: 0.000000000e+00 mm²
#   PASS: actual electrode gap verified.
#
# JJ2: 2 nearby pad candidates
#   LEFT electrode :
#     (-0.8849999999999999, -0.0025, -0.8775, 0.0025)
#   RIGHT electrode:
#     (-0.8574999999999999, -0.0025, -0.85, 0.0025)
#   Actual gap width : 20.000 um
#   Actual gap height: 5.000 um
#   Gap center: (-0.867500, 0.000000) mm
#   Gap-center error: 0.000 um
#   Main-metal area inside gap: 0.000000000e+00 mm²
#   PASS: actual electrode gap verified.
#
# JJ3: 2 nearby pad candidates
#   LEFT electrode :
#     (1.2499999999999998, -0.0024999999999999988, 1.2574999999999998, 0.0025000000000000022)
#   RIGHT electrode:
#     (1.2774999999999999, -0.0025000000000000022, 1.285, 0.0024999999999999988)
#   Actual gap width : 20.000 um
#   Actual gap height: 5.000 um
#   Gap center: (1.267500, 0.000000) mm
#   Gap-center error: 0.000 um
#   Main-metal area inside gap: 0.000000000e+00 mm²
#   PASS: actual electrode gap verified.
#
# JJ4: 2 nearby pad candidates
#   LEFT electrode :
#     (1.515, -0.0025, 1.5225, 0.0025)
#   RIGHT electrode:
#     (1.5425, -0.0025, 1.55, 0.0025)
#   Actual gap width : 20.000 um
#   Actual gap height: 5.000 um
#   Gap center: (1.532500, 0.000000) mm
#   Gap-center error: 0.000 um
#   Main-metal area inside gap: 0.000000000e+00 mm²
#   PASS: actual electrode gap verified.
#
# JJ5: 2 nearby pad candidates
#   LEFT electrode :
#     (-1.15, -2.7024999999999997, -1.1424999999999998, -2.6975)
#   RIGHT electrode:
#     (-1.1224999999999998, -2.7024999999999997, -1.1149999999999998, -2.6975)
#   Actual gap width : 20.000 um
#   Actual gap height: 5.000 um
#   Gap center: (-1.132500, -2.700000) mm
#   Gap-center error: 0.000 um
#   Main-metal area inside gap: 0.000000000e+00 mm²
#   PASS: actual electrode gap verified.
#
# JJ6: 2 nearby pad candidates
#   LEFT electrode :
#     (-0.8849999999999999, -2.7024999999999997, -0.8775, -2.6975)
#   RIGHT electrode:
#     (-0.8574999999999999, -2.7024999999999997, -0.85, -2.6975)
#   Actual gap width : 20.000 um
#   Actual gap height: 5.000 um
#   Gap center: (-0.867500, -2.700000) mm
#   Gap-center error: 0.000 um
#   Main-metal area inside gap: 0.000000000e+00 mm²
#   PASS: actual electrode gap verified.
#
# JJ7: 2 nearby pad candidates
#   LEFT electrode :
#     (1.2499999999999998, -2.7024999999999997, 1.2574999999999998, -2.6975)
#   RIGHT electrode:
#     (1.2774999999999999, -2.7024999999999997, 1.285, -2.6975)
#   Actual gap width : 20.000 um
#   Actual gap height: 5.000 um
#   Gap center: (1.267500, -2.700000) mm
#   Gap-center error: 0.000 um
#   Main-metal area inside gap: 0.000000000e+00 mm²
#   PASS: actual electrode gap verified.
#
# JJ8: 2 nearby pad candidates
#   LEFT electrode :
#     (1.515, -2.7024999999999997, 1.5225, -2.6975)
#   RIGHT electrode:
#     (1.5425, -2.7024999999999997, 1.55, -2.6975)
#   Actual gap width : 20.000 um
#   Actual gap height: 5.000 um
#   Gap center: (1.532500, -2.700000) mm
#   Gap-center error: 0.000 um
#   Main-metal area inside gap: 0.000000000e+00 mm²
#   PASS: actual electrode gap verified.
#
#
# ================================================================================
# FINAL 8-JJ GEOMETRY VALIDATION
# ================================================================================
#
# JJ1: gap=20.000 x 5.000 um, center error=0.000 um
# JJ2: gap=20.000 x 5.000 um, center error=0.000 um
# JJ3: gap=20.000 x 5.000 um, center error=0.000 um
# JJ4: gap=20.000 x 5.000 um, center error=0.000 um
# JJ5: gap=20.000 x 5.000 um, center error=0.000 um
# JJ6: gap=20.000 x 5.000 um, center error=0.000 um
# JJ7: gap=20.000 x 5.000 um, center error=0.000 um
# JJ8: gap=20.000 x 5.000 um, center error=0.000 um
#
# ================================================================================
# RESULT
# ================================================================================
#
# PASS: All 8 JJ locations match the GDS.
#
# PASS: All 8 JJs have two real electrode pads.
#
# PASS: The electrode gaps are determined from the actual
#       GDS electrode geometry rather than artificially subtracting
#       a rectangle from the unified metal.
#
# PASS: Main superconducting metal does not occupy the physical
#       JJ gaps.
#
# PASS: Geometry is suitable for the NEXT stage:
#       constructing conformal silicon/vacuum + PEC + JJ surfaces.
#
# IMPORTANT:
# Do NOT run Palace yet.
# Do NOT generate a 3D mesh yet.
#
# The next mesh generator should use these actual gap polygons
# directly as JJ surfaces.

# %%
# =============================================================================
# ROBUST 8-JJ CONFORMAL PALACE MESH - V12
# =============================================================================
#
# IMPORTANT:
#   This version uses the ACTUAL EMPTY JJ GAPS found in the GDS.
#
#   It does NOT:
#       - subtract a fake JJ rectangle from unified metal
#       - modify the metal geometry using JJ references
#       - run Palace
#
#   It creates:
#       - silicon substrate
#       - vacuum
#       - superconducting PEC surfaces
#       - 8 physical JJ surfaces occupying the real 20 x 5 um gaps
#
#   RAM SAFETY:
#       - coarse bulk mesh
#       - local JJ refinement
#       - hard tetrahedron safety limit
#       - no Palace execution
#
# =============================================================================

import os
import gc
import gdspy
import gmsh
import numpy as np

from shapely.geometry import Polygon
from shapely.ops import unary_union

# =============================================================================
# PATHS
# =============================================================================

GDS_FILE = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_export_manuscript.gds"
)

OUTPUT_MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ_v12.msh"
)

# =============================================================================
# GDS
# =============================================================================

TOP_CELL_NAME = "TOP_main_1"

MAIN_LAYER = 1
MAIN_DATATYPE = 0

PAD_LAYER = 1
PAD_DATATYPE = 10

JJ_LAYER = 53
JJ_DATATYPE = 0

# =============================================================================
# JJ LOCATIONS
# =============================================================================

JJ_TARGETS = np.array([
    [-1.132500,  0.000000],
    [-0.867500,  0.000000],
    [ 1.267500,  0.000000],
    [ 1.532500,  0.000000],
    [-1.132500, -2.700000],
    [-0.867500, -2.700000],
    [ 1.267500, -2.700000],
    [ 1.532500, -2.700000],
])

# =============================================================================
# GEOMETRY / MESH PARAMETERS
# =============================================================================
#
# Units here are mm because GDS geometry is in mm.
#
# 500 um bulk = 0.500 mm
# 50  um JJ   = 0.050 mm
#
# This is intentionally coarse because your previous 13.9M tetrahedral mesh
# required ~8 GB just to reach the eigenvalue stage and was killed by Colab.
# =============================================================================

BULK_SIZE = 0.500       # mm = 500 um
JJ_SIZE   = 0.050       # mm = 50 um

# Substrate/vacuum dimensions
CHIP_X = 14.0           # mm
CHIP_Y = 14.0           # mm

SUBSTRATE_THICKNESS = 0.500   # mm
VACUUM_HEIGHT       = 0.500   # mm

Z_INTERFACE = 0.0

# Hard safety limit
MAX_TETS = 4_000_000

# =============================================================================
# TOLERANCES
# =============================================================================

JJ_MATCH_TOL = 0.005     # mm = 5 um
AREA_TOL = 1e-10

# =============================================================================
# HELPERS
# =============================================================================

def polygon_list_from_spec(spec_dict, spec):
    """Convert gdspy polygon arrays to valid Shapely polygons."""

    arr = spec_dict.get(spec, [])

    result = []

    for p in arr:

        p = np.asarray(p, dtype=float)

        if len(p) < 3:
            continue

        try:
            shp = Polygon(p)

            if not shp.is_valid:
                shp = shp.buffer(0)

            if shp.is_empty:
                continue

            if shp.area <= AREA_TOL:
                continue

            result.append(shp)

        except Exception:
            continue

    return result


def shapely_to_loops(geom):
    """
    Convert Polygon/MultiPolygon to exterior coordinate loops.
    Coordinates are in mm.
    """

    loops = []

    if geom.is_empty:
        return loops

    if geom.geom_type == "Polygon":

        loops.append(
            np.asarray(
                geom.exterior.coords,
                dtype=float
            )
        )

    elif geom.geom_type == "MultiPolygon":

        for poly in geom.geoms:

            if poly.is_empty:
                continue

            loops.append(
                np.asarray(
                    poly.exterior.coords,
                    dtype=float
                )
            )

    else:
        raise RuntimeError(
            f"Unsupported geometry type: {geom.geom_type}"
        )

    return loops


def add_planar_surface_from_loop(points, z=0.0):

    point_tags = []

    for x, y in points:

        point_tags.append(
            gmsh.model.geo.addPoint(
                float(x),
                float(y),
                float(z)
            )
        )

    line_tags = []

    for i in range(len(point_tags) - 1):

        a = point_tags[i]
        b = point_tags[i + 1]

        if a == b:
            continue

        line_tags.append(
            gmsh.model.geo.addLine(a, b)
        )

    if len(line_tags) < 3:
        raise RuntimeError(
            "Could not create a valid polygon boundary."
        )

    curve_loop = gmsh.model.geo.addCurveLoop(
        line_tags
    )

    surface = gmsh.model.geo.addPlaneSurface(
        [curve_loop]
    )

    return surface


# =============================================================================
# HEADER
# =============================================================================

print("=" * 80)
print("ROBUST 8-JJ CONFORMAL PALACE MESH - V12")
print("=" * 80)

print("\nGDS:")
print(GDS_FILE)

print("\nOutput:")
print(OUTPUT_MESH)

print("\nMesh parameters:")
print(f"  Bulk = {BULK_SIZE*1000:.0f} um")
print(f"  JJ   = {JJ_SIZE*1000:.0f} um")

# =============================================================================
# READ GDS
# =============================================================================

print("\n" + "=" * 80)
print("READING GDS")
print("=" * 80)

gds = gdspy.GdsLibrary(
    infile=GDS_FILE
)

print(
    f"Loaded {len(gds.cells)} cells."
)

if TOP_CELL_NAME not in gds.cells:
    raise RuntimeError(
        f"Required cell {TOP_CELL_NAME} not found."
    )

top = gds.cells[TOP_CELL_NAME]

print(
    f"Using top cell: {top.name}"
)

# =============================================================================
# EXTRACT TOP-CELL POLYGONS
# =============================================================================

specs = top.get_polygons(
    by_spec=True,
    depth=None
)

# =============================================================================
# MAIN METAL
# =============================================================================

print("\nExtracting main superconducting metal...")

main_polys = polygon_list_from_spec(
    specs,
    (MAIN_LAYER, MAIN_DATATYPE)
)

print(
    f"Main metal polygons: {len(main_polys)}"
)

if not main_polys:
    raise RuntimeError(
        "No main metal polygons found."
    )

print("Uniting main metal...")

main_metal = unary_union(
    main_polys
)

print(
    "Main metal geometry:",
    main_metal.geom_type
)

print(
    f"Main metal area: "
    f"{main_metal.area:.12f} mm²"
)

# =============================================================================
# JJ REFERENCES
# =============================================================================

print("\nExtracting JJ reference polygons...")

jj_polys = polygon_list_from_spec(
    specs,
    (JJ_LAYER, JJ_DATATYPE)
)

print(
    f"JJ polygons found: {len(jj_polys)}"
)

if len(jj_polys) != 8:
    raise RuntimeError(
        f"Expected 8 JJ polygons, found {len(jj_polys)}."
    )

# =============================================================================
# MATCH JJ REFERENCES
# =============================================================================

print("\nMatching JJ references...")

unused_jj = list(jj_polys)
matched_jj = []

for i, target in enumerate(
    JJ_TARGETS,
    start=1
):

    best = None
    best_distance = float("inf")

    for poly in unused_jj:

        c = poly.centroid

        d = np.hypot(
            c.x - target[0],
            c.y - target[1]
        )

        if d < best_distance:

            best_distance = d
            best = poly

    if best is None:
        raise RuntimeError(
            f"JJ{i} could not be matched."
        )

    if best_distance > JJ_MATCH_TOL:

        raise RuntimeError(
            f"JJ{i} mismatch: "
            f"{best_distance*1000:.3f} um"
        )

    unused_jj.remove(best)
    matched_jj.append(best)

    c = best.centroid

    print(
        f"JJ{i}: "
        f"centroid=({c.x:.6f}, {c.y:.6f}) mm, "
        f"error={best_distance*1000:.3f} um"
    )

# =============================================================================
# EXTRACT ACTUAL ELECTRODE PADS
# =============================================================================

print("\nExtracting actual JJ electrode pads...")

pad_polys = polygon_list_from_spec(
    specs,
    (PAD_LAYER, PAD_DATATYPE)
)

print(
    f"Pad polygons: {len(pad_polys)}"
)

if len(pad_polys) == 0:
    raise RuntimeError(
        "No Layer 1 / datatype 10 pads found."
    )

# =============================================================================
# IDENTIFY ACTUAL JJ GAPS
# =============================================================================

print("\n" + "=" * 80)
print("IDENTIFYING ACTUAL JJ GAPS")
print("=" * 80)

jj_gaps = []

for i, target in enumerate(
    JJ_TARGETS,
    start=1
):

    x0, y0 = target

    nearby = []

    for pad in pad_polys:

        cx = pad.centroid.x
        cy = pad.centroid.y

        if (
            abs(cx - x0) < 0.060
            and
            abs(cy - y0) < 0.020
        ):
            nearby.append(pad)

    left_candidates = [
        p for p in nearby
        if p.centroid.x < x0
    ]

    right_candidates = [
        p for p in nearby
        if p.centroid.x > x0
    ]

    if not left_candidates or not right_candidates:

        raise RuntimeError(
            f"JJ{i}: could not find both electrodes."
        )

    left = min(
        left_candidates,
        key=lambda p:
        abs(p.centroid.x - x0)
    )

    right = min(
        right_candidates,
        key=lambda p:
        abs(p.centroid.x - x0)
    )

    lb = left.bounds
    rb = right.bounds

    gap_left = lb[2]
    gap_right = rb[0]

    gap_bottom = max(
        lb[1],
        rb[1]
    )

    gap_top = min(
        lb[3],
        rb[3]
    )

    gap_width = gap_right - gap_left
    gap_height = gap_top - gap_bottom

    gap_cx = 0.5 * (
        gap_left + gap_right
    )

    gap_cy = 0.5 * (
        gap_bottom + gap_top
    )

    center_error = np.hypot(
        gap_cx - x0,
        gap_cy - y0
    )

    print(
        f"JJ{i}: "
        f"{gap_width*1000:.3f} x "
        f"{gap_height*1000:.3f} um, "
        f"center error="
        f"{center_error*1000:.3f} um"
    )

    if gap_width <= 0 or gap_height <= 0:

        raise RuntimeError(
            f"JJ{i}: invalid physical gap."
        )

    if abs(gap_width - 0.020) > 2e-6:

        raise RuntimeError(
            f"JJ{i}: unexpected gap width."
        )

    if abs(gap_height - 0.005) > 2e-6:

        raise RuntimeError(
            f"JJ{i}: unexpected gap height."
        )

    if center_error > 2e-6:

        raise RuntimeError(
            f"JJ{i}: gap is not centered on JJ."
        )

    # The JJ is the actual EMPTY region.
    jj_gap = Polygon([
        (gap_left,  gap_bottom),
        (gap_right, gap_bottom),
        (gap_right, gap_top),
        (gap_left,  gap_top),
    ])

    jj_gaps.append(jj_gap)

print(
    "\nPASS: all 8 physical JJ gaps recovered."
)

# =============================================================================
# IMPORTANT:
# WE DO NOT SUBTRACT JJ GAPS FROM MAIN METAL.
# THE GAPS ARE ALREADY EMPTY IN THE GDS.
# =============================================================================

print("\nNo artificial JJ subtraction will be performed.")

# =============================================================================
# INITIALIZE GMSH
# =============================================================================

print("\n" + "=" * 80)
print("INITIALIZING GMSH")
print("=" * 80)

gmsh.initialize()

try:

    gmsh.option.setNumber(
        "General.Terminal",
        1
    )

    gmsh.model.add(
        "palace_8JJ_v12"
    )

    # =========================================================================
    # CREATE SILICON + VACUUM
    # =========================================================================

    print("\nCreating silicon substrate...")

    sx = CHIP_X / 2
    sy = CHIP_Y / 2

    silicon = gmsh.model.occ.addBox(
        -sx,
        -sy,
        -SUBSTRATE_THICKNESS,
        CHIP_X,
        CHIP_Y,
        SUBSTRATE_THICKNESS
    )

    print("Creating vacuum...")

    vacuum = gmsh.model.occ.addBox(
        -sx,
        -sy,
        0.0,
        CHIP_X,
        CHIP_Y,
        VACUUM_HEIGHT
    )

    # =========================================================================
    # CREATE METAL SURFACES
    # =========================================================================

    print("\nCreating superconducting metal surfaces...")

    metal_loops = shapely_to_loops(
        main_metal
    )

    metal_surfaces = []

    # Use OCC geometry for robust surface construction.
    for loop in metal_loops:

        if len(loop) < 4:
            continue

        pts = []

        for x, y in loop:

            pts.append(
                gmsh.model.occ.addPoint(
                    float(x),
                    float(y),
                    0.0
                )
            )

        lines = []

        for k in range(len(pts) - 1):

            lines.append(
                gmsh.model.occ.addLine(
                    pts[k],
                    pts[k + 1]
                )
            )

        if len(lines) < 3:
            continue

        cl = gmsh.model.occ.addCurveLoop(
            lines
        )

        sf = gmsh.model.occ.addPlaneSurface(
            [cl]
        )

        metal_surfaces.append(sf)

    print(
        f"Metal surfaces created: "
        f"{len(metal_surfaces)}"
    )

    if not metal_surfaces:
        raise RuntimeError(
            "No superconducting metal surface created."
        )

    # =========================================================================
    # CREATE JJ SURFACES
    # =========================================================================

    print("\nCreating physical JJ surfaces...")

    jj_surface_tags = []

    for i, gap in enumerate(
        jj_gaps,
        start=1
    ):

        coords = np.asarray(
            gap.exterior.coords,
            dtype=float
        )

        pts = []

        for x, y in coords:

            pts.append(
                gmsh.model.occ.addPoint(
                    float(x),
                    float(y),
                    0.0
                )
            )

        lines = []

        for k in range(len(pts) - 1):

            lines.append(
                gmsh.model.occ.addLine(
                    pts[k],
                    pts[k + 1]
                )
            )

        cl = gmsh.model.occ.addCurveLoop(
            lines
        )

        sf = gmsh.model.occ.addPlaneSurface(
            [cl]
        )

        jj_surface_tags.append(sf)

        print(
            f"JJ{i}: surface={sf}"
        )

    # =========================================================================
    # SYNCHRONIZE
    # =========================================================================

    print("\nSynchronizing OCC...")

    gmsh.model.occ.synchronize()

    # =========================================================================
    # FRAGMENT SILICON/VACUUM WITH INTERFACE GEOMETRY
    # =========================================================================
    #
    # We fragment only the 3D substrate/vacuum volumes.
    # Metal and JJ surfaces remain explicit 2-D entities.
    # This avoids the previous aggressive fragmentation failures.
    # =========================================================================

    print(
        "\nFragmenting silicon/vacuum volumes..."
    )

    objects = [
        (3, silicon),
        (3, vacuum)
    ]

    fragmented, _ = gmsh.model.occ.fragment(
        objects,
        []
    )

    gmsh.model.occ.synchronize()

    # =========================================================================
    # IDENTIFY 3D VOLUMES
    # =========================================================================

    volumes = gmsh.model.getEntities(
        3
    )

    print(
        f"\n3D volumes found: {len(volumes)}"
    )

    if len(volumes) != 2:

        raise RuntimeError(
            f"Expected 2 volumes, found {len(volumes)}."
        )

    silicon_volumes = []
    vacuum_volumes = []

    for dim, tag in volumes:

        com = gmsh.model.occ.getCenterOfMass(
            dim,
            tag
        )

        if com[2] < 0:

            silicon_volumes.append(tag)

        elif com[2] > 0:

            vacuum_volumes.append(tag)

    print(
        "Silicon volumes:",
        silicon_volumes
    )

    print(
        "Vacuum volumes:",
        vacuum_volumes
    )

    if len(silicon_volumes) != 1:

        raise RuntimeError(
            "Could not uniquely identify silicon."
        )

    if len(vacuum_volumes) != 1:

        raise RuntimeError(
            "Could not uniquely identify vacuum."
        )

    # =========================================================================
    # PHYSICAL GROUPS
    # =========================================================================

    print(
        "\nCreating physical groups..."
    )

    silicon_group = gmsh.model.addPhysicalGroup(
        3,
        silicon_volumes,
        2
    )

    gmsh.model.setPhysicalName(
        3,
        silicon_group,
        "Silicon_Substrate"
    )

    vacuum_group = gmsh.model.addPhysicalGroup(
        3,
        vacuum_volumes,
        1
    )

    gmsh.model.setPhysicalName(
        3,
        vacuum_group,
        "Vacuum"
    )

    # -------------------------------------------------------------------------
    # PEC group
    # -------------------------------------------------------------------------

    pec_group = gmsh.model.addPhysicalGroup(
        2,
        metal_surfaces,
        10
    )

    gmsh.model.setPhysicalName(
        2,
        pec_group,
        "Superconducting_Metal"
    )

    # -------------------------------------------------------------------------
    # JJ groups
    # -------------------------------------------------------------------------

    for i, sf in enumerate(
        jj_surface_tags,
        start=1
    ):

        tag = 19 + i

        group = gmsh.model.addPhysicalGroup(
            2,
            [sf],
            tag
        )

        gmsh.model.setPhysicalName(
            2,
            group,
            f"JJ{i}"
        )

    # =========================================================================
    # MESH CONTROL
    # =========================================================================

    print(
        "\nConfiguring coarse mesh..."
    )

    gmsh.option.setNumber(
        "Mesh.MeshSizeMin",
        JJ_SIZE
    )

    gmsh.option.setNumber(
        "Mesh.MeshSizeMax",
        BULK_SIZE
    )

    gmsh.option.setNumber(
        "Mesh.Algorithm3D",
        1
    )

    gmsh.option.setNumber(
        "Mesh.Optimize",
        1
    )

    gmsh.option.setNumber(
        "Mesh.OptimizeNetgen",
        0
    )

    # =========================================================================
    # JJ LOCAL REFINEMENT
    # =========================================================================

    print(
        "\nApplying local JJ refinement..."
    )

    # Distance fields around the 8 actual JJ surfaces.
    #
    # We deliberately use a modest 50 um size.
    # No 20 um or smaller refinement is used here.

    jj_field_ids = []

    for sf in jj_surface_tags:

        distance_field = (
            gmsh.model.mesh.field.add(
                "Distance"
            )
        )

        gmsh.model.mesh.field.setNumbers(
            distance_field,
            "FacesList",
            [sf]
        )

        jj_field_ids.append(
            distance_field
        )

    if jj_field_ids:

        threshold_fields = []

        for f in jj_field_ids:

            tf = (
                gmsh.model.mesh.field.add(
                    "Threshold"
                )
            )

            gmsh.model.mesh.field.setNumber(
                tf,
                "InField",
                f
            )

            gmsh.model.mesh.field.setNumber(
                tf,
                "SizeMin",
                JJ_SIZE
            )

            gmsh.model.mesh.field.setNumber(
                tf,
                "SizeMax",
                BULK_SIZE
            )

            gmsh.model.mesh.field.setNumber(
                tf,
                "DistMin",
                0.05
            )

            gmsh.model.mesh.field.setNumber(
                tf,
                "DistMax",
                0.20
            )

            threshold_fields.append(tf)

        min_field = (
            gmsh.model.mesh.field.add(
                "Min"
            )
        )

        gmsh.model.mesh.field.setNumbers(
            min_field,
            "FieldsList",
            threshold_fields
        )

        gmsh.model.mesh.field.setAsBackgroundMesh(
            min_field
        )

    # =========================================================================
    # GENERATE 3D MESH
    # =========================================================================

    print("\n" + "=" * 80)
    print("GENERATING COARSE 3D MESH")
    print("=" * 80)

    print(
        f"Bulk size : {BULK_SIZE*1000:.0f} um"
    )

    print(
        f"JJ size   : {JJ_SIZE*1000:.0f} um"
    )

    print(
        f"Safety limit: {MAX_TETS:,} tetrahedra"
    )

    gmsh.model.mesh.generate(
        3
    )

    # =========================================================================
    # MESH STATISTICS
    # =========================================================================

    print("\nChecking mesh...")

    node_tags, node_coords, _ = (
        gmsh.model.mesh.getNodes()
    )

    element_types, element_tags, element_nodes = (
        gmsh.model.mesh.getElements(3)
    )

    tetra_count = 0

    for etype, tags in zip(
        element_types,
        element_tags
    ):

        # Gmsh type 4 = 4-node tetrahedron
        if etype == 4:

            tetra_count += len(tags)

    print(
        f"\nNodes      : {len(node_tags):,}"
    )

    print(
        f"Tetrahedra : {tetra_count:,}"
    )

    # =========================================================================
    # HARD RAM SAFETY CHECK
    # =========================================================================

    if tetra_count > MAX_TETS:

        print(
            "\n" + "=" * 80
        )

        print(
            "SAFETY STOP"
        )

        print(
            "=" * 80
        )

        print(
            f"Generated {tetra_count:,} tetrahedra."
        )

        print(
            f"Limit is {MAX_TETS:,}."
        )

        print(
            "\nMesh will NOT be written."
        )

        print(
            "Reduce refinement before continuing."
        )

        raise RuntimeError(
            "Mesh exceeds RAM safety limit."
        )

    # =========================================================================
    # WRITE MSH 2.2
    # =========================================================================

    print(
        "\nWriting MSH 2.2..."
    )

    gmsh.option.setNumber(
        "Mesh.MshFileVersion",
        2.2
    )

    gmsh.write(
        OUTPUT_MESH
    )

    # =========================================================================
    # FINAL PHYSICAL GROUP REPORT
    # =========================================================================

    print("\n" + "=" * 80)
    print("PHYSICAL GROUPS")
    print("=" * 80)

    for dim, tag in gmsh.model.getPhysicalGroups():

        name = gmsh.model.getPhysicalName(
            dim,
            tag
        )

        print(
            f"dim={dim}, "
            f"id={tag}, "
            f"name={name}"
        )

    # =========================================================================
    # FILE SIZE
    # =========================================================================

    if os.path.exists(OUTPUT_MESH):

        size_gb = (
            os.path.getsize(OUTPUT_MESH)
            / (1024**3)
        )

        print(
            f"\nMesh file size: "
            f"{size_gb:.3f} GB"
        )

    print("\n" + "=" * 80)
    print("MESH CREATED SUCCESSFULLY")
    print("=" * 80)

    print(
        f"\nMesh:\n{OUTPUT_MESH}"
    )

    print(
        "\nIMPORTANT:"
    )

    print(
        "Do NOT run Palace yet."
    )

    print(
        "First inspect the mesh statistics and "
        "Palace physical-group compatibility."
    )

finally:

    gmsh.finalize()

    # Release Python/GDS memory
    del gds
    del main_polys
    del pad_polys
    del jj_polys
    del main_metal

    gc.collect()
# Out:
# ================================================================================
# ROBUST 8-JJ CONFORMAL PALACE MESH - V12
# ================================================================================
#
# GDS:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds
#
# Output:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v12.msh
#
# Mesh parameters:
#   Bulk = 500 um
#   JJ   = 50 um
#
# ================================================================================
# READING GDS
# ================================================================================
# Loaded 19 cells.
# Using top cell: TOP_main_1
#
# Extracting main superconducting metal...
# Main metal polygons: 2450
# Uniting main metal...
# Main metal geometry: Polygon
# Main metal area: 185.750736791720 mm²
#
# Extracting JJ reference polygons...
# JJ polygons found: 8
#
# Matching JJ references...
# JJ1: centroid=(-1.132500, 0.000000) mm, error=0.000 um
# JJ2: centroid=(-0.867500, -0.000000) mm, error=0.000 um
# JJ3: centroid=(1.267500, 0.000000) mm, error=0.000 um
# JJ4: centroid=(1.532500, -0.000000) mm, error=0.000 um
# JJ5: centroid=(-1.132500, -2.700000) mm, error=0.000 um
# JJ6: centroid=(-0.867500, -2.700000) mm, error=0.000 um
# JJ7: centroid=(1.267500, -2.700000) mm, error=0.000 um
# JJ8: centroid=(1.532500, -2.700000) mm, error=0.000 um
#
# Extracting actual JJ electrode pads...
# Pad polygons: 90
#
# ================================================================================
# IDENTIFYING ACTUAL JJ GAPS
# ================================================================================
# JJ1: 20.000 x 5.000 um, center error=0.000 um
# JJ2: 20.000 x 5.000 um, center error=0.000 um
# JJ3: 20.000 x 5.000 um, center error=0.000 um
# JJ4: 20.000 x 5.000 um, center error=0.000 um
# JJ5: 20.000 x 5.000 um, center error=0.000 um
# JJ6: 20.000 x 5.000 um, center error=0.000 um
# JJ7: 20.000 x 5.000 um, center error=0.000 um
# JJ8: 20.000 x 5.000 um, center error=0.000 um
#
# PASS: all 8 physical JJ gaps recovered.
#
# No artificial JJ subtraction will be performed.
#
# ================================================================================
# INITIALIZING GMSH
# ================================================================================
#
# Creating silicon substrate...
# Creating vacuum...
#
# Creating superconducting metal surfaces...
# Metal surfaces created: 1
#
# Creating physical JJ surfaces...
# JJ1: surface=14
# JJ2: surface=15
# JJ3: surface=16
# JJ4: surface=17
# JJ5: surface=18
# JJ6: surface=19
# JJ7: surface=20
# JJ8: surface=21
#
# Synchronizing OCC...
#
# Fragmenting silicon/vacuum volumes...
#
# 3D volumes found: 2
# Silicon volumes: [1]
# Vacuum volumes: [2]
#
# Creating physical groups...
#
# Configuring coarse mesh...
#
# Applying local JJ refinement...
#
# ================================================================================
# GENERATING COARSE 3D MESH
# ================================================================================
# Bulk size : 500 um
# JJ size   : 50 um
# Safety limit: 4,000,000 tetrahedra
#
# Checking mesh...
#
# Nodes      : 10,387
# Tetrahedra : 11,925
#
# Writing MSH 2.2...
#
# ================================================================================
# PHYSICAL GROUPS
# ================================================================================
# dim=2, id=10, name=Superconducting_Metal
# dim=2, id=20, name=JJ1
# dim=2, id=21, name=JJ2
# dim=2, id=22, name=JJ3
# dim=2, id=23, name=JJ4
# dim=2, id=24, name=JJ5
# dim=2, id=25, name=JJ6
# dim=2, id=26, name=JJ7
# dim=2, id=27, name=JJ8
# dim=3, id=1, name=Vacuum
# dim=3, id=2, name=Silicon_Substrate
#
# Mesh file size: 0.001 GB
#
# ================================================================================
# MESH CREATED SUCCESSFULLY
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v12.msh
#
# IMPORTANT:
# Do NOT run Palace yet.
# First inspect the mesh statistics and Palace physical-group compatibility.

# %%
# =============================================================================
# PALACE V12 — SAFE MESH TOPOLOGY / PHYSICAL-GROUP TEST
# =============================================================================
#
# This script:
#   1. Reads the existing V12 MSH only
#   2. Counts volume tetrahedra
#   3. Counts surface triangles for every physical group
#   4. Verifies all 8 JJ groups
#   5. Verifies Superconducting_Metal
#   6. Checks whether physical surface elements exist
#   7. Checks whether JJ surfaces are geometrically located at z = 0
#
# NO Palace execution.
# NO mesh generation.
# NO large RAM allocation.
#
# =============================================================================

import os
import gc
import gmsh
import numpy as np

MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ_v12.msh"
)

print("=" * 80)
print("PALACE V12 — SAFE MESH TOPOLOGY TEST")
print("=" * 80)

print("\nMesh:")
print(MESH)

if not os.path.exists(MESH):
    raise RuntimeError("Mesh file does not exist.")

size_mb = os.path.getsize(MESH) / (1024**2)

print(
    f"Mesh size: {size_mb:.3f} MB"
)

# =============================================================================
# INITIALIZE
# =============================================================================

gmsh.initialize()

try:

    gmsh.option.setNumber(
        "General.Terminal",
        1
    )

    gmsh.open(MESH)

    print("\nPASS: Gmsh opened the mesh.")

    # =========================================================================
    # BASIC MESH COUNTS
    # =========================================================================

    node_tags, node_coords, _ = (
        gmsh.model.mesh.getNodes()
    )

    print("\n" + "=" * 80)
    print("GLOBAL MESH")
    print("=" * 80)

    print(
        f"Nodes: {len(node_tags):,}"
    )

    # =========================================================================
    # ELEMENT COUNTS
    # =========================================================================

    print("\n" + "=" * 80)
    print("ELEMENT TYPES")
    print("=" * 80)

    types, tags, nodes = (
        gmsh.model.mesh.getElements()
    )

    total_tets = 0
    total_triangles = 0

    element_names = {
        1: "2-node line",
        2: "3-node triangle",
        3: "4-node quadrilateral",
        4: "4-node tetrahedron",
        5: "8-node hexahedron",
        9: "6-node second-order triangle",
        10: "9-node second-order quadrilateral",
        11: "10-node second-order tetrahedron",
    }

    for etype, etags in zip(
        types,
        tags
    ):

        count = len(etags)

        name = element_names.get(
            etype,
            f"type {etype}"
        )

        print(
            f"{etype:3d} : "
            f"{name:30s} "
            f"{count:,}"
        )

        if etype == 4:
            total_tets += count

        if etype == 2:
            total_triangles += count

    print(
        f"\n4-node tetrahedra: "
        f"{total_tets:,}"
    )

    print(
        f"3-node triangles: "
        f"{total_triangles:,}"
    )

    if total_tets == 0:
        raise RuntimeError(
            "CRITICAL: No tetrahedral volume elements found."
        )

    # =========================================================================
    # PHYSICAL GROUPS
    # =========================================================================

    print("\n" + "=" * 80)
    print("PHYSICAL GROUPS")
    print("=" * 80)

    physical_groups = {}

    for dim, tag in gmsh.model.getPhysicalGroups():

        name = gmsh.model.getPhysicalName(
            dim,
            tag
        )

        entities = gmsh.model.getEntitiesForPhysicalGroup(
            dim,
            tag
        )

        physical_groups[name] = (
            dim,
            tag,
            list(entities)
        )

        print(
            f"dim={dim} "
            f"id={tag:2d} "
            f"name={name:25s} "
            f"entities={len(entities)}"
        )

    # =========================================================================
    # REQUIRED VOLUME GROUPS
    # =========================================================================

    print("\n" + "=" * 80)
    print("VOLUME GROUP CHECK")
    print("=" * 80)

    required_volumes = [
        "Vacuum",
        "Silicon_Substrate",
    ]

    for name in required_volumes:

        if name not in physical_groups:
            raise RuntimeError(
                f"FAIL: Missing physical volume group: {name}"
            )

        dim, tag, entities = physical_groups[name]

        if dim != 3:
            raise RuntimeError(
                f"FAIL: {name} is not dimension 3."
            )

        count = 0

        for entity in entities:

            etypes, etags, _ = (
                gmsh.model.mesh.getElements(
                    3,
                    entity
                )
            )

            for etype, arr in zip(
                etypes,
                etags
            ):

                if etype == 4:
                    count += len(arr)

        print(
            f"PASS: {name:25s} "
            f"tetrahedra={count:,}"
        )

        if count == 0:
            raise RuntimeError(
                f"FAIL: {name} contains no tetrahedra."
            )

    # =========================================================================
    # PEC CHECK
    # =========================================================================

    print("\n" + "=" * 80)
    print("PEC SURFACE CHECK")
    print("=" * 80)

    if "Superconducting_Metal" not in physical_groups:

        raise RuntimeError(
            "FAIL: Superconducting_Metal group missing."
        )

    dim, tag, entities = (
        physical_groups[
            "Superconducting_Metal"
        ]
    )

    if dim != 2:

        raise RuntimeError(
            "FAIL: Superconducting_Metal "
            "is not a surface group."
        )

    pec_triangles = 0

    for entity in entities:

        etypes, etags, _ = (
            gmsh.model.mesh.getElements(
                2,
                entity
            )
        )

        for etype, arr in zip(
            etypes,
            etags
        ):

            if etype == 2:
                pec_triangles += len(arr)

    print(
        f"PEC entities   : {len(entities)}"
    )

    print(
        f"PEC triangles  : {pec_triangles:,}"
    )

    if pec_triangles == 0:

        raise RuntimeError(
            "FAIL: Superconducting_Metal "
            "contains no triangular surface elements."
        )

    print(
        "PASS: PEC surface elements exist."
    )

    # =========================================================================
    # JJ CHECK
    # =========================================================================

    print("\n" + "=" * 80)
    print("8-JJ SURFACE CHECK")
    print("=" * 80)

    jj_triangle_counts = {}

    for i in range(1, 9):

        name = f"JJ{i}"

        if name not in physical_groups:

            raise RuntimeError(
                f"FAIL: Missing physical group {name}."
            )

        dim, tag, entities = (
            physical_groups[name]
        )

        if dim != 2:

            raise RuntimeError(
                f"FAIL: {name} is not dimension 2."
            )

        triangles = 0

        for entity in entities:

            etypes, etags, _ = (
                gmsh.model.mesh.getElements(
                    2,
                    entity
                )
            )

            for etype, arr in zip(
                etypes,
                etags
            ):

                if etype == 2:
                    triangles += len(arr)

        jj_triangle_counts[name] = triangles

        print(
            f"{name}: "
            f"entities={len(entities)}, "
            f"triangles={triangles:,}"
        )

        if triangles == 0:

            raise RuntimeError(
                f"FAIL: {name} has no surface triangles."
            )

    print(
        "\nPASS: all 8 JJ groups contain "
        "surface elements."
    )

    # =========================================================================
    # JJ Z-LOCATION TEST
    # =========================================================================

    print("\n" + "=" * 80)
    print("JJ GEOMETRIC LOCATION CHECK")
    print("=" * 80)

    for i in range(1, 9):

        name = f"JJ{i}"

        dim, tag, entities = (
            physical_groups[name]
        )

        all_z = []

        for entity in entities:

            ntags, coords, _ = (
                gmsh.model.mesh.getNodes(
                    2,
                    entity,
                    includeBoundary=True
                )
            )

            if len(coords) == 0:
                continue

            coords = np.asarray(
                coords
            ).reshape(
                -1,
                3
            )

            all_z.extend(
                coords[:, 2]
            )

        if not all_z:

            raise RuntimeError(
                f"FAIL: Could not obtain "
                f"nodes for {name}."
            )

        all_z = np.asarray(
            all_z
        )

        max_abs_z = np.max(
            np.abs(all_z)
        )

        print(
            f"{name}: "
            f"max |z| = "
            f"{max_abs_z*1e6:.3f} um"
        )

        if max_abs_z > 1e-9:

            print(
                f"WARNING: {name} is not exactly "
                f"on z=0."
            )

    # =========================================================================
    # FINAL DECISION
    # =========================================================================

    print("\n" + "=" * 80)
    print("FINAL RESULT")
    print("=" * 80)

    print(
        "\nPASS: Mesh can be read by Gmsh."
    )

    print(
        "PASS: Volume tetrahedra exist."
    )

    print(
        "PASS: Vacuum physical group exists."
    )

    print(
        "PASS: Silicon_Substrate physical group exists."
    )

    print(
        "PASS: Superconducting_Metal surface elements exist."
    )

    print(
        "PASS: JJ1-JJ8 physical surface elements exist."
    )

    print(
        "\nDO NOT RUN THE FULL PALACE SIMULATION YET."
    )

    print(
        "If this test passes, the next test should be "
        "a very small Palace mesh-read test."
    )

finally:

    gmsh.finalize()

    gc.collect()
# Out:
# ================================================================================
# PALACE V12 — SAFE MESH TOPOLOGY TEST
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v12.msh
# Mesh size: 1.204 MB
#
# PASS: Gmsh opened the mesh.
#
# ================================================================================
# GLOBAL MESH
# ================================================================================
# Nodes: 10,362
#
# ================================================================================
# ELEMENT TYPES
# ================================================================================
#   2 : 3-node triangle                13,970
#   4 : 4-node tetrahedron             11,925
#
# 4-node tetrahedra: 11,925
# 3-node triangles: 13,970
#
# ================================================================================
# PHYSICAL GROUPS
# ================================================================================
# dim=2 id=10 name=Superconducting_Metal     entities=1
# dim=2 id=20 name=JJ1                       entities=1
# dim=2 id=21 name=JJ2                       entities=1
# dim=2 id=22 name=JJ3                       entities=1
# dim=2 id=23 name=JJ4                       entities=1
# dim=2 id=24 name=JJ5                       entities=1
# dim=2 id=25 name=JJ6                       entities=1
# dim=2 id=26 name=JJ7                       entities=1
# dim=2 id=27 name=JJ8                       entities=1
# dim=3 id= 1 name=Vacuum                    entities=1
# dim=3 id= 2 name=Silicon_Substrate         entities=1
#
# ================================================================================
# VOLUME GROUP CHECK
# ================================================================================
# PASS: Vacuum                    tetrahedra=5,990
# PASS: Silicon_Substrate         tetrahedra=5,935
#
# ================================================================================
# PEC SURFACE CHECK
# ================================================================================
# PEC entities   : 1
# PEC triangles  : 13,954
# PASS: PEC surface elements exist.
#
# ================================================================================
# 8-JJ SURFACE CHECK
# ================================================================================
# JJ1: entities=1, triangles=2
# JJ2: entities=1, triangles=2
# JJ3: entities=1, triangles=2
# JJ4: entities=1, triangles=2
# JJ5: entities=1, triangles=2
# JJ6: entities=1, triangles=2
# JJ7: entities=1, triangles=2
# JJ8: entities=1, triangles=2
#
# PASS: all 8 JJ groups contain surface elements.
#
# ================================================================================
# JJ GEOMETRIC LOCATION CHECK
# ================================================================================
# JJ1: max |z| = 0.000 um
# JJ2: max |z| = 0.000 um
# JJ3: max |z| = 0.000 um
# JJ4: max |z| = 0.000 um
# JJ5: max |z| = 0.000 um
# JJ6: max |z| = 0.000 um
# JJ7: max |z| = 0.000 um
# JJ8: max |z| = 0.000 um
#
# ================================================================================
# FINAL RESULT
# ================================================================================
#
# PASS: Mesh can be read by Gmsh.
# PASS: Volume tetrahedra exist.
# PASS: Vacuum physical group exists.
# PASS: Silicon_Substrate physical group exists.
# PASS: Superconducting_Metal surface elements exist.
# PASS: JJ1-JJ8 physical surface elements exist.
#
# DO NOT RUN THE FULL PALACE SIMULATION YET.
# If this test passes, the next test should be a very small Palace mesh-read test.

# %%
# =============================================================================
# V12 — MFEM STABLE3D CONNECTIVITY DIAGNOSTIC
# =============================================================================
#
# Purpose:
#   Find problematic tetrahedral connectivity that can trigger
#   MFEM::STable3D::operator().
#
# Palace is NOT executed.
# No mesh generation.
#
# =============================================================================

import gmsh
import numpy as np
from collections import defaultdict
import os
import gc

MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ_v12.msh"
)

print("=" * 80)
print("V12 — TETRAHEDRAL CONNECTIVITY DIAGNOSTIC")
print("=" * 80)

print("\nMesh:")
print(MESH)

if not os.path.exists(MESH):
    raise RuntimeError("Mesh file not found.")

gmsh.initialize()

try:

    gmsh.option.setNumber(
        "General.Terminal",
        1
    )

    gmsh.open(MESH)

    # -------------------------------------------------------------------------
    # GET TETRAHEDRA
    # -------------------------------------------------------------------------

    types, tags, node_blocks = (
        gmsh.model.mesh.getElements(
            3
        )
    )

    tet_nodes = None
    tet_tags = None

    for etype, etags, enodes in zip(
        types,
        tags,
        node_blocks
    ):

        # Gmsh type 4 = 4-node tetrahedron
        if etype == 4:

            tet_tags = np.asarray(
                etags,
                dtype=np.int64
            )

            tet_nodes = np.asarray(
                enodes,
                dtype=np.int64
            ).reshape(
                -1,
                4
            )

            break

    if tet_nodes is None:

        raise RuntimeError(
            "No 4-node tetrahedra found."
        )

    print(
        f"\nTetrahedra: {len(tet_nodes):,}"
    )

    # -------------------------------------------------------------------------
    # CHECK REPEATED VERTICES
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("CHECK 1 — REPEATED VERTICES")
    print("=" * 80)

    repeated = []

    for i, tet in enumerate(tet_nodes):

        if len(set(tet)) != 4:

            repeated.append(
                (
                    int(tet_tags[i]),
                    tet.tolist()
                )
            )

    print(
        f"Degenerate/repeated-vertex tetrahedra: "
        f"{len(repeated)}"
    )

    if repeated:

        for item in repeated[:20]:

            print(
                "BAD:",
                item
            )

        raise RuntimeError(
            "Repeated vertex indices found."
        )

    print(
        "PASS: no tetrahedron contains "
        "repeated vertex indices."
    )

    # -------------------------------------------------------------------------
    # CHECK DUPLICATE TETRAHEDRA
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("CHECK 2 — DUPLICATE TETRAHEDRA")
    print("=" * 80)

    canonical = np.sort(
        tet_nodes,
        axis=1
    )

    unique_tets, inverse, counts = np.unique(
        canonical,
        axis=0,
        return_inverse=True,
        return_counts=True
    )

    duplicate_groups = np.where(
        counts > 1
    )[0]

    print(
        f"Unique tetrahedra : {len(unique_tets):,}"
    )

    print(
        f"Duplicate groups  : {len(duplicate_groups):,}"
    )

    if len(duplicate_groups) > 0:

        print(
            "\nWARNING: duplicate tetrahedra detected."
        )

        shown = 0

        for group in duplicate_groups:

            indices = np.where(
                inverse == group
            )[0]

            print(
                "Duplicate tetrahedra:",
                indices[:10].tolist()
            )

            shown += 1

            if shown >= 20:
                break

    else:

        print(
            "PASS: no duplicate tetrahedra."
        )

    # -------------------------------------------------------------------------
    # FACE CONNECTIVITY
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("CHECK 3 — TETRAHEDRAL FACE CONNECTIVITY")
    print("=" * 80)

    face_owner = defaultdict(list)

    # Four triangular faces of each tetrahedron
    face_patterns = (
        (0, 1, 2),
        (0, 1, 3),
        (0, 2, 3),
        (1, 2, 3),
    )

    for i, tet in enumerate(tet_nodes):

        tet_tag = int(
            tet_tags[i]
        )

        for pattern in face_patterns:

            face = tuple(
                sorted(
                    int(tet[j])
                    for j in pattern
                )
            )

            face_owner[face].append(
                tet_tag
            )

    # -------------------------------------------------------------------------
    # FACE MULTIPLICITY
    # -------------------------------------------------------------------------

    multiplicities = defaultdict(int)

    for owners in face_owner.values():

        multiplicities[
            len(owners)
        ] += 1

    print(
        "\nFace multiplicity:"
    )

    for n in sorted(
        multiplicities
    ):

        print(
            f"  {n} tetrahedra -> "
            f"{multiplicities[n]:,} faces"
        )

    bad_faces = {
        face: owners
        for face, owners in face_owner.items()
        if len(owners) > 2
    }

    if bad_faces:

        print(
            "\nCRITICAL: faces shared by >2 tetrahedra:"
        )

        for face, owners in list(
            bad_faces.items()
        )[:30]:

            print(
                f"face={face}, "
                f"owners={owners}"
            )

        raise RuntimeError(
            "Non-manifold tetrahedral face connectivity detected."
        )

    print(
        "\nPASS: no triangular face belongs "
        "to more than two tetrahedra."
    )

    # -------------------------------------------------------------------------
    # NON-MANIFOLD EDGE CHECK
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("CHECK 4 — EDGE CONNECTIVITY")
    print("=" * 80)

    edge_faces = defaultdict(set)

    for face in face_owner:

        a, b, c = face

        edge_faces[
            tuple(sorted((a, b)))
        ].add(face)

        edge_faces[
            tuple(sorted((a, c)))
        ].add(face)

        edge_faces[
            tuple(sorted((b, c)))
        ].add(face)

    # An edge can have many faces on a legitimate closed 3D
    # mesh, so we don't declare >2 automatically bad.
    #
    # Instead identify extremely unusual connectivity.

    edge_counts = np.array(
        [
            len(v)
            for v in edge_faces.values()
        ],
        dtype=np.int64
    )

    print(
        f"Unique edges: {len(edge_counts):,}"
    )

    print(
        f"Minimum faces/edge: {edge_counts.min()}"
    )

    print(
        f"Maximum faces/edge: {edge_counts.max()}"
    )

    print(
        f"Average faces/edge: {edge_counts.mean():.3f}"
    )

    # -------------------------------------------------------------------------
    # NODE VALIDITY
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("CHECK 5 — NODE REFERENCES")
    print("=" * 80)

    node_tags, node_coords, _ = (
        gmsh.model.mesh.getNodes()
    )

    valid_nodes = set(
        int(x)
        for x in node_tags
    )

    invalid_refs = []

    for i, tet in enumerate(
        tet_nodes
    ):

        for node in tet:

            if int(node) not in valid_nodes:

                invalid_refs.append(
                    (
                        int(tet_tags[i]),
                        int(node)
                    )
                )

    print(
        f"Invalid node references: "
        f"{len(invalid_refs)}"
    )

    if invalid_refs:

        for x in invalid_refs[:20]:
            print(
                "BAD:",
                x
            )

        raise RuntimeError(
            "Tetrahedron references a "
            "nonexistent mesh node."
        )

    print(
        "PASS: all tetrahedral node "
        "references are valid."
    )

    # -------------------------------------------------------------------------
    # VOLUME CHECK
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("CHECK 6 — ZERO / NEGATIVE VOLUME")
    print("=" * 80)

    coords = np.asarray(
        node_coords
    ).reshape(
        -1,
        3
    )

    node_index = {
        int(tag): i
        for i, tag in enumerate(
            node_tags
        )
    }

    zero_volume = []
    negative_volume = []

    for i, tet in enumerate(
        tet_nodes
    ):

        try:

            p0 = coords[
                node_index[int(tet[0])]
            ]

            p1 = coords[
                node_index[int(tet[1])]
            ]

            p2 = coords[
                node_index[int(tet[2])]
            ]

            p3 = coords[
                node_index[int(tet[3])]
            ]

        except KeyError:
            continue

        v = np.dot(
            p1 - p0,
            np.cross(
                p2 - p0,
                p3 - p0
            )
        ) / 6.0

        if abs(v) < 1e-18:

            zero_volume.append(
                int(tet_tags[i])
            )

        elif v < 0:

            negative_volume.append(
                int(tet_tags[i])
            )

    print(
        f"Zero-volume tetrahedra: "
        f"{len(zero_volume):,}"
    )

    print(
        f"Negative-orientation tetrahedra: "
        f"{len(negative_volume):,}"
    )

    if zero_volume:

        print(
            "\nCRITICAL: zero-volume elements detected."
        )

        print(
            zero_volume[:20]
        )

    else:

        print(
            "PASS: no zero-volume tetrahedra."
        )

    # -------------------------------------------------------------------------
    # PHYSICAL SURFACE / VOLUME CONSISTENCY
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("CHECK 7 — PHYSICAL GROUP ELEMENTS")
    print("=" * 80)

    for dim, ptag in (
        gmsh.model.getPhysicalGroups()
    ):

        name = gmsh.model.getPhysicalName(
            dim,
            ptag
        )

        entities = (
            gmsh.model.getEntitiesForPhysicalGroup(
                dim,
                ptag
            )
        )

        count = 0

        for entity in entities:

            etypes, etags, _ = (
                gmsh.model.mesh.getElements(
                    dim,
                    entity
                )
            )

            for etype, arr in zip(
                etypes,
                etags
            ):

                count += len(arr)

        print(
            f"{dim:1d} "
            f"{ptag:2d} "
            f"{name:25s} "
            f"{count:,} elements"
        )

    # -------------------------------------------------------------------------
    # FINAL RESULT
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("DIAGNOSTIC RESULT")
    print("=" * 80)

    print(
        "\nThe V12 mesh contains:"
    )

    print(
        f"  {len(tet_nodes):,} tetrahedra"
    )

    print(
        f"  {len(node_tags):,} nodes"
    )

    print(
        f"  {len(face_owner):,} unique tetrahedral faces"
    )

    print(
        "\nIf all checks above PASS, the next step is "
        "NOT a larger simulation."
    )

    print(
        "Instead we should identify the exact "
        "tetrahedral/face topology that MFEM "
        "STable3D rejects."
    )

finally:

    gmsh.finalize()

    gc.collect()
# Out:
# ================================================================================
# V12 — TETRAHEDRAL CONNECTIVITY DIAGNOSTIC
# ================================================================================
#
# Mesh:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v12.msh
#
# Tetrahedra: 11,925
#
# ================================================================================
# CHECK 1 — REPEATED VERTICES
# ================================================================================
# Degenerate/repeated-vertex tetrahedra: 0
# PASS: no tetrahedron contains repeated vertex indices.
#
# ================================================================================
# CHECK 2 — DUPLICATE TETRAHEDRA
# ================================================================================
# Unique tetrahedra : 11,925
# Duplicate groups  : 0
# PASS: no duplicate tetrahedra.
#
# ================================================================================
# CHECK 3 — TETRAHEDRAL FACE CONNECTIVITY
# ================================================================================
#
# Face multiplicity:
#   1 tetrahedra -> 4,534 faces
#   2 tetrahedra -> 21,583 faces
#
# PASS: no triangular face belongs to more than two tetrahedra.
#
# ================================================================================
# CHECK 4 — EDGE CONNECTIVITY
# ================================================================================
# Unique edges: 17,340
# Minimum faces/edge: 2
# Maximum faces/edge: 9
# Average faces/edge: 4.519
#
# ================================================================================
# CHECK 5 — NODE REFERENCES
# ================================================================================
# Invalid node references: 0
# PASS: all tetrahedral node references are valid.
#
# ================================================================================
# CHECK 6 — ZERO / NEGATIVE VOLUME
# ================================================================================
# Zero-volume tetrahedra: 0
# Negative-orientation tetrahedra: 0
# PASS: no zero-volume tetrahedra.
#
# ================================================================================
# CHECK 7 — PHYSICAL GROUP ELEMENTS
# ================================================================================
# 2 10 Superconducting_Metal     13,954 elements
# 2 20 JJ1                       2 elements
# 2 21 JJ2                       2 elements
# 2 22 JJ3                       2 elements
# 2 23 JJ4                       2 elements
# 2 24 JJ5                       2 elements
# 2 25 JJ6                       2 elements
# 2 26 JJ7                       2 elements
# 2 27 JJ8                       2 elements
# 3  1 Vacuum                    5,990 elements
# 3  2 Silicon_Substrate         5,935 elements
#
# ================================================================================
# DIAGNOSTIC RESULT
# ================================================================================
#
# The V12 mesh contains:
#   11,925 tetrahedra
#   10,362 nodes
#   26,117 unique tetrahedral faces
#
# If all checks above PASS, the next step is NOT a larger simulation.
# Instead we should identify the exact tetrahedral/face topology that MFEM STable3D rejects.

# %%
# =============================================================================
# V12 — MFEM STable3D-STYLE TOPOLOGY DIAGNOSTIC
# =============================================================================
#
# Palace previously aborted with:
#
#   MFEM abort: (r,c,f) = (35,4462,6735)
#   mfem::STable3D::operator()
#
# This script does NOT run Palace.
#
# It investigates:
#   tetrahedron -> face
#   face -> edge
#   edge -> vertex
#
# and reports suspicious local topology.
#
# =============================================================================

import gmsh
import numpy as np
from collections import defaultdict
import os
import gc

MESH = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ_v12.msh"
)

print("=" * 80)
print("V12 — MFEM STable3D-STYLE TOPOLOGY DIAGNOSTIC")
print("=" * 80)

gmsh.initialize()

try:

    gmsh.option.setNumber(
        "General.Terminal",
        0
    )

    gmsh.open(MESH)

    # -------------------------------------------------------------------------
    # READ TETRAHEDRA
    # -------------------------------------------------------------------------

    types, tags, blocks = (
        gmsh.model.mesh.getElements(3)
    )

    tet_nodes = None
    tet_tags = None

    for etype, etags, enodes in zip(
        types,
        tags,
        blocks
    ):

        if etype == 4:

            tet_tags = np.asarray(
                etags,
                dtype=np.int64
            )

            tet_nodes = np.asarray(
                enodes,
                dtype=np.int64
            ).reshape(-1, 4)

            break

    if tet_nodes is None:
        raise RuntimeError(
            "No tetrahedra found."
        )

    print(
        f"Tetrahedra: {len(tet_nodes):,}"
    )

    # -------------------------------------------------------------------------
    # MFEM-LIKE LOCAL TOPOLOGY
    # -------------------------------------------------------------------------
    #
    # A tetrahedron has:
    #
    #   4 vertices
    #   6 edges
    #   4 faces
    #
    # -------------------------------------------------------------------------

    EDGE_PATTERNS = [
        (0, 1),
        (0, 2),
        (0, 3),
        (1, 2),
        (1, 3),
        (2, 3),
    ]

    FACE_PATTERNS = [
        (0, 1, 2),
        (0, 1, 3),
        (0, 2, 3),
        (1, 2, 3),
    ]

    # -------------------------------------------------------------------------
    # BUILD GLOBAL EDGE TABLE
    # -------------------------------------------------------------------------

    edge_to_tets = defaultdict(list)
    edge_to_faces = defaultdict(set)

    tet_edges = []

    for ti, tet in enumerate(tet_nodes):

        edges = []

        for a, b in EDGE_PATTERNS:

            edge = tuple(
                sorted(
                    (
                        int(tet[a]),
                        int(tet[b])
                    )
                )
            )

            edges.append(edge)

            edge_to_tets[edge].append(ti)

        tet_edges.append(edges)

    print(
        f"Global edges: {len(edge_to_tets):,}"
    )

    # -------------------------------------------------------------------------
    # BUILD GLOBAL FACE TABLE
    # -------------------------------------------------------------------------

    face_to_tets = defaultdict(list)
    face_to_edges = {}

    tet_faces = []

    for ti, tet in enumerate(tet_nodes):

        faces = []

        for a, b, c in FACE_PATTERNS:

            face = tuple(
                sorted(
                    (
                        int(tet[a]),
                        int(tet[b]),
                        int(tet[c])
                    )
                )
            )

            faces.append(face)

            face_to_tets[face].append(ti)

            # Three edges of the face
            va, vb, vc = face

            edges = [
                tuple(sorted((va, vb))),
                tuple(sorted((va, vc))),
                tuple(sorted((vb, vc))),
            ]

            face_to_edges[face] = edges

            for edge in edges:
                edge_to_faces[edge].add(face)

        tet_faces.append(faces)

    print(
        f"Global faces: {len(face_to_tets):,}"
    )

    # -------------------------------------------------------------------------
    # CHECK A — FACE MULTIPLICITY
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("A — FACE MULTIPLICITY")
    print("=" * 80)

    face_hist = defaultdict(int)

    for face, owners in face_to_tets.items():

        face_hist[len(owners)] += 1

    for n in sorted(face_hist):

        print(
            f"{n} tetrahedra -> "
            f"{face_hist[n]:,} faces"
        )

    bad_faces = [
        (face, owners)
        for face, owners in face_to_tets.items()
        if len(owners) > 2
    ]

    if bad_faces:

        print(
            "\nCRITICAL: non-manifold faces detected."
        )

        for face, owners in bad_faces[:20]:

            print(
                f"face={face}"
            )

            print(
                f"tetrahedra={owners}"
            )

    else:

        print(
            "\nPASS: no face has more than "
            "two tetrahedral owners."
        )

    # -------------------------------------------------------------------------
    # CHECK B — EVERY TET HAS EXACTLY 4 UNIQUE FACES
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("B — TETRAHEDRON FACE STRUCTURE")
    print("=" * 80)

    bad_tets = []

    for ti, faces in enumerate(tet_faces):

        if len(faces) != 4:

            bad_tets.append(ti)

        if len(set(faces)) != 4:

            bad_tets.append(ti)

    bad_tets = sorted(
        set(bad_tets)
    )

    print(
        f"Bad tetrahedra: {len(bad_tets)}"
    )

    if bad_tets:

        for ti in bad_tets[:20]:

            print(
                "tet:",
                int(tet_tags[ti]),
                tet_nodes[ti]
            )

    else:

        print(
            "PASS: every tetrahedron has "
            "4 unique triangular faces."
        )

    # -------------------------------------------------------------------------
    # CHECK C — FACE MUST HAVE 3 UNIQUE EDGES
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("C — FACE EDGE STRUCTURE")
    print("=" * 80)

    bad_face_edges = []

    for face, edges in face_to_edges.items():

        if len(edges) != 3:

            bad_face_edges.append(
                (
                    face,
                    edges
                )
            )

        elif len(set(edges)) != 3:

            bad_face_edges.append(
                (
                    face,
                    edges
                )
            )

    print(
        f"Bad faces: {len(bad_face_edges)}"
    )

    if bad_face_edges:

        for face, edges in bad_face_edges[:20]:

            print(
                "face:",
                face,
                "edges:",
                edges
            )

    else:

        print(
            "PASS: every face has "
            "3 unique edges."
        )

    # -------------------------------------------------------------------------
    # CHECK D — EDGE ENDPOINT VALIDITY
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("D — EDGE VERTEX STRUCTURE")
    print("=" * 80)

    bad_edges = []

    for edge in edge_to_tets:

        if len(edge) != 2:

            bad_edges.append(
                edge
            )

        elif edge[0] == edge[1]:

            bad_edges.append(
                edge
            )

    print(
        f"Bad edges: {len(bad_edges)}"
    )

    if bad_edges:

        for edge in bad_edges[:20]:

            print(
                "BAD EDGE:",
                edge
            )

    else:

        print(
            "PASS: all edges have "
            "two distinct vertices."
        )

    # -------------------------------------------------------------------------
    # CHECK E — EDGE / FACE CONSISTENCY
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("E — EDGE/FACE CONSISTENCY")
    print("=" * 80)

    inconsistent_edges = []

    for edge, faces in edge_to_faces.items():

        for face in faces:

            if edge not in face_to_edges[face]:

                inconsistent_edges.append(
                    (
                        edge,
                        face
                    )
                )

    print(
        f"Inconsistent edge/face pairs: "
        f"{len(inconsistent_edges)}"
    )

    if inconsistent_edges:

        for x in inconsistent_edges[:20]:

            print(
                "BAD:",
                x
            )

    else:

        print(
            "PASS: edge/face connectivity "
            "is consistent."
        )

    # -------------------------------------------------------------------------
    # CHECK F — TET/FACE OWNER CONSISTENCY
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("F — TET/FACE OWNER CONSISTENCY")
    print("=" * 80)

    inconsistent_owners = []

    for ti, faces in enumerate(tet_faces):

        for face in faces:

            owners = face_to_tets[face]

            if ti not in owners:

                inconsistent_owners.append(
                    (
                        ti,
                        face,
                        owners
                    )
                )

    print(
        f"Inconsistent ownership records: "
        f"{len(inconsistent_owners)}"
    )

    if inconsistent_owners:

        for x in inconsistent_owners[:20]:

            print(
                "BAD:",
                x
            )

    else:

        print(
            "PASS: tetrahedron/face "
            "ownership is consistent."
        )

    # -------------------------------------------------------------------------
    # CHECK G — ISOLATED / SUSPICIOUS EDGES
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("G — EDGE FACE COUNTS")
    print("=" * 80)

    edge_face_hist = defaultdict(int)

    for edge, faces in edge_to_faces.items():

        edge_face_hist[
            len(faces)
        ] += 1

    for n in sorted(edge_face_hist):

        print(
            f"{n} faces -> "
            f"{edge_face_hist[n]:,} edges"
        )

    # -------------------------------------------------------------------------
    # CHECK H — PHYSICAL SURFACE SHARING
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("H — PHYSICAL SURFACE / TETRA CONNECTIVITY")
    print("=" * 80)

    # Physical surface triangles
    # are collected and compared against
    # tetrahedral boundary faces.

    physical_surface_faces = {}

    for dim, ptag in gmsh.model.getPhysicalGroups():

        if dim != 2:
            continue

        name = gmsh.model.getPhysicalName(
            dim,
            ptag
        )

        faces = set()

        entities = (
            gmsh.model.getEntitiesForPhysicalGroup(
                dim,
                ptag
            )
        )

        for entity in entities:

            etypes, etags, enodes = (
                gmsh.model.mesh.getElements(
                    dim,
                    entity
                )
            )

            for etype, nodes in zip(
                etypes,
                enodes
            ):

                # 3-node triangle
                if etype != 2:
                    continue

                tri_nodes = np.asarray(
                    nodes,
                    dtype=np.int64
                ).reshape(-1, 3)

                for tri in tri_nodes:

                    face = tuple(
                        sorted(
                            int(x)
                            for x in tri
                        )
                    )

                    faces.add(face)

        physical_surface_faces[name] = faces

        print(
            f"{name:25s}: "
            f"{len(faces):,} physical triangles"
        )

    # Compare physical triangles with
    # tetrahedral faces.
    #
    # Every physical surface triangle should
    # correspond to a tetrahedral face.

    for name, faces in physical_surface_faces.items():

        missing = [
            face
            for face in faces
            if face not in face_to_tets
        ]

        print(
            f"{name:25s}: "
            f"unmatched={len(missing):,}"
        )

        if missing:

            print(
                "WARNING: physical triangles "
                "not found in tetrahedral topology."
            )

            for face in missing[:10]:

                print(
                    "  ",
                    face
                )

    # -------------------------------------------------------------------------
    # FINAL
    # -------------------------------------------------------------------------

    print("\n" + "=" * 80)
    print("FINAL DIAGNOSTIC")
    print("=" * 80)

    total_problems = (
        len(bad_faces)
        + len(bad_tets)
        + len(bad_face_edges)
        + len(bad_edges)
        + len(inconsistent_edges)
        + len(inconsistent_owners)
    )

    print(
        f"\nTopology problem count: "
        f"{total_problems}"
    )

    if total_problems == 0:

        print(
            "\nPASS: Basic tetrahedral topology "
            "is internally consistent."
        )

        print(
            "\nThis is important:"
        )

        print(
            "The MFEM STable3D crash is therefore "
            "likely caused by the way the surface "
            "elements / physical boundaries are "
            "connected to the volume mesh, rather "
            "than a simple degenerate tetrahedron."
        )

    else:

        print(
            "\nFAIL: topology inconsistencies "
            "were detected."
        )

        print(
            "Do NOT run Palace."
        )

    print(
        "\nNo Palace process was started."
    )

finally:

    gmsh.finalize()
    gc.collect()
# Out:
# ================================================================================
# V12 — MFEM STable3D-STYLE TOPOLOGY DIAGNOSTIC
# ================================================================================
# Tetrahedra: 11,925
# Global edges: 17,340
# Global faces: 26,117
#
# ================================================================================
# A — FACE MULTIPLICITY
# ================================================================================
# 1 tetrahedra -> 4,534 faces
# 2 tetrahedra -> 21,583 faces
#
# PASS: no face has more than two tetrahedral owners.
#
# ================================================================================
# B — TETRAHEDRON FACE STRUCTURE
# ================================================================================
# Bad tetrahedra: 0
# PASS: every tetrahedron has 4 unique triangular faces.
#
# ================================================================================
# C — FACE EDGE STRUCTURE
# ================================================================================
# Bad faces: 0
# PASS: every face has 3 unique edges.
#
# ================================================================================
# D — EDGE VERTEX STRUCTURE
# ================================================================================
# Bad edges: 0
# PASS: all edges have two distinct vertices.
#
# ================================================================================
# E — EDGE/FACE CONSISTENCY
# ================================================================================
# Inconsistent edge/face pairs: 0
# PASS: edge/face connectivity is consistent.
#
# ================================================================================
# F — TET/FACE OWNER CONSISTENCY
# ================================================================================
# Inconsistent ownership records: 0
# PASS: tetrahedron/face ownership is consistent.
#
# ================================================================================
# G — EDGE FACE COUNTS
# ================================================================================
# 2 faces -> 232 edges
# 3 faces -> 2,619 edges
# 4 faces -> 6,998 edges
# 5 faces -> 3,566 edges
# 6 faces -> 3,392 edges
# 7 faces -> 420 edges
# 8 faces -> 101 edges
# 9 faces -> 12 edges
#
# ================================================================================
# H — PHYSICAL SURFACE / TETRA CONNECTIVITY
# ================================================================================
# Superconducting_Metal    : 13,954 physical triangles
# JJ1                      : 2 physical triangles
# JJ2                      : 2 physical triangles
# JJ3                      : 2 physical triangles
# JJ4                      : 2 physical triangles
# JJ5                      : 2 physical triangles
# JJ6                      : 2 physical triangles
# JJ7                      : 2 physical triangles
# JJ8                      : 2 physical triangles
# Superconducting_Metal    : unmatched=13,954
# WARNING: physical triangles not found in tetrahedral topology.
#    (4924, 4925, 4926)
#    (2617, 3282, 5955)
#    (4515, 6384, 7136)
#    (4515, 5637, 6384)
#    (392, 393, 5327)
#    (6613, 6778, 7076)
#    (797, 4948, 6415)
#    (5192, 5578, 6420)
#    (1871, 1872, 1930)
#    (2862, 2863, 4080)
# JJ1                      : unmatched=2
# WARNING: physical triangles not found in tetrahedral topology.
#    (330, 331, 332)
#    (329, 330, 332)
# JJ2                      : unmatched=2
# WARNING: physical triangles not found in tetrahedral topology.
#    (334, 335, 336)
#    (333, 334, 336)
# JJ3                      : unmatched=2
# WARNING: physical triangles not found in tetrahedral topology.
#    (338, 339, 340)
#    (337, 338, 340)
# JJ4                      : unmatched=2
# WARNING: physical triangles not found in tetrahedral topology.
#    (342, 343, 344)
#    (341, 342, 344)
# JJ5                      : unmatched=2
# WARNING: physical triangles not found in tetrahedral topology.
#    (345, 346, 348)
#    (346, 347, 348)
# JJ6                      : unmatched=2
# WARNING: physical triangles not found in tetrahedral topology.
#    (349, 350, 352)
#    (350, 351, 352)
# JJ7                      : unmatched=2
# WARNING: physical triangles not found in tetrahedral topology.
#    (353, 354, 356)
#    (354, 355, 356)
# JJ8                      : unmatched=2
# WARNING: physical triangles not found in tetrahedral topology.
#    (358, 359, 360)
#    (357, 358, 360)
#
# ================================================================================
# FINAL DIAGNOSTIC
# ================================================================================
#
# Topology problem count: 0
#
# PASS: Basic tetrahedral topology is internally consistent.
#
# This is important:
# The MFEM STable3D crash is therefore likely caused by the way the surface elements / physical boundaries are connected to the volume mesh, rather than a simple degenerate tetrahedron.
#
# No Palace process was started.

# %%
# =============================================================================
# ROBUST 8-JJ PALACE CONFORMAL MESH - V13 SAFE / LOW-MEMORY
# =============================================================================
#
# IMPORTANT:
#   - This script ONLY creates and validates the Gmsh mesh.
#   - It DOES NOT run Palace.
#   - It is deliberately conservative for Google Colab.
#
# Main goal:
#   Fix the V12 problem where physical PEC/JJ triangles were not actual
#   tetrahedral faces.
#
# Strategy:
#   GDS
#    -> actual metal geometry
#    -> actual JJ electrode gaps
#    -> silicon + vacuum volumes
#    -> OCC fragment ALL interface surfaces with volumes
#    -> generate ONE conformal 3D mesh
#    -> identify physical surfaces from the fragmented geometry
#    -> verify physical triangles are tetrahedral faces
#
# =============================================================================

import os
import sys
import math
import gc
from collections import defaultdict

import numpy as np

# -----------------------------------------------------------------------------
# USER SETTINGS
# -----------------------------------------------------------------------------

GDS_FILE = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_export_manuscript.gds"
)

OUT_FILE = (
    "/content/drive/MyDrive/Palace6/meshes/"
    "quantum_chip_mesh_8JJ_v13.msh"
)

# GDS geometry is in mm.
# Palace later uses L0 = 0.001 m/mm.
#
# Chip:
CHIP_X = 14.0       # mm
CHIP_Y = 14.0       # mm

# z coordinates in mm
Z_SILICON_BOTTOM = -0.5
Z_INTERFACE       =  0.0
Z_VACUUM_TOP      =  0.5

# Conservative mesh sizes
BULK_SIZE = 0.50    # 500 um
JJ_SIZE   = 0.05    # 50 um

# HARD SAFETY LIMIT
#
# We intentionally keep this MUCH lower than the previous
# 11.9k mesh? 500k is still tiny compared with the failed
# 13.8 million tetrahedron mesh.
MAX_TETS = 500_000

# If mesh exceeds this, immediately abort.
MAX_NODES = 250_000

# GDS layers
MAIN_LAYER = 1
MAIN_DATATYPE = 0

PAD_LAYER = 1
PAD_DATATYPE = 10

JJ_LAYER = 53
JJ_DATATYPE = 0

# Known JJ locations, mm
JJ_LOCATIONS = [
    (-1.1325,  0.0000),
    (-0.8675,  0.0000),
    ( 1.2675,  0.0000),
    ( 1.5325,  0.0000),

    (-1.1325, -2.7000),
    (-0.8675, -2.7000),
    ( 1.2675, -2.7000),
    ( 1.5325, -2.7000),
]

# Physical attributes
VACUUM_ATTR = 1
SILICON_ATTR = 2
METAL_ATTR = 10

JJ_ATTRS = [20, 21, 22, 23, 24, 25, 26, 27]

# =============================================================================
# IMPORTS
# =============================================================================

try:
    import gmsh
except Exception as e:
    raise RuntimeError(
        "gmsh Python package is required. "
        "Install with: pip install gmsh"
    ) from e

try:
    import gdstk
except Exception as e:
    raise RuntimeError(
        "gdstk is required. Install with: pip install gdstk"
    ) from e

try:
    from shapely.geometry import Polygon, MultiPolygon, box
    from shapely.ops import unary_union
except Exception as e:
    raise RuntimeError(
        "shapely is required. Install with: pip install shapely"
    ) from e


# =============================================================================
# HELPERS
# =============================================================================

def polygon_from_gdstk(poly):
    """
    Convert a gdstk polygon to a Shapely Polygon.
    """
    pts = np.asarray(poly.points, dtype=float)

    if len(pts) < 3:
        return None

    p = Polygon(pts)

    if not p.is_valid:
        p = p.buffer(0)

    if p.is_empty:
        return None

    return p


def iter_gdstk_polygons(cell):
    """
    Recursively obtain polygons from a gdstk cell through flattened
    references.
    """
    # Flatten the cell in a copy so references are resolved.
    tmp = cell.copy(name="__flattened_tmp__")
    tmp.flatten()

    for p in tmp.polygons:
        yield p


def shapely_to_polygons(geom):
    """
    Return a list of valid Polygon objects.
    """
    if geom is None or geom.is_empty:
        return []

    if geom.geom_type == "Polygon":
        return [geom]

    if geom.geom_type == "MultiPolygon":
        return list(geom.geoms)

    if geom.geom_type == "GeometryCollection":
        out = []
        for g in geom.geoms:
            if g.geom_type == "Polygon":
                out.append(g)
            elif g.geom_type == "MultiPolygon":
                out.extend(list(g.geoms))
        return out

    return []


def add_planar_surface(poly, z=0.0):
    """
    Create a Gmsh OCC plane surface from a Shapely polygon.

    Returns:
        surface tag
    """

    if poly.is_empty:
        return None

    # Repair tiny geometric defects.
    if not poly.is_valid:
        poly = poly.buffer(0)

    if poly.is_empty:
        return None

    outer = list(poly.exterior.coords)
    if len(outer) < 4:
        return None

    def make_loop(coords):
        point_tags = []
        line_tags = []

        # Do not duplicate the closing point.
        coords = list(coords[:-1])

        for x, y in coords:
            point_tags.append(
                gmsh.model.occ.addPoint(
                    float(x),
                    float(y),
                    float(z)
                )
            )

        n = len(point_tags)

        for i in range(n):
            a = point_tags[i]
            b = point_tags[(i + 1) % n]

            if a == b:
                continue

            line_tags.append(
                gmsh.model.occ.addLine(a, b)
            )

        if len(line_tags) < 3:
            return None

        return gmsh.model.occ.addCurveLoop(line_tags)

    outer_loop = make_loop(outer)

    if outer_loop is None:
        return None

    holes = []

    for ring in poly.interiors:
        loop = make_loop(list(ring.coords))
        if loop is not None:
            holes.append(loop)

    try:
        surface = gmsh.model.occ.addPlaneSurface(
            [outer_loop] + holes
        )
    except Exception:
        return None

    return surface


def surface_center(surface_tag):
    """
    Geometric center of a surface.
    """
    try:
        com = gmsh.model.occ.getCenterOfMass(
            2,
            surface_tag
        )
        return np.asarray(com, dtype=float)
    except Exception:
        return None


def surface_area(surface_tag):
    try:
        return float(
            gmsh.model.occ.getMass(2, surface_tag)
        )
    except Exception:
        return 0.0


def print_ram(label=""):
    """
    Colab-safe RAM report.
    """
    try:
        import psutil

        vm = psutil.virtual_memory()

        print(
            f"[RAM {label}] "
            f"Total={vm.total/1024**3:.2f} GB | "
            f"Available={vm.available/1024**3:.2f} GB | "
            f"Used={vm.used/1024**3:.2f} GB"
        )
    except Exception:
        pass


# =============================================================================
# START
# =============================================================================

print("=" * 80)
print("ROBUST 8-JJ PALACE CONFORMAL MESH - V13")
print("=" * 80)

print(f"GDS:")
print(GDS_FILE)
print()
print(f"Output:")
print(OUT_FILE)
print()
print(f"Bulk mesh : {BULK_SIZE*1000:.0f} um")
print(f"JJ mesh   : {JJ_SIZE*1000:.0f} um")
print(f"MAX TETRAHEDRA : {MAX_TETS:,}")
print(f"MAX NODES      : {MAX_NODES:,}")

print_ram("START")


# =============================================================================
# READ GDS
# =============================================================================

print()
print("=" * 80)
print("READING GDS")
print("=" * 80)

if not os.path.isfile(GDS_FILE):
    raise FileNotFoundError(GDS_FILE)

lib = gdstk.read_gds(GDS_FILE)

print(f"Loaded {len(lib.cells)} cells.")

# Locate the chip cell.
cell_names = [c.name for c in lib.cells]

print("Available cells:")
for name in cell_names:
    print(" ", name)

preferred = [
    "TOP_main_1",
    "TOP",
]

chip_cell = None

for name in preferred:
    for c in lib.cells:
        if c.name == name:
            chip_cell = c
            break
    if chip_cell is not None:
        break

if chip_cell is None:
    # Fall back to TOP if present.
    for c in lib.cells:
        if c.name.upper() == "TOP":
            chip_cell = c
            break

if chip_cell is None:
    raise RuntimeError(
        "Could not identify chip top cell."
    )

print(f"Using chip cell: {chip_cell.name}")


# =============================================================================
# EXTRACT POLYGONS
# =============================================================================

print()
print("=" * 80)
print("EXTRACTING GDS GEOMETRY")
print("=" * 80)

flat = chip_cell.copy(name="__V13_FLAT__")
flat.flatten()

main_polys = []
pad_polys = []
jj_ref_polys = []

for p in flat.polygons:

    layer = int(p.layer)
    datatype = int(p.datatype)

    geom = polygon_from_gdstk(p)

    if geom is None:
        continue

    if layer == MAIN_LAYER and datatype == MAIN_DATATYPE:
        main_polys.append(geom)

    elif layer == PAD_LAYER and datatype == PAD_DATATYPE:
        pad_polys.append(geom)

    elif layer == JJ_LAYER and datatype == JJ_DATATYPE:
        jj_ref_polys.append(geom)


print(f"Main metal polygons : {len(main_polys)}")
print(f"Pad polygons         : {len(pad_polys)}")
print(f"JJ reference polygons: {len(jj_ref_polys)}")


# =============================================================================
# MAIN METAL
# =============================================================================

print()
print("Uniting main superconducting metal...")

main_metal = unary_union(main_polys)

if main_metal.is_empty:
    raise RuntimeError("Main metal geometry is empty.")

if not main_metal.is_valid:
    main_metal = main_metal.buffer(0)

print(f"Main metal geometry: {main_metal.geom_type}")
print(
    f"Main metal area: "
    f"{main_metal.area:.12f} mm²"
)


# =============================================================================
# MATCH JJ REFERENCES
# =============================================================================

if len(jj_ref_polys) != 8:
    raise RuntimeError(
        f"Expected 8 JJ references, found "
        f"{len(jj_ref_polys)}."
    )

print()
print("=" * 80)
print("MATCHING 8 JJ REFERENCES")
print("=" * 80)

matched_refs = []

for i, (x0, y0) in enumerate(JJ_LOCATIONS):

    best = None
    best_d = float("inf")

    for p in jj_ref_polys:

        c = p.centroid

        d = math.hypot(
            c.x - x0,
            c.y - y0
        )

        if d < best_d:
            best_d = d
            best = p

    if best is None:
        raise RuntimeError(
            f"JJ{i+1} reference not found."
        )

    if best_d > 1e-5:
        raise RuntimeError(
            f"JJ{i+1} reference mismatch: "
            f"{best_d*1000:.3f} um"
        )

    matched_refs.append(best)

    print(
        f"JJ{i+1}: "
        f"centroid=({best.centroid.x:.6f}, "
        f"{best.centroid.y:.6f}) mm, "
        f"error={best_d*1000:.3f} um"
    )


# =============================================================================
# FIND ACTUAL ELECTRODE PAIRS
# =============================================================================

print()
print("=" * 80)
print("IDENTIFYING ACTUAL JJ ELECTRODE PAIRS")
print("=" * 80)

jj_gaps = []

for i, ref in enumerate(matched_refs):

    cx = ref.centroid.x
    cy = ref.centroid.y

    # Find pad polygons near this JJ.
    candidates = []

    for p in pad_polys:

        c = p.centroid

        dx = c.x - cx
        dy = c.y - cy

        # Local search window.
        if abs(dx) <= 0.08 and abs(dy) <= 0.02:
            candidates.append(p)

    if len(candidates) < 2:
        raise RuntimeError(
            f"JJ{i+1}: only "
            f"{len(candidates)} nearby pad candidates."
        )

    # The electrodes are separated primarily in x.
    candidates.sort(
        key=lambda p: p.centroid.x
    )

    left = candidates[0]
    right = candidates[-1]

    # Verify both are actually close in y.
    if (
        abs(left.centroid.y - cy) > 0.01
        or
        abs(right.centroid.y - cy) > 0.01
    ):
        raise RuntimeError(
            f"JJ{i+1}: electrode y positions invalid."
        )

    lx0, ly0, lx1, ly1 = left.bounds
    rx0, ry0, rx1, ry1 = right.bounds

    gap_x0 = lx1
    gap_x1 = rx0

    gap_y0 = max(ly0, ry0)
    gap_y1 = min(ly1, ry1)

    if gap_x1 <= gap_x0:
        raise RuntimeError(
            f"JJ{i+1}: electrode pads overlap."
        )

    if gap_y1 <= gap_y0:
        raise RuntimeError(
            f"JJ{i+1}: electrode y ranges do not overlap."
        )

    gap = box(
        gap_x0,
        gap_y0,
        gap_x1,
        gap_y1
    )

    gc = gap.centroid

    center_error = math.hypot(
        gc.x - cx,
        gc.y - cy
    )

    width_um = gap.bounds[2] - gap.bounds[0]
    height_um = gap.bounds[3] - gap.bounds[1]

    width_um *= 1000
    height_um *= 1000

    print()
    print(f"JJ{i+1}:")
    print(
        f"  gap = "
        f"{width_um:.3f} x "
        f"{height_um:.3f} um"
    )
    print(
        f"  center error = "
        f"{center_error*1000:.3f} um"
    )

    if center_error > 1e-6:
        raise RuntimeError(
            f"JJ{i+1}: gap center mismatch."
        )

    jj_gaps.append(gap)


# =============================================================================
# VERY IMPORTANT:
#
# The actual electrode pads are already part of the GDS geometry.
# We DO NOT manufacture an artificial JJ gap.
#
# The JJ gap itself is retained as an interface surface.
# =============================================================================

print()
print("PASS: 8 physical JJ gaps recovered from GDS.")


# =============================================================================
# BUILD COMPLETE METAL
# =============================================================================

print()
print("=" * 80)
print("BUILDING COMPLETE SUPERCONDUCTING METAL")
print("=" * 80)

# Only select the pad polygons that actually belong to one of the 8 JJs.
selected_pads = []

for gap in jj_gaps:

    gx0, gy0, gx1, gy1 = gap.bounds

    for p in pad_polys:

        # Pad must touch the JJ neighborhood.
        expanded = gap.buffer(0.00001)

        if p.intersects(expanded):
            selected_pads.append(p)

# Remove duplicate geometries.
unique_pads = []

for p in selected_pads:

    if not any(
        p.equals(q)
        for q in unique_pads
    ):
        unique_pads.append(p)

print(
    f"Selected JJ electrode polygons: "
    f"{len(unique_pads)}"
)

# Union main metal + actual JJ electrode pads.
complete_metal = unary_union(
    [main_metal] + unique_pads
)

if not complete_metal.is_valid:
    complete_metal = complete_metal.buffer(0)

print(
    f"Complete metal geometry: "
    f"{complete_metal.geom_type}"
)

print(
    f"Complete metal area: "
    f"{complete_metal.area:.12f} mm²"
)


# =============================================================================
# VERIFY JJ GAPS ARE ACTUALLY EMPTY
# =============================================================================

print()
print("=" * 80)
print("VERIFYING PHYSICAL JJ GAPS")
print("=" * 80)

for i, gap in enumerate(jj_gaps):

    overlap = complete_metal.intersection(gap).area

    print(
        f"JJ{i+1}: "
        f"metal overlap = "
        f"{overlap:.6e} mm²"
    )

    # A physical JJ gap must not be covered by PEC metal.
    if overlap > 1e-10:
        raise RuntimeError(
            f"JJ{i+1} gap is occupied by metal."
        )

print("PASS: all JJ gaps are physically open.")


# =============================================================================
# INITIALIZE GMSH
# =============================================================================

print()
print("=" * 80)
print("INITIALIZING GMSH")
print("=" * 80)

gmsh.initialize()

try:

    gmsh.option.setNumber(
        "General.Terminal",
        1
    )

    gmsh.option.setNumber(
        "General.Verbosity",
        1
    )

    gmsh.model.add(
        "Palace_V13_Conformal"
    )

    occ = gmsh.model.occ


    # -------------------------------------------------------------------------
    # 3D VOLUMES
    # -------------------------------------------------------------------------

    print("Creating silicon volume...")

    silicon = occ.addBox(
        -CHIP_X/2,
        -CHIP_Y/2,
        Z_SILICON_BOTTOM,
        CHIP_X,
        CHIP_Y,
        Z_INTERFACE - Z_SILICON_BOTTOM
    )

    print("Creating vacuum volume...")

    vacuum = occ.addBox(
        -CHIP_X/2,
        -CHIP_Y/2,
        Z_INTERFACE,
        CHIP_X,
        CHIP_Y,
        Z_VACUUM_TOP - Z_INTERFACE
    )


    # -------------------------------------------------------------------------
    # CREATE INTERFACE SURFACES
    #
    # IMPORTANT:
    # These are not independently meshed later.
    # They are OCC entities used in the volume fragmentation.
    # -------------------------------------------------------------------------

    print("Creating metal interface surfaces...")

    metal_polygons = shapely_to_polygons(
        complete_metal
    )

    if len(metal_polygons) == 0:
        raise RuntimeError(
            "No metal polygons after union."
        )

    metal_surfaces = []

    for p in metal_polygons:

        s = add_planar_surface(
            p,
            Z_INTERFACE
        )

        if s is not None:
            metal_surfaces.append(s)

    print(
        f"Metal interface surfaces: "
        f"{len(metal_surfaces)}"
    )


    # -------------------------------------------------------------------------
    # CREATE ACTUAL JJ SURFACES
    # -------------------------------------------------------------------------

    print("Creating actual JJ interface surfaces...")

    jj_surface_tags = []

    for i, gap in enumerate(jj_gaps):

        s = add_planar_surface(
            gap,
            Z_INTERFACE
        )

        if s is None:
            raise RuntimeError(
                f"Could not create JJ{i+1} surface."
            )

        jj_surface_tags.append(s)

        print(
            f"JJ{i+1}: surface={s}"
        )


    # -------------------------------------------------------------------------
    # FRAGMENT VOLUMES WITH INTERFACE GEOMETRY
    #
    # This is the critical difference from V12.
    #
    # The interface surfaces are inserted into the OCC volume topology BEFORE
    # meshing, forcing Gmsh to share nodes between surface and volume elements.
    # -------------------------------------------------------------------------

    print()
    print("=" * 80)
    print("OCC CONFORMAL FRAGMENTATION")
    print("=" * 80)

    volume_objects = [
        (3, silicon),
        (3, vacuum)
    ]

    interface_objects = (
        [(2, s) for s in metal_surfaces]
        +
        [(2, s) for s in jj_surface_tags]
    )

    all_tools = volume_objects + interface_objects

    print(
        f"Volume entities     : "
        f"{len(volume_objects)}"
    )

    print(
        f"Interface surfaces  : "
        f"{len(interface_objects)}"
    )

    print("Fragmenting...")

    frag_out, frag_map = occ.fragment(
        volume_objects,
        interface_objects,
        removeObject=True,
        removeTool=False
    )

    occ.synchronize()

    print(
        f"Fragmentation returned "
        f"{len(frag_out)} entities."
    )


    # -------------------------------------------------------------------------
    # GET RESULTING VOLUMES
    # -------------------------------------------------------------------------

    volumes = [
        tag
        for dim, tag in frag_out
        if dim == 3
    ]

    print(
        f"Resulting 3D volumes: "
        f"{len(volumes)}"
    )

    if len(volumes) != 2:
        raise RuntimeError(
            "Expected exactly two 3D volumes."
        )


    # Identify silicon/vacuum by center of mass.
    silicon_volume = None
    vacuum_volume = None

    for tag in volumes:

        com = occ.getCenterOfMass(
            3,
            tag
        )

        print(
            f"Volume {tag}: "
            f"center z={com[2]:+.6f} mm"
        )

        if com[2] < 0:
            silicon_volume = tag

        elif com[2] > 0:
            vacuum_volume = tag

    if silicon_volume is None:
        raise RuntimeError(
            "Could not identify silicon volume."
        )

    if vacuum_volume is None:
        raise RuntimeError(
            "Could not identify vacuum volume."
        )

    print(
        f"Silicon volume: {silicon_volume}"
    )

    print(
        f"Vacuum volume: {vacuum_volume}"
    )


    # -------------------------------------------------------------------------
    # PHYSICAL VOLUMES
    # -------------------------------------------------------------------------

    gmsh.model.addPhysicalGroup(
        3,
        [vacuum_volume],
        VACUUM_ATTR
    )

    gmsh.model.setPhysicalName(
        3,
        VACUUM_ATTR,
        "Vacuum"
    )

    gmsh.model.addPhysicalGroup(
        3,
        [silicon_volume],
        SILICON_ATTR
    )

    gmsh.model.setPhysicalName(
        3,
        SILICON_ATTR,
        "Silicon_Substrate"
    )


    # -------------------------------------------------------------------------
    # IDENTIFY ACTUAL INTERFACE FACES
    #
    # We now inspect the faces belonging to the fragmented volumes.
    # Only THESE faces can become Palace physical surfaces.
    # -------------------------------------------------------------------------

    print()
    print("=" * 80)
    print("IDENTIFYING CONFORMAL INTERFACE FACES")
    print("=" * 80)

    interface_faces = []

    for vtag in [silicon_volume, vacuum_volume]:

        boundary = gmsh.model.getBoundary(
            [(3, vtag)],
            oriented=False,
            recursive=False
        )

        for dim, ftag in boundary:

            if dim != 2:
                continue

            com = occ.getCenterOfMass(
                2,
                ftag
            )

            # Interface is z = 0.
            if abs(com[2] - Z_INTERFACE) < 1e-8:

                interface_faces.append(
                    ftag
                )

    interface_faces = sorted(
        set(interface_faces)
    )

    print(
        f"Interface faces at z=0: "
        f"{len(interface_faces)}"
    )

    if not interface_faces:
        raise RuntimeError(
            "No z=0 interface faces found."
        )


    # -------------------------------------------------------------------------
    # CLASSIFY JJ FACES BY ACTUAL GEOMETRIC LOCATION
    # -------------------------------------------------------------------------

    print()
    print("Classifying JJ faces...")

    jj_faces = [[] for _ in range(8)]
    pec_faces = []

    for ftag in interface_faces:

        com = occ.getCenterOfMass(
            2,
            ftag
        )

        area = occ.getMass(
            2,
            ftag
        )

        matched_jj = None

        for i, gap in enumerate(jj_gaps):

            gx0, gy0, gx1, gy1 = gap.bounds

            # Require center to be inside JJ gap.
            if (
                gx0 - 1e-8 <= com[0] <= gx1 + 1e-8
                and
                gy0 - 1e-8 <= com[1] <= gy1 + 1e-8
            ):
                matched_jj = i
                break

        if matched_jj is not None:

            jj_faces[matched_jj].append(
                ftag
            )

        else:

            # Any other z=0 interface face is superconducting metal.
            pec_faces.append(
                ftag
            )


    # -------------------------------------------------------------------------
    # JJ VALIDATION
    # -------------------------------------------------------------------------

    for i in range(8):

        print(
            f"JJ{i+1}: "
            f"{len(jj_faces[i])} conformal "
            f"interface faces"
        )

        if len(jj_faces[i]) == 0:
            raise RuntimeError(
                f"JJ{i+1} has no conformal "
                f"interface face."
            )


    # -------------------------------------------------------------------------
    # PEC VALIDATION
    # -------------------------------------------------------------------------

    print()
    print(
        f"PEC interface faces: "
        f"{len(pec_faces)}"
    )

    if len(pec_faces) == 0:
        raise RuntimeError(
            "No PEC interface faces found."
        )


    # -------------------------------------------------------------------------
    # PHYSICAL PEC
    # -------------------------------------------------------------------------

    gmsh.model.addPhysicalGroup(
        2,
        pec_faces,
        METAL_ATTR
    )

    gmsh.model.setPhysicalName(
        2,
        METAL_ATTR,
        "Superconducting_Metal"
    )


    # -------------------------------------------------------------------------
    # PHYSICAL JJs
    # -------------------------------------------------------------------------

    for i in range(8):

        attr = JJ_ATTRS[i]

        gmsh.model.addPhysicalGroup(
            2,
            jj_faces[i],
            attr
        )

        gmsh.model.setPhysicalName(
            2,
            attr,
            f"JJ{i+1}"
        )


    # -------------------------------------------------------------------------
    # MESH SIZE
    # -------------------------------------------------------------------------

    print()
    print("=" * 80)
    print("CONFIGURING CONSERVATIVE MESH")
    print("=" * 80)

    # Global coarse mesh.
    gmsh.option.setNumber(
        "Mesh.MeshSizeMin",
        BULK_SIZE
    )

    gmsh.option.setNumber(
        "Mesh.MeshSizeMax",
        BULK_SIZE
    )

    # First-order tetrahedra.
    gmsh.option.setNumber(
        "Mesh.ElementOrder",
        1
    )

    # Avoid unnecessary optimization that can consume memory.
    gmsh.option.setNumber(
        "Mesh.Optimize",
        0
    )

    gmsh.option.setNumber(
        "Mesh.OptimizeNetgen",
        0
    )

    # JJ-local refinement.
    #
    # Use distance fields rather than creating another independent mesh.
    jj_edges = []

    for i in range(8):

        for ftag in jj_faces[i]:

            boundary = gmsh.model.getBoundary(
                [(2, ftag)],
                oriented=False,
                recursive=False
            )

            for dim, tag in boundary:

                if dim == 1:
                    jj_edges.append(tag)

    jj_edges = sorted(
        set(jj_edges)
    )

    print(
        f"JJ boundary curves: "
        f"{len(jj_edges)}"
    )

    if jj_edges:

        dist = gmsh.model.mesh.field.add(
            "Distance"
        )

        gmsh.model.mesh.field.setNumbers(
            dist,
            "CurvesList",
            jj_edges
        )

        threshold = gmsh.model.mesh.field.add(
            "Threshold"
        )

        gmsh.model.mesh.field.setNumber(
            threshold,
            "InField",
            dist
        )

        gmsh.model.mesh.field.setNumber(
            threshold,
            "SizeMin",
            JJ_SIZE
        )

        gmsh.model.mesh.field.setNumber(
            threshold,
            "SizeMax",
            BULK_SIZE
        )

        gmsh.model.mesh.field.setNumber(
            threshold,
            "DistMin",
            0.03
        )

        gmsh.model.mesh.field.setNumber(
            threshold,
            "DistMax",
            0.15
        )

        gmsh.model.mesh.field.setAsBackgroundMesh(
            threshold
        )


    # -------------------------------------------------------------------------
    # FINAL SYNCHRONIZATION
    # -------------------------------------------------------------------------

    occ.synchronize()


    # -------------------------------------------------------------------------
    # GENERATE 3D MESH
    # -------------------------------------------------------------------------

    print()
    print("=" * 80)
    print("GENERATING LOW-MEMORY CONFORMAL 3D MESH")
    print("=" * 80)

    print_ram("BEFORE MESH")

    gmsh.model.mesh.generate(3)

    print_ram("AFTER MESH")


    # -------------------------------------------------------------------------
    # MESH STATISTICS
    # -------------------------------------------------------------------------

    node_tags, node_coords, _ = (
        gmsh.model.mesh.getNodes()
    )

    node_count = len(node_tags)

    tet_count = 0

    # Gmsh type 4 = 4-node tetrahedron.
    types, elem_tags, elem_nodes = (
        gmsh.model.mesh.getElements(3)
    )

    for etype, tags, nodes in zip(
        types,
        elem_tags,
        elem_nodes
    ):

        if etype == 4:
            tet_count += len(tags)


    print()
    print("=" * 80)
    print("MESH STATISTICS")
    print("=" * 80)

    print(
        f"Nodes      : {node_count:,}"
    )

    print(
        f"Tetrahedra : {tet_count:,}"
    )

    # HARD SAFETY CHECK.
    if node_count > MAX_NODES:

        print(
            f"\nABORT: node count "
            f"{node_count:,} exceeds "
            f"limit {MAX_NODES:,}."
        )

        raise RuntimeError(
            "Mesh too large for safe Colab run."
        )

    if tet_count > MAX_TETS:

        print(
            f"\nABORT: tetrahedron count "
            f"{tet_count:,} exceeds "
            f"limit {MAX_TETS:,}."
        )

        raise RuntimeError(
            "Mesh too large for safe Colab run."
        )

    print(
        "PASS: mesh is below safety limits."
    )


    # -------------------------------------------------------------------------
    # WRITE MESH
    # -------------------------------------------------------------------------

    print()
    print("=" * 80)
    print("WRITING MSH 2.2")
    print("=" * 80)

    gmsh.option.setNumber(
        "Mesh.MshFileVersion",
        2.2
    )

    gmsh.write(
        OUT_FILE
    )

    print(
        f"Mesh written:\n{OUT_FILE}"
    )

    print(
        f"Mesh size: "
        f"{os.path.getsize(OUT_FILE)/1024**2:.2f} MB"
    )


    # -------------------------------------------------------------------------
    # PHYSICAL GROUP SUMMARY
    # -------------------------------------------------------------------------

    print()
    print("=" * 80)
    print("PHYSICAL GROUPS")
    print("=" * 80)

    groups = gmsh.model.getPhysicalGroups()

    for dim, attr in groups:

        name = gmsh.model.getPhysicalName(
            dim,
            attr
        )

        entities = (
            gmsh.model.getEntitiesForPhysicalGroup(
                dim,
                attr
            )
        )

        print(
            f"dim={dim}, "
            f"id={attr}, "
            f"name={name}, "
            f"entities={len(entities)}"
        )


    # -------------------------------------------------------------------------
    # SAVE A SMALL TOPOLOGY REPORT
    # -------------------------------------------------------------------------

    report_file = OUT_FILE.replace(
        ".msh",
        "_report.txt"
    )

    with open(
        report_file,
        "w"
    ) as f:

        f.write(
            "PALACE V13 CONFORMAL MESH REPORT\n"
        )

        f.write(
            "=================================\n\n"
        )

        f.write(
            f"Nodes: {node_count}\n"
        )

        f.write(
            f"Tetrahedra: {tet_count}\n\n"
        )

        f.write(
            "Physical groups:\n"
        )

        for dim, attr in groups:

            name = gmsh.model.getPhysicalName(
                dim,
                attr
            )

            f.write(
                f"dim={dim} "
                f"id={attr} "
                f"name={name}\n"
            )

        f.write("\nJJ faces:\n")

        for i in range(8):

            f.write(
                f"JJ{i+1}: "
                f"{len(jj_faces[i])} faces\n"
            )

        f.write(
            f"\nPEC faces: "
            f"{len(pec_faces)}\n"
        )

    print(
        f"\nReport:\n{report_file}"
    )

    print_ram("FINISHED")

    print()
    print("=" * 80)
    print("V13 MESH GENERATION COMPLETE")
    print("=" * 80)

    print()
    print("IMPORTANT:")
    print("DO NOT RUN PALACE YET.")
    print()
    print("First run the separate MSH topology checker.")
    print("The critical requirement is:")
    print()
    print("  PEC unmatched physical triangles = 0")
    print("  JJ1 unmatched = 0")
    print("  JJ2 unmatched = 0")
    print("  ...")
    print("  JJ8 unmatched = 0")
    print()
    print("Only after that should Palace be started.")

finally:

    try:
        gmsh.finalize()
    except Exception:
        pass

    gc.collect()

    print()
    print("Gmsh finalized.")
    print_ram("POST-GMSH")
# Out:
# ================================================================================
# ROBUST 8-JJ PALACE CONFORMAL MESH - V13
# ================================================================================
# GDS:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_export_manuscript.gds
#
# Output:
# /content/drive/MyDrive/Palace6/meshes/quantum_chip_mesh_8JJ_v13.msh
#
# Bulk mesh : 500 um
# JJ mesh   : 50 um
# MAX TETRAHEDRA : 500,000
# MAX NODES      : 250,000
# [RAM START] Total=50.99 GB | Available=49.43 GB | Used=1.02 GB
#
# ================================================================================
# READING GDS
# ================================================================================
# Loaded 19 cells.
# Available cells:
#   TOP
#   TOP_main
#   TOP_main_1
#   ground_main_1
#   my_other_junction
#   FakeJunction_02
#   FakeJunction_01
#   pads_my_other_junction_QComponent_is_1_name_is_poly4
#   pads_my_other_junction_QComponent_is_1_name_is_poly5
#   pads_my_other_junction_QComponent_is_2_name_is_poly4
#   pads_my_other_junction_QComponent_is_2_name_is_poly5
#   pads_my_other_junction_QComponent_is_3_name_is_poly4
#   pads_my_other_junction_QComponent_is_3_name_is_poly5
#   pads_my_other_junction_QComponent_is_4_name_is_poly4
#   pads_my_other_junction_QComponent_is_4_name_is_poly5
#   TOP_main_1_NoCheese_99
#   TOP_main_1_one_hole
#   TOP_main_1_Cheese_diff
#   TOP_main_1_Cheese_100
# Using chip cell: TOP_main_1
#
# ================================================================================
# EXTRACTING GDS GEOMETRY
# ================================================================================
# Main metal polygons : 2450
# Pad polygons         : 90
# JJ reference polygons: 8
#
# Uniting main superconducting metal...
# Main metal geometry: Polygon
# Main metal area: 185.750736791720 mm²
#
# ================================================================================
# MATCHING 8 JJ REFERENCES
# ================================================================================
# JJ1: centroid=(-1.132500, 0.000000) mm, error=0.000 um
# JJ2: centroid=(-0.867500, -0.000000) mm, error=0.000 um
# JJ3: centroid=(1.267500, 0.000000) mm, error=0.000 um
# JJ4: centroid=(1.532500, -0.000000) mm, error=0.000 um
# JJ5: centroid=(-1.132500, -2.700000) mm, error=0.000 um
# JJ6: centroid=(-0.867500, -2.700000) mm, error=0.000 um
# JJ7: centroid=(1.267500, -2.700000) mm, error=0.000 um
# JJ8: centroid=(1.532500, -2.700000) mm, error=0.000 um
#
# ================================================================================
# IDENTIFYING ACTUAL JJ ELECTRODE PAIRS
# ================================================================================
#
# JJ1:
#   gap = 20.000 x 5.000 um
#   center error = 0.000 um
#
# JJ2:
#   gap = 20.000 x 5.000 um
#   center error = 0.000 um
#
# JJ3:
#   gap = 20.000 x 5.000 um
#   center error = 0.000 um
#
# JJ4:
#   gap = 20.000 x 5.000 um
#   center error = 0.000 um
#
# JJ5:
#   gap = 20.000 x 5.000 um
#   center error = 0.000 um
#
# JJ6:
#   gap = 20.000 x 5.000 um
#   center error = 0.000 um
#
# JJ7:
#   gap = 20.000 x 5.000 um
#   center error = 0.000 um
#
# JJ8:
#   gap = 20.000 x 5.000 um
#   center error = 0.000 um
#
# PASS: 8 physical JJ gaps recovered from GDS.
#
# ================================================================================
# BUILDING COMPLETE SUPERCONDUCTING METAL
# ================================================================================
# Selected JJ electrode polygons: 16
# Complete metal geometry: MultiPolygon
# Complete metal area: 185.751336791720 mm²
#
# ================================================================================
# VERIFYING PHYSICAL JJ GAPS
# ================================================================================
# JJ1: metal overlap = 0.000000e+00 mm²
# JJ2: metal overlap = 0.000000e+00 mm²
# JJ3: metal overlap = 0.000000e+00 mm²
# JJ4: metal overlap = 0.000000e+00 mm²
# JJ5: metal overlap = 0.000000e+00 mm²
# JJ6: metal overlap = 0.000000e+00 mm²
# JJ7: metal overlap = 0.000000e+00 mm²
# JJ8: metal overlap = 0.000000e+00 mm²
# PASS: all JJ gaps are physically open.
#
# ================================================================================
# INITIALIZING GMSH
# ================================================================================
# Creating silicon volume...
# Creating vacuum volume...
# Creating metal interface surfaces...
# Metal interface surfaces: 17
# Creating actual JJ interface surfaces...
# JJ1: surface=30
# JJ2: surface=31
# JJ3: surface=32
# JJ4: surface=33
# JJ5: surface=34
# JJ6: surface=35
# JJ7: surface=36
# JJ8: surface=37
#
# ================================================================================
# OCC CONFORMAL FRAGMENTATION
# ================================================================================
# Volume entities     : 2
# Interface surfaces  : 25
# Fragmenting...
# Fragmentation returned 57 entities.
# Resulting 3D volumes: 2
# Volume 1: center z=-0.250000 mm
# Volume 2: center z=+0.250000 mm
# Silicon volume: 1
# Vacuum volume: 2
#
# ================================================================================
# IDENTIFYING CONFORMAL INTERFACE FACES
# ================================================================================
# Interface faces at z=0: 45
#
# Classifying JJ faces...
# JJ1: 1 conformal interface faces
# JJ2: 1 conformal interface faces
# JJ3: 1 conformal interface faces
# JJ4: 1 conformal interface faces
# JJ5: 1 conformal interface faces
# JJ6: 1 conformal interface faces
# JJ7: 1 conformal interface faces
# JJ8: 1 conformal interface faces
#
# PEC interface faces: 37
#
# ================================================================================
# CONFIGURING CONSERVATIVE MESH
# ================================================================================
# JJ boundary curves: 32
#
# ================================================================================
# GENERATING LOW-MEMORY CONFORMAL 3D MESH
# ================================================================================
# [RAM BEFORE MESH] Total=50.99 GB | Available=49.20 GB | Used=1.25 GB

# %%
# !apt-get -qq install klayout

# %% [markdown]
# # New Section
